# %%
import json
import requests
import time
import string
import pandas as pd

# %%
response = requests.get("https://api.idescat.cat/emex/v1/dades.json?lang=en")

# %%
meta = response.json()

# %%
meta['fitxes'].keys()
# Out:
# dict_keys(['p', 'indicadors', 'lang', 'version', 'cols', 'n', 'o'])

# %%
meta['fitxes']['cols']['col']
# Out:
# [{'scheme': 'mun', 'id': '250019', 'content': 'Abella de la Conca'},
#  {'scheme': 'mun', 'id': '080018', 'content': 'Abrera'},
#  {'scheme': 'mun', 'id': '250024', 'content': 'Àger'},
#  {'scheme': 'mun', 'id': '250030', 'content': 'Agramunt'},
#  {'scheme': 'mun', 'id': '080023', 'content': 'Aguilar de Segarra'},
#  {'scheme': 'mun', 'id': '170010', 'content': 'Agullana'},
#  {'scheme': 'mun', 'id': '080142', 'content': 'Aiguafreda'},
#  {'scheme': 'mun', 'id': '430017', 'content': 'Aiguamúrcia'},
#  {'scheme': 'mun', 'id': '170025', 'content': 'Aiguaviva'},
#  {'scheme': 'mun', 'id': '250387', 'content': 'Aitona'},
#  {'scheme': 'mun', 'id': '250045', 'content': 'Alamús, els'},
#  {'scheme': 'mun', 'id': '250058', 'content': 'Alàs i Cerc'},
#  {'scheme': 'mun', 'id': '250061', 'content': "Albagés, l'"},
#  {'scheme': 'mun', 'id': '170031', 'content': 'Albanyà'},
#  {'scheme': 'mun', 'id': '250077', 'content': 'Albatàrrec'},
#  {'scheme': 'mun', 'id': '250083', 'content': 'Albesa'},
#  {'scheme': 'mun', 'id': '250096', 'content': "Albi, l'"},
#  {'scheme': 'mun', 'id': '430022', 'content': 'Albinyana'},
#  {'scheme': 'mun', 'id': '430038', 'content': "Albiol, l'"},
#  {'scheme': 'mun', 'id': '170046', 'content': 'Albons'},
#  {'scheme': 'mun', 'id': '430043', 'content': 'Alcanar'},
#  {'scheme': 'mun', 'id': '250100', 'content': 'Alcanó'},
#  {'scheme': 'mun', 'id': '250117', 'content': 'Alcarràs'},
#  {'scheme': 'mun', 'id': '250122', 'content': 'Alcoletge'},
#  {'scheme': 'mun', 'id': '430056', 'content': 'Alcover'},
#  {'scheme': 'mun', 'id': '439044', 'content': "Aldea, l'"},
#  {'scheme': 'mun', 'id': '430069', 'content': 'Aldover'},
#  {'scheme': 'mun', 'id': '430075', 'content': "Aleixar, l'"},
#  {'scheme': 'mun', 'id': '080039', 'content': 'Alella'},
#  {'scheme': 'mun', 'id': '430081', 'content': 'Alfara de Carles'},
#  {'scheme': 'mun', 'id': '250138', 'content': 'Alfarràs'},
#  {'scheme': 'mun', 'id': '250143', 'content': 'Alfés'},
#  {'scheme': 'mun', 'id': '430094', 'content': 'Alforja'},
#  {'scheme': 'mun', 'id': '250156', 'content': 'Algerri'},
#  {'scheme': 'mun', 'id': '250169', 'content': 'Alguaire'},
#  {'scheme': 'mun', 'id': '250175', 'content': 'Alins'},
#  {'scheme': 'mun', 'id': '430108', 'content': 'Alió'},
#  {'scheme': 'mun', 'id': '250194', 'content': 'Almacelles'},
#  {'scheme': 'mun', 'id': '250208', 'content': 'Almatret'},
#  {'scheme': 'mun', 'id': '250215', 'content': 'Almenar'},
#  {'scheme': 'mun', 'id': '430115', 'content': 'Almoster'},
#  {'scheme': 'mun', 'id': '250220', 'content': 'Alòs de Balaguer'},
#  {'scheme': 'mun', 'id': '170062', 'content': 'Alp'},
#  {'scheme': 'mun', 'id': '080044', 'content': 'Alpens'},
#  {'scheme': 'mun', 'id': '250236', 'content': 'Alpicat'},
#  {'scheme': 'mun', 'id': '250241', 'content': 'Alt Àneu'},
#  {'scheme': 'mun', 'id': '430120', 'content': 'Altafulla'},
#  {'scheme': 'mun', 'id': '170078', 'content': 'Amer'},
#  {'scheme': 'mun', 'id': '430136', 'content': "Ametlla de Mar, l'"},
#  {'scheme': 'mun', 'id': '080057', 'content': "Ametlla del Vallès, l'"},
#  {'scheme': 'mun', 'id': '439060', 'content': "Ampolla, l'"},
#  {'scheme': 'mun', 'id': '430141', 'content': 'Amposta'},
#  {'scheme': 'mun', 'id': '170084', 'content': 'Anglès'},
#  {'scheme': 'mun', 'id': '250273', 'content': 'Anglesola'},
#  {'scheme': 'mun', 'id': '250292', 'content': 'Arbeca'},
#  {'scheme': 'mun', 'id': '430167', 'content': "Arboç, l'"},
#  {'scheme': 'mun', 'id': '430154', 'content': 'Arbolí'},
#  {'scheme': 'mun', 'id': '170097', 'content': 'Arbúcies'},
#  {'scheme': 'mun', 'id': '080060', 'content': 'Arenys de Mar'},
#  {'scheme': 'mun', 'id': '080076', 'content': 'Arenys de Munt'},
#  {'scheme': 'mun', 'id': '170101', 'content': 'Argelaguer'},
#  {'scheme': 'mun', 'id': '080082', 'content': 'Argençola'},
#  {'scheme': 'mun', 'id': '430173', 'content': "Argentera, l'"},
#  {'scheme': 'mun', 'id': '080095', 'content': 'Argentona'},
#  {'scheme': 'mun', 'id': '170118', 'content': "Armentera, l'"},
#  {'scheme': 'mun', 'id': '430189', 'content': 'Arnes'},
#  {'scheme': 'mun', 'id': '250313', 'content': 'Arres'},
#  {'scheme': 'mun', 'id': '250328', 'content': 'Arsèguel'},
#  {'scheme': 'mun', 'id': '080109', 'content': 'Artés'},
#  {'scheme': 'mun', 'id': '250334', 'content': 'Artesa de Lleida'},
#  {'scheme': 'mun', 'id': '250349', 'content': 'Artesa de Segre'},
#  {'scheme': 'mun', 'id': '430192', 'content': 'Ascó'},
#  {'scheme': 'mun', 'id': '250365', 'content': 'Aspa'},
#  {'scheme': 'mun', 'id': '250371', 'content': 'Avellanes i Santa Linya, les'},
#  {'scheme': 'mun', 'id': '080116', 'content': 'Avià'},
#  {'scheme': 'mun', 'id': '080121', 'content': 'Avinyó'},
#  {'scheme': 'mun', 'id': '170123', 'content': 'Avinyonet de Puigventós'},
#  {'scheme': 'mun', 'id': '080137', 'content': 'Avinyonet del Penedès'},
#  {'scheme': 'mun', 'id': '080155', 'content': 'Badalona'},
#  {'scheme': 'mun', 'id': '089045', 'content': 'Badia del Vallès'},
#  {'scheme': 'mun', 'id': '080168', 'content': 'Bagà'},
#  {'scheme': 'mun', 'id': '250390', 'content': 'Baix Pallars'},
#  {'scheme': 'mun', 'id': '250404', 'content': 'Balaguer'},
#  {'scheme': 'mun', 'id': '080174', 'content': 'Balenyà'},
#  {'scheme': 'mun', 'id': '080180', 'content': 'Balsareny'},
#  {'scheme': 'mun', 'id': '430206', 'content': 'Banyeres del Penedès'},
#  {'scheme': 'mun', 'id': '170157', 'content': 'Banyoles'},
#  {'scheme': 'mun', 'id': '250411', 'content': 'Barbens'},
#  {'scheme': 'mun', 'id': '430213', 'content': 'Barberà de la Conca'},
#  {'scheme': 'mun', 'id': '082520', 'content': 'Barberà del Vallès'},
#  {'scheme': 'mun', 'id': '080193', 'content': 'Barcelona'},
#  {'scheme': 'mun', 'id': '250426', 'content': 'Baronia de Rialb, la'},
#  {'scheme': 'mun', 'id': '170160', 'content': 'Bàscara'},
#  {'scheme': 'mun', 'id': '250447', 'content': 'Bassella'},
#  {'scheme': 'mun', 'id': '430228', 'content': 'Batea'},
#  {'scheme': 'mun', 'id': '250450', 'content': 'Bausen'},
#  {'scheme': 'mun', 'id': '080207', 'content': 'Begues'},
#  {'scheme': 'mun', 'id': '170139', 'content': 'Begur'},
#  {'scheme': 'mun', 'id': '250463', 'content': 'Belianes'},
#  {'scheme': 'mun', 'id': '250485', 'content': "Bell-lloc d'Urgell"},
#  {'scheme': 'mun', 'id': '251706', 'content': 'Bellaguarda'},
#  {'scheme': 'mun', 'id': '170182', 'content': "Bellcaire d'Empordà"},
#  {'scheme': 'mun', 'id': '250479', 'content': "Bellcaire d'Urgell"},
#  {'scheme': 'mun', 'id': '250498', 'content': "Bellmunt d'Urgell"},
#  {'scheme': 'mun', 'id': '430234', 'content': 'Bellmunt del Priorat'},
#  {'scheme': 'mun', 'id': '080214', 'content': 'Bellprat'},
#  {'scheme': 'mun', 'id': '250501', 'content': 'Bellpuig'},
#  {'scheme': 'mun', 'id': '430249', 'content': 'Bellvei'},
#  {'scheme': 'mun', 'id': '250518', 'content': 'Bellver de Cerdanya'},
#  {'scheme': 'mun', 'id': '250523', 'content': 'Bellvís'},
#  {'scheme': 'mun', 'id': '250539', 'content': 'Benavent de Segrià'},
#  {'scheme': 'mun', 'id': '430252', 'content': 'Benifallet'},
#  {'scheme': 'mun', 'id': '430265', 'content': 'Benissanet'},
#  {'scheme': 'mun', 'id': '080229', 'content': 'Berga'},
#  {'scheme': 'mun', 'id': '170195', 'content': 'Besalú'},
#  {'scheme': 'mun', 'id': '170209', 'content': 'Bescanó'},
#  {'scheme': 'mun', 'id': '170216', 'content': 'Beuda'},
#  {'scheme': 'mun', 'id': '080235', 'content': 'Bigues i Riells del Fai'},
#  {'scheme': 'mun', 'id': '250557', 'content': 'Biosca'},
#  {'scheme': 'mun', 'id': '170221', 'content': "Bisbal d'Empordà, la"},
#  {'scheme': 'mun', 'id': '430271', 'content': 'Bisbal de Falset, la'},
#  {'scheme': 'mun', 'id': '430287', 'content': 'Bisbal del Penedès, la'},
#  {'scheme': 'mun', 'id': '172348', 'content': 'Biure'},
#  {'scheme': 'mun', 'id': '430290', 'content': 'Blancafort'},
#  {'scheme': 'mun', 'id': '170237', 'content': 'Blanes'},
#  {'scheme': 'mun', 'id': '170293', 'content': 'Boadella i les Escaules'},
#  {'scheme': 'mun', 'id': '170242', 'content': 'Bolvir'},
#  {'scheme': 'mun', 'id': '430304', 'content': 'Bonastre'},
#  {'scheme': 'mun', 'id': '250576', 'content': 'Bòrdes, Es'},
#  {'scheme': 'mun', 'id': '170255', 'content': 'Bordils'},
#  {'scheme': 'mun', 'id': '250582', 'content': 'Borges Blanques, les'},
#  {'scheme': 'mun', 'id': '430311', 'content': 'Borges del Camp, les'},
#  {'scheme': 'mun', 'id': '170268', 'content': 'Borrassà'},
#  {'scheme': 'mun', 'id': '080240', 'content': 'Borredà'},
#  {'scheme': 'mun', 'id': '250595', 'content': 'Bossòst'},
#  {'scheme': 'mun', 'id': '430326', 'content': 'Bot'},
#  {'scheme': 'mun', 'id': '430332', 'content': 'Botarell'},
#  {'scheme': 'mun', 'id': '250560', 'content': 'Bovera'},
#  {'scheme': 'mun', 'id': '430347', 'content': 'Bràfim'},
#  {'scheme': 'mun', 'id': '170274', 'content': 'Breda'},
#  {'scheme': 'mun', 'id': '080253', 'content': 'Bruc, el'},
#  {'scheme': 'mun', 'id': '080266', 'content': 'Brull, el'},
#  {'scheme': 'mun', 'id': '170280', 'content': 'Brunyola i Sant Martí Sapresa'},
#  {'scheme': 'mun', 'id': '430350', 'content': 'Cabacés'},
#  {'scheme': 'mun', 'id': '250609', 'content': 'Cabanabona'},
#  {'scheme': 'mun', 'id': '170314', 'content': 'Cabanelles'},
#  {'scheme': 'mun', 'id': '170307', 'content': 'Cabanes'},
#  {'scheme': 'mun', 'id': '080272', 'content': 'Cabanyes, les'},
#  {'scheme': 'mun', 'id': '250616', 'content': 'Cabó'},
#  {'scheme': 'mun', 'id': '430363', 'content': 'Cabra del Camp'},
#  {'scheme': 'mun', 'id': '080288', 'content': "Cabrera d'Anoia"},
#  {'scheme': 'mun', 'id': '080291', 'content': 'Cabrera de Mar'},
#  {'scheme': 'mun', 'id': '080305', 'content': 'Cabrils'},
#  {'scheme': 'mun', 'id': '170329', 'content': 'Cadaqués'},
#  {'scheme': 'mun', 'id': '080312', 'content': 'Calaf'},
#  {'scheme': 'mun', 'id': '430379', 'content': 'Calafell'},
#  {'scheme': 'mun', 'id': '080348', 'content': 'Calders'},
#  {'scheme': 'mun', 'id': '080327', 'content': "Caldes d'Estrac"},
#  {'scheme': 'mun', 'id': '170335', 'content': 'Caldes de Malavella'},
#  {'scheme': 'mun', 'id': '080333', 'content': 'Caldes de Montbui'},
#  {'scheme': 'mun', 'id': '080351', 'content': 'Calella'},
#  {'scheme': 'mun', 'id': '080370', 'content': 'Calldetenes'},
#  {'scheme': 'mun', 'id': '080386', 'content': 'Callús'},
#  {'scheme': 'mun', 'id': '080364', 'content': 'Calonge de Segarra'},
#  {'scheme': 'mun', 'id': '170340', 'content': 'Calonge i Sant Antoni'},
#  {'scheme': 'mun', 'id': '250621', 'content': 'Camarasa'},
#  {'scheme': 'mun', 'id': '439039', 'content': 'Camarles'},
#  {'scheme': 'mun', 'id': '430385', 'content': 'Cambrils'},
#  {'scheme': 'mun', 'id': '170353', 'content': 'Camós'},
#  {'scheme': 'mun', 'id': '170366', 'content': 'Campdevànol'},
#  {'scheme': 'mun', 'id': '170372', 'content': 'Campelles'},
#  {'scheme': 'mun', 'id': '080399', 'content': 'Campins'},
#  {'scheme': 'mun', 'id': '170388', 'content': 'Campllong'},
#  {'scheme': 'mun', 'id': '170391', 'content': 'Camprodon'},
#  {'scheme': 'mun', 'id': '250637', 'content': 'Canejan'},
#  {'scheme': 'mun', 'id': '170405', 'content': "Canet d'Adri"},
#  {'scheme': 'mun', 'id': '080403', 'content': 'Canet de Mar'},
#  {'scheme': 'mun', 'id': '439076', 'content': 'Canonja, la'},
#  {'scheme': 'mun', 'id': '080410', 'content': 'Canovelles'},
#  {'scheme': 'mun', 'id': '080425', 'content': 'Cànoves i Samalús'},
#  {'scheme': 'mun', 'id': '170412', 'content': 'Cantallops'},
#  {'scheme': 'mun', 'id': '080431', 'content': 'Canyelles'},
#  {'scheme': 'mun', 'id': '430398', 'content': 'Capafonts'},
#  {'scheme': 'mun', 'id': '430402', 'content': 'Capçanes'},
#  {'scheme': 'mun', 'id': '080446', 'content': 'Capellades'},
#  {'scheme': 'mun', 'id': '170427', 'content': 'Capmany'},
#  {'scheme': 'mun', 'id': '080459', 'content': 'Capolat'},
#  {'scheme': 'mun', 'id': '080462', 'content': 'Cardedeu'},
#  {'scheme': 'mun', 'id': '080478', 'content': 'Cardona'},
#  {'scheme': 'mun', 'id': '080484', 'content': 'Carme'},
#  {'scheme': 'mun', 'id': '430419', 'content': 'Caseres'},
#  {'scheme': 'mun', 'id': '170448', 'content': 'Cassà de la Selva'},
#  {'scheme': 'mun', 'id': '080497', 'content': 'Casserres'},
#  {'scheme': 'mun', 'id': '080575', 'content': "Castell de l'Areny"},
#  {'scheme': 'mun', 'id': '259046', 'content': 'Castell de Mur'},
#  {'scheme': 'mun', 'id': '170486', 'content': "Castell-Platja d'Aro"},
#  {'scheme': 'mun', 'id': '250642', 'content': 'Castellar de la Ribera'},
#  {'scheme': 'mun', 'id': '080522', 'content': "Castellar de n'Hug"},
#  {'scheme': 'mun', 'id': '080500', 'content': 'Castellar del Riu'},
#  {'scheme': 'mun', 'id': '080517', 'content': 'Castellar del Vallès'},
#  {'scheme': 'mun', 'id': '080538', 'content': 'Castellbell i el Vilar'},
#  {'scheme': 'mun', 'id': '080543', 'content': 'Castellbisbal'},
#  {'scheme': 'mun', 'id': '080556', 'content': 'Castellcir'},
#  {'scheme': 'mun', 'id': '250674', 'content': 'Castelldans'},
#  {'scheme': 'mun', 'id': '080569', 'content': 'Castelldefels'},
#  {'scheme': 'mun', 'id': '080581', 'content': 'Castellet i la Gornal'},
#  {'scheme': 'mun', 'id': '170464', 'content': 'Castellfollit de la Roca'},
#  {'scheme': 'mun', 'id': '080608', 'content': 'Castellfollit de Riubregós'},
#  {'scheme': 'mun', 'id': '080594', 'content': 'Castellfollit del Boix'},
#  {'scheme': 'mun', 'id': '080615', 'content': 'Castellgalí'},
#  {'scheme': 'mun', 'id': '080620', 'content': 'Castellnou de Bages'},
#  {'scheme': 'mun', 'id': '250680', 'content': 'Castellnou de Seana'},
#  {'scheme': 'mun', 'id': '170470', 'content': "Castelló d'Empúries"},
#  {'scheme': 'mun', 'id': '250693', 'content': 'Castelló de Farfanya'},
#  {'scheme': 'mun', 'id': '080636', 'content': 'Castellolí'},
#  {'scheme': 'mun', 'id': '250707', 'content': 'Castellserà'},
#  {'scheme': 'mun', 'id': '080641', 'content': 'Castellterçol'},
#  {'scheme': 'mun', 'id': '430424', 'content': 'Castellvell del Camp'},
#  {'scheme': 'mun', 'id': '080654', 'content': 'Castellví de la Marca'},
#  {'scheme': 'mun', 'id': '080667', 'content': 'Castellví de Rosanes'},
#  {'scheme': 'mun', 'id': '430430', 'content': 'Catllar, el'},
#  {'scheme': 'mun', 'id': '250714', 'content': 'Cava'},
#  {'scheme': 'mun', 'id': '171899', 'content': 'Cellera de Ter, la'},
#  {'scheme': 'mun', 'id': '170499', 'content': 'Celrà'},
#  {'scheme': 'mun', 'id': '080673', 'content': 'Centelles'},
#  {'scheme': 'mun', 'id': '082687', 'content': 'Cercs'},
#  {'scheme': 'mun', 'id': '082665', 'content': 'Cerdanyola del Vallès'},
#  {'scheme': 'mun', 'id': '080689', 'content': 'Cervelló'},
#  {'scheme': 'mun', 'id': '250729', 'content': 'Cervera'},
#  {'scheme': 'mun', 'id': '250735', 'content': 'Cervià de les Garrigues'},
#  {'scheme': 'mun', 'id': '170502', 'content': 'Cervià de Ter'},
#  {'scheme': 'mun', 'id': '170519', 'content': 'Cistella'},
#  {'scheme': 'mun', 'id': '250740', 'content': 'Ciutadilla'},
#  {'scheme': 'mun', 'id': '250753', 'content': 'Clariana de Cardener'},
#  {'scheme': 'mun', 'id': '250766', 'content': 'Cogul, el'},
#  {'scheme': 'mun', 'id': '170545', 'content': 'Colera'},
#  {'scheme': 'mun', 'id': '250772', 'content': 'Coll de Nargó'},
#  {'scheme': 'mun', 'id': '080692', 'content': 'Collbató'},
#  {'scheme': 'mun', 'id': '430458', 'content': 'Colldejou'},
#  {'scheme': 'mun', 'id': '080706', 'content': 'Collsuspina'},
#  {'scheme': 'mun', 'id': '170558', 'content': 'Colomers'},
#  {'scheme': 'mun', 'id': '251636', 'content': 'Coma i la Pedra, la'},
#  {'scheme': 'mun', 'id': '251615', 'content': 'Conca de Dalt'},
#  {'scheme': 'mun', 'id': '430461', 'content': 'Conesa'},
#  {'scheme': 'mun', 'id': '430477', 'content': 'Constantí'},
#  {'scheme': 'mun', 'id': '080713', 'content': 'Copons'},
#  {'scheme': 'mun', 'id': '430483', 'content': "Corbera d'Ebre"},
#  {'scheme': 'mun', 'id': '080728', 'content': 'Corbera de Llobregat'},
#  {'scheme': 'mun', 'id': '250788', 'content': 'Corbins'},
#  {'scheme': 'mun', 'id': '170577', 'content': 'Corçà'},
#  {'scheme': 'mun', 'id': '080734', 'content': 'Cornellà de Llobregat'},
#  {'scheme': 'mun', 'id': '170561', 'content': 'Cornellà del Terri'},
#  {'scheme': 'mun', 'id': '430496', 'content': 'Cornudella de Montsant'},
#  {'scheme': 'mun', 'id': '430509', 'content': 'Creixell'},
#  {'scheme': 'mun', 'id': '170583', 'content': 'Crespià'},
#  {'scheme': 'mun',
#   'id': '179011',
#   'content': "Cruïlles, Monells i Sant Sadurní de l'Heura"},
#  {'scheme': 'mun', 'id': '080749', 'content': 'Cubelles'},
#  {'scheme': 'mun', 'id': '250791', 'content': 'Cubells'},
#  {'scheme': 'mun', 'id': '430516', 'content': 'Cunit'},
#  {'scheme': 'mun', 'id': '170600', 'content': 'Darnius'},
#  {'scheme': 'mun', 'id': '170617', 'content': 'Das'},
#  {'scheme': 'mun', 'id': '439018', 'content': 'Deltebre'},
#  {'scheme': 'mun', 'id': '080752', 'content': 'Dosrius'},
#  {'scheme': 'mun', 'id': '430537', 'content': 'Duesaigües'},
#  {'scheme': 'mun', 'id': '170622', 'content': "Escala, l'"},
#  {'scheme': 'mun', 'id': '080765', 'content': 'Esparreguera'},
#  {'scheme': 'mun', 'id': '170638', 'content': 'Espinelves'},
#  {'scheme': 'mun', 'id': '250812', 'content': "Espluga Calba, l'"},
#  {'scheme': 'mun', 'id': '430542', 'content': "Espluga de Francolí, l'"},
#  {'scheme': 'mun', 'id': '080771', 'content': 'Esplugues de Llobregat'},
#  {'scheme': 'mun', 'id': '170643', 'content': 'Espolla'},
#  {'scheme': 'mun', 'id': '170656', 'content': 'Esponellà'},
#  {'scheme': 'mun', 'id': '250827', 'content': 'Espot'},
#  {'scheme': 'mun', 'id': '080787', 'content': "Espunyola, l'"},
#  {'scheme': 'mun', 'id': '082541', 'content': "Esquirol, l'"},
#  {'scheme': 'mun', 'id': '250886', 'content': 'Estamariu'},
#  {'scheme': 'mun', 'id': '080790', 'content': "Estany, l'"},
#  {'scheme': 'mun', 'id': '250851', 'content': 'Estaràs'},
#  {'scheme': 'mun', 'id': '250864', 'content': "Esterri d'Àneu"},
#  {'scheme': 'mun', 'id': '250870', 'content': 'Esterri de Cardós'},
#  {'scheme': 'mun', 'id': '430555', 'content': 'Falset'},
#  {'scheme': 'mun', 'id': '170059', 'content': "Far d'Empordà, el"},
#  {'scheme': 'mun', 'id': '250899', 'content': 'Farrera'},
#  {'scheme': 'mun', 'id': '430568', 'content': 'Fatarella, la'},
#  {'scheme': 'mun', 'id': '430574', 'content': 'Febró, la'},
#  {'scheme': 'mun', 'id': '081347', 'content': 'Figaró-Montmany'},
#  {'scheme': 'mun', 'id': '080804', 'content': 'Fígols'},
#  {'scheme': 'mun', 'id': '259084', 'content': 'Fígols i Alinyà'},
#  {'scheme': 'mun', 'id': '430580', 'content': 'Figuera, la'},
#  {'scheme': 'mun', 'id': '170669', 'content': 'Figueres'},
#  {'scheme': 'mun', 'id': '430593', 'content': 'Figuerola del Camp'},
#  {'scheme': 'mun', 'id': '170675', 'content': 'Flaçà'},
#  {'scheme': 'mun', 'id': '430607', 'content': 'Flix'},
#  {'scheme': 'mun', 'id': '250925', 'content': 'Floresta, la'},
#  {'scheme': 'mun', 'id': '080826', 'content': 'Fogars de la Selva'},
#  {'scheme': 'mun', 'id': '080811', 'content': 'Fogars de Montclús'},
#  {'scheme': 'mun', 'id': '170681', 'content': 'Foixà'},
#  {'scheme': 'mun', 'id': '080832', 'content': 'Folgueroles'},
#  {'scheme': 'mun', 'id': '250931', 'content': 'Fondarella'},
#  {'scheme': 'mun', 'id': '080847', 'content': 'Fonollosa'},
#  {'scheme': 'mun', 'id': '080850', 'content': 'Font-rubí'},
#  {'scheme': 'mun', 'id': '170694', 'content': 'Fontanals de Cerdanya'},
#  {'scheme': 'mun', 'id': '170708', 'content': 'Fontanilles'},
#  {'scheme': 'mun', 'id': '170715', 'content': 'Fontcoberta'},
#  {'scheme': 'mun', 'id': '250946', 'content': 'Foradada'},
#  {'scheme': 'mun', 'id': '179026', 'content': 'Forallac'},
#  {'scheme': 'mun', 'id': '430614', 'content': 'Forès'},
#  {'scheme': 'mun', 'id': '170736', 'content': 'Fornells de la Selva'},
#  {'scheme': 'mun', 'id': '170741', 'content': 'Fortià'},
#  {'scheme': 'mun', 'id': '080863', 'content': 'Franqueses del Vallès, les'},
#  {'scheme': 'mun', 'id': '430629', 'content': 'Freginals'},
#  {'scheme': 'mun', 'id': '250962', 'content': 'Fuliola, la'},
#  {'scheme': 'mun', 'id': '250978', 'content': 'Fulleda'},
#  {'scheme': 'mun', 'id': '080902', 'content': 'Gaià'},
#  {'scheme': 'mun', 'id': '430635', 'content': 'Galera, la'},
#  {'scheme': 'mun', 'id': '080879', 'content': 'Gallifa'},
#  {'scheme': 'mun', 'id': '430640', 'content': 'Gandesa'},
#  {'scheme': 'mun', 'id': '430653', 'content': 'Garcia'},
#  {'scheme': 'mun', 'id': '430666', 'content': 'Garidells, els'},
#  {'scheme': 'mun', 'id': '080885', 'content': 'Garriga, la'},
#  {'scheme': 'mun', 'id': '170754', 'content': 'Garrigàs'},
#  {'scheme': 'mun', 'id': '170767', 'content': 'Garrigoles'},
#  {'scheme': 'mun', 'id': '170773', 'content': 'Garriguella'},
#  {'scheme': 'mun', 'id': '080898', 'content': 'Gavà'},
#  {'scheme': 'mun', 'id': '250984', 'content': 'Gavet de la Conca'},
#  {'scheme': 'mun', 'id': '080919', 'content': 'Gelida'},
#  {'scheme': 'mun', 'id': '170789', 'content': 'Ger'},
#  {'scheme': 'mun', 'id': '259123', 'content': 'Gimenells i el Pla de la Font'},
#  {'scheme': 'mun', 'id': '430672', 'content': 'Ginestar'},
#  {'scheme': 'mun', 'id': '170792', 'content': 'Girona'},
#  {'scheme': 'mun', 'id': '080924', 'content': 'Gironella'},
#  {'scheme': 'mun', 'id': '080930', 'content': 'Gisclareny'},
#  {'scheme': 'mun', 'id': '430688', 'content': 'Godall'},
#  {'scheme': 'mun', 'id': '250997', 'content': 'Golmés'},
#  {'scheme': 'mun', 'id': '170806', 'content': 'Gombrèn'},
#  {'scheme': 'mun', 'id': '251001', 'content': 'Gósol'},
#  {'scheme': 'mun', 'id': '080945', 'content': 'Granada, la'},
#  {'scheme': 'mun', 'id': '251018', 'content': 'Granadella, la'},
#  {'scheme': 'mun', 'id': '080958', 'content': 'Granera'},
#  {'scheme': 'mun', 'id': '251023', 'content': "Granja d'Escarp, la"},
#  {'scheme': 'mun', 'id': '080961', 'content': 'Granollers'},
#  {'scheme': 'mun', 'id': '251039', 'content': 'Granyanella'},
#  {'scheme': 'mun', 'id': '251057', 'content': 'Granyena de les Garrigues'},
#  {'scheme': 'mun', 'id': '251044', 'content': 'Granyena de Segarra'},
#  {'scheme': 'mun', 'id': '430691', 'content': 'Gratallops'},
#  {'scheme': 'mun', 'id': '080977', 'content': 'Gualba'},
#  {'scheme': 'mun', 'id': '170813', 'content': 'Gualta'},
#  {'scheme': 'mun', 'id': '080996', 'content': 'Guardiola de Berguedà'},
#  {'scheme': 'mun', 'id': '430705', 'content': 'Guiamets, els'},
#  {'scheme': 'mun', 'id': '170828', 'content': 'Guils de Cerdanya'},
#  {'scheme': 'mun', 'id': '251095', 'content': 'Guimerà'},
#  {'scheme': 'mun', 'id': '259031', 'content': "Guingueta d'Àneu, la"},
#  {'scheme': 'mun', 'id': '251109', 'content': 'Guissona'},
#  {'scheme': 'mun', 'id': '251116', 'content': 'Guixers'},
#  {'scheme': 'mun', 'id': '081000', 'content': 'Gurb'},
#  {'scheme': 'mun', 'id': '430712', 'content': 'Horta de Sant Joan'},
#  {'scheme': 'mun', 'id': '081017', 'content': "Hospitalet de Llobregat, l'"},
#  {'scheme': 'mun', 'id': '081629', 'content': 'Hostalets de Pierola, els'},
#  {'scheme': 'mun', 'id': '170834', 'content': 'Hostalric'},
#  {'scheme': 'mun', 'id': '081022', 'content': 'Igualada'},
#  {'scheme': 'mun', 'id': '251155', 'content': 'Isona i Conca Dellà'},
#  {'scheme': 'mun', 'id': '170849', 'content': 'Isòvol'},
#  {'scheme': 'mun', 'id': '251137', 'content': "Ivars d'Urgell"},
#  {'scheme': 'mun', 'id': '251121', 'content': 'Ivars de Noguera'},
#  {'scheme': 'mun', 'id': '251142', 'content': 'Ivorra'},
#  {'scheme': 'mun', 'id': '170852', 'content': 'Jafre'},
#  {'scheme': 'mun', 'id': '170865', 'content': 'Jonquera, la'},
#  {'scheme': 'mun', 'id': '081038', 'content': 'Jorba'},
#  {'scheme': 'mun', 'id': '259101', 'content': 'Josa i Tuixén'},
#  {'scheme': 'mun', 'id': '170871', 'content': 'Juià'},
#  {'scheme': 'mun', 'id': '251180', 'content': 'Juncosa'},
#  {'scheme': 'mun', 'id': '251193', 'content': 'Juneda'},
#  {'scheme': 'mun', 'id': '251214', 'content': 'Les'},
#  {'scheme': 'mun', 'id': '251229', 'content': 'Linyola'},
#  {'scheme': 'mun', 'id': '081043', 'content': 'Llacuna, la'},
#  {'scheme': 'mun', 'id': '170887', 'content': 'Lladó'},
#  {'scheme': 'mun', 'id': '251235', 'content': 'Lladorre'},
#  {'scheme': 'mun', 'id': '251240', 'content': 'Lladurs'},
#  {'scheme': 'mun', 'id': '081056', 'content': 'Llagosta, la'},
#  {'scheme': 'mun', 'id': '170890', 'content': 'Llagostera'},
#  {'scheme': 'mun', 'id': '170904', 'content': 'Llambilles'},
#  {'scheme': 'mun', 'id': '170911', 'content': 'Llanars'},
#  {'scheme': 'mun', 'id': '170926', 'content': 'Llançà'},
#  {'scheme': 'mun', 'id': '251253', 'content': 'Llardecans'},
#  {'scheme': 'mun', 'id': '251266', 'content': 'Llavorsí'},
#  {'scheme': 'mun', 'id': '251207', 'content': 'Lleida'},
#  {'scheme': 'mun', 'id': '170932', 'content': 'Llers'},
#  {'scheme': 'mun', 'id': '251272', 'content': 'Lles de Cerdanya'},
#  {'scheme': 'mun', 'id': '081075', 'content': "Lliçà d'Amunt"},
#  {'scheme': 'mun', 'id': '081081', 'content': 'Lliçà de Vall'},
#  {'scheme': 'mun', 'id': '251288', 'content': 'Llimiana'},
#  {'scheme': 'mun', 'id': '081069', 'content': 'Llinars del Vallès'},
#  {'scheme': 'mun', 'id': '170947', 'content': 'Llívia'},
#  {'scheme': 'mun', 'id': '430727', 'content': 'Lloar, el'},
#  {'scheme': 'mun', 'id': '251291', 'content': 'Llobera'},
#  {'scheme': 'mun', 'id': '430733', 'content': 'Llorac'},
#  {'scheme': 'mun', 'id': '430748', 'content': 'Llorenç del Penedès'},
#  {'scheme': 'mun', 'id': '170950', 'content': 'Lloret de Mar'},
#  {'scheme': 'mun', 'id': '170963', 'content': 'Llosses, les'},
#  {'scheme': 'mun', 'id': '081094', 'content': 'Lluçà'},
#  {'scheme': 'mun', 'id': '171024', 'content': 'Maçanet de Cabrenys'},
#  {'scheme': 'mun', 'id': '171030', 'content': 'Maçanet de la Selva'},
#  {'scheme': 'mun', 'id': '170979', 'content': 'Madremanya'},
#  {'scheme': 'mun', 'id': '170985', 'content': 'Maià de Montcal'},
#  {'scheme': 'mun', 'id': '251333', 'content': 'Maials'},
#  {'scheme': 'mun', 'id': '251305', 'content': 'Maldà'},
#  {'scheme': 'mun', 'id': '081108', 'content': 'Malgrat de Mar'},
#  {'scheme': 'mun', 'id': '081115', 'content': 'Malla'},
#  {'scheme': 'mun', 'id': '081120', 'content': 'Manlleu'},
#  {'scheme': 'mun', 'id': '081136', 'content': 'Manresa'},
#  {'scheme': 'mun', 'id': '430764', 'content': 'Marçà'},
#  {'scheme': 'mun', 'id': '430751', 'content': 'Margalef'},
#  {'scheme': 'mun', 'id': '082423', 'content': 'Marganell'},
#  {'scheme': 'mun', 'id': '081141', 'content': 'Martorell'},
#  {'scheme': 'mun', 'id': '081154', 'content': 'Martorelles'},
#  {'scheme': 'mun', 'id': '430770', 'content': 'Mas de Barberans'},
#  {'scheme': 'mun', 'id': '171002', 'content': 'Masarac'},
#  {'scheme': 'mun', 'id': '430786', 'content': 'Masdenverge'},
#  {'scheme': 'mun', 'id': '081167', 'content': 'Masies de Roda, les'},
#  {'scheme': 'mun', 'id': '081173', 'content': 'Masies de Voltregà, les'},
#  {'scheme': 'mun', 'id': '430799', 'content': 'Masllorenç'},
#  {'scheme': 'mun', 'id': '081189', 'content': 'Masnou, el'},
#  {'scheme': 'mun', 'id': '430803', 'content': 'Masó, la'},
#  {'scheme': 'mun', 'id': '430810', 'content': 'Maspujols'},
#  {'scheme': 'mun', 'id': '081192', 'content': 'Masquefa'},
#  {'scheme': 'mun', 'id': '430825', 'content': 'Masroig, el'},
#  {'scheme': 'mun', 'id': '251312', 'content': 'Massalcoreig'},
#  {'scheme': 'mun', 'id': '171019', 'content': 'Massanes'},
#  {'scheme': 'mun', 'id': '251327', 'content': 'Massoteres'},
#  {'scheme': 'mun', 'id': '081206', 'content': 'Matadepera'},
#  {'scheme': 'mun', 'id': '081213', 'content': 'Mataró'},
#  {'scheme': 'mun', 'id': '081228', 'content': 'Mediona'},
#  {'scheme': 'mun', 'id': '251348', 'content': 'Menàrguens'},
#  {'scheme': 'mun', 'id': '170998', 'content': 'Meranges'},
#  {'scheme': 'mun', 'id': '171058', 'content': 'Mieres'},
#  {'scheme': 'mun', 'id': '430831', 'content': 'Milà, el'},
#  {'scheme': 'mun', 'id': '251351', 'content': 'Miralcamp'},
#  {'scheme': 'mun', 'id': '430846', 'content': 'Miravet'},
#  {'scheme': 'mun', 'id': '081385', 'content': 'Moià'},
#  {'scheme': 'mun', 'id': '430859', 'content': 'Molar, el'},
#  {'scheme': 'mun', 'id': '081234', 'content': 'Molins de Rei'},
#  {'scheme': 'mun', 'id': '251370', 'content': 'Mollerussa'},
#  {'scheme': 'mun', 'id': '171061', 'content': 'Mollet de Peralada'},
#  {'scheme': 'mun', 'id': '081249', 'content': 'Mollet del Vallès'},
#  {'scheme': 'mun', 'id': '171077', 'content': 'Molló'},
#  {'scheme': 'mun', 'id': '251364', 'content': 'Molsosa, la'},
#  {'scheme': 'mun', 'id': '081287', 'content': 'Monistrol de Calders'},
#  {'scheme': 'mun', 'id': '081271', 'content': 'Monistrol de Montserrat'},
#  {'scheme': 'mun', 'id': '430918', 'content': 'Mont-ral'},
#  {'scheme': 'mun', 'id': '171100', 'content': 'Mont-ras'},
#  {'scheme': 'mun', 'id': '430923', 'content': 'Mont-roig del Camp'},
#  {'scheme': 'mun', 'id': '171096', 'content': 'Montagut i Oix'},
#  {'scheme': 'mun', 'id': '430862', 'content': 'Montblanc'},
#  {'scheme': 'mun', 'id': '430884', 'content': 'Montbrió del Camp'},
#  {'scheme': 'mun', 'id': '081252', 'content': 'Montcada i Reixac'},
#  {'scheme': 'mun', 'id': '081304', 'content': 'Montclar'},
#  {'scheme': 'mun', 'id': '251399', 'content': 'Montellà i Martinet'},
#  {'scheme': 'mun', 'id': '081311', 'content': 'Montesquiu'},
#  {'scheme': 'mun', 'id': '251403', 'content': 'Montferrer i Castellbò'},
#  {'scheme': 'mun', 'id': '430897', 'content': 'Montferri'},
#  {'scheme': 'mun', 'id': '251386', 'content': 'Montgai'},
#  {'scheme': 'mun', 'id': '081265', 'content': 'Montgat'},
#  {'scheme': 'mun', 'id': '081326', 'content': 'Montmajor'},
#  {'scheme': 'mun', 'id': '081332', 'content': 'Montmaneu'},
#  {'scheme': 'mun', 'id': '430901', 'content': 'Montmell, el'},
#  {'scheme': 'mun', 'id': '081350', 'content': 'Montmeló'},
#  {'scheme': 'mun', 'id': '251425', 'content': 'Montoliu de Lleida'},
#  {'scheme': 'mun', 'id': '251410', 'content': 'Montoliu de Segarra'},
#  {'scheme': 'mun', 'id': '251431', 'content': 'Montornès de Segarra'},
#  {'scheme': 'mun', 'id': '081363', 'content': 'Montornès del Vallès'},
#  {'scheme': 'mun', 'id': '081379', 'content': 'Montseny'},
#  {'scheme': 'mun', 'id': '430939', 'content': "Móra d'Ebre"},
#  {'scheme': 'mun', 'id': '430944', 'content': 'Móra la Nova'},
#  {'scheme': 'mun', 'id': '430957', 'content': 'Morell, el'},
#  {'scheme': 'mun', 'id': '430960', 'content': 'Morera de Montsant, la'},
#  {'scheme': 'mun', 'id': '081290', 'content': 'Muntanyola'},
#  {'scheme': 'mun', 'id': '081398', 'content': 'Mura'},
#  {'scheme': 'mun', 'id': '251459', 'content': 'Nalec'},
#  {'scheme': 'mun', 'id': '250254', 'content': 'Naut Aran'},
#  {'scheme': 'mun', 'id': '081402', 'content': 'Navarcles'},
#  {'scheme': 'mun', 'id': '081419', 'content': 'Navàs'},
#  {'scheme': 'mun', 'id': '171117', 'content': 'Navata'},
#  {'scheme': 'mun', 'id': '251462', 'content': 'Navès'},
#  {'scheme': 'mun', 'id': '081424', 'content': 'Nou de Berguedà, la'},
#  {'scheme': 'mun', 'id': '430976', 'content': 'Nou de Gaià, la'},
#  {'scheme': 'mun', 'id': '430982', 'content': 'Nulles'},
#  {'scheme': 'mun', 'id': '251484', 'content': 'Odèn'},
#  {'scheme': 'mun', 'id': '081430', 'content': 'Òdena'},
#  {'scheme': 'mun', 'id': '171122', 'content': 'Ogassa'},
#  {'scheme': 'mun', 'id': '081458', 'content': 'Olèrdola'},
#  {'scheme': 'mun', 'id': '081461', 'content': 'Olesa de Bonesvalls'},
#  {'scheme': 'mun', 'id': '081477', 'content': 'Olesa de Montserrat'},
#  {'scheme': 'mun', 'id': '251497', 'content': 'Oliana'},
#  {'scheme': 'mun', 'id': '251500', 'content': 'Oliola'},
#  {'scheme': 'mun', 'id': '251517', 'content': 'Olius'},
#  {'scheme': 'mun', 'id': '081483', 'content': 'Olivella'},
#  {'scheme': 'mun', 'id': '081496', 'content': 'Olost'},
#  {'scheme': 'mun', 'id': '171143', 'content': 'Olot'},
#  {'scheme': 'mun', 'id': '251522', 'content': 'Oluges, les'},
#  {'scheme': 'mun', 'id': '081445', 'content': 'Olvan'},
#  {'scheme': 'mun', 'id': '251538', 'content': 'Omellons, els'},
#  {'scheme': 'mun', 'id': '251543', 'content': 'Omells de na Gaia, els'},
#  {'scheme': 'mun', 'id': '171156', 'content': 'Ordis'},
#  {'scheme': 'mun', 'id': '251556', 'content': 'Organyà'},
#  {'scheme': 'mun', 'id': '081509', 'content': 'Orís'},
#  {'scheme': 'mun', 'id': '081516', 'content': 'Oristà'},
#  {'scheme': 'mun', 'id': '081521', 'content': 'Orpí'},
#  {'scheme': 'mun', 'id': '081537', 'content': 'Òrrius'},
#  {'scheme': 'mun', 'id': '251569', 'content': 'Os de Balaguer'},
#  {'scheme': 'mun', 'id': '171169', 'content': 'Osor'},
#  {'scheme': 'mun', 'id': '251575', 'content': 'Ossó de Sió'},
#  {'scheme': 'mun', 'id': '081542', 'content': 'Pacs del Penedès'},
#  {'scheme': 'mun', 'id': '081555', 'content': 'Palafolls'},
#  {'scheme': 'mun', 'id': '171175', 'content': 'Palafrugell'},
#  {'scheme': 'mun', 'id': '171181', 'content': 'Palamós'},
#  {'scheme': 'mun', 'id': '251581', 'content': "Palau d'Anglesola, el"},
#  {'scheme': 'mun', 'id': '171194', 'content': 'Palau de Santa Eulàlia'},
#  {'scheme': 'mun', 'id': '171215', 'content': 'Palau-sator'},
#  {'scheme': 'mun', 'id': '171208', 'content': 'Palau-saverdera'},
#  {'scheme': 'mun', 'id': '081568', 'content': 'Palau-solità i Plegamans'},
#  {'scheme': 'mun', 'id': '431009', 'content': 'Pallaresos, els'},
#  {'scheme': 'mun', 'id': '081574', 'content': 'Pallejà'},
#  {'scheme': 'mun', 'id': '430995', 'content': "Palma d'Ebre, la"},
#  {'scheme': 'mun', 'id': '089058', 'content': 'Palma de Cervelló, la'},
#  {'scheme': 'mun', 'id': '171236', 'content': 'Palol de Revardit'},
#  {'scheme': 'mun', 'id': '171241', 'content': 'Pals'},
#  {'scheme': 'mun', 'id': '081580', 'content': 'Papiol, el'},
#  {'scheme': 'mun', 'id': '171254', 'content': 'Pardines'},
#  {'scheme': 'mun', 'id': '081593', 'content': 'Parets del Vallès'},
#  {'scheme': 'mun', 'id': '171267', 'content': 'Parlavà'},
#  {'scheme': 'mun', 'id': '431016', 'content': 'Passanant i Belltall'},
#  {'scheme': 'mun', 'id': '171289', 'content': 'Pau'},
#  {'scheme': 'mun', 'id': '431021', 'content': 'Paüls'},
#  {'scheme': 'mun', 'id': '171292', 'content': 'Pedret i Marzà'},
#  {'scheme': 'mun', 'id': '251641', 'content': 'Penelles'},
#  {'scheme': 'mun', 'id': '171306', 'content': 'Pera, la'},
#  {'scheme': 'mun', 'id': '081607', 'content': 'Perafita'},
#  {'scheme': 'mun', 'id': '431037', 'content': 'Perafort'},
#  {'scheme': 'mun', 'id': '171328', 'content': 'Peralada'},
#  {'scheme': 'mun', 'id': '251654', 'content': 'Peramola'},
#  {'scheme': 'mun', 'id': '431042', 'content': 'Perelló, el'},
#  {'scheme': 'mun', 'id': '081614', 'content': 'Piera'},
#  {'scheme': 'mun', 'id': '431055', 'content': 'Piles, les'},
#  {'scheme': 'mun', 'id': '081635', 'content': 'Pineda de Mar'},
#  {'scheme': 'mun', 'id': '431068', 'content': 'Pinell de Brai, el'},
#  {'scheme': 'mun', 'id': '251667', 'content': 'Pinell de Solsonès'},
#  {'scheme': 'mun', 'id': '251673', 'content': 'Pinós'},
#  {'scheme': 'mun', 'id': '431074', 'content': 'Pira'},
#  {'scheme': 'mun', 'id': '431080', 'content': 'Pla de Santa Maria, el'},
#  {'scheme': 'mun', 'id': '081640', 'content': 'Pla del Penedès, el'},
#  {'scheme': 'mun', 'id': '171334', 'content': "Planes d'Hostoles, les"},
#  {'scheme': 'mun', 'id': '171349', 'content': 'Planoles'},
#  {'scheme': 'mun', 'id': '259118', 'content': 'Plans de Sió, els'},
#  {'scheme': 'mun', 'id': '251689', 'content': 'Poal, el'},
#  {'scheme': 'mun', 'id': '251692', 'content': 'Pobla de Cérvoles, la'},
#  {'scheme': 'mun', 'id': '081653', 'content': 'Pobla de Claramunt, la'},
#  {'scheme': 'mun', 'id': '081666', 'content': 'Pobla de Lillet, la'},
#  {'scheme': 'mun', 'id': '431093', 'content': 'Pobla de Mafumet, la'},
#  {'scheme': 'mun', 'id': '431107', 'content': 'Pobla de Massaluca, la'},
#  {'scheme': 'mun', 'id': '431114', 'content': 'Pobla de Montornès, la'},
#  {'scheme': 'mun', 'id': '251713', 'content': 'Pobla de Segur, la'},
#  {'scheme': 'mun', 'id': '431129', 'content': 'Poboleda'},
#  {'scheme': 'mun', 'id': '081672', 'content': 'Polinyà'},
#  {'scheme': 'mun', 'id': '431135', 'content': "Pont d'Armentera, el"},
#  {'scheme': 'mun', 'id': '250306', 'content': 'Pont de Bar, el'},
#  {'scheme': 'mun', 'id': '171352', 'content': 'Pont de Molins'},
#  {'scheme': 'mun', 'id': '251734', 'content': 'Pont de Suert, el'},
#  {'scheme': 'mun',
#   'id': '081825',
#   'content': 'Pont de Vilomara i Rocafort, el'},
#  {'scheme': 'mun', 'id': '431418', 'content': 'Pontils'},
#  {'scheme': 'mun', 'id': '081688', 'content': 'Pontons'},
#  {'scheme': 'mun', 'id': '171365', 'content': 'Pontós'},
#  {'scheme': 'mun', 'id': '251728', 'content': 'Ponts'},
#  {'scheme': 'mun', 'id': '171371', 'content': 'Porqueres'},
#  {'scheme': 'mun', 'id': '431140', 'content': 'Porrera'},
#  {'scheme': 'mun', 'id': '171404', 'content': 'Port de la Selva, el'},
#  {'scheme': 'mun', 'id': '171387', 'content': 'Portbou'},
#  {'scheme': 'mun', 'id': '251749', 'content': 'Portella, la'},
#  {'scheme': 'mun', 'id': '431153', 'content': 'Pradell de la Teixeta'},
#  {'scheme': 'mun', 'id': '431166', 'content': 'Prades'},
#  {'scheme': 'mun', 'id': '431172', 'content': 'Prat de Comte'},
#  {'scheme': 'mun', 'id': '081691', 'content': 'Prat de Llobregat, el'},
#  {'scheme': 'mun', 'id': '431188', 'content': 'Pratdip'},
#  {'scheme': 'mun', 'id': '081712', 'content': 'Prats de Lluçanès'},
#  {'scheme': 'mun', 'id': '081705', 'content': 'Prats de Rei, els'},
#  {'scheme': 'mun', 'id': '251752', 'content': 'Prats i Sansor'},
#  {'scheme': 'mun', 'id': '251765', 'content': 'Preixana'},
#  {'scheme': 'mun', 'id': '251771', 'content': 'Preixens'},
#  {'scheme': 'mun', 'id': '082303', 'content': 'Premià de Dalt'},
#  {'scheme': 'mun', 'id': '081727', 'content': 'Premià de Mar'},
#  {'scheme': 'mun', 'id': '171390', 'content': 'Preses, les'},
#  {'scheme': 'mun', 'id': '251790', 'content': 'Prullans'},
#  {'scheme': 'mun', 'id': '081751', 'content': 'Puig-reig'},
#  {'scheme': 'mun', 'id': '171411', 'content': 'Puigcerdà'},
#  {'scheme': 'mun', 'id': '081748', 'content': 'Puigdàlber'},
#  {'scheme': 'mun', 'id': '251804', 'content': 'Puiggròs'},
#  {'scheme': 'mun', 'id': '431191', 'content': 'Puigpelat'},
#  {'scheme': 'mun', 'id': '251811', 'content': "Puigverd d'Agramunt"},
#  {'scheme': 'mun', 'id': '251826', 'content': 'Puigverd de Lleida'},
#  {'scheme': 'mun', 'id': '081764', 'content': 'Pujalt'},
#  {'scheme': 'mun', 'id': '081770', 'content': 'Quar, la'},
#  {'scheme': 'mun', 'id': '171426', 'content': 'Quart'},
#  {'scheme': 'mun', 'id': '170433', 'content': 'Queralbs'},
#  {'scheme': 'mun', 'id': '431205', 'content': 'Querol'},
#  {'scheme': 'mun', 'id': '171432', 'content': 'Rabós'},
#  {'scheme': 'mun', 'id': '081786', 'content': 'Rajadell'},
#  {'scheme': 'mun', 'id': '431362', 'content': 'Ràpita, la'},
#  {'scheme': 'mun', 'id': '431212', 'content': 'Rasquera'},
#  {'scheme': 'mun', 'id': '171447', 'content': 'Regencós'},
#  {'scheme': 'mun', 'id': '081799', 'content': 'Rellinars'},
#  {'scheme': 'mun', 'id': '431227', 'content': 'Renau'},
#  {'scheme': 'mun', 'id': '431233', 'content': 'Reus'},
#  {'scheme': 'mun', 'id': '251832', 'content': 'Rialp'},
#  {'scheme': 'mun', 'id': '431248', 'content': 'Riba, la'},
#  {'scheme': 'mun', 'id': '431251', 'content': "Riba-roja d'Ebre"},
#  {'scheme': 'mun', 'id': '259059', 'content': "Ribera d'Ondara"},
#  {'scheme': 'mun', 'id': '251850', 'content': "Ribera d'Urgellet"},
#  {'scheme': 'mun', 'id': '171450', 'content': 'Ribes de Freser'},
#  {'scheme': 'mun', 'id': '171463', 'content': 'Riells i Viabrea'},
#  {'scheme': 'mun', 'id': '431264', 'content': 'Riera de Gaià, la'},
#  {'scheme': 'mun', 'id': '251863', 'content': 'Riner'},
#  {'scheme': 'mun', 'id': '171479', 'content': 'Ripoll'},
#  {'scheme': 'mun', 'id': '081803', 'content': 'Ripollet'},
#  {'scheme': 'mun', 'id': '259139', 'content': 'Riu de Cerdanya'},
#  {'scheme': 'mun', 'id': '171485', 'content': 'Riudarenes'},
#  {'scheme': 'mun', 'id': '171498', 'content': 'Riudaura'},
#  {'scheme': 'mun', 'id': '431270', 'content': 'Riudecanyes'},
#  {'scheme': 'mun', 'id': '431286', 'content': 'Riudecols'},
#  {'scheme': 'mun', 'id': '171501', 'content': 'Riudellots de la Selva'},
#  {'scheme': 'mun', 'id': '431299', 'content': 'Riudoms'},
#  {'scheme': 'mun', 'id': '171518', 'content': 'Riumors'},
#  {'scheme': 'mun', 'id': '081810', 'content': 'Roca del Vallès, la'},
#  {'scheme': 'mun', 'id': '431303', 'content': 'Rocafort de Queralt'},
#  {'scheme': 'mun', 'id': '431310', 'content': 'Roda de Berà'},
#  {'scheme': 'mun', 'id': '081831', 'content': 'Roda de Ter'},
#  {'scheme': 'mun', 'id': '431325', 'content': 'Rodonyà'},
#  {'scheme': 'mun', 'id': '431331', 'content': 'Roquetes'},
#  {'scheme': 'mun', 'id': '171523', 'content': 'Roses'},
#  {'scheme': 'mun', 'id': '251898', 'content': 'Rosselló'},
#  {'scheme': 'mun', 'id': '431346', 'content': 'Rourell, el'},
#  {'scheme': 'mun', 'id': '081846', 'content': 'Rubí'},
#  {'scheme': 'mun', 'id': '081859', 'content': 'Rubió'},
#  {'scheme': 'mun', 'id': '171539', 'content': 'Rupià'},
#  {'scheme': 'mun', 'id': '089019', 'content': 'Rupit i Pruit'},
#  {'scheme': 'mun', 'id': '081878', 'content': 'Sabadell'},
#  {'scheme': 'mun', 'id': '081884', 'content': 'Sagàs'},
#  {'scheme': 'mun', 'id': '251902', 'content': 'Salàs de Pallars'},
#  {'scheme': 'mun', 'id': '081901', 'content': 'Saldes'},
#  {'scheme': 'mun', 'id': '171544', 'content': 'Sales de Llierca'},
#  {'scheme': 'mun', 'id': '081918', 'content': 'Sallent'},
#  {'scheme': 'mun', 'id': '431359', 'content': 'Salomó'},
#  {'scheme': 'mun', 'id': '439057', 'content': 'Salou'},
#  {'scheme': 'mun', 'id': '171557', 'content': 'Salt'},
#  {'scheme': 'mun', 'id': '251919', 'content': 'Sanaüja'},
#  {'scheme': 'mun', 'id': '081944', 'content': 'Sant Adrià de Besòs'},
#  {'scheme': 'mun', 'id': '081957', 'content': 'Sant Agustí de Lluçanès'},
#  {'scheme': 'mun', 'id': '081960', 'content': 'Sant Andreu de la Barca'},
#  {'scheme': 'mun', 'id': '081976', 'content': 'Sant Andreu de Llavaneres'},
#  {'scheme': 'mun', 'id': '171576', 'content': 'Sant Andreu Salou'},
#  {'scheme': 'mun', 'id': '171833', 'content': 'Sant Aniol de Finestres'},
#  {'scheme': 'mun', 'id': '081982', 'content': 'Sant Antoni de Vilamajor'},
#  {'scheme': 'mun', 'id': '081995', 'content': 'Sant Bartomeu del Grau'},
#  {'scheme': 'mun', 'id': '082009', 'content': 'Sant Boi de Llobregat'},
#  {'scheme': 'mun', 'id': '082016', 'content': 'Sant Boi de Lluçanès'},
#  {'scheme': 'mun', 'id': '082037', 'content': 'Sant Cebrià de Vallalta'},
#  {'scheme': 'mun', 'id': '082021', 'content': 'Sant Celoni'},
#  {'scheme': 'mun', 'id': '082042', 'content': 'Sant Climent de Llobregat'},
#  {'scheme': 'mun', 'id': '171582', 'content': 'Sant Climent Sescebes'},
#  {'scheme': 'mun', 'id': '082055', 'content': 'Sant Cugat del Vallès'},
#  {'scheme': 'mun', 'id': '082068', 'content': 'Sant Cugat Sesgarrigues'},
#  {'scheme': 'mun', 'id': '251961', 'content': 'Sant Esteve de la Sarga'},
#  {'scheme': 'mun', 'id': '082074', 'content': 'Sant Esteve de Palautordera'},
#  {'scheme': 'mun', 'id': '082080', 'content': 'Sant Esteve Sesrovires'},
#  {'scheme': 'mun', 'id': '171595', 'content': 'Sant Feliu de Buixalleu'},
#  {'scheme': 'mun', 'id': '082107', 'content': 'Sant Feliu de Codines'},
#  {'scheme': 'mun', 'id': '171609', 'content': 'Sant Feliu de Guíxols'},
#  {'scheme': 'mun', 'id': '082114', 'content': 'Sant Feliu de Llobregat'},
#  {'scheme': 'mun', 'id': '171616', 'content': 'Sant Feliu de Pallerols'},
#  {'scheme': 'mun', 'id': '082129', 'content': 'Sant Feliu Sasserra'},
#  {'scheme': 'mun', 'id': '171621', 'content': 'Sant Ferriol'},
#  {'scheme': 'mun', 'id': '082093', 'content': 'Sant Fost de Campsentelles'},
#  {'scheme': 'mun', 'id': '082135', 'content': 'Sant Fruitós de Bages'},
#  {'scheme': 'mun', 'id': '171637', 'content': 'Sant Gregori'},
#  {'scheme': 'mun', 'id': '251924', 'content': 'Sant Guim de Freixenet'},
#  {'scheme': 'mun', 'id': '251977', 'content': 'Sant Guim de la Plana'},
#  {'scheme': 'mun', 'id': '171642', 'content': 'Sant Hilari Sacalm'},
#  {'scheme': 'mun', 'id': '082153', 'content': 'Sant Hipòlit de Voltregà'},
#  {'scheme': 'mun', 'id': '081939', 'content': 'Sant Iscle de Vallalta'},
#  {'scheme': 'mun', 'id': '439023', 'content': "Sant Jaume d'Enveja"},
#  {'scheme': 'mun', 'id': '082166', 'content': 'Sant Jaume de Frontanyà'},
#  {'scheme': 'mun', 'id': '171655', 'content': 'Sant Jaume de Llierca'},
#  {'scheme': 'mun', 'id': '431378', 'content': 'Sant Jaume dels Domenys'},
#  {'scheme': 'mun', 'id': '171674', 'content': 'Sant Joan de les Abadesses'},
#  {'scheme': 'mun', 'id': '171680', 'content': 'Sant Joan de Mollet'},
#  {'scheme': 'mun', 'id': '082188', 'content': 'Sant Joan de Vilatorrada'},
#  {'scheme': 'mun', 'id': '082172', 'content': 'Sant Joan Despí'},
#  {'scheme': 'mun', 'id': '171851', 'content': 'Sant Joan les Fonts'},
#  {'scheme': 'mun', 'id': '171668', 'content': 'Sant Jordi Desvalls'},
#  {'scheme': 'mun', 'id': '089030', 'content': 'Sant Julià de Cerdanyola'},
#  {'scheme': 'mun', 'id': '171693', 'content': 'Sant Julià de Ramis'},
#  {'scheme': 'mun', 'id': '082205', 'content': 'Sant Julià de Vilatorta'},
#  {'scheme': 'mun', 'id': '179032', 'content': 'Sant Julià del Llor i Bonmatí'},
#  {'scheme': 'mun', 'id': '082212', 'content': 'Sant Just Desvern'},
#  {'scheme': 'mun', 'id': '082227', 'content': "Sant Llorenç d'Hortons"},
#  {'scheme': 'mun', 'id': '171714', 'content': 'Sant Llorenç de la Muga'},
#  {'scheme': 'mun', 'id': '251930', 'content': 'Sant Llorenç de Morunys'},
#  {'scheme': 'mun', 'id': '082233', 'content': 'Sant Llorenç Savall'},
#  {'scheme': 'mun', 'id': '082251', 'content': "Sant Martí d'Albars"},
#  {'scheme': 'mun', 'id': '082248', 'content': 'Sant Martí de Centelles'},
#  {'scheme': 'mun', 'id': '171729', 'content': 'Sant Martí de Llémena'},
#  {'scheme': 'mun', 'id': '259025', 'content': 'Sant Martí de Riucorb'},
#  {'scheme': 'mun', 'id': '082264', 'content': 'Sant Martí de Tous'},
#  {'scheme': 'mun', 'id': '082270', 'content': 'Sant Martí Sarroca'},
#  {'scheme': 'mun', 'id': '082286', 'content': 'Sant Martí Sesgueioles'},
#  {'scheme': 'mun', 'id': '171735', 'content': 'Sant Martí Vell'},
#  {'scheme': 'mun', 'id': '082299', 'content': 'Sant Mateu de Bages'},
#  {'scheme': 'mun', 'id': '171740', 'content': 'Sant Miquel de Campmajor'},
#  {'scheme': 'mun', 'id': '171753', 'content': 'Sant Miquel de Fluvià'},
#  {'scheme': 'mun', 'id': '171766', 'content': 'Sant Mori'},
#  {'scheme': 'mun', 'id': '171772', 'content': 'Sant Pau de Segúries'},
#  {'scheme': 'mun', 'id': '082310', 'content': 'Sant Pere de Ribes'},
#  {'scheme': 'mun', 'id': '082325', 'content': 'Sant Pere de Riudebitlles'},
#  {'scheme': 'mun', 'id': '082331', 'content': 'Sant Pere de Torelló'},
#  {'scheme': 'mun', 'id': '082346', 'content': 'Sant Pere de Vilamajor'},
#  {'scheme': 'mun', 'id': '171788', 'content': 'Sant Pere Pescador'},
#  {'scheme': 'mun', 'id': '081897', 'content': 'Sant Pere Sallavinera'},
#  {'scheme': 'mun', 'id': '082359', 'content': 'Sant Pol de Mar'},
#  {'scheme': 'mun', 'id': '082362', 'content': 'Sant Quintí de Mediona'},
#  {'scheme': 'mun', 'id': '082378', 'content': 'Sant Quirze de Besora'},
#  {'scheme': 'mun', 'id': '082384', 'content': 'Sant Quirze del Vallès'},
#  {'scheme': 'mun', 'id': '082397', 'content': 'Sant Quirze Safaja'},
#  {'scheme': 'mun', 'id': '251945', 'content': 'Sant Ramon'},
#  {'scheme': 'mun', 'id': '082401', 'content': "Sant Sadurní d'Anoia"},
#  {'scheme': 'mun', 'id': '082418', 'content': "Sant Sadurní d'Osormort"},
#  {'scheme': 'mun', 'id': '080983', 'content': 'Sant Salvador de Guardiola'},
#  {'scheme': 'mun', 'id': '082628', 'content': 'Sant Vicenç de Castellet'},
#  {'scheme': 'mun', 'id': '082649', 'content': 'Sant Vicenç de Montalt'},
#  {'scheme': 'mun', 'id': '082652', 'content': 'Sant Vicenç de Torelló'},
#  {'scheme': 'mun', 'id': '082634', 'content': 'Sant Vicenç dels Horts'},
#  {'scheme': 'mun', 'id': '431384', 'content': 'Santa Bàrbara'},
#  {'scheme': 'mun', 'id': '082439', 'content': 'Santa Cecília de Voltregà'},
#  {'scheme': 'mun', 'id': '082444', 'content': 'Santa Coloma de Cervelló'},
#  {'scheme': 'mun', 'id': '171805', 'content': 'Santa Coloma de Farners'},
#  {'scheme': 'mun', 'id': '082457', 'content': 'Santa Coloma de Gramenet'},
#  {'scheme': 'mun', 'id': '431397', 'content': 'Santa Coloma de Queralt'},
#  {'scheme': 'mun', 'id': '171812', 'content': "Santa Cristina d'Aro"},
#  {'scheme': 'mun', 'id': '082460', 'content': 'Santa Eugènia de Berga'},
#  {'scheme': 'mun', 'id': '082476', 'content': 'Santa Eulàlia de Riuprimer'},
#  {'scheme': 'mun', 'id': '082482', 'content': 'Santa Eulàlia de Ronçana'},
#  {'scheme': 'mun', 'id': '082495', 'content': 'Santa Fe del Penedès'},
#  {'scheme': 'mun', 'id': '171827', 'content': "Santa Llogaia d'Àlguema"},
#  {'scheme': 'mun', 'id': '082508', 'content': 'Santa Margarida de Montbui'},
#  {'scheme': 'mun', 'id': '082515', 'content': 'Santa Margarida i els Monjos'},
#  {'scheme': 'mun', 'id': '082589', 'content': "Santa Maria d'Oló"},
#  {'scheme': 'mun', 'id': '082536', 'content': 'Santa Maria de Besora'},
#  {'scheme': 'mun', 'id': '082567', 'content': 'Santa Maria de Martorelles'},
#  {'scheme': 'mun', 'id': '082554', 'content': 'Santa Maria de Merlès'},
#  {'scheme': 'mun', 'id': '082573', 'content': 'Santa Maria de Miralles'},
#  {'scheme': 'mun', 'id': '082592', 'content': 'Santa Maria de Palautordera'},
#  {'scheme': 'mun', 'id': '431401', 'content': 'Santa Oliva'},
#  {'scheme': 'mun', 'id': '171848', 'content': 'Santa Pau'},
#  {'scheme': 'mun', 'id': '082606', 'content': 'Santa Perpètua de Mogoda'},
#  {'scheme': 'mun', 'id': '082613', 'content': 'Santa Susanna'},
#  {'scheme': 'mun', 'id': '081923', 'content': 'Santpedor'},
#  {'scheme': 'mun', 'id': '431423', 'content': 'Sarral'},
#  {'scheme': 'mun', 'id': '171864', 'content': 'Sarrià de Ter'},
#  {'scheme': 'mun', 'id': '252017', 'content': 'Sarroca de Bellera'},
#  {'scheme': 'mun', 'id': '252000', 'content': 'Sarroca de Lleida'},
#  {'scheme': 'mun', 'id': '171870', 'content': 'Saus, Camallera i Llampaies'},
#  {'scheme': 'mun', 'id': '431439', 'content': 'Savallà del Comtat'},
#  {'scheme': 'mun', 'id': '431444', 'content': 'Secuita, la'},
#  {'scheme': 'mun', 'id': '171886', 'content': 'Selva de Mar, la'},
#  {'scheme': 'mun', 'id': '431457', 'content': 'Selva del Camp, la'},
#  {'scheme': 'mun', 'id': '431460', 'content': 'Senan'},
#  {'scheme': 'mun', 'id': '430445', 'content': 'Sénia, la'},
#  {'scheme': 'mun', 'id': '252022', 'content': 'Senterada'},
#  {'scheme': 'mun', 'id': '250352', 'content': 'Sentiu de Sió, la'},
#  {'scheme': 'mun', 'id': '082671', 'content': 'Sentmenat'},
#  {'scheme': 'mun', 'id': '171903', 'content': 'Serinyà'},
#  {'scheme': 'mun', 'id': '252043', 'content': 'Seròs'},
#  {'scheme': 'mun', 'id': '171910', 'content': 'Serra de Daró'},
#  {'scheme': 'mun', 'id': '171925', 'content': 'Setcases'},
#  {'scheme': 'mun', 'id': '252038', 'content': "Seu d'Urgell, la"},
#  {'scheme': 'mun', 'id': '082690', 'content': 'Seva'},
#  {'scheme': 'mun', 'id': '252056', 'content': 'Sidamon'},
#  {'scheme': 'mun', 'id': '171931', 'content': 'Sils'},
#  {'scheme': 'mun', 'id': '082704', 'content': 'Sitges'},
#  {'scheme': 'mun', 'id': '170524', 'content': 'Siurana'},
#  {'scheme': 'mun', 'id': '082711', 'content': 'Sobremunt'},
#  {'scheme': 'mun', 'id': '252069', 'content': 'Soleràs, el'},
#  {'scheme': 'mun', 'id': '431476', 'content': 'Solivella'},
#  {'scheme': 'mun', 'id': '252075', 'content': 'Solsona'},
#  {'scheme': 'mun', 'id': '082726', 'content': 'Sora'},
#  {'scheme': 'mun', 'id': '252081', 'content': 'Soriguera'},
#  {'scheme': 'mun', 'id': '252094', 'content': 'Sort'},
#  {'scheme': 'mun', 'id': '252108', 'content': 'Soses'},
#  {'scheme': 'mun', 'id': '082732', 'content': 'Subirats'},
#  {'scheme': 'mun', 'id': '252115', 'content': 'Sudanell'},
#  {'scheme': 'mun', 'id': '252120', 'content': 'Sunyer'},
#  {'scheme': 'mun', 'id': '082747', 'content': 'Súria'},
#  {'scheme': 'mun', 'id': '171946', 'content': 'Susqueda'},
#  {'scheme': 'mun', 'id': '082763', 'content': 'Tagamanent'},
#  {'scheme': 'mun', 'id': '082779', 'content': 'Talamanca'},
#  {'scheme': 'mun', 'id': '252154', 'content': 'Talarn'},
#  {'scheme': 'mun', 'id': '252167', 'content': 'Talavera'},
#  {'scheme': 'mun', 'id': '171959', 'content': "Tallada d'Empordà, la"},
#  {'scheme': 'mun', 'id': '082785', 'content': 'Taradell'},
#  {'scheme': 'mun', 'id': '431482', 'content': 'Tarragona'},
#  {'scheme': 'mun', 'id': '252173', 'content': 'Tàrrega'},
#  {'scheme': 'mun', 'id': '252189', 'content': 'Tarrés'},
#  {'scheme': 'mun', 'id': '252192', 'content': 'Tarroja de Segarra'},
#  {'scheme': 'mun', 'id': '082750', 'content': 'Tavèrnoles'},
#  {'scheme': 'mun', 'id': '082802', 'content': 'Tavertet'},
#  {'scheme': 'mun', 'id': '082819', 'content': 'Teià'},
#  {'scheme': 'mun', 'id': '252206', 'content': 'Térmens'},
#  {'scheme': 'mun', 'id': '171962', 'content': 'Terrades'},
#  {'scheme': 'mun', 'id': '082798', 'content': 'Terrassa'},
#  {'scheme': 'mun', 'id': '082824', 'content': 'Tiana'},
#  {'scheme': 'mun', 'id': '252213', 'content': 'Tírvia'},
#  {'scheme': 'mun', 'id': '252228', 'content': 'Tiurana'},
#  {'scheme': 'mun', 'id': '431495', 'content': 'Tivenys'},
#  {'scheme': 'mun', 'id': '431508', 'content': 'Tivissa'},
#  {'scheme': 'mun', 'id': '082830', 'content': 'Tona'},
#  {'scheme': 'mun', 'id': '252234', 'content': 'Torà'},
#  {'scheme': 'mun', 'id': '082845', 'content': 'Tordera'},
#  {'scheme': 'mun', 'id': '082858', 'content': 'Torelló'},
#  {'scheme': 'mun', 'id': '252249', 'content': 'Torms, els'},
#  {'scheme': 'mun', 'id': '252252', 'content': 'Tornabous'},
#  {'scheme': 'mun', 'id': '252271', 'content': 'Torre de Cabdella, la'},
#  {'scheme': 'mun', 'id': '082861', 'content': 'Torre de Claramunt, la'},
#  {'scheme': 'mun', 'id': '431515', 'content': 'Torre de Fontaubella, la'},
#  {'scheme': 'mun', 'id': '431520', 'content': "Torre de l'Espanyol, la"},
#  {'scheme': 'mun', 'id': '252332', 'content': 'Torre-serona'},
#  {'scheme': 'mun', 'id': '252265', 'content': 'Torrebesses'},
#  {'scheme': 'mun', 'id': '431536', 'content': 'Torredembarra'},
#  {'scheme': 'mun', 'id': '252287', 'content': 'Torrefarrera'},
#  {'scheme': 'mun', 'id': '259078', 'content': 'Torrefeta i Florejacs'},
#  {'scheme': 'mun', 'id': '252304', 'content': 'Torregrossa'},
#  {'scheme': 'mun', 'id': '252311', 'content': 'Torrelameu'},
#  {'scheme': 'mun', 'id': '082877', 'content': 'Torrelavit'},
#  {'scheme': 'mun', 'id': '082883', 'content': 'Torrelles de Foix'},
#  {'scheme': 'mun', 'id': '082896', 'content': 'Torrelles de Llobregat'},
#  {'scheme': 'mun', 'id': '171978', 'content': 'Torrent'},
#  {'scheme': 'mun', 'id': '252326', 'content': 'Torres de Segre'},
#  {'scheme': 'mun', 'id': '171984', 'content': 'Torroella de Fluvià'},
#  {'scheme': 'mun', 'id': '171997', 'content': 'Torroella de Montgrí'},
#  {'scheme': 'mun', 'id': '431541', 'content': 'Torroja del Priorat'},
#  {'scheme': 'mun', 'id': '172001', 'content': 'Tortellà'},
#  {'scheme': 'mun', 'id': '431554', 'content': 'Tortosa'},
#  {'scheme': 'mun', 'id': '172018', 'content': 'Toses'},
#  {'scheme': 'mun', 'id': '172023', 'content': 'Tossa de Mar'},
#  {'scheme': 'mun', 'id': '252347', 'content': 'Tremp'},
#  {'scheme': 'mun', 'id': '172044', 'content': 'Ullà'},
#  {'scheme': 'mun', 'id': '082900', 'content': 'Ullastrell'},
#  {'scheme': 'mun', 'id': '172057', 'content': 'Ullastret'},
#  {'scheme': 'mun', 'id': '431567', 'content': 'Ulldecona'},
#  {'scheme': 'mun', 'id': '431573', 'content': 'Ulldemolins'},
#  {'scheme': 'mun', 'id': '172039', 'content': 'Ultramort'},
#  {'scheme': 'mun', 'id': '172060', 'content': 'Urús'},
#  {'scheme': 'mun', 'id': '082917', 'content': 'Vacarisses'},
#  {'scheme': 'mun', 'id': '170144', 'content': 'Vajol, la'},
#  {'scheme': 'mun', 'id': '172076', 'content': "Vall d'en Bas, la"},
#  {'scheme': 'mun', 'id': '172082', 'content': 'Vall de Bianya, la'},
#  {'scheme': 'mun', 'id': '250432', 'content': 'Vall de Boí, la'},
#  {'scheme': 'mun', 'id': '259010', 'content': 'Vall de Cardós'},
#  {'scheme': 'mun', 'id': '172095', 'content': 'Vall-llobrega'},
#  {'scheme': 'mun', 'id': '082922', 'content': "Vallbona d'Anoia"},
#  {'scheme': 'mun', 'id': '252385', 'content': 'Vallbona de les Monges'},
#  {'scheme': 'mun', 'id': '082938', 'content': 'Vallcebre'},
#  {'scheme': 'mun', 'id': '431589', 'content': 'Vallclara'},
#  {'scheme': 'mun', 'id': '252402', 'content': 'Vallfogona de Balaguer'},
#  {'scheme': 'mun', 'id': '171707', 'content': 'Vallfogona de Ripollès'},
#  {'scheme': 'mun', 'id': '431592', 'content': 'Vallfogona de Riucorb'},
#  {'scheme': 'mun', 'id': '082943', 'content': 'Vallgorguina'},
#  {'scheme': 'mun', 'id': '082956', 'content': 'Vallirana'},
#  {'scheme': 'mun', 'id': '431606', 'content': 'Vallmoll'},
#  {'scheme': 'mun', 'id': '082969', 'content': 'Vallromanes'},
#  {'scheme': 'mun', 'id': '431613', 'content': 'Valls'},
#  {'scheme': 'mun', 'id': '259062', 'content': "Valls d'Aguilar, les"},
#  {'scheme': 'mun', 'id': '252398', 'content': 'Valls de Valira, les'},
#  {'scheme': 'mun',
#   'id': '431628',
#   'content': "Vandellòs i l'Hospitalet de l'Infant"},
#  {'scheme': 'mun', 'id': '259097', 'content': 'Vansa i Fórnols, la'},
#  {'scheme': 'mun', 'id': '082975', 'content': 'Veciana'},
#  {'scheme': 'mun', 'id': '431634', 'content': 'Vendrell, el'},
#  {'scheme': 'mun', 'id': '172109', 'content': 'Ventalló'},
#  {'scheme': 'mun', 'id': '252424', 'content': 'Verdú'},
#  {'scheme': 'mun', 'id': '172116', 'content': 'Verges'},
#  {'scheme': 'mun', 'id': '431649', 'content': 'Vespella de Gaià'},
#  {'scheme': 'mun', 'id': '082981', 'content': 'Vic'},
#  {'scheme': 'mun', 'id': '172121', 'content': 'Vidrà'},
#  {'scheme': 'mun', 'id': '172137', 'content': 'Vidreres'},
#  {'scheme': 'mun', 'id': '252430', 'content': 'Vielha e Mijaran'},
#  {'scheme': 'mun', 'id': '431704', 'content': 'Vila-rodona'},
#  {'scheme': 'mun', 'id': '172305', 'content': 'Vila-sacra'},
#  {'scheme': 'mun', 'id': '252521', 'content': 'Vila-sana'},
#  {'scheme': 'mun', 'id': '431711', 'content': 'Vila-seca'},
#  {'scheme': 'mun', 'id': '431652', 'content': 'Vilabella'},
#  {'scheme': 'mun', 'id': '172142', 'content': 'Vilabertran'},
#  {'scheme': 'mun', 'id': '172155', 'content': 'Vilablareix'},
#  {'scheme': 'mun', 'id': '082994', 'content': 'Vilada'},
#  {'scheme': 'mun', 'id': '172174', 'content': 'Viladamat'},
#  {'scheme': 'mun', 'id': '172168', 'content': 'Viladasens'},
#  {'scheme': 'mun', 'id': '083015', 'content': 'Viladecans'},
#  {'scheme': 'mun', 'id': '083008', 'content': 'Viladecavalls'},
#  {'scheme': 'mun', 'id': '172180', 'content': 'Vilademuls'},
#  {'scheme': 'mun', 'id': '172207', 'content': 'Viladrau'},
#  {'scheme': 'mun', 'id': '172214', 'content': 'Vilafant'},
#  {'scheme': 'mun', 'id': '083054', 'content': 'Vilafranca del Penedès'},
#  {'scheme': 'mun', 'id': '252445', 'content': 'Vilagrassa'},
#  {'scheme': 'mun', 'id': '172235', 'content': 'Vilajuïga'},
#  {'scheme': 'mun', 'id': '431750', 'content': 'Vilalba dels Arcs'},
#  {'scheme': 'mun', 'id': '083067', 'content': 'Vilalba Sasserra'},
#  {'scheme': 'mun', 'id': '252458', 'content': 'Vilaller'},
#  {'scheme': 'mun', 'id': '172240', 'content': 'Vilallonga de Ter'},
#  {'scheme': 'mun', 'id': '431665', 'content': 'Vilallonga del Camp'},
#  {'scheme': 'mun', 'id': '172253', 'content': 'Vilamacolum'},
#  {'scheme': 'mun', 'id': '172266', 'content': 'Vilamalla'},
#  {'scheme': 'mun', 'id': '172272', 'content': 'Vilamaniscle'},
#  {'scheme': 'mun', 'id': '252477', 'content': 'Vilamòs'},
#  {'scheme': 'mun', 'id': '172288', 'content': 'Vilanant'},
#  {'scheme': 'mun', 'id': '431671', 'content': "Vilanova d'Escornalbou"},
#  {'scheme': 'mun', 'id': '252483', 'content': 'Vilanova de Bellpuig'},
#  {'scheme': 'mun', 'id': '252496', 'content': "Vilanova de l'Aguda"},
#  {'scheme': 'mun', 'id': '252542', 'content': 'Vilanova de la Barca'},
#  {'scheme': 'mun', 'id': '252509', 'content': 'Vilanova de Meià'},
#  {'scheme': 'mun', 'id': '431687', 'content': 'Vilanova de Prades'},
#  {'scheme': 'mun', 'id': '083036', 'content': 'Vilanova de Sau'},
#  {'scheme': 'mun', 'id': '252516', 'content': 'Vilanova de Segrià'},
#  {'scheme': 'mun', 'id': '083020', 'content': 'Vilanova del Camí'},
#  {'scheme': 'mun', 'id': '089024', 'content': 'Vilanova del Vallès'},
#  {'scheme': 'mun', 'id': '083073', 'content': 'Vilanova i la Geltrú'},
#  {'scheme': 'mun', 'id': '431690', 'content': 'Vilaplana'},
#  {'scheme': 'mun', 'id': '082140', 'content': 'Vilassar de Dalt'},
#  {'scheme': 'mun', 'id': '082191', 'content': 'Vilassar de Mar'},
#  {'scheme': 'mun', 'id': '172229', 'content': 'Vilaür'},
#  {'scheme': 'mun', 'id': '431726', 'content': 'Vilaverd'},
#  {'scheme': 'mun', 'id': '431732', 'content': 'Vilella Alta, la'},
#  {'scheme': 'mun', 'id': '431747', 'content': 'Vilella Baixa, la'},
#  {'scheme': 'mun', 'id': '172333', 'content': "Vilobí d'Onyar"},
#  {'scheme': 'mun', 'id': '083041', 'content': 'Vilobí del Penedès'},
#  {'scheme': 'mun', 'id': '172327', 'content': 'Vilopriu'},
#  {'scheme': 'mun', 'id': '252537', 'content': 'Vilosell, el'},
#  {'scheme': 'mun', 'id': '431763', 'content': 'Vimbodí i Poblet'},
#  {'scheme': 'mun', 'id': '252555', 'content': 'Vinaixa'},
#  {'scheme': 'mun', 'id': '431779', 'content': 'Vinebre'},
#  {'scheme': 'mun', 'id': '431785', 'content': 'Vinyols i els Arcs'},
#  {'scheme': 'mun', 'id': '083089', 'content': 'Viver i Serrateix'},
#  {'scheme': 'mun', 'id': '430521', 'content': 'Xerta'},
#  {'scheme': 'com', 'id': '01', 'content': 'Alt Camp'},
#  {'scheme': 'com', 'id': '02', 'content': 'Alt Empordà'},
#  {'scheme': 'com', 'id': '03', 'content': 'Alt Penedès'},
#  {'scheme': 'com', 'id': '04', 'content': 'Alt Urgell'},
#  {'scheme': 'com', 'id': '05', 'content': 'Alta Ribagorça'},
#  {'scheme': 'com', 'id': '06', 'content': 'Anoia'},
#  {'scheme': 'com', 'id': '07', 'content': 'Bages'},
#  {'scheme': 'com', 'id': '08', 'content': 'Baix Camp'},
#  {'scheme': 'com', 'id': '09', 'content': 'Baix Ebre'},
#  {'scheme': 'com', 'id': '10', 'content': 'Baix Empordà'},
#  {'scheme': 'com', 'id': '11', 'content': 'Baix Llobregat'},
#  {'scheme': 'com', 'id': '12', 'content': 'Baix Penedès'},
#  {'scheme': 'com', 'id': '13', 'content': 'Barcelonès'},
#  {'scheme': 'com', 'id': '14', 'content': 'Berguedà'},
#  {'scheme': 'com', 'id': '15', 'content': 'Cerdanya'},
#  {'scheme': 'com', 'id': '16', 'content': 'Conca de Barberà'},
#  {'scheme': 'com', 'id': '17', 'content': 'Garraf'},
#  {'scheme': 'com', 'id': '18', 'content': 'Garrigues'},
#  {'scheme': 'com', 'id': '19', 'content': 'Garrotxa'},
#  {'scheme': 'com', 'id': '20', 'content': 'Gironès'},
#  {'scheme': 'com', 'id': '21', 'content': 'Maresme'},
#  {'scheme': 'com', 'id': '22', 'content': 'Montsià'},
#  {'scheme': 'com', 'id': '23', 'content': 'Noguera'},
#  {'scheme': 'com', 'id': '24', 'content': 'Osona'},
#  {'scheme': 'com', 'id': '25', 'content': 'Pallars Jussà'},
#  {'scheme': 'com', 'id': '26', 'content': 'Pallars Sobirà'},
#  {'scheme': 'com', 'id': '27', 'content': "Pla d'Urgell"},
#  {'scheme': 'com', 'id': '28', 'content': "Pla de l'Estany"},
#  {'scheme': 'com', 'id': '29', 'content': 'Priorat'},
#  {'scheme': 'com', 'id': '30', 'content': "Ribera d'Ebre"},
#  {'scheme': 'com', 'id': '31', 'content': 'Ripollès'},
#  {'scheme': 'com', 'id': '32', 'content': 'Segarra'},
#  {'scheme': 'com', 'id': '33', 'content': 'Segrià'},
#  {'scheme': 'com', 'id': '34', 'content': 'Selva'},
#  {'scheme': 'com', 'id': '35', 'content': 'Solsonès'},
#  {'scheme': 'com', 'id': '36', 'content': 'Tarragonès'},
#  {'scheme': 'com', 'id': '37', 'content': 'Terra Alta'},
#  {'scheme': 'com', 'id': '38', 'content': 'Urgell'},
#  {'scheme': 'com', 'id': '39', 'content': 'Aran'},
#  {'scheme': 'com', 'id': '40', 'content': 'Vallès Occidental'},
#  {'scheme': 'com', 'id': '41', 'content': 'Vallès Oriental'},
#  {'scheme': 'com', 'id': '42', 'content': 'Moianès'},
#  {'scheme': 'ca', 'id': '09', 'content': 'Catalunya'}]

# %%
mun_response = requests.get("https://api.idescat.cat/emex/v1/dades.json?id=080018&lang=en")

# %%
mun_response.json()
# Out:
# {'fitxes': {'p': 'id=080018',
#   'gg': {'g': [{'tt': {'t': {'ff': {'f': [{'r': '2021',
#           'c': 'Surface area',
#           'u': 'km²',
#           'v': '19.94,485.99,32108.00',
#           'calt': 'Surface area',
#           'id': 'f271',
#           'updated': '2021-12-23T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'Altitude',
#           'u': 'm',
#           'v': '105,_,_',
#           'calt': 'Altitude',
#           'id': 'f258',
#           'updated': '2014-02-17T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'Longitude',
#           'u': 'º',
#           'v': '1.903100,_,_',
#           'calt': 'Longitude',
#           'id': 'f328',
#           'updated': '2014-02-17T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'Latitude',
#           'u': 'º',
#           'v': '41.518531,_,_',
#           'calt': 'Latitude',
#           'id': 'f329',
#           'updated': '2014-02-17T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'UTM coordinates x',
#           'u': 'm',
#           'v': '408471,_,_',
#           'calt': 'UTM coordinates x',
#           'id': 'f259',
#           'updated': '2014-02-17T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'UTM coordinates y',
#           'u': 'm',
#           'v': '4596983,_,_',
#           'calt': 'UTM coordinates y',
#           'id': 'f260',
#           'updated': '2014-02-17T11:00:00+00:00'}]},
#        'c': 'Geographic indicators',
#        'id': 't176',
#        'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:080018&lang=en'}},
#      'c': 'Territory',
#      'id': 'g173'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Surface area',
#            'u': 'km²',
#            'v': '19.94,485.99,32108.00',
#            'calt': 'Surface area',
#            'id': 'f261'},
#           {'c': 'Density',
#            'u': 'inh./km²',
#            'v': '632.9,1714.7,241.8',
#            'calt': 'Density',
#            'id': 'f262'}]},
#         'r': '2021',
#         'c': 'Density of population',
#         'calt': 'Density',
#         'id': 't192',
#         'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:080018&lang=en',
#         'updated': '2021-12-23T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Men',
#            'v': '6373,409210,3819831',
#            'calt': 'Men',
#            'id': 'f318'},
#           {'c': 'Women',
#            'v': '6247,424102,3943531',
#            'calt': 'Women',
#            'id': 'f320'},
#           {'c': 'Total',
#            'v': '12620,833312,7763362',
#            'calt': 'Population',
#            'id': 'f321'}]},
#         'r': '2021',
#         'c': 'Population. By sex',
#         's': 'Idescat, from the Continuous Register Statistic of INE.',
#         'calt': 'Sex',
#         'id': 't195',
#         'l': 'https://www.idescat.cat/pub/?id=pmh&n=446&geo=mun:080018&lang=en',
#         'updated': '2022-02-28T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'From 0 to 14 years',
#            'v': '2138,128735,1139260',
#            'calt': 'Population from 0 to 14 years',
#            'id': 'f167'},
#           {'c': 'From 15 to 64 years',
#            'v': '8503,554817,5145431',
#            'calt': 'Population from 15 to 64 years',
#            'id': 'f27'},
#           {'c': 'From 65 to 84 years',
#            'v': '1749,128135,1228528',
#            'calt': 'Population from 65 to 84 years',
#            'id': 'f28'},
#           {'c': 'From 85 years and over',
#            'v': '230,21625,250143',
#            'calt': 'Population from 85 years and over',
#            'id': 'f29'},
#           {'c': 'Total',
#            'v': '12620,833312,7763362',
#            'calt': 'Population',
#            'id': 'f171'}]},
#         'r': '2021',
#         'c': 'Population. By age groups',
#         's': 'Idescat, from the Continuous Register Statistic of INE.',
#         'calt': 'Age groups',
#         'id': 't25',
#         'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:080018&lang=en',
#         'updated': '2022-02-28T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'From 0 to 14 years',
#            'v': '1100,66082,586182',
#            'calt': 'Men from 0 to 14 years',
#            'id': 'f176'},
#           {'c': 'From 15 to 64 years',
#            'v': '4366,278413,2598440',
#            'calt': 'Men from 15 to 64 years',
#            'id': 'f33'},
#           {'c': 'From 65 to 84 years',
#            'v': '809,57388,552061',
#            'calt': 'Men from 65 to 84 years',
#            'id': 'f34'},
#           {'c': 'From 85 years and over',
#            'v': '98,7327,83148',
#            'calt': 'Men from 85 years and over',
#            'id': 'f35'},
#           {'c': 'Total',
#            'v': '6373,409210,3819831',
#            'calt': 'Men',
#            'id': 'f36'}]},
#         'r': '2021',
#         'c': 'Population. By age groups. Men',
#         's': 'Idescat, from the Continuous Register Statistic of INE.',
#         'calt': 'Age groups. Men',
#         'id': 't31',
#         'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:080018&lang=en',
#         'updated': '2022-02-28T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'From 0 to 14 years',
#            'v': '1038,62653,553078',
#            'calt': 'Women from 0 to 14 years',
#            'id': 'f38'},
#           {'c': 'From 15 to 64 years',
#            'v': '4137,276404,2546991',
#            'calt': 'Women from 15 to 64 years',
#            'id': 'f39'},
#           {'c': 'From 65 to 84 years',
#            'v': '940,70747,676467',
#            'calt': 'Women from 65 to 84 years',
#            'id': 'f40'},
#           {'c': 'From 85 years and over',
#            'v': '132,14298,166995',
#            'calt': 'Women from 85 years and over',
#            'id': 'f41'},
#           {'c': 'Total',
#            'v': '6247,424102,3943531',
#            'calt': 'Women',
#            'id': 'f42'}]},
#         'r': '2021',
#         'c': 'Population. By age groups. Women',
#         's': 'Idescat, from the Continuous Register Statistic of INE.',
#         'calt': 'Age groups. Women',
#         'id': 't37',
#         'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:080018&lang=en',
#         'updated': '2022-02-28T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Catalonia',
#            'v': '8717,535280,4952278',
#            'calt': 'Population born in Catalonia',
#            'id': 'f69'},
#           {'c': 'Rest of Spain',
#            'v': '2575,167204,1212621',
#            'calt': 'Population born in rest of Spain',
#            'id': 'f72'},
#           {'c': 'Abroad',
#            'v': '1328,130828,1598463',
#            'calt': 'Population born abroad',
#            'id': 'f73'},
#           {'c': 'Total',
#            'v': '12620,833312,7763362',
#            'calt': 'Population',
#            'id': 'f74'}]},
#         'r': '2021',
#         'c': 'Population. By place of birth',
#         's': 'Idescat, from the Continuous Register Statistic of INE.',
#         'calt': 'Place of birth',
#         'id': 't68',
#         'l': 'https://www.idescat.cat/pub/?id=pmh&n=674&geo=mun:080018&lang=en',
#         'updated': '2022-02-28T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Spanish',
#            'v': '11778,741920,6512697',
#            'calt': 'Population with Spanish nationality',
#            'id': 'f183'},
#           {'c': 'Foreign',
#            'v': '842,91392,1250665',
#            'calt': 'Population with foreign nationality',
#            'id': 'f184'},
#           {'c': 'Total',
#            'v': '12620,833312,7763362',
#            'calt': 'Population',
#            'id': 'f263'}]},
#         'r': '2021',
#         'c': 'Population. By nationality',
#         's': 'Idescat, from the Continuous Register Statistic of INE.',
#         'calt': 'Nationality',
#         'id': 't75',
#         'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:080018&lang=en',
#         'updated': '2022-02-28T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Spanish',
#            'v': '5968,363371,3172812',
#            'calt': 'Men with Spanish nationality',
#            'id': 'f178'},
#           {'c': 'Foreign',
#            'v': '405,45839,647019',
#            'calt': 'Men with foreign nationality',
#            'id': 'f77'},
#           {'c': 'Total',
#            'v': '6373,409210,3819831',
#            'calt': 'Men',
#            'id': 'f264'}]},
#         'r': '2021',
#         'c': 'Population. By nationality. Men',
#         's': 'Idescat, from the Continuous Register Statistic of INE.',
#         'calt': 'Nationality. Men',
#         'id': 't78',
#         'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:080018&lang=en',
#         'updated': '2022-02-28T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Spanish',
#            'v': '5810,378549,3339885',
#            'calt': 'Women with Spanish nationality',
#            'id': 'f82'},
#           {'c': 'Foreign',
#            'v': '437,45553,603646',
#            'calt': 'Women with foreign nationality',
#            'id': 'f83'},
#           {'c': 'Total',
#            'v': '6247,424102,3943531',
#            'calt': 'Women',
#            'id': 'f265'}]},
#         'r': '2021',
#         'c': 'Population. By nationality. Women',
#         's': 'Idescat, from the Continuous Register Statistic of INE.',
#         'calt': 'Nationality. Women',
#         'id': 't81',
#         'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:080018&lang=en',
#         'updated': '2022-02-28T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Men',
#            'v': '124,9249,172716',
#            'calt': 'Men resident abroad',
#            'id': 'f334'},
#           {'c': 'Women',
#            'v': '129,8739,167798',
#            'calt': 'Women resident abroad',
#            'id': 'f335'},
#           {'c': 'Total',
#            'v': '253,17988,340514',
#            'calt': 'Population resident abroad',
#            'id': 'f336'}]},
#         'r': '2021',
#         'c': 'Population resident abroad on 1 January. By sex',
#         's': '',
#         'calt': 'Population resident abroad',
#         'id': 't197',
#         'l': 'https://www.idescat.cat/pub/?id=phre&n=3697&geo=mun:080018&lang=en',
#         'updated': '2021-04-22T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Resident population',
#            'v': '12538,834653,_',
#            'calt': 'Resident population',
#            'id': 'f341'},
#           {'c': 'AFTE seasonal population',
#            'v': '388,-16645,_',
#            'calt': 'AFTE seasonal population',
#            'id': 'f342'},
#           {'c': 'Total',
#            'v': '12926,818008,_',
#            'calt': 'AFTE population',
#            'id': 'f343'},
#           {'c': 'AFTE population / resident population',
#            'u': '%',
#            'v': '103.1,98.0,_',
#            'calt': 'AFTE pop. / resident pop.',
#            'id': 'f344'}]},
#         'r': '2020',
#         'c': 'AFTE population (annual full time equivalents)',
#         's': 'Idescat. Estimacions de població estacional (base 2016).',
#         'calt': 'Seasonal population',
#         'id': 't198',
#         'l': 'https://www.idescat.cat/pub/?id=epe&n=9522&geo=mun:080018&lang=en',
#         'updated': '2021-11-29T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Resident Students',
#            'v': '2475,141015,1237395',
#            'calt': 'Resident Students (School Age)',
#            'id': 'f380'},
#           {'c': 'Resident Students who study in the same municipality',
#            'u': '%',
#            'v': '71.5,79.2,82.8',
#            'calt': 'Resident Students who study in the same municipality',
#            'id': 'f381'}]},
#         'r': 'SY 2020/21',
#         'c': 'Statistics on Commuting for Non-University Studies',
#         's': "Idescat, a partir de les dades de la matrícula del Departament d'Educació.",
#         'calt': 'Commuting for Study Reasons',
#         'id': 't211',
#         'l': 'https://www.idescat.cat/pub/?id=emoesc&n=8809&geo=mun:080018&lang=en',
#         'updated': '2021-11-18T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Boys',
#            'v': '41,3001,29832',
#            'calt': 'Births. Boys',
#            'id': 'f185'},
#           {'c': 'Girls',
#            'v': '49,2908,28632',
#            'calt': 'Births. Girls',
#            'id': 'f186'},
#           {'c': 'Total',
#            'v': '90,5909,58464',
#            'calt': 'Births',
#            'id': 'f187'}]},
#         'r': '2020',
#         'c': 'Births. By sex',
#         's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#         'calt': 'Births',
#         'id': 't164',
#         'l': 'https://www.idescat.cat/pub/?id=naix&n=364&geo=mun:080018&lang=en',
#         'updated': '2022-01-17T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Men',
#            'v': '49,4031,39828',
#            'calt': 'Deaths. Men',
#            'id': 'f181'},
#           {'c': 'Women',
#            'v': '48,3898,39956',
#            'calt': 'Deaths. Women',
#            'id': 'f182'},
#           {'c': 'Total',
#            'v': '97,7929,79784',
#            'calt': 'Deaths',
#            'id': 'f188'}]},
#         'r': '2020',
#         'c': 'Deaths. By sex',
#         's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#         'calt': 'Deaths',
#         'id': 't165',
#         'l': 'https://www.idescat.cat/pub/?id=def&n=365&geo=mun:080018&lang=en',
#         'updated': '2021-12-10T11:00:00+00:00'},
#        {'ff': {'f': {'c': 'Total',
#           'v': '35,1731,15662',
#           'calt': 'Marriages',
#           'id': 'f179'}},
#         'r': '2020',
#         'c': 'Marriages',
#         's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#         'calt': 'Marriages',
#         'id': 't166',
#         'l': 'https://www.idescat.cat/pub/?id=mat&n=317&geo=mun:080018&lang=en',
#         'updated': '2022-01-17T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'One person',
#            'v': '861,57388,686810',
#            'calt': 'One person households',
#            'id': 'f98'},
#           {'c': 'Two people',
#            'v': '1258,92911,933679',
#            'calt': 'Two person households',
#            'id': 'f99'},
#           {'c': 'Three people',
#            'v': '1233,70884,631635',
#            'calt': 'Three person households',
#            'id': 'f100'},
#           {'c': 'Four people and over',
#            'v': '1098,78556,692821',
#            'calt': 'Four or more person households',
#            'id': 'f101'},
#           {'c': 'Total',
#            'v': '4450,299739,2944944',
#            'calt': 'Households',
#            'id': 'f107'}]},
#         'r': '2011',
#         'c': 'Households. By size',
#         's': "Idescat, based on the INE's Population and Housing Census.",
#         'calt': 'Size of the households',
#         'id': 't97',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=8274&geo=mun:080018&lang=en',
#         'updated': '2015-11-26T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'One person',
#            'v': '861,57388,686810',
#            'calt': 'One person households',
#            'id': 'f109'},
#           {'c': 'Couple without children',
#            'v': '1069,74040,725737',
#            'calt': 'Households with childless couple',
#            'id': 'f111'},
#           {'c': 'Couple with children',
#            'v': '2030,123072,1059975',
#            'calt': 'Househols with couples with children',
#            'id': 'f112'},
#           {'c': 'Father or mother with children',
#            'v': '349,31155,308995',
#            'calt': 'Single parent households',
#            'id': 'f113'},
#           {'c': 'Total',
#            'v': '4450,299739,2944944',
#            'calt': 'Households',
#            'id': 'f115'}]},
#         'r': '2011',
#         'c': 'Households. By type of nucleus',
#         's': "Idescat, based on the INE's Population and Housing Census.",
#         'calt': 'Type of households',
#         'id': 't108',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=531&geo=mun:080018&lang=en',
#         'updated': '2014-12-17T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Balance with Catalonia',
#            'v': '102,425,_',
#            'calt': 'Migrations (balance) with Catalonia',
#            'id': 'f322'},
#           {'c': 'Balance with Spain',
#            'v': '-41,-1527,-8971',
#            'calt': 'Migrations (balance) with Spain',
#            'id': 'f323'},
#           {'c': 'Internal migratory net balance',
#            'v': '61,-1102,-8971',
#            'calt': 'Internal migratory net balance',
#            'id': 'f324'}]},
#         'r': '2020',
#         'c': 'Internal migrations. Destination-origin balances',
#         's': "Idescat, based on the INE's Residential Variation Statistics.",
#         'calt': 'Internal migrations',
#         'id': 't196',
#         'l': 'https://www.idescat.cat/pub/?id=mm&n=223&geo=mun:080018&lang=en',
#         'updated': '2021-09-29T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Immigrations',
#            'v': '62,7860,118760',
#            'calt': 'External immigrations',
#            'id': 'f372'},
#           {'c': 'Emigrations',
#            'v': '52,4011,62236',
#            'calt': 'External emigrations',
#            'id': 'f373'}]},
#         'r': '2020',
#         'c': 'External migrations',
#         's': "Idescat, based on the INE's Residential Variation Statistics.",
#         'calt': 'External migrations',
#         'id': 't208',
#         'l': 'https://www.idescat.cat/pub/?id=mm&n=5489&geo=mun:080018&lang=en',
#         'updated': '2021-09-29T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Rest of EU',
#            'v': '7,943,17499',
#            'calt': 'Immigrations from the rest of EU',
#            'id': 'f314'},
#           {'c': 'Rest of the world',
#            'v': '55,6917,101261',
#            'calt': 'Immigrations from the rest of the world',
#            'id': 'f316'},
#           {'c': 'Total',
#            'v': '62,7860,118760',
#            'calt': 'External immigrations',
#            'id': 'f317'}]},
#         'r': '2020',
#         'c': 'External immigrations. By place of origin',
#         's': "Idescat, based on the INE's Residential Variation Statistics.",
#         'calt': 'External immigrations',
#         'id': 't194',
#         'l': 'https://www.idescat.cat/pub/?id=mm&n=487&geo=mun:080018&lang=en',
#         'updated': '2021-09-29T10:00:00+00:00'},
#        {'ff': {'f': [{'r': '2011',
#            'c': 'Population Growth',
#            'v': '3191,108833,1176733',
#            'calt': 'Intercensal Population Growth',
#            'id': 'f359'},
#           {'r': '2001-2011',
#            'c': 'Population Growth (annual average)',
#            'u': 'rate per 1,000 inhabitants',
#            'v': '31.23,14.56,16.98',
#            'calt': 'Intercensal Population Growth (annual average)',
#            'id': 'f360'},
#           {'r': '2001-2011',
#            'c': 'Natural Increase (annual average)',
#            'u': 'rate per 1,000 inhabitants',
#            'v': '9.33,5.84,3.04',
#            'calt': 'Intercensal Natural Increase Ratio (annual average)',
#            'id': 'f361'},
#           {'r': '2001-2011',
#            'c': 'Net Migration (annual average)',
#            'u': 'rate per 1,000 inhabitants',
#            'v': '21.9,8.72,13.94',
#            'calt': 'Intercensal Net Migration Ratio (annual average)',
#            'id': 'f362'}]},
#         'c': '2001-2011 Intercensal Population Growth',
#         's': 'Idescat.',
#         'calt': 'Intercensal Population Growth',
#         'id': 't202',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=97&geo=mun:080018&lang=en',
#         'updated': '2012-12-14T11:00:00+00:00'}]},
#      'c': 'Population',
#      'id': 'g168'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Understand',
#            'v': '10796,730102,6949344',
#            'calt': 'Population that understands Catalan',
#            'id': 'f91'},
#           {'c': 'Speak',
#            'v': '7703,526488,5345484',
#            'calt': 'Population that can speak Catalan',
#            'id': 'f92'},
#           {'c': 'Read',
#            'v': '8748,583523,5750348',
#            'calt': 'Population that can read Catalan',
#            'id': 'f93'},
#           {'c': 'Write',
#            'v': '6099,402912,4069219',
#            'calt': 'Population that can write Catalan',
#            'id': 'f94'},
#           {'c': 'Do not understand',
#            'v': '556,44446,356728',
#            'calt': "Population that doesn't understand Catalan",
#            'id': 'f95'},
#           {'c': 'Total',
#            'v': '11351,774549,7306072',
#            'calt': 'Population of 2 years and over',
#            'id': 'f96'}]},
#         'r': '2011',
#         'c': 'Population of 2 years and over. By knowledge of Catalan',
#         's': "Idescat, based on the INE's Population and Housing Census.",
#         'calt': 'Knowledge of Catalan',
#         'id': 't90',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=17&geo=mun:080018&lang=en',
#         'updated': '2013-11-21T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Public',
#            'v': '1,33,459',
#            'calt': 'Public libraries',
#            'id': 'f270'},
#           {'c': 'Others',
#            'v': '0,23,391',
#            'calt': 'Other libraries',
#            'id': 'f327'},
#           {'c': 'Total', 'v': '1,56,850', 'calt': 'Libraries', 'id': 'f177'}]},
#         'r': '2018',
#         'c': 'Libraries',
#         's': 'Idescat. Library Statistics.',
#         'calt': 'Libraries',
#         'id': 't156',
#         'l': 'https://www.idescat.cat/pub/?id=bib&n=327&geo=mun:080018&lang=en',
#         'updated': '2019-12-10T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Pavilions',
#            'v': '2,81,1005',
#            'calt': 'Pavilions',
#            'id': 'f293'},
#           {'c': 'Multisport courts',
#            'v': '9,765,8373',
#            'calt': 'Multisport courts',
#            'id': 'f294'},
#           {'c': 'Multisport fields',
#            'v': '2,134,2281',
#            'calt': 'Multisport fields',
#            'id': 'f295'},
#           {'c': 'Sports halls',
#            'v': '12,953,9152',
#            'calt': 'Sports halls',
#            'id': 'f296'},
#           {'c': 'Indoor swimming pools',
#            'v': '2,106,1097',
#            'calt': 'Indoor swimming pools',
#            'id': 'f301'},
#           {'c': 'Athelitcs tracks',
#            'v': '0,49,438',
#            'calt': 'Athelitcs tracks',
#            'id': 'f302'},
#           {'c': 'Other facilities',
#            'v': '42,2584,29001',
#            'calt': 'Other sports facilities',
#            'id': 'f299'},
#           {'c': 'Total',
#            'v': '69,4672,51347',
#            'calt': 'Sports facilities',
#            'id': 'f300'}]},
#         'r': '2021',
#         'c': 'Sports facilities',
#         's': "Idescat, based on data from the Consell Català de l'Esport.",
#         'calt': 'Sports facilities',
#         'id': 't175',
#         'l': 'https://www.idescat.cat/pub/?id=eesp&n=4332&geo=mun:080018&lang=en',
#         'updated': '2022-01-20T11:00:00+00:00'}]},
#      'c': 'Culture · Language',
#      'id': 'g172'},
#     {'tt': {'t': {'ff': {'f': [{'c': 'Primary education or lower',
#           'v': '16.9,17.3,17.7',
#           'calt': 'Primary education or lower',
#           'id': 'f386'},
#          {'c': 'First stage of secondary education',
#           'v': '30.5,27.6,27.4',
#           'calt': 'First stage of secondary education',
#           'id': 'f387'},
#          {'c': 'Second stage of secondary education',
#           'v': '25.8,24.1,23.2',
#           'calt': 'Second stage of secondary education',
#           'id': 'f388'},
#          {'c': 'Higher education',
#           'v': '26.9,31.0,31.8',
#           'calt': 'Higher education',
#           'id': 'f389'}]},
#        'r': '2019 (p)',
#        'c': 'Population aged 15 and over. By level of education attained',
#        's': 'Idescat. Educational Attainment Statistics.',
#        'u': '%',
#        'calt': 'Level of education attained',
#        'id': 't215',
#        'l': 'https://www.idescat.cat/pub/?id=eep&n=14540&geo=mun:080018&lang=en',
#        'updated': '2021-10-25T10:00:00+00:00'}},
#      'c': 'Education',
#      'id': 'g214'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Electors',
#            'v': '8851,592809,5376553',
#            'calt': 'Electors (Municipal elec.)',
#            'id': 'f266'},
#           {'c': 'Turnout',
#            'u': '%',
#            'v': '59.0,56.5,58.5',
#            'calt': 'Turnout (Municipal elec.)',
#            'id': 'f149'}]},
#         'r': '2015',
#         'c': 'Municipal elections',
#         's': 'Idescat, based on data from the Departament de Governació i Relacions Institucionals.',
#         'calt': 'Municipal elections',
#         'id': 't148',
#         'l': 'https://www.idescat.cat/pub/?id=elem&n=391&geo=mun:080018&lang=en',
#         'updated': '2016-10-03T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Electors',
#            'v': '8965,594817,5554455',
#            'calt': 'Electors ( Parliament of Catalonia)',
#            'id': 'f267'},
#           {'c': 'Turnout',
#            'u': '%',
#            'v': '85.3,83.2,79.1',
#            'calt': 'Turnout (Parliament Catalonia)',
#            'id': 'f254'}]},
#         'r': '2017',
#         'c': 'Elections to the Parliament of Catalonia',
#         's': 'Idescat i Departament de Polítiques Digitals i Administració Pública.',
#         'calt': 'Elections to the Parliament of Catalonia',
#         'id': 't189',
#         'l': 'https://www.idescat.cat/pub/?id=elepc&n=389&geo=mun:080018&lang=en',
#         'updated': '2018-11-23T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Electors',
#            'v': '8907,590248,5519912',
#            'calt': 'Electors (Congress)',
#            'id': 'f268'},
#           {'c': 'Turnout',
#            'u': '%',
#            'v': '70.9,67.9,63.4',
#            'calt': 'Turnout (Elec. Congress)',
#            'id': 'f255'}]},
#         'r': '2016',
#         'c': 'Elections to the Congress of Deputies',
#         's': 'Idescat, based on data from the Departament de Governació i Relacions Institucionals.',
#         'calt': 'Elections to the Congress of Deputies',
#         'id': 't190',
#         'l': 'https://www.idescat.cat/pub/?id=elecd&n=385&geo=mun:080018&lang=en',
#         'updated': '2017-10-27T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Turnout',
#            'u': '%',
#            'v': '47.3,46.6,47.6',
#            'calt': 'Turnout (Elec. European Parliament)',
#            'id': 'f256'},
#           {'c': 'Electors',
#            'v': '8806,586069,5318296',
#            'calt': 'Electors (Elec. European Parliament)',
#            'id': 'f269'}]},
#         'r': '2014 (p)',
#         'c': 'Elections to the European Parliament',
#         'calt': 'Elections to the European Parliament',
#         'id': 't191',
#         'l': 'https://www.idescat.cat/pub/?id=elepe&n=390&geo=mun:080018&lang=en',
#         'updated': '2015-10-07T10:00:00+00:00'}]},
#      'c': 'Elections',
#      'id': 'g174'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Employed population',
#            'v': '5192,329732,3033916',
#            'calt': 'Employed population',
#            'id': 'f221'},
#           {'c': 'Unemployed population',
#            'v': '1531,110493,1052138',
#            'calt': 'Unemployed population',
#            'id': 'f222'},
#           {'c': 'Active population',
#            'v': '6723,440225,4086055',
#            'calt': 'Active population',
#            'id': 'f223'},
#           {'c': 'Inactive population',
#            'v': '5078,353901,3386882',
#            'calt': 'Inactive population',
#            'id': 'f60'},
#           {'c': 'Population of 16 years and over',
#            'v': '9465,648580,6223448',
#            'calt': 'Population of 16 years and over',
#            'id': 'f224'}]},
#         'r': '2011',
#         'c': 'Population. By relation with economic activity',
#         's': "Idescat, based on the INE's Population and Housing Census.",
#         'calt': 'Relation with economic activity',
#         'id': 't56',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=270&geo=mun:080018&lang=en',
#         'updated': '2014-06-30T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Men',
#            'v': '3144,188960,1773542',
#            'calt': 'Men',
#            'id': 'f378'},
#           {'c': 'Women',
#            'v': '2617,171108,1563911',
#            'calt': 'Women',
#            'id': 'f379'},
#           {'c': 'Total',
#            'v': '5761,360068,3337453',
#            'calt': 'Contributors to Social Security according to the residence of the contributor',
#            'id': 'f377'}]},
#         'r': '02/2022',
#         'c': 'Contributors to Social Security according to the residence of the contributor',
#         's': 'Idescat.',
#         'calt': "Contributors to Social Security according to contributors's residence",
#         'id': 't210',
#         'l': 'https://www.idescat.cat/pub/?id=afi&n=8604&geo=mun:080018&lang=en',
#         'updated': '2022-03-11T11:00:00+00:00'},
#        {'ff': {'f': {'c': 'Total',
#           'v': '5947,375929,3508935',
#           'calt': 'Afiliations Social Security according residence',
#           'id': 'f363'}},
#         'r': '02/2022',
#         'c': 'Affiliations to Social Security according to the residence of the contributor',
#         's': 'Idescat.',
#         'calt': "Affiliations to Social Security according to contributor's residence",
#         'id': 't203',
#         'l': 'https://www.idescat.cat/pub/?id=afi&n=8598&geo=mun:080018&lang=en',
#         'updated': '2022-03-11T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Industry',
#            'v': '2699,49349,444816',
#            'calt': 'Industry affiliations to General SS',
#            'id': 'f278'},
#           {'c': 'Services',
#            'v': '3452,215667,2248270',
#            'calt': 'Services affiliations to General SS',
#            'id': 'f280'},
#           {'c': 'Total',
#            'v': '6508,283607,2845189',
#            'calt': 'Affiliations to General SS',
#            'id': 'f282'}]},
#         'r': '12/2021 (p)',
#         'c': 'Affiliations to S. S. general system according to the location of the affilation. By sectors',
#         's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#         'calt': 'Affiliations to general system according to location of affilation. By sectors',
#         'id': 't183',
#         'l': 'https://www.idescat.cat/pub/?id=afic&n=8270&geo=mun:080018&lang=en',
#         'updated': '2022-01-17T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Agriculture',
#            'v': '6,367,22038',
#            'calt': 'Affiliations contributors to Self-Employed SS',
#            'id': 'f229'},
#           {'c': 'Industry',
#            'v': '33,3320,38167',
#            'calt': 'Industry affiliations to Self-Employed SS',
#            'id': 'f288'},
#           {'c': 'Construction',
#            'v': '103,6888,69755',
#            'calt': 'Affiliations contributors to Self-Employed SS',
#            'id': 'f289'},
#           {'c': 'Services',
#            'v': '486,40309,428694',
#            'calt': 'Services afiliaciones to Self-Employed SS',
#            'id': 'f290'},
#           {'c': 'Total',
#            'v': '628,50884,558654',
#            'calt': 'Affiliations to Self-Employed SS',
#            'id': 'f291'}]},
#         'r': '12/2021 (p)',
#         'c': 'Affiliations to S. S. self-employed system according to the location of the affilation. By sectors',
#         's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#         'calt': 'Affiliations to self-employed system according to location of affilation. By sectors',
#         'id': 't184',
#         'l': 'https://www.idescat.cat/pub/?id=afic&n=8272&geo=mun:080018&lang=en',
#         'updated': '2022-01-17T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Up to 50 workers',
#            'v': '3006,117945,1236248',
#            'calt': 'Affiliations to SS centres with up to 50 workers',
#            'id': 'f225'},
#           {'c': 'From 51 to 250 workers',
#            'v': '2610,74718,661338',
#            'calt': 'Affiliations to SS centres with 51 to 250 workers',
#            'id': 'f284'},
#           {'c': 'From 251 workers and over',
#            'v': '892,90944,947603',
#            'calt': 'Affiliations to SS centres with 251 or more workers',
#            'id': 'f227'},
#           {'c': 'Total',
#            'v': '6508,283607,2845189',
#            'calt': 'Affiliations to General SS',
#            'id': 'f286'}]},
#         'r': '12/2021 (p)',
#         'c': 'Affiliations to S. S. general system according to the location of the affilation. By size of centre',
#         's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#         'calt': 'Affiliations to gen. system according to location of affilation. By size of the centre',
#         'id': 't185',
#         'l': 'https://www.idescat.cat/pub/?id=afic&n=8271&geo=mun:080018&lang=en',
#         'updated': '2022-01-17T11:00:00+00:00'},
#        {'ff': {'f': {'c': 'Total',
#           'v': '397,21074,243338',
#           'calt': 'Contributory accounts',
#           'id': 'f239'}},
#         'r': '12/2021 (p)',
#         'c': 'Contributory accounts',
#         's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#         'calt': 'Contributory accounts of Social Security',
#         'id': 't186',
#         'l': 'https://www.idescat.cat/pub/?id=afic&n=8273&geo=mun:080018&lang=en',
#         'updated': '2022-01-17T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Total',
#            'v': '2406,173022,1720098',
#            'calt': 'Contributory Social Security pensions',
#            'id': 'f375',
#            'updated': '2020-05-29T10:00:00+00:00'},
#           {'c': 'Average pension',
#            'u': 'euros',
#            'v': '1153.73,1098.23,1041.97',
#            'calt': 'Average contributory pension',
#            'id': 'f376',
#            'updated': '2020-05-29T10:00:00+00:00'}]},
#         'r': '2019',
#         'c': 'Contributory Social Security pensions. December',
#         's': '',
#         'calt': 'Contributory Social Security pensions',
#         'id': 't209',
#         'l': 'https://www.idescat.cat/pub/?id=pens&geo=mun:080018&lang=en'},
#        {'ff': {'f': [{'c': 'Men',
#            'v': '1178,79691,737855',
#            'calt': 'Men',
#            'id': 'f382'},
#           {'c': 'Women',
#            'v': '997,75881,775829',
#            'calt': 'Women',
#            'id': 'f383'},
#           {'c': 'Total',
#            'v': '2175,155572,1513684',
#            'calt': 'Total',
#            'id': 'f384'}]},
#         'r': '2019',
#         'c': 'Contributory Social Security Pensioners. By sex. December',
#         's': '',
#         'calt': 'Contributory Social Security Pensioners',
#         'id': 't212',
#         'l': 'https://www.idescat.cat/pub/?id=pens&n=10756&geo=mun:080018&lang=en',
#         'updated': '2020-05-29T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Agriculture',
#            'v': '7.2,251.8,9562.4',
#            'calt': 'Registered unemployment. Agriculture',
#            'id': 'f243'},
#           {'c': 'Industry',
#            'v': '80.2,4736.6,45324.2',
#            'calt': 'Registered unemployment. Industry',
#            'id': 'f303'},
#           {'c': 'Construction',
#            'v': '36.4,3312.8,33714.0',
#            'calt': 'Registered unemployment. Construction',
#            'id': 'f304'},
#           {'c': 'Services',
#            'v': '488.4,33019.1,320048.0',
#            'calt': 'Registered unemployment. Services',
#            'id': 'f305'},
#           {'c': 'Without previous employment',
#            'v': '23.6,2536.7,28517.0',
#            'calt': 'Registered unemployment (without previous employment)',
#            'id': 'f307'},
#           {'c': 'Total',
#            'v': '635.9,43856.9,437165.6',
#            'calt': 'Registered unemployment',
#            'id': 'f308'}]},
#         'r': '2021',
#         'c': 'Registered unemployment. By sectors',
#         's': 'Ministry of Business and Employment.',
#         'u': 'annual averages',
#         'calt': 'Registered unemployment by sectors',
#         'id': 't188',
#         'l': 'https://www.idescat.cat/pub/?id=atureg&n=4302&geo=mun:080018&lang=en',
#         'updated': '2022-01-13T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Men',
#            'v': '262.7,18734.7,191728.2',
#            'calt': 'Registered unemployment. Men',
#            'id': 'f240'},
#           {'c': 'Women',
#            'v': '373.2,25122.3,245437.3',
#            'calt': 'Registered unemployment. Women',
#            'id': 'f241'},
#           {'c': 'Total',
#            'v': '635.9,43856.9,437165.6',
#            'calt': 'Registered unemployment',
#            'id': 'f242'}]},
#         'r': '2021',
#         'c': 'Registered unemployment. By sex',
#         's': 'Ministry of Business and Employment.',
#         'u': 'annual averages',
#         'calt': 'Registered unemployment by sex',
#         'id': 't187',
#         'l': 'https://www.idescat.cat/pub/?id=atureg&n=4299&geo=mun:080018&lang=en',
#         'updated': '2022-01-13T11:00:00+00:00'}]},
#      'c': 'Labour',
#      'id': 'g169'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Main',
#            'v': '4450,299739,2944944',
#            'calt': 'Main family dwellings',
#            'id': 'f250'},
#           {'c': 'Secondary',
#            'v': '503,19769,470081',
#            'calt': 'Secondary family dwellings',
#            'id': 'f119'},
#           {'c': 'Vacant',
#            'v': '269,31381,448356',
#            'calt': 'Vacant family dwellings',
#            'id': 'f120'},
#           {'c': 'Total',
#            'v': '5222,350889,3863381',
#            'calt': 'Family dwellings',
#            'id': 'f122'}]},
#         'r': '2011',
#         'c': 'Family dwellings. By type',
#         's': "Idescat, based on the INE's Population and Housing Census.",
#         'calt': 'Type of dwellings',
#         'id': 't116',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=30&geo=mun:080018&lang=en',
#         'updated': '2013-12-19T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Rented',
#            'v': '335,42467,582701',
#            'calt': 'Rented main family homes',
#            'id': 'f128'},
#           {'c': 'Total',
#            'v': '4450,299739,2944944',
#            'calt': 'Main family homes',
#            'id': 'f131'}]},
#         'r': '2011',
#         'c': 'Main family dwellings. By type of tenancy',
#         's': "Idescat, based on the INE's Population and Housing Census.",
#         'calt': 'Type of tenancy of dwellings',
#         'id': 't124',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=310&geo=mun:080018&lang=en',
#         'updated': '2013-12-19T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'From 61 to 90 m²',
#            'v': '1975,164383,1476187',
#            'calt': 'Main family homes from 61 to 90 m²',
#            'id': 'f190'},
#           {'c': 'From 91 to 120 m²',
#            'v': '1324,48008,560379',
#            'calt': 'Main family homes from 91 to 120 m²',
#            'id': 'f191'},
#           {'c': 'From 121 m² and over',
#            'v': '939,30327,369412',
#            'calt': 'Main family homes from 121 m² and over',
#            'id': 'f192'},
#           {'c': 'Total',
#            'v': '4450,299739,2944944',
#            'calt': 'Main family homes',
#            'id': 'f193'}]},
#         'r': '2011',
#         'c': 'Main family dwellings. By useful surface area',
#         's': "Idescat, based on the INE's Population and Housing Census.",
#         'calt': 'Useful surface area of dwellings',
#         'id': 't177',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=7008&geo=mun:080018&lang=en',
#         'updated': '2013-12-19T11:00:00+00:00'},
#        {'ff': {'f': {'c': 'Small area socioeconòmic index',
#           'v': '104.1,103.9,100.0',
#           'calt': 'Small area socioeconòmic index',
#           'id': 'f385'}},
#         'r': '2018 (p)',
#         'c': 'Small area socioeconomic index (STI). Index Catalonia=100',
#         's': 'Idescat. Small Area Socioeconomic Index',
#         'u': 'Catalonia index=100',
#         'calt': 'STI',
#         'id': 't213',
#         'l': 'https://www.idescat.cat/pub/?id=ist&n=14034&geo=mun:080018&lang=en',
#         'updated': '2021-04-28T10:00:00+00:00'}]},
#      'c': 'Quality of life',
#      'id': 'g171'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'GDP',
#            'u': 'millions of euros',
#            'v': '649.2,28006.4,249900.5',
#            'calt': 'GDP',
#            'id': 'f2'},
#           {'c': 'GDP per capita',
#            'u': 'thousands of euros',
#            'v': '52.3,34.0,32.6',
#            'calt': 'GDP per capita',
#            'id': 'f3'},
#           {'c': 'GDP per capita',
#            'u': 'Catalonia index=100',
#            'v': '160.5,104.4,100.0',
#            'calt': 'GDP per capita (Catalonia=100)',
#            'id': 'f4'}]},
#         'r': '2019',
#         'c': 'Gross domestic product (2019 Benchmark revision)',
#         's': 'Idescat.',
#         'calt': 'GDP',
#         'id': 't1',
#         'l': 'https://www.idescat.cat/pub/?geo=mun:080018&id=pibc&n=13830#Plegable=geo&lang=en',
#         'updated': '2020-12-16T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Agriculture',
#            'v': '0.5,19.7,2197.8',
#            'calt': 'GVA agriculture',
#            'id': 'f194'},
#           {'c': 'Industry',
#            'v': '223.7,6616.9,44266.6',
#            'calt': 'GVA industry',
#            'id': 'f195'},
#           {'c': 'Construction',
#            'v': '17.8,1155.1,12140.5',
#            'calt': 'GVA construction',
#            'id': 'f196'},
#           {'c': 'Services',
#            'v': '353.8,17911.4,170742.4',
#            'calt': 'GAV services',
#            'id': 'f197'},
#           {'c': 'Total',
#            'v': '595.8,25703.0,229347.2',
#            'calt': 'GVA',
#            'id': 'f251'}]},
#         'r': '2019',
#         'c': 'Gross value added (2019 Benchmark revision). By sectors',
#         's': 'Idescat.',
#         'u': 'millions of euros',
#         'calt': 'GVA',
#         'id': 't178',
#         'l': 'https://www.idescat.cat/pub/?id=pibc&n=13831&geo=mun:080018&lang=en',
#         'updated': '2021-12-15T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'GDHI',
#            'u': 'thousands of euros',
#            'v': '217630,14909650,133679103',
#            'calt': 'GDHI',
#            'id': 'f6'},
#           {'c': 'GDHI per capita',
#            'u': 'thousands of euros',
#            'v': '17.7,18.3,17.6',
#            'calt': 'GDHI per capita',
#            'id': 'f7'},
#           {'c': 'GDHI per capita',
#            'u': 'Catalonia index=100',
#            'v': '100.3,103.7,100.0',
#            'calt': 'GDHI per capita (Catalonia=100)',
#            'id': 'f8'}]},
#         'r': '2018',
#         'c': 'Gross disposable household income. 2019 Benchmark revision',
#         's': 'Idescat.',
#         'calt': 'Disposable household income',
#         'id': 't5',
#         'l': 'https://www.idescat.cat/pub/?id=rfdbc&n=13301&geo=mun:080018&lang=en',
#         'updated': '2021-04-30T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Number of receipts',
#            'v': '7311,530560,5855886',
#            'calt': 'IBI. Receipts',
#            'id': 'f198'},
#           {'c': 'Taxable base by receipt',
#            'u': 'euros',
#            'v': '77450.8,84237.4,70537.2',
#            'calt': 'IBI. Taxable base by receipt',
#            'id': 'f199'},
#           {'c': 'Integral quota by receipt',
#            'u': 'euros',
#            'v': '625.5,530.1,485.9',
#            'calt': 'IBI. Integral quota by receipt',
#            'id': 'f200'}]},
#         'r': '2020',
#         'c': 'Urban property tax (IBI)',
#         's': 'Idescat, based on data from the Dirección General del Catastro.',
#         'calt': 'Urban property tax',
#         'id': 't179',
#         'l': 'https://www.idescat.cat/pub/?id=ibi&n=173&geo=mun:080018&lang=en',
#         'updated': '2021-06-29T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Taxable base by declarer',
#            'v': '24636,25950,24984',
#            'calt': 'IRPF. Taxable base by declarer',
#            'id': 'f10'},
#           {'c': 'Resulting quota from self-payment by declarer',
#            'v': '5680,7105,7193',
#            'calt': 'IRPF. Resulting quotafrom self-payment by declarer',
#            'id': 'f11'}]},
#         'r': '2019',
#         'c': 'Personal Income Tax (IRPF)',
#         's': "Idescat, based on data from the Agència Estatal d'Administració Tributària.",
#         'u': 'euros',
#         'calt': 'Personal Income Tax',
#         'id': 't9',
#         'l': 'https://www.idescat.cat/pub/?id=irpf&n=4070&geo=mun:080018&lang=en',
#         'updated': '2021-11-26T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Total weath by declarer',
#            'u': 'euros',
#            'v': '368165,475679,516035',
#            'calt': 'IPPF. Total wealth per declarer',
#            'id': 'f180'},
#           {'c': 'Real assets',
#            'u': '%',
#            'v': '37.5,45.3,37.4',
#            'calt': 'IPPF. Declaration of real assets',
#            'id': 'f202'},
#           {'c': 'Financial assets',
#            'u': '%',
#            'v': '62.5,54.7,62.6',
#            'calt': 'IPPF. Declaration of financial assets',
#            'id': 'f203'}]},
#         'r': '2007',
#         'c': 'Wealth tax (IPPF)',
#         's': "Idescat, based on data from the Agència Estatal d'Administració Tributària.",
#         'calt': 'Wealth tax',
#         'id': 't167',
#         'l': 'https://www.idescat.cat/pub/?id=ippf&n=382&geo=mun:080018&lang=en',
#         'updated': '2010-06-11T10:00:00+00:00'}]},
#      'c': 'Main aggregates · Public sector finance',
#      'id': 'g163'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Cultivated land',
#            'v': '211,3092,792425',
#            'calt': 'Cultivated land surface',
#            'id': 'f133'},
#           {'c': 'Permanent pasture',
#            'v': '310,530,355107',
#            'calt': 'Permanent pasture surface',
#            'id': 'f134'},
#           {'c': 'Total',
#            'v': '521,3622,1147532',
#            'calt': 'Used agricultural area',
#            'id': 'f345'}]},
#         'r': '2009',
#         'c': 'Used agricultural area (UAA)',
#         's': '',
#         'u': 'hectares',
#         'calt': 'Used agricultural area',
#         'id': 't132',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=5173&geo=mun:080018&lang=en',
#         'updated': '2012-04-04T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Herbaceous crops',
#            'v': '145,1627,511150',
#            'calt': 'Herbaceous crops',
#            'id': 'f346'},
#           {'c': 'Fruit trees',
#            'v': '19,748,110819',
#            'calt': 'Fruit trees crops',
#            'id': 'f347'},
#           {'c': 'Olives',
#            'v': '16,296,101236',
#            'calt': 'Olives crops',
#            'id': 'f348'},
#           {'c': 'Vines',
#            'v': '31,410,61391',
#            'calt': 'Vines crops',
#            'id': 'f349'},
#           {'c': 'Others',
#            'v': '0,11,7829',
#            'calt': 'Other crops',
#            'id': 'f350'},
#           {'c': 'Total',
#            'v': '211,3092,792425',
#            'calt': 'Cultivated land',
#            'id': 'f351'}]},
#         'r': '2009',
#         'c': 'Cultivated land. By type of crop',
#         's': '',
#         'u': 'hectares',
#         'calt': 'Cultivated land',
#         'id': 't199',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=5084&geo=mun:080018&lang=en',
#         'updated': '2012-03-20T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Without land',
#            'v': '1,12,1519',
#            'calt': 'Farms without land',
#            'id': 'f352'},
#           {'c': 'With land',
#            'v': '13,601,59320',
#            'calt': 'Farms with land',
#            'id': 'f353'},
#           {'c': 'Total',
#            'v': '14,613,60839',
#            'calt': 'Farms with and without land',
#            'id': 'f356'}]},
#         'r': '2009',
#         'c': 'Farms. By land ownership',
#         's': '',
#         'calt': 'Land ownership',
#         'id': 't200',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=5172&geo=mun:080018&lang=en',
#         'updated': '2012-04-04T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Without livestock',
#            'v': '10,557,47172',
#            'calt': 'Farms without livestock',
#            'id': 'f139'},
#           {'c': 'With livestock',
#            'v': '4,56,13667',
#            'calt': 'Farms with livestock',
#            'id': 'f204'},
#           {'c': 'Total',
#            'v': '14,613,60839',
#            'calt': 'Farms with and without livestock',
#            'id': 'f138'}]},
#         'r': '2009',
#         'c': 'Farms. By livestock ownership',
#         's': '',
#         'calt': 'Livestock ownership',
#         'id': 't137',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=5172&geo=mun:080018&lang=en',
#         'updated': '2012-04-04T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Bovine',
#            'v': '593,624,544135',
#            'calt': 'Bovine head',
#            'id': 'f141'},
#           {'c': 'Ovine',
#            'v': '656,5420,600082',
#            'calt': 'Ovine head',
#            'id': 'f142'},
#           {'c': 'Caprine',
#            'v': '84,787,71748',
#            'calt': 'Caprine head',
#            'id': 'f252'},
#           {'c': 'Porcine',
#            'v': '0,952,6742638',
#            'calt': 'Porcine head',
#            'id': 'f144'},
#           {'c': 'Avian',
#            'v': '33,7900,43890563',
#            'calt': 'Avian head',
#            'id': 'f145'},
#           {'c': 'Female rabbits',
#            'v': '0,841,335054',
#            'calt': 'Female rabbits head',
#            'id': 'f146'},
#           {'c': 'Equine',
#            'v': '0,450,19352',
#            'calt': 'Equine head',
#            'id': 'f147'}]},
#         'r': '2009',
#         'c': 'Head of livestock. By species',
#         's': '',
#         'calt': 'Head of livestock',
#         'id': 't140',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=5107&geo=mun:080018&lang=en',
#         'updated': '2012-04-04T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'State subsidised housing starts',
#            'v': '0,426,1903',
#            'calt': 'State subsidised housing starts',
#            'id': 'f13'},
#           {'c': 'Housing starts',
#            'v': '94,1378,11395',
#            'calt': 'Housing starts',
#            'id': 'f14'}]},
#         'r': '2020',
#         'c': 'Housing construction',
#         's': "Idescat, based on data from the Departament de Territori i Sostenibilitat. Secretaria d'Habitatge i Millora Urbana.",
#         'calt': 'Housing construction',
#         'id': 't12',
#         'l': 'https://www.idescat.cat/pub/?id=habit&n=86&geo=mun:080018&lang=en',
#         'updated': '2021-04-28T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Hotels',
#            'v': '1,86,3083',
#            'calt': 'Hotels',
#            'id': 'f215',
#            'updated': '2021-07-01T10:00:00+00:00'},
#           {'c': 'Hotel beds',
#            'v': '39,10822,318954',
#            'calt': 'Hotel beds',
#            'id': 'f216',
#            'updated': '2021-07-01T10:00:00+00:00'},
#           {'c': 'Campsites',
#            'v': '0,2,351',
#            'calt': 'Campsites',
#            'id': 'f217',
#            'updated': '2021-07-01T10:00:00+00:00'},
#           {'c': 'Campsite places',
#            'v': '0,3042,262346',
#            'calt': 'Campsite places',
#            'id': 'f218',
#            'updated': '2021-07-01T10:00:00+00:00'},
#           {'c': 'Rural tourism',
#            'v': '0,3,2514',
#            'calt': 'Rural tourism',
#            'id': 'f219',
#            'updated': '2021-07-01T10:00:00+00:00'},
#           {'c': 'Rural tourism beds',
#            'v': '0,29,20190',
#            'calt': 'Rural tourism beds',
#            'id': 'f220',
#            'updated': '2021-07-01T10:00:00+00:00'}]},
#         'r': '2020',
#         'c': 'Tourist accommodation',
#         's': 'Idescat, based on data from the Ministry of Business and Labour.',
#         'calt': 'Tourist accommodation',
#         'id': 't182',
#         'l': 'https://www.idescat.cat/pub/?id=turall&geo=mun:080018&lang=en'},
#        {'ff': {'f': [{'c': 'Estate cars',
#            'v': '7153,376998,3554258',
#            'calt': 'Cars',
#            'id': 'f19'},
#           {'c': 'Motorcycles',
#            'v': '1302,88175,882094',
#            'calt': 'Motorcycles',
#            'id': 'f325'},
#           {'c': 'Industrial vehicles',
#            'v': '1280,66090,779051',
#            'calt': 'Industrial vehicles',
#            'id': 'f272'},
#           {'c': 'Others',
#            'v': '872,15535,172003',
#            'calt': 'Other  vehicles',
#            'id': 'f326'},
#           {'c': 'Total',
#            'v': '10607,546798,5387406',
#            'calt': 'Fleet of vehicles',
#            'id': 'f163'}]},
#         'r': '2020',
#         'c': 'Fleet of vehicles',
#         's': 'Idescat, based on data from the DGT.',
#         'calt': 'Fleet of vehicles',
#         'id': 't18',
#         'l': 'https://www.idescat.cat/pub/?id=parcc&n=291&geo=mun:080018&lang=en',
#         'updated': '2021-09-22T10:00:00+00:00'}]},
#      'c': 'Economic sectors',
#      'id': 'g170'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Generation per capita',
#            'u': 'kg/inhab./day',
#            'v': '1.41,1.28,1.40',
#            'calt': 'Municipal waste per capita',
#            'id': 'f366'},
#           {'c': 'Selective collection',
#            'u': '%',
#            'v': '26.6,42.0,45.9',
#            'calt': 'Selective collection of municipal waste',
#            'id': 'f368'}]},
#         'r': '2020',
#         'c': 'Municipal waste',
#         's': 'The Waste Agency of Catalonia.',
#         'calt': 'Municipal waste',
#         'id': 't204',
#         'l': 'https://www.idescat.cat/pub/?id=resmc&n=6997&geo=mun:080018&lang=en',
#         'updated': '2022-02-14T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Establishments with yearly waste declarations',
#            'v': '59,1778,15740',
#            'calt': 'Establishments with yearly ind. waste declarations',
#            'id': 'f371'},
#           {'c': 'Industrial waste',
#            'u': 'tonnes',
#            'v': '63678.95,382064.46,3812262.98',
#            'calt': 'Industrial waste',
#            'id': 'f369'}]},
#         'r': '2019',
#         'c': 'Industrial waste',
#         's': 'The Waste Agency of Catalonia.',
#         'calt': 'Industrial waste',
#         'id': 't207',
#         'l': 'https://www.idescat.cat/pub/?id=resic&n=7083&geo=mun:080018&lang=en',
#         'updated': '2021-05-04T10:00:00+00:00'}]},
#      'c': 'Environment',
#      'id': 'g205'}]},
#   'lang': 'en',
#   'version': '1.00',
#   'cols': {'col': [{'scheme': 'mun', 'id': '080018', 'content': 'Abrera'},
#     {'scheme': 'com', 'id': '11', 'content': 'Baix Llobregat'},
#     {'scheme': 'ca', 'id': '09', 'content': 'Catalunya'}]},
#   'o': 'dades'}}

# %%
def request_mun(mun_id):
    mun_res = requests.get("https://api.idescat.cat/emex/v1/dades.json?id={}&lang=en".format(mun_id))
    return mun_res.json()
   

def create_meta_municipalities():
    """
    Retrieves dictionairy containing all municipalities from the idescat. Structure of the dict:
        key: id of the mun
        value: name of the mun
    """
    meta = {}
    mun_res = requests.get("https://api.idescat.cat/emex/v1/dades.json?lang=en")
    mun_meta = mun_res.json()
    muns = mun_meta['fitxes']['cols']['col']
    for mun in muns:
        meta[mun['id']] = mun['content']
        
    return meta


def collect_all_muns(meta, n):
    """
    Collects all the data of each municipality, making a request every n seconds
    """
    
    start_time = time.time()
    municipality_dict = {}
    i = 0
    for identifier in meta.keys():
        
        municipality_dict[identifier] = request_mun(identifier)
        time.sleep(n)
        i += 1
        if i == 10:
            break
    
    print("Retrieved data of {} municipalities in {} seconds".format(i ,int(time.time()-start_time)))
    return municipality_dict

# %%
testmeta = create_meta_municipalities()

# %%
test = collect_all_muns(testmeta, 0.2)
# Out:
# Retrieved data of 10 municipalities in 4 seconds

# %%
with open("test.json", 'w') as file:
    json.dump(test['250019'], file)

# %%
pd.read_json('test.json')
# Out:
#                                                    250019  \
# fitxes  {'p': 'id=250019', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    80018   \
# fitxes  {'p': 'id=080018', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    250024  \
# fitxes  {'p': 'id=250024', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    250030  \
# fitxes  {'p': 'id=250030', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    80023   \
# fitxes  {'p': 'id=080023', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    170010  \
# fitxes  {'p': 'id=170010', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    80142   \
# fitxes  {'p': 'id=080142', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    430017  \
# fitxes  {'p': 'id=430017', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    170025  \
# fitxes  {'p': 'id=170025', 'gg': {'g': [{'tt': {'t': {...
#
#                                                    250387
# fitxes  {'p': 'id=250387', 'gg': {'g': [{'tt': {'t': {...

# %%
pd.json_normalize(test['250024']['fitxes']['gg']['g'], max_level=10)
# Out:
#                                          c    id  \
# 0                                Territory  g173
# 1                               Population  g168
# 2                       Culture · Language  g172
# 3                                Education  g214
# 4                                Elections  g174
# 5                                   Labour  g169
# 6                          Quality of life  g171
# 7  Main aggregates · Public sector finance  g163
# 8                         Economic sectors  g170
# 9                              Environment  g205
#
#                                            tt.t.ff.f  \
# 0  [{'r': '2021', 'c': 'Surface area', 'u': 'km²'...
# 1                                                NaN
# 2                                                NaN
# 3  [{'c': 'Primary education or lower', 'v': '23....
# 4                                                NaN
# 5                                                NaN
# 6  [{'c': 'Main', 'v': '259,15288,2944944', 'calt...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                               tt.t.c tt.t.id  \
# 0                              Geographic indicators    t176
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3  Population aged 15 and over. By level of educa...    t215
# 4                                                NaN     NaN
# 5                                                NaN     NaN
# 6                          Family dwellings. By type    t116
# 7                                                NaN     NaN
# 8                                                NaN     NaN
# 9                                                NaN     NaN
#
#                                               tt.t.l  \
# 0  https://www.idescat.cat/pub/?id=inddt&n=396&ge...
# 1                                                NaN
# 2                                                NaN
# 3  https://www.idescat.cat/pub/?id=eep&n=14540&ge...
# 4                                                NaN
# 5                                                NaN
# 6  https://www.idescat.cat/pub/?id=censph&n=30&ge...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                                 tt.t    tt.t.r  \
# 0                                                NaN       NaN
# 1  [{'ff': {'f': [{'c': 'Surface area', 'u': 'km²...       NaN
# 2  [{'ff': {'f': [{'c': 'Understand', 'v': '508,3...       NaN
# 3                                                NaN  2019 (p)
# 4  [{'ff': {'f': [{'c': 'Electors', 'v': '505,280...       NaN
# 5  [{'ff': {'f': [{'c': 'Men', 'v': '139,9307,177...       NaN
# 6                                                NaN      2011
# 7  [{'ff': {'f': [{'c': 'Number of receipts', 'v'...       NaN
# 8  [{'ff': {'f': [{'c': 'Cultivated land', 'v': '...       NaN
# 9  [{'ff': {'f': [{'c': 'Generation per capita', ...       NaN
#
#                                               tt.t.s tt.t.u  \
# 0                                                NaN    NaN
# 1                                                NaN    NaN
# 2                                                NaN    NaN
# 3        Idescat. Educational Attainment Statistics.      %
# 4                                                NaN    NaN
# 5                                                NaN    NaN
# 6  Idescat, based on the INE's Population and Hou...    NaN
# 7                                                NaN    NaN
# 8                                                NaN    NaN
# 9                                                NaN    NaN
#
#                      tt.t.calt               tt.t.updated
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3  Level of education attained  2021-10-25T10:00:00+00:00
# 4                          NaN                        NaN
# 5                          NaN                        NaN
# 6            Type of dwellings  2013-12-19T11:00:00+00:00
# 7                          NaN                        NaN
# 8                          NaN                        NaN
# 9                          NaN                        NaN

# %%
print("amount of lists in the first layer of the complicated json: " + str(len(test['250019']['fitxes']['gg']['g'])))
total = 0
for i in range(0,10):
    print("lenght of the list in the second layer of the complicated json: "+ str(len(test['250019']['fitxes']['gg']['g'][i]['tt']['t'])))
    total += len(test['250019']['fitxes']['gg']['g'][i]['tt']['t'])
    
print(total)
# Out:
# amount of lists in the first layer of the complicated json: 10
# lenght of the list in the second layer of the complicated json: 4
# lenght of the list in the second layer of the complicated json: 18
# lenght of the list in the second layer of the complicated json: 3
# lenght of the list in the second layer of the complicated json: 9
# lenght of the list in the second layer of the complicated json: 3
# lenght of the list in the second layer of the complicated json: 10
# lenght of the list in the second layer of the complicated json: 8
# lenght of the list in the second layer of the complicated json: 2
# lenght of the list in the second layer of the complicated json: 8
# lenght of the list in the second layer of the complicated json: 2
# 67

# %%
test['250019']['fitxes']['gg']['g'][1]['tt']['t'][1]['ff']['f'][1]['v']
# Out:
# '82,6460,3943531'

# %%
test['250019']['fitxes']['gg']['g'][1]['tt']['t'][1]['c']
# Out:
# 'Population. By sex'

# %%
test['250019']['fitxes']['gg']['g']
# Out:
# [{'tt': {'t': {'ff': {'f': [{'r': '2021',
#        'c': 'Surface area',
#        'u': 'km²',
#        'v': '78.27,1343.09,32108.00',
#        'calt': 'Surface area',
#        'id': 'f271',
#        'updated': '2021-12-23T11:00:00+00:00'},
#       {'r': '2013',
#        'c': 'Altitude',
#        'u': 'm',
#        'v': '956,_,_',
#        'calt': 'Altitude',
#        'id': 'f258',
#        'updated': '2014-02-17T11:00:00+00:00'},
#       {'r': '2013',
#        'c': 'Longitude',
#        'u': 'º',
#        'v': '1.092892,_,_',
#        'calt': 'Longitude',
#        'id': 'f328',
#        'updated': '2014-02-17T11:00:00+00:00'},
#       {'r': '2013',
#        'c': 'Latitude',
#        'u': 'º',
#        'v': '42.162392,_,_',
#        'calt': 'Latitude',
#        'id': 'f329',
#        'updated': '2014-02-17T11:00:00+00:00'},
#       {'r': '2013',
#        'c': 'UTM coordinates x',
#        'u': 'm',
#        'v': '342450,_,_',
#        'calt': 'UTM coordinates x',
#        'id': 'f259',
#        'updated': '2014-02-17T11:00:00+00:00'},
#       {'r': '2013',
#        'c': 'UTM coordinates y',
#        'u': 'm',
#        'v': '4669650,_,_',
#        'calt': 'UTM coordinates y',
#        'id': 'f260',
#        'updated': '2014-02-17T11:00:00+00:00'}]},
#     'c': 'Geographic indicators',
#     'id': 't176',
#     'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:250019&lang=en'}},
#   'c': 'Territory',
#   'id': 'g173'},
#  {'tt': {'t': [{'ff': {'f': [{'c': 'Surface area',
#         'u': 'km²',
#         'v': '78.27,1343.09,32108.00',
#         'calt': 'Surface area',
#         'id': 'f261'},
#        {'c': 'Density',
#         'u': 'inh./km²',
#         'v': '2.2,9.8,241.8',
#         'calt': 'Density',
#         'id': 'f262'}]},
#      'r': '2021',
#      'c': 'Density of population',
#      'calt': 'Density',
#      'id': 't192',
#      'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:250019&lang=en',
#      'updated': '2021-12-23T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Men',
#         'v': '89,6710,3819831',
#         'calt': 'Men',
#         'id': 'f318'},
#        {'c': 'Women', 'v': '82,6460,3943531', 'calt': 'Women', 'id': 'f320'},
#        {'c': 'Total',
#         'v': '171,13170,7763362',
#         'calt': 'Population',
#         'id': 'f321'}]},
#      'r': '2021',
#      'c': 'Population. By sex',
#      's': 'Idescat, from the Continuous Register Statistic of INE.',
#      'calt': 'Sex',
#      'id': 't195',
#      'l': 'https://www.idescat.cat/pub/?id=pmh&n=446&geo=mun:250019&lang=en',
#      'updated': '2022-02-28T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'From 0 to 14 years',
#         'v': '16,1573,1139260',
#         'calt': 'Population from 0 to 14 years',
#         'id': 'f167'},
#        {'c': 'From 15 to 64 years',
#         'v': '110,8200,5145431',
#         'calt': 'Population from 15 to 64 years',
#         'id': 'f27'},
#        {'c': 'From 65 to 84 years',
#         'v': '33,2523,1228528',
#         'calt': 'Population from 65 to 84 years',
#         'id': 'f28'},
#        {'c': 'From 85 years and over',
#         'v': '12,874,250143',
#         'calt': 'Population from 85 years and over',
#         'id': 'f29'},
#        {'c': 'Total',
#         'v': '171,13170,7763362',
#         'calt': 'Population',
#         'id': 'f171'}]},
#      'r': '2021',
#      'c': 'Population. By age groups',
#      's': 'Idescat, from the Continuous Register Statistic of INE.',
#      'calt': 'Age groups',
#      'id': 't25',
#      'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:250019&lang=en',
#      'updated': '2022-02-28T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'From 0 to 14 years',
#         'v': '8,811,586182',
#         'calt': 'Men from 0 to 14 years',
#         'id': 'f176'},
#        {'c': 'From 15 to 64 years',
#         'v': '59,4334,2598440',
#         'calt': 'Men from 15 to 64 years',
#         'id': 'f33'},
#        {'c': 'From 65 to 84 years',
#         'v': '14,1242,552061',
#         'calt': 'Men from 65 to 84 years',
#         'id': 'f34'},
#        {'c': 'From 85 years and over',
#         'v': '8,323,83148',
#         'calt': 'Men from 85 years and over',
#         'id': 'f35'},
#        {'c': 'Total', 'v': '89,6710,3819831', 'calt': 'Men', 'id': 'f36'}]},
#      'r': '2021',
#      'c': 'Population. By age groups. Men',
#      's': 'Idescat, from the Continuous Register Statistic of INE.',
#      'calt': 'Age groups. Men',
#      'id': 't31',
#      'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:250019&lang=en',
#      'updated': '2022-02-28T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'From 0 to 14 years',
#         'v': '8,762,553078',
#         'calt': 'Women from 0 to 14 years',
#         'id': 'f38'},
#        {'c': 'From 15 to 64 years',
#         'v': '51,3866,2546991',
#         'calt': 'Women from 15 to 64 years',
#         'id': 'f39'},
#        {'c': 'From 65 to 84 years',
#         'v': '19,1281,676467',
#         'calt': 'Women from 65 to 84 years',
#         'id': 'f40'},
#        {'c': 'From 85 years and over',
#         'v': '4,551,166995',
#         'calt': 'Women from 85 years and over',
#         'id': 'f41'},
#        {'c': 'Total', 'v': '82,6460,3943531', 'calt': 'Women', 'id': 'f42'}]},
#      'r': '2021',
#      'c': 'Population. By age groups. Women',
#      's': 'Idescat, from the Continuous Register Statistic of INE.',
#      'calt': 'Age groups. Women',
#      'id': 't37',
#      'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:250019&lang=en',
#      'updated': '2022-02-28T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Catalonia',
#         'v': '143,9619,4952278',
#         'calt': 'Population born in Catalonia',
#         'id': 'f69'},
#        {'c': 'Rest of Spain',
#         'v': '8,1271,1212621',
#         'calt': 'Population born in rest of Spain',
#         'id': 'f72'},
#        {'c': 'Abroad',
#         'v': '20,2280,1598463',
#         'calt': 'Population born abroad',
#         'id': 'f73'},
#        {'c': 'Total',
#         'v': '171,13170,7763362',
#         'calt': 'Population',
#         'id': 'f74'}]},
#      'r': '2021',
#      'c': 'Population. By place of birth',
#      's': 'Idescat, from the Continuous Register Statistic of INE.',
#      'calt': 'Place of birth',
#      'id': 't68',
#      'l': 'https://www.idescat.cat/pub/?id=pmh&n=674&geo=mun:250019&lang=en',
#      'updated': '2022-02-28T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Spanish',
#         'v': '151,11350,6512697',
#         'calt': 'Population with Spanish nationality',
#         'id': 'f183'},
#        {'c': 'Foreign',
#         'v': '20,1820,1250665',
#         'calt': 'Population with foreign nationality',
#         'id': 'f184'},
#        {'c': 'Total',
#         'v': '171,13170,7763362',
#         'calt': 'Population',
#         'id': 'f263'}]},
#      'r': '2021',
#      'c': 'Population. By nationality',
#      's': 'Idescat, from the Continuous Register Statistic of INE.',
#      'calt': 'Nationality',
#      'id': 't75',
#      'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:250019&lang=en',
#      'updated': '2022-02-28T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Spanish',
#         'v': '79,5736,3172812',
#         'calt': 'Men with Spanish nationality',
#         'id': 'f178'},
#        {'c': 'Foreign',
#         'v': '10,974,647019',
#         'calt': 'Men with foreign nationality',
#         'id': 'f77'},
#        {'c': 'Total', 'v': '89,6710,3819831', 'calt': 'Men', 'id': 'f264'}]},
#      'r': '2021',
#      'c': 'Population. By nationality. Men',
#      's': 'Idescat, from the Continuous Register Statistic of INE.',
#      'calt': 'Nationality. Men',
#      'id': 't78',
#      'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:250019&lang=en',
#      'updated': '2022-02-28T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Spanish',
#         'v': '72,5614,3339885',
#         'calt': 'Women with Spanish nationality',
#         'id': 'f82'},
#        {'c': 'Foreign',
#         'v': '10,846,603646',
#         'calt': 'Women with foreign nationality',
#         'id': 'f83'},
#        {'c': 'Total', 'v': '82,6460,3943531', 'calt': 'Women', 'id': 'f265'}]},
#      'r': '2021',
#      'c': 'Population. By nationality. Women',
#      's': 'Idescat, from the Continuous Register Statistic of INE.',
#      'calt': 'Nationality. Women',
#      'id': 't81',
#      'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:250019&lang=en',
#      'updated': '2022-02-28T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Men',
#         'v': '25,608,172716',
#         'calt': 'Men resident abroad',
#         'id': 'f334'},
#        {'c': 'Women',
#         'v': '32,625,167798',
#         'calt': 'Women resident abroad',
#         'id': 'f335'},
#        {'c': 'Total',
#         'v': '57,1233,340514',
#         'calt': 'Population resident abroad',
#         'id': 'f336'}]},
#      'r': '2021',
#      'c': 'Population resident abroad on 1 January. By sex',
#      's': '',
#      'calt': 'Population resident abroad',
#      'id': 't197',
#      'l': 'https://www.idescat.cat/pub/?id=phre&n=3697&geo=mun:250019&lang=en',
#      'updated': '2021-04-22T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Resident Students',
#         'v': '30,1865,1237395',
#         'calt': 'Resident Students (School Age)',
#         'id': 'f380'},
#        {'c': 'Resident Students who study in the same municipality',
#         'u': '%',
#         'v': '0.0,75.6,82.8',
#         'calt': 'Resident Students who study in the same municipality',
#         'id': 'f381'}]},
#      'r': 'SY 2020/21',
#      'c': 'Statistics on Commuting for Non-University Studies',
#      's': "Idescat, a partir de les dades de la matrícula del Departament d'Educació.",
#      'calt': 'Commuting for Study Reasons',
#      'id': 't211',
#      'l': 'https://www.idescat.cat/pub/?id=emoesc&n=8809&geo=mun:250019&lang=en',
#      'updated': '2021-11-18T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Boys',
#         'v': '0,39,29832',
#         'calt': 'Births. Boys',
#         'id': 'f185'},
#        {'c': 'Girls',
#         'v': '1,33,28632',
#         'calt': 'Births. Girls',
#         'id': 'f186'},
#        {'c': 'Total', 'v': '1,72,58464', 'calt': 'Births', 'id': 'f187'}]},
#      'r': '2020',
#      'c': 'Births. By sex',
#      's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#      'calt': 'Births',
#      'id': 't164',
#      'l': 'https://www.idescat.cat/pub/?id=naix&n=364&geo=mun:250019&lang=en',
#      'updated': '2022-01-17T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Men',
#         'v': '0,108,39828',
#         'calt': 'Deaths. Men',
#         'id': 'f181'},
#        {'c': 'Women',
#         'v': '0,113,39956',
#         'calt': 'Deaths. Women',
#         'id': 'f182'},
#        {'c': 'Total', 'v': '0,221,79784', 'calt': 'Deaths', 'id': 'f188'}]},
#      'r': '2020',
#      'c': 'Deaths. By sex',
#      's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#      'calt': 'Deaths',
#      'id': 't165',
#      'l': 'https://www.idescat.cat/pub/?id=def&n=365&geo=mun:250019&lang=en',
#      'updated': '2021-12-10T11:00:00+00:00'},
#     {'ff': {'f': {'c': 'Total',
#        'v': '0,20,15662',
#        'calt': 'Marriages',
#        'id': 'f179'}},
#      'r': '2020',
#      'c': 'Marriages',
#      's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#      'calt': 'Marriages',
#      'id': 't166',
#      'l': 'https://www.idescat.cat/pub/?id=mat&n=317&geo=mun:250019&lang=en',
#      'updated': '2022-01-17T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Balance with Catalonia',
#         'v': '-8,163,_',
#         'calt': 'Migrations (balance) with Catalonia',
#         'id': 'f322'},
#        {'c': 'Balance with Spain',
#         'v': '-1,-121,-8971',
#         'calt': 'Migrations (balance) with Spain',
#         'id': 'f323'},
#        {'c': 'Internal migratory net balance',
#         'v': '-9,42,-8971',
#         'calt': 'Internal migratory net balance',
#         'id': 'f324'}]},
#      'r': '2020',
#      'c': 'Internal migrations. Destination-origin balances',
#      's': "Idescat, based on the INE's Residential Variation Statistics.",
#      'calt': 'Internal migrations',
#      'id': 't196',
#      'l': 'https://www.idescat.cat/pub/?id=mm&n=223&geo=mun:250019&lang=en',
#      'updated': '2021-09-29T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Immigrations',
#         'v': '0,164,118760',
#         'calt': 'External immigrations',
#         'id': 'f372'},
#        {'c': 'Emigrations',
#         'v': '0,91,62236',
#         'calt': 'External emigrations',
#         'id': 'f373'}]},
#      'r': '2020',
#      'c': 'External migrations',
#      's': "Idescat, based on the INE's Residential Variation Statistics.",
#      'calt': 'External migrations',
#      'id': 't208',
#      'l': 'https://www.idescat.cat/pub/?id=mm&n=5489&geo=mun:250019&lang=en',
#      'updated': '2021-09-29T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Rest of EU',
#         'v': '0,44,17499',
#         'calt': 'Immigrations from the rest of EU',
#         'id': 'f314'},
#        {'c': 'Rest of the world',
#         'v': '0,120,101261',
#         'calt': 'Immigrations from the rest of the world',
#         'id': 'f316'},
#        {'c': 'Total',
#         'v': '0,164,118760',
#         'calt': 'External immigrations',
#         'id': 'f317'}]},
#      'r': '2020',
#      'c': 'External immigrations. By place of origin',
#      's': "Idescat, based on the INE's Residential Variation Statistics.",
#      'calt': 'External immigrations',
#      'id': 't194',
#      'l': 'https://www.idescat.cat/pub/?id=mm&n=487&geo=mun:250019&lang=en',
#      'updated': '2021-09-29T10:00:00+00:00'},
#     {'ff': {'f': [{'r': '2011',
#         'c': 'Population Growth',
#         'v': '-7,1689,1176733',
#         'calt': 'Intercensal Population Growth',
#         'id': 'f359'},
#        {'r': '2001-2011',
#         'c': 'Population Growth (annual average)',
#         'u': 'rate per 1,000 inhabitants',
#         'v': '-3.87,13.09,16.98',
#         'calt': 'Intercensal Population Growth (annual average)',
#         'id': 'f360'},
#        {'r': '2001-2011',
#         'c': 'Natural Increase (annual average)',
#         'u': 'rate per 1,000 inhabitants',
#         'v': '-7.97,-4.92,3.04',
#         'calt': 'Intercensal Natural Increase Ratio (annual average)',
#         'id': 'f361'},
#        {'r': '2001-2011',
#         'c': 'Net Migration (annual average)',
#         'u': 'rate per 1,000 inhabitants',
#         'v': '4.11,18.02,13.94',
#         'calt': 'Intercensal Net Migration Ratio (annual average)',
#         'id': 'f362'}]},
#      'c': '2001-2011 Intercensal Population Growth',
#      's': 'Idescat.',
#      'calt': 'Intercensal Population Growth',
#      'id': 't202',
#      'l': 'https://www.idescat.cat/pub/?id=censph&n=97&geo=mun:250019&lang=en',
#      'updated': '2012-12-14T11:00:00+00:00'}]},
#   'c': 'Population',
#   'id': 'g168'},
#  {'tt': {'t': [{'ff': {'f': [{'c': 'Understand',
#         'v': '169,12680,6949344',
#         'calt': 'Population that understands Catalan',
#         'id': 'f91'},
#        {'c': 'Speak',
#         'v': '164,11028,5345484',
#         'calt': 'Population that can speak Catalan',
#         'id': 'f92'},
#        {'c': 'Read',
#         'v': '161,11052,5750348',
#         'calt': 'Population that can read Catalan',
#         'id': 'f93'},
#        {'c': 'Write',
#         'v': '107,8246,4069219',
#         'calt': 'Population that can write Catalan',
#         'id': 'f94'},
#        {'c': 'Do not understand',
#         'v': '0,403,356728',
#         'calt': "Population that doesn't understand Catalan",
#         'id': 'f95'},
#        {'c': 'Total',
#         'v': '169,13083,7306072',
#         'calt': 'Population of 2 years and over',
#         'id': 'f96'}]},
#      'r': '2011',
#      'c': 'Population of 2 years and over. By knowledge of Catalan',
#      's': "Idescat, based on the INE's Population and Housing Census.",
#      'calt': 'Knowledge of Catalan',
#      'id': 't90',
#      'l': 'https://www.idescat.cat/pub/?id=censph&n=17&geo=mun:250019&lang=en',
#      'updated': '2013-11-21T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Public',
#         'v': '0,2,459',
#         'calt': 'Public libraries',
#         'id': 'f270'},
#        {'c': 'Others',
#         'v': '0,2,391',
#         'calt': 'Other libraries',
#         'id': 'f327'},
#        {'c': 'Total', 'v': '0,4,850', 'calt': 'Libraries', 'id': 'f177'}]},
#      'r': '2018',
#      'c': 'Libraries',
#      's': 'Idescat. Library Statistics.',
#      'calt': 'Libraries',
#      'id': 't156',
#      'l': 'https://www.idescat.cat/pub/?id=bib&n=327&geo=mun:250019&lang=en',
#      'updated': '2019-12-10T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Pavilions',
#         'v': '0,8,1005',
#         'calt': 'Pavilions',
#         'id': 'f293'},
#        {'c': 'Multisport courts',
#         'v': '0,35,8373',
#         'calt': 'Multisport courts',
#         'id': 'f294'},
#        {'c': 'Multisport fields',
#         'v': '0,9,2281',
#         'calt': 'Multisport fields',
#         'id': 'f295'},
#        {'c': 'Sports halls',
#         'v': '0,27,9152',
#         'calt': 'Sports halls',
#         'id': 'f296'},
#        {'c': 'Indoor swimming pools',
#         'v': '0,1,1097',
#         'calt': 'Indoor swimming pools',
#         'id': 'f301'},
#        {'c': 'Athelitcs tracks',
#         'v': '0,1,438',
#         'calt': 'Athelitcs tracks',
#         'id': 'f302'},
#        {'c': 'Other facilities',
#         'v': '0,122,29001',
#         'calt': 'Other sports facilities',
#         'id': 'f299'},
#        {'c': 'Total',
#         'v': '0,203,51347',
#         'calt': 'Sports facilities',
#         'id': 'f300'}]},
#      'r': '2021',
#      'c': 'Sports facilities',
#      's': "Idescat, based on data from the Consell Català de l'Esport.",
#      'calt': 'Sports facilities',
#      'id': 't175',
#      'l': 'https://www.idescat.cat/pub/?id=eesp&n=4332&geo=mun:250019&lang=en',
#      'updated': '2022-01-20T11:00:00+00:00'}]},
#   'c': 'Culture · Language',
#   'id': 'g172'},
#  {'tt': {'t': {'ff': {'f': [{'c': 'Primary education or lower',
#        'v': '23.3,22.5,17.7',
#        'calt': 'Primary education or lower',
#        'id': 'f386'},
#       {'c': 'First stage of secondary education',
#        'v': '26.4,24.3,27.4',
#        'calt': 'First stage of secondary education',
#        'id': 'f387'},
#       {'c': 'Second stage of secondary education',
#        'v': '17.0,23.1,23.2',
#        'calt': 'Second stage of secondary education',
#        'id': 'f388'},
#       {'c': 'Higher education',
#        'v': '33.3,30.1,31.8',
#        'calt': 'Higher education',
#        'id': 'f389'}]},
#     'r': '2019 (p)',
#     'c': 'Population aged 15 and over. By level of education attained',
#     's': 'Idescat. Estadística dels estudis de la població.',
#     'u': '%',
#     'calt': 'Level of education attained',
#     'id': 't215',
#     'l': 'https://www.idescat.cat/pub/?id=eep&n=14540&geo=mun:250019&lang=en',
#     'updated': '2021-10-25T10:00:00+00:00'}},
#   'c': 'Education',
#   'id': 'g214'},
#  {'tt': {'t': [{'ff': {'f': [{'c': 'Electors',
#         'v': '145,9833,5554455',
#         'calt': 'Electors ( Parliament of Catalonia)',
#         'id': 'f267'},
#        {'c': 'Turnout',
#         'u': '%',
#         'v': '80.7,79.6,79.1',
#         'calt': 'Turnout (Parliament Catalonia)',
#         'id': 'f254'}]},
#      'r': '2017',
#      'c': 'Elections to the Parliament of Catalonia',
#      's': 'Idescat i Departament de Polítiques Digitals i Administració Pública.',
#      'calt': 'Elections to the Parliament of Catalonia',
#      'id': 't189',
#      'l': 'https://www.idescat.cat/pub/?id=elepc&n=389&geo=mun:250019&lang=en',
#      'updated': '2018-11-23T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Electors',
#         'v': '144,9917,5519912',
#         'calt': 'Electors (Congress)',
#         'id': 'f268'},
#        {'c': 'Turnout',
#         'u': '%',
#         'v': '50.7,61.6,63.4',
#         'calt': 'Turnout (Elec. Congress)',
#         'id': 'f255'}]},
#      'r': '2016',
#      'c': 'Elections to the Congress of Deputies',
#      's': 'Idescat, based on data from the Departament de Governació i Relacions Institucionals.',
#      'calt': 'Elections to the Congress of Deputies',
#      'id': 't190',
#      'l': 'https://www.idescat.cat/pub/?id=elecd&n=385&geo=mun:250019&lang=en',
#      'updated': '2017-10-27T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Turnout',
#         'u': '%',
#         'v': '42.0,48.6,47.6',
#         'calt': 'Turnout (Elec. European Parliament)',
#         'id': 'f256'},
#        {'c': 'Electors',
#         'v': '143,10087,5318296',
#         'calt': 'Electors (Elec. European Parliament)',
#         'id': 'f269'}]},
#      'r': '2014 (p)',
#      'c': 'Elections to the European Parliament',
#      'calt': 'Elections to the European Parliament',
#      'id': 't191',
#      'l': 'https://www.idescat.cat/pub/?id=elepe&n=390&geo=mun:250019&lang=en',
#      'updated': '2015-10-07T10:00:00+00:00'}]},
#   'c': 'Elections',
#   'id': 'g174'},
#  {'tt': {'t': [{'ff': {'f': [{'c': 'Men',
#         'v': '38,2767,1773542',
#         'calt': 'Men',
#         'id': 'f378'},
#        {'c': 'Women', 'v': '31,2361,1563911', 'calt': 'Women', 'id': 'f379'},
#        {'c': 'Total',
#         'v': '69,5128,3337453',
#         'calt': 'Contributors to Social Security according to the residence of the contributor',
#         'id': 'f377'}]},
#      'r': '02/2022',
#      'c': 'Contributors to Social Security according to the residence of the contributor',
#      's': 'Idescat.',
#      'calt': "Contributors to Social Security according to contributors's residence",
#      'id': 't210',
#      'l': 'https://www.idescat.cat/pub/?id=afi&n=8604&geo=mun:250019&lang=en',
#      'updated': '2022-03-11T11:00:00+00:00'},
#     {'ff': {'f': {'c': 'Total',
#        'v': '75,5517,3508935',
#        'calt': 'Afiliations Social Security according residence',
#        'id': 'f363'}},
#      'r': '02/2022',
#      'c': 'Affiliations to Social Security according to the residence of the contributor',
#      's': 'Idescat.',
#      'calt': "Affiliations to Social Security according to contributor's residence",
#      'id': 't203',
#      'l': 'https://www.idescat.cat/pub/?id=afi&n=8598&geo=mun:250019&lang=en',
#      'updated': '2022-03-11T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Agriculture',
#         'v': '13,132,9822',
#         'calt': 'Agriculture affiliations to General SS',
#         'id': 'f273'},
#        {'c': 'Industry',
#         'v': '0,170,444816',
#         'calt': 'Industry affiliations to General SS',
#         'id': 'f278'},
#        {'c': 'Construction',
#         'v': '0,334,142281',
#         'calt': 'Construction affiliations to General SS',
#         'id': 'f279'},
#        {'c': 'Services',
#         'v': '13,2094,2248270',
#         'calt': 'Services affiliations to General SS',
#         'id': 'f280'},
#        {'c': 'Total',
#         'v': '26,2730,2845189',
#         'calt': 'Affiliations to General SS',
#         'id': 'f282'}]},
#      'r': '12/2021 (p)',
#      'c': 'Affiliations to S. S. general system according to the location of the affilation. By sectors',
#      's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#      'calt': 'Affiliations to general system according to location of affilation. By sectors',
#      'id': 't183',
#      'l': 'https://www.idescat.cat/pub/?id=afic&n=8270&geo=mun:250019&lang=en',
#      'updated': '2022-01-17T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Agriculture',
#         'v': '24,385,22038',
#         'calt': 'Affiliations contributors to Self-Employed SS',
#         'id': 'f229'},
#        {'c': 'Services',
#         'v': '5,662,428694',
#         'calt': 'Services afiliaciones to Self-Employed SS',
#         'id': 'f290'},
#        {'c': 'Total',
#         'v': '30,1290,558654',
#         'calt': 'Affiliations to Self-Employed SS',
#         'id': 'f291'}]},
#      'r': '12/2021 (p)',
#      'c': 'Affiliations to S. S. self-employed system according to the location of the affilation. By sectors',
#      's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#      'calt': 'Affiliations to self-employed system according to location of affilation. By sectors',
#      'id': 't184',
#      'l': 'https://www.idescat.cat/pub/?id=afic&n=8272&geo=mun:250019&lang=en',
#      'updated': '2022-01-17T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Up to 50 workers',
#         'v': '26,1860,1236248',
#         'calt': 'Affiliations to SS centres with up to 50 workers',
#         'id': 'f225'},
#        {'c': 'From 51 to 250 workers',
#         'v': '0,870,661338',
#         'calt': 'Affiliations to SS centres with 51 to 250 workers',
#         'id': 'f284'},
#        {'c': 'From 251 workers and over',
#         'v': '0,0,947603',
#         'calt': 'Affiliations to SS centres with 251 or more workers',
#         'id': 'f227'},
#        {'c': 'Total',
#         'v': '26,2730,2845189',
#         'calt': 'Affiliations to General SS',
#         'id': 'f286'}]},
#      'r': '12/2021 (p)',
#      'c': 'Affiliations to S. S. general system according to the location of the affilation. By size of centre',
#      's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#      'calt': 'Affiliations to gen. system according to location of affilation. By size of the centre',
#      'id': 't185',
#      'l': 'https://www.idescat.cat/pub/?id=afic&n=8271&geo=mun:250019&lang=en',
#      'updated': '2022-01-17T11:00:00+00:00'},
#     {'ff': {'f': {'c': 'Total',
#        'v': '8,509,243338',
#        'calt': 'Contributory accounts',
#        'id': 'f239'}},
#      'r': '12/2021 (p)',
#      'c': 'Contributory accounts',
#      's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#      'calt': 'Contributory accounts of Social Security',
#      'id': 't186',
#      'l': 'https://www.idescat.cat/pub/?id=afic&n=8273&geo=mun:250019&lang=en',
#      'updated': '2022-01-17T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Total',
#         'v': '53,3810,1720098',
#         'calt': 'Contributory Social Security pensions',
#         'id': 'f375',
#         'updated': '2020-05-29T10:00:00+00:00'},
#        {'c': 'Average pension',
#         'u': 'euros',
#         'v': '676.79,874.02,1041.97',
#         'calt': 'Average contributory pension',
#         'id': 'f376',
#         'updated': '2020-05-29T10:00:00+00:00'}]},
#      'r': '2019',
#      'c': 'Contributory Social Security pensions. December',
#      's': '',
#      'calt': 'Contributory Social Security pensions',
#      'id': 't209',
#      'l': 'https://www.idescat.cat/pub/?id=pens&geo=mun:250019&lang=en'},
#     {'ff': {'f': [{'c': 'Men',
#         'v': '23,1570,737855',
#         'calt': 'Men',
#         'id': 'f382'},
#        {'c': 'Women', 'v': '22,1613,775829', 'calt': 'Women', 'id': 'f383'},
#        {'c': 'Total', 'v': '45,3183,1513684', 'calt': 'Total', 'id': 'f384'}]},
#      'r': '2019',
#      'c': 'Contributory Social Security Pensioners. By sex. December',
#      's': '',
#      'calt': 'Contributory Social Security Pensioners',
#      'id': 't212',
#      'l': 'https://www.idescat.cat/pub/?id=pens&n=10756&geo=mun:250019&lang=en',
#      'updated': '2020-05-29T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Agriculture',
#         'v': '0.6,42.4,9562.4',
#         'calt': 'Registered unemployment. Agriculture',
#         'id': 'f243'},
#        {'c': 'Industry',
#         'v': '3.0,47.6,45324.2',
#         'calt': 'Registered unemployment. Industry',
#         'id': 'f303'},
#        {'c': 'Construction',
#         'v': '0.0,69.2,33714.0',
#         'calt': 'Registered unemployment. Construction',
#         'id': 'f304'},
#        {'c': 'Services',
#         'v': '6.1,467.1,320048.0',
#         'calt': 'Registered unemployment. Services',
#         'id': 'f305'},
#        {'c': 'Without previous employment',
#         'v': '0.0,30.3,28517.0',
#         'calt': 'Registered unemployment (without previous employment)',
#         'id': 'f307'},
#        {'c': 'Total',
#         'v': '9.7,656.7,437165.6',
#         'calt': 'Registered unemployment',
#         'id': 'f308'}]},
#      'r': '2021',
#      'c': 'Registered unemployment. By sectors',
#      's': 'Ministry of Business and Employment.',
#      'u': 'annual averages',
#      'calt': 'Registered unemployment by sectors',
#      'id': 't188',
#      'l': 'https://www.idescat.cat/pub/?id=atureg&n=4302&geo=mun:250019&lang=en',
#      'updated': '2022-01-13T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Men',
#         'v': '5.7,310.6,191728.2',
#         'calt': 'Registered unemployment. Men',
#         'id': 'f240'},
#        {'c': 'Women',
#         'v': '4.0,346.1,245437.3',
#         'calt': 'Registered unemployment. Women',
#         'id': 'f241'},
#        {'c': 'Total',
#         'v': '9.7,656.7,437165.6',
#         'calt': 'Registered unemployment',
#         'id': 'f242'}]},
#      'r': '2021',
#      'c': 'Registered unemployment. By sex',
#      's': 'Ministry of Business and Employment.',
#      'u': 'annual averages',
#      'calt': 'Registered unemployment by sex',
#      'id': 't187',
#      'l': 'https://www.idescat.cat/pub/?id=atureg&n=4299&geo=mun:250019&lang=en',
#      'updated': '2022-01-13T11:00:00+00:00'}]},
#   'c': 'Labour',
#   'id': 'g169'},
#  {'tt': {'t': {'ff': {'f': [{'c': 'Main',
#        'v': '62,5639,2944944',
#        'calt': 'Main family dwellings',
#        'id': 'f250'},
#       {'c': 'Secondary',
#        'v': '28,3786,470081',
#        'calt': 'Secondary family dwellings',
#        'id': 'f119'},
#       {'c': 'Total',
#        'v': '90,10966,3863381',
#        'calt': 'Family dwellings',
#        'id': 'f122'}]},
#     'r': '2011',
#     'c': 'Family dwellings. By type',
#     's': "Idescat, based on the INE's Population and Housing Census.",
#     'calt': 'Type of dwellings',
#     'id': 't116',
#     'l': 'https://www.idescat.cat/pub/?id=censph&n=30&geo=mun:250019&lang=en',
#     'updated': '2013-12-19T11:00:00+00:00'}},
#   'c': 'Quality of life',
#   'id': 'g171'},
#  {'tt': {'t': [{'ff': {'f': [{'c': 'Number of receipts',
#         'v': '181,17974,5855886',
#         'calt': 'IBI. Receipts',
#         'id': 'f198'},
#        {'c': 'Taxable base by receipt',
#         'u': 'euros',
#         'v': '20265.2,29494.8,70537.2',
#         'calt': 'IBI. Taxable base by receipt',
#         'id': 'f199'},
#        {'c': 'Integral quota by receipt',
#         'u': 'euros',
#         'v': '121.6,204.0,485.9',
#         'calt': 'IBI. Integral quota by receipt',
#         'id': 'f200'}]},
#      'r': '2020',
#      'c': 'Urban property tax (IBI)',
#      's': 'Idescat, based on data from the Dirección General del Catastro.',
#      'calt': 'Urban property tax',
#      'id': 't179',
#      'l': 'https://www.idescat.cat/pub/?id=ibi&n=173&geo=mun:250019&lang=en',
#      'updated': '2021-06-29T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Taxable base by declarer',
#         'v': '10332,19087,24984',
#         'calt': 'IRPF. Taxable base by declarer',
#         'id': 'f10'},
#        {'c': 'Resulting quota from self-payment by declarer',
#         'v': '3477,5136,7193',
#         'calt': 'IRPF. Resulting quotafrom self-payment by declarer',
#         'id': 'f11'}]},
#      'r': '2019',
#      'c': 'Personal Income Tax (IRPF)',
#      's': "Idescat, based on data from the Agència Estatal d'Administració Tributària.",
#      'u': 'euros',
#      'calt': 'Personal Income Tax',
#      'id': 't9',
#      'l': 'https://www.idescat.cat/pub/?id=irpf&n=4070&geo=mun:250019&lang=en',
#      'updated': '2021-11-26T11:00:00+00:00'}]},
#   'c': 'Main aggregates · Public sector finance',
#   'id': 'g163'},
#  {'tt': {'t': [{'ff': {'f': [{'c': 'Cultivated land',
#         'v': '412,16919,792425',
#         'calt': 'Cultivated land surface',
#         'id': 'f133'},
#        {'c': 'Permanent pasture',
#         'v': '1048,35219,355107',
#         'calt': 'Permanent pasture surface',
#         'id': 'f134'},
#        {'c': 'Total',
#         'v': '1460,52138,1147532',
#         'calt': 'Used agricultural area',
#         'id': 'f345'}]},
#      'r': '2009',
#      'c': 'Used agricultural area (UAA)',
#      's': '',
#      'u': 'hectares',
#      'calt': 'Used agricultural area',
#      'id': 't132',
#      'l': 'https://www.idescat.cat/pub/?id=censag&n=5173&geo=mun:250019&lang=en',
#      'updated': '2012-04-04T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Herbaceous crops',
#         'v': '226,14140,511150',
#         'calt': 'Herbaceous crops',
#         'id': 'f346'},
#        {'c': 'Fruit trees',
#         'v': '169,1749,110819',
#         'calt': 'Fruit trees crops',
#         'id': 'f347'},
#        {'c': 'Olives',
#         'v': '6,609,101236',
#         'calt': 'Olives crops',
#         'id': 'f348'},
#        {'c': 'Vines', 'v': '1,400,61391', 'calt': 'Vines crops', 'id': 'f349'},
#        {'c': 'Others', 'v': '11,22,7829', 'calt': 'Other crops', 'id': 'f350'},
#        {'c': 'Total',
#         'v': '412,16919,792425',
#         'calt': 'Cultivated land',
#         'id': 'f351'}]},
#      'r': '2009',
#      'c': 'Cultivated land. By type of crop',
#      's': '',
#      'u': 'hectares',
#      'calt': 'Cultivated land',
#      'id': 't199',
#      'l': 'https://www.idescat.cat/pub/?id=censag&n=5084&geo=mun:250019&lang=en',
#      'updated': '2012-03-20T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Without land',
#         'v': '3,19,1519',
#         'calt': 'Farms without land',
#         'id': 'f352'},
#        {'c': 'With land',
#         'v': '27,870,59320',
#         'calt': 'Farms with land',
#         'id': 'f353'},
#        {'c': 'Total',
#         'v': '30,889,60839',
#         'calt': 'Farms with and without land',
#         'id': 'f356'}]},
#      'r': '2009',
#      'c': 'Farms. By land ownership',
#      's': '',
#      'calt': 'Land ownership',
#      'id': 't200',
#      'l': 'https://www.idescat.cat/pub/?id=censag&n=5172&geo=mun:250019&lang=en',
#      'updated': '2012-04-04T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Without livestock',
#         'v': '11,542,47172',
#         'calt': 'Farms without livestock',
#         'id': 'f139'},
#        {'c': 'With livestock',
#         'v': '19,347,13667',
#         'calt': 'Farms with livestock',
#         'id': 'f204'},
#        {'c': 'Total',
#         'v': '30,889,60839',
#         'calt': 'Farms with and without livestock',
#         'id': 'f138'}]},
#      'r': '2009',
#      'c': 'Farms. By livestock ownership',
#      's': '',
#      'calt': 'Livestock ownership',
#      'id': 't137',
#      'l': 'https://www.idescat.cat/pub/?id=censag&n=5172&geo=mun:250019&lang=en',
#      'updated': '2012-04-04T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Bovine',
#         'v': '195,13121,544135',
#         'calt': 'Bovine head',
#         'id': 'f141'},
#        {'c': 'Ovine',
#         'v': '2030,45750,600082',
#         'calt': 'Ovine head',
#         'id': 'f142'},
#        {'c': 'Caprine',
#         'v': '176,3026,71748',
#         'calt': 'Caprine head',
#         'id': 'f252'},
#        {'c': 'Porcine',
#         'v': '7289,149104,6742638',
#         'calt': 'Porcine head',
#         'id': 'f144'},
#        {'c': 'Avian',
#         'v': '75010,350918,43890563',
#         'calt': 'Avian head',
#         'id': 'f145'},
#        {'c': 'Female rabbits',
#         'v': '150,1625,335054',
#         'calt': 'Female rabbits head',
#         'id': 'f146'},
#        {'c': 'Equine',
#         'v': '9,981,19352',
#         'calt': 'Equine head',
#         'id': 'f147'}]},
#      'r': '2009',
#      'c': 'Head of livestock. By species',
#      's': '',
#      'calt': 'Head of livestock',
#      'id': 't140',
#      'l': 'https://www.idescat.cat/pub/?id=censag&n=5107&geo=mun:250019&lang=en',
#      'updated': '2012-04-04T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'State subsidised housing starts',
#         'v': '0,0,1903',
#         'calt': 'State subsidised housing starts',
#         'id': 'f13'},
#        {'c': 'Housing starts',
#         'v': '0,8,11395',
#         'calt': 'Housing starts',
#         'id': 'f14'}]},
#      'r': '2020',
#      'c': 'Housing construction',
#      's': "Idescat, based on data from the Departament de Territori i Sostenibilitat. Secretaria d'Habitatge i Millora Urbana.",
#      'calt': 'Housing construction',
#      'id': 't12',
#      'l': 'https://www.idescat.cat/pub/?id=habit&n=86&geo=mun:250019&lang=en',
#      'updated': '2021-04-28T10:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Hotels',
#         'v': '0,18,3083',
#         'calt': 'Hotels',
#         'id': 'f215',
#         'updated': '2021-07-01T10:00:00+00:00'},
#        {'c': 'Hotel beds',
#         'v': '0,707,318954',
#         'calt': 'Hotel beds',
#         'id': 'f216',
#         'updated': '2021-07-01T10:00:00+00:00'},
#        {'c': 'Campsites',
#         'v': '0,5,351',
#         'calt': 'Campsites',
#         'id': 'f217',
#         'updated': '2021-07-01T10:00:00+00:00'},
#        {'c': 'Campsite places',
#         'v': '0,1794,262346',
#         'calt': 'Campsite places',
#         'id': 'f218',
#         'updated': '2021-07-01T10:00:00+00:00'},
#        {'c': 'Rural tourism',
#         'v': '2,60,2514',
#         'calt': 'Rural tourism',
#         'id': 'f219',
#         'updated': '2021-07-01T10:00:00+00:00'},
#        {'c': 'Rural tourism beds',
#         'v': '9,503,20190',
#         'calt': 'Rural tourism beds',
#         'id': 'f220',
#         'updated': '2021-07-01T10:00:00+00:00'}]},
#      'r': '2020',
#      'c': 'Tourist accommodation',
#      's': 'Idescat, based on data from the Ministry of Business and Labour.',
#      'calt': 'Tourist accommodation',
#      'id': 't182',
#      'l': 'https://www.idescat.cat/pub/?id=turall&geo=mun:250019&lang=en'},
#     {'ff': {'f': [{'c': 'Estate cars',
#         'v': '175,6961,3554258',
#         'calt': 'Cars',
#         'id': 'f19'},
#        {'c': 'Motorcycles',
#         'v': '13,895,882094',
#         'calt': 'Motorcycles',
#         'id': 'f325'},
#        {'c': 'Industrial vehicles',
#         'v': '189,2853,779051',
#         'calt': 'Industrial vehicles',
#         'id': 'f272'},
#        {'c': 'Others',
#         'v': '135,726,172003',
#         'calt': 'Other  vehicles',
#         'id': 'f326'},
#        {'c': 'Total',
#         'v': '512,11435,5387406',
#         'calt': 'Fleet of vehicles',
#         'id': 'f163'}]},
#      'r': '2020',
#      'c': 'Fleet of vehicles',
#      's': 'Idescat, based on data from the DGT.',
#      'calt': 'Fleet of vehicles',
#      'id': 't18',
#      'l': 'https://www.idescat.cat/pub/?id=parcc&n=291&geo=mun:250019&lang=en',
#      'updated': '2021-09-22T10:00:00+00:00'}]},
#   'c': 'Economic sectors',
#   'id': 'g170'},
#  {'tt': {'t': [{'ff': {'f': [{'c': 'Generation per capita',
#         'u': 'kg/inhab./day',
#         'v': '1.24,1.50,1.40',
#         'calt': 'Municipal waste per capita',
#         'id': 'f366'},
#        {'c': 'Selective collection',
#         'u': '%',
#         'v': '40.7,43.2,45.9',
#         'calt': 'Selective collection of municipal waste',
#         'id': 'f368'}]},
#      'r': '2020',
#      'c': 'Municipal waste',
#      's': 'The Waste Agency of Catalonia.',
#      'calt': 'Municipal waste',
#      'id': 't204',
#      'l': 'https://www.idescat.cat/pub/?id=resmc&n=6997&geo=mun:250019&lang=en',
#      'updated': '2022-02-14T11:00:00+00:00'},
#     {'ff': {'f': [{'c': 'Establishments with yearly waste declarations',
#         'v': '0,46,15166',
#         'calt': 'Establishments with yearly ind. waste declarations',
#         'id': 'f371'},
#        {'c': 'Industrial waste',
#         'u': 'tonnes',
#         'v': '0.00,937.38,3793347.50',
#         'calt': 'Industrial waste',
#         'id': 'f369'}]},
#      'r': '2017',
#      'c': 'Industrial waste',
#      's': 'The Waste Agency of Catalonia.',
#      'calt': 'Industrial waste',
#      'id': 't207',
#      'l': 'https://www.idescat.cat/pub/?id=resic&n=7083&geo=mun:250019&lang=en',
#      'updated': '2019-05-15T10:00:00+00:00'}]},
#   'c': 'Environment',
#   'id': 'g205'}]

# %%
len(test['250019']['fitxes']['gg']['g'])
# Out:
# 10

# %%
test['250019']['fitxes']['cols']['col']
# Out:
# [{'scheme': 'mun', 'id': '250019', 'content': 'Abella de la Conca'},
#  {'scheme': 'com', 'id': '25', 'content': 'Pallars Jussà'},
#  {'scheme': 'ca', 'id': '09', 'content': 'Catalunya'}]

# %%
# def parse_mun_to_dict_of_list(data):
#     """FUnction build before the knowledge of data not being complete."""
#     columns = {}
#     for key in data.keys():
#         print(data[key]['fitxes']['cols']['col'][0]['id'])
#         print(key)
#         assert data[key]['fitxes']['cols']['col'][0]['id'] == key
        
        
#         for g in data[key]['fitxes']['gg']['g']:
            
#             if type(g['tt']['t']) == type(dict):
                
#                 if type(g['tt']['t']['ff']['f']) == type(dict):
#                     value = value_splitter(g['tt']['t']['ff']['f']['v'])
#                     if g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt'] in columns.keys():
#                         columns[g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt']].append(value)
#                     else:
#                         columns[g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt']] = [value]
#                 else:
#                     for f in g['tt']['t']['ff']['f']:
#                         value = value_splitter(f['v'])
#                         if g['tt']['t']['c'] + "_" + f['calt'] in columns.keys():
#                             columns[g['tt']['t']['c'] + "_" + f['calt']].append(value)
#                         else:
#                             columns[g['tt']['t']['c'] + "_" + f['calt']] = [value]
#             else:
#                 for t in g['tt']['t']:
#                     if type(t['ff']['f']) == type(dict):
#                         value = value_splitter(t['ff']['f']['v'])
#                         if t['c'] + "_" + t['ff']['f']['calt'] in columns.keys():
#                             columns[t['c'] + "_" + t['ff']['f']['calt']].append(value)
#                         else:
#                             columns[t['c'] + "_" + t['ff']['f']['calt']] = [value]
#                     else:
#                         for f in t['ff']['f']:
#                             value = value_splitter(f['v'])
#                             if t['c'] + "_" + f['calt'] in columns.keys():
#                                 columns[t['c'] + "_" + f['calt']].append(value)
#                             else:
#                                 columns[t['c'] + "_" + f['calt']] = [value]
                    
#     return columns

# %%
def value_splitter(value):
    assert type(value) == str
    mun, com, ca = value.split(',')
    return mun, com, ca


def is_not_in_column_names(column_names, name):
    if name in column_names:
        return False
    else:
        return True

        
def get_column_names_from_muns(data):
    """Returns all the names of the columns which are in the data set
    It looks super cumbersome because the people from idescat do not know how to keep consistency in their data
    """
    column_names = []
    # For each municipality in the data, go over the json.
    for key in data.keys():
        # Check if the municipality is really that municipality.
        assert data[key]['fitxes']['cols']['col'][0]['id'] == key
        
        # go over all 'groups' in the dictoinary structure
        for g in data[key]['fitxes']['gg']['g']:
            
            # Check if the group contains one or more tables. The group is a dictoinary of tables when there is
            # is multiple tables in the group, and a list when there is only one. When this if statement returns true,
            # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
            if type(g['tt']['t']) == dict:

                # Check if the table contains one or more rows. The table is a list of rows when there is
                # is multiple rows in the table, and a dictionary when there is only one. When this if statement returns true,
                # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
                if type(g['tt']['t']['ff']['f']) == dict:
                    
                    # Check if the name is already in the column names list, and otherwise append it to the list.
                    if is_not_in_column_names(column_names, g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt']):
                        column_names.append(g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt'])
                else:
                    for f in g['tt']['t']['ff']['f']:
                        # Check if the name is already in the column names list, and otherwise append it to the list.
                        if is_not_in_column_names(column_names, g['tt']['t']['c'] + "_" + f['calt']):
                            column_names.append(g['tt']['t']['c'] + "_" + f['calt'])
                        #print(f['calt'])
            else:
                for t in g['tt']['t']:
                    
                    # Check if the table contains one or more rows. The table is a dictoinary of rows when there is
                    # is multiple rows in the table, and a list when there is only one. When this if statement returns true,
                    # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
                    if type(t['ff']['f']) == dict:
                        # Check if the name is already in the column names list, and otherwise append it to the list.
                        if is_not_in_column_names(column_names, t['c'] + "_" + t['ff']['f']['calt']):
                            column_names.append(t['c'] + "_" + t['ff']['f']['calt'])

                    else:
                        for f in t['ff']['f']:
                            # Check if the name is already in the column names list, and otherwise append it to the list.
                            if is_not_in_column_names(column_names, t['c'] + "_" + f['calt']):
                                column_names.append(t['c'] + "_" + f['calt'])
    return column_names
        
    
def make_col_dict(column_names):
    col_dict = {}
    for col in column_names:
        col_dict[col] = []
    return col_dict


def retrieve_mun_from_json(data, columns):
    column_names = list(columns.keys())
    for g in data['fitxes']['gg']['g']:
            
        # Check if the group contains one or more tables. The group is a dictoinary of tables when there is
        # is multiple tables in the group, and a list when there is only one. When this if statement returns true,
        # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
        if type(g['tt']['t']) == dict:

            # Check if the table contains one or more rows. The table is a dictoinary of rows when there is
            # is multiple rows in the table, and a list when there is only one. When this if statement returns true,
            # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
            if type(g['tt']['t']['ff']['f']) == dict:
                v, _, _ = value_splitter(g['tt']['t']['ff']['f']['v'])
                columns[g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt']].append(v)
                print(g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt'])
                print(g['tt']['t']['ff']['f']['r'])
                column_names.remove(g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt'])
            else:
                for f in g['tt']['t']['ff']['f']:
                    v, _, _ = value_splitter(f['v'])
                    columns[g['tt']['t']['c'] + "_" + f['calt']].append(v)
                    print(g['tt']['t']['c'] + "_" + f['calt'])
                    print('f')
                    column_names.remove(g['tt']['t']['c'] + "_" + f['calt'])
        else:
            for t in g['tt']['t']:
                    
                # Check if the table contains one or more rows. The table is a dictoinary of rows when there is
                # is multiple rows in the table, and a list when there is only one. When this if statement returns true,
                # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
                if type(t['ff']['f']) == dict:
                    v, _, _ = value_splitter(t['ff']['f']['v'])
                    columns[t['c'] + "_" + t['ff']['f']['calt']].append(v)
                    print(t['c'] + "_" + t['ff']['f']['calt'])
                    print(t['ff']['f']['r'])
                    column_names.remove(t['c'] + "_" + t['ff']['f']['calt'])
                else:
                    for f in t['ff']['f']:                     
                        v, _, _ = value_splitter(f['v'])
                        columns[t['c'] + "_" + f['calt']].append(v)
                        print(t['c'] + "_" + f['calt'])
                        print(f['r'])
                        column_names.remove(t['c'] + "_" + f['calt'])
    
    for c in column_names:
        columns[c].append('nan')
    return columns

# %%
x = get_column_names_from_muns(test)

# %%
s = make_col_dict(x)

# %%
v, _, _ = value_splitter('78.27,1343.09,32108.00')

# %%
test['080018']['fitxes']['cols']['col'][0]
# Out:
# {'scheme': 'mun', 'id': '080018', 'content': 'Abrera'}

# %%
check = retrieve_mun_from_json(test['080018'], s)
# Out:
# Geographic indicators_Surface area
# f
# Geographic indicators_Altitude
# f
# Geographic indicators_Longitude
# f
# Geographic indicators_Latitude
# f
# Geographic indicators_UTM coordinates x
# f
# Geographic indicators_UTM coordinates y
# f
# Density of population_Surface area
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-184-7a16b996f3fb> in <module>
# ----> 1 check = retrieve_mun_from_json(test['080018'], s)
#
# <ipython-input-179-3b66c0796030> in retrieve_mun_from_json(data, columns)
#     112                         columns[t['c'] + "_" + f['calt']].append(v)
#     113                         print(t['c'] + "_" + f['calt'])
# --> 114                         print(f['r'])
#     115                         column_names.remove(t['c'] + "_" + f['calt'])
#     116
#
# KeyError: 'r'

# %%
list(s.keys()).remove('Geographic indicators_Surface area')

# %%
check
# Out:
# {'Geographic indicators_Surface area': ['19.94', '78.27', '19.94'],
#  'Geographic indicators_Altitude': ['105', '956', '105'],
#  'Geographic indicators_Longitude': ['1.903100', '1.092892', '1.903100'],
#  'Geographic indicators_Latitude': ['41.518531', '42.162392', '41.518531'],
#  'Geographic indicators_UTM coordinates x': ['408471', '342450', '408471'],
#  'Geographic indicators_UTM coordinates y': ['4596983', '4669650', '4596983'],
#  'Density of population_Surface area': ['19.94', '78.27', '19.94'],
#  'Density of population_Density': ['632.9', '2.2', '632.9'],
#  'Population. By sex_Men': ['6373', '89', '6373'],
#  'Population. By sex_Women': ['6247', '82', '6247'],
#  'Population. By sex_Population': ['12620', '171', '12620'],
#  'Population. By age groups_Population from 0 to 14 years': ['2138',
#   '16',
#   '2138'],
#  'Population. By age groups_Population from 15 to 64 years': ['8503',
#   '110',
#   '8503'],
#  'Population. By age groups_Population from 65 to 84 years': ['1749',
#   '33',
#   '1749'],
#  'Population. By age groups_Population from 85 years and over': ['230',
#   '12',
#   '230'],
#  'Population. By age groups_Population': ['12620', '171', '12620'],
#  'Population. By age groups. Men_Men from 0 to 14 years': ['1100',
#   '8',
#   '1100'],
#  'Population. By age groups. Men_Men from 15 to 64 years': ['4366',
#   '59',
#   '4366'],
#  'Population. By age groups. Men_Men from 65 to 84 years': ['809',
#   '14',
#   '809'],
#  'Population. By age groups. Men_Men from 85 years and over': ['98',
#   '8',
#   '98'],
#  'Population. By age groups. Men_Men': ['6373', '89', '6373'],
#  'Population. By age groups. Women_Women from 0 to 14 years': ['1038',
#   '8',
#   '1038'],
#  'Population. By age groups. Women_Women from 15 to 64 years': ['4137',
#   '51',
#   '4137'],
#  'Population. By age groups. Women_Women from 65 to 84 years': ['940',
#   '19',
#   '940'],
#  'Population. By age groups. Women_Women from 85 years and over': ['132',
#   '4',
#   '132'],
#  'Population. By age groups. Women_Women': ['6247', '82', '6247'],
#  'Population. By place of birth_Population born in Catalonia': ['8717',
#   '143',
#   '8717'],
#  'Population. By place of birth_Population born in rest of Spain': ['2575',
#   '8',
#   '2575'],
#  'Population. By place of birth_Population born abroad': ['1328',
#   '20',
#   '1328'],
#  'Population. By place of birth_Population': ['12620', '171', '12620'],
#  'Population. By nationality_Population with Spanish nationality': ['11778',
#   '151',
#   '11778'],
#  'Population. By nationality_Population with foreign nationality': ['842',
#   '20',
#   '842'],
#  'Population. By nationality_Population': ['12620', '171', '12620'],
#  'Population. By nationality. Men_Men with Spanish nationality': ['5968',
#   '79',
#   '5968'],
#  'Population. By nationality. Men_Men with foreign nationality': ['405',
#   '10',
#   '405'],
#  'Population. By nationality. Men_Men': ['6373', '89', '6373'],
#  'Population. By nationality. Women_Women with Spanish nationality': ['5810',
#   '72',
#   '5810'],
#  'Population. By nationality. Women_Women with foreign nationality': ['437',
#   '10',
#   '437'],
#  'Population. By nationality. Women_Women': ['6247', '82', '6247'],
#  'Population resident abroad on 1 January. By sex_Men resident abroad': ['124',
#   '25',
#   '124'],
#  'Population resident abroad on 1 January. By sex_Women resident abroad': ['129',
#   '32',
#   '129'],
#  'Population resident abroad on 1 January. By sex_Population resident abroad': ['253',
#   '57',
#   '253'],
#  'Statistics on Commuting for Non-University Studies_Resident Students (School Age)': ['2475',
#   '30'],
#  'Statistics on Commuting for Non-University Studies_Resident Students who study in the same municipality': ['71.5',
#   '0.0'],
#  'Births. By sex_Births. Boys': ['41', '0'],
#  'Births. By sex_Births. Girls': ['49', '1'],
#  'Births. By sex_Births': ['90', '1'],
#  'Deaths. By sex_Deaths. Men': ['49', '0'],
#  'Deaths. By sex_Deaths. Women': ['48', '0'],
#  'Deaths. By sex_Deaths': ['97', '0'],
#  'Marriages_Marriages': ['35', '0'],
#  'Internal migrations. Destination-origin balances_Migrations (balance) with Catalonia': ['102',
#   '-8'],
#  'Internal migrations. Destination-origin balances_Migrations (balance) with Spain': ['-41',
#   '-1'],
#  'Internal migrations. Destination-origin balances_Internal migratory net balance': ['61',
#   '-9'],
#  'External migrations_External immigrations': ['62', '0'],
#  'External migrations_External emigrations': ['52', '0'],
#  'External immigrations. By place of origin_Immigrations from the rest of EU': ['7',
#   '0'],
#  'External immigrations. By place of origin_Immigrations from the rest of the world': ['55',
#   '0'],
#  'External immigrations. By place of origin_External immigrations': ['62',
#   '0'],
#  '2001-2011 Intercensal Population Growth_Intercensal Population Growth': ['3191',
#   '-7'],
#  '2001-2011 Intercensal Population Growth_Intercensal Population Growth (annual average)': ['31.23',
#   '-3.87'],
#  '2001-2011 Intercensal Population Growth_Intercensal Natural Increase Ratio (annual average)': ['9.33',
#   '-7.97'],
#  '2001-2011 Intercensal Population Growth_Intercensal Net Migration Ratio (annual average)': ['21.9',
#   '4.11'],
#  'Population of 2 years and over. By knowledge of Catalan_Population that understands Catalan': ['10796',
#   '169'],
#  'Population of 2 years and over. By knowledge of Catalan_Population that can speak Catalan': ['7703',
#   '164'],
#  'Population of 2 years and over. By knowledge of Catalan_Population that can read Catalan': ['8748',
#   '161'],
#  'Population of 2 years and over. By knowledge of Catalan_Population that can write Catalan': ['6099',
#   '107'],
#  "Population of 2 years and over. By knowledge of Catalan_Population that doesn't understand Catalan": ['556',
#   '0'],
#  'Population of 2 years and over. By knowledge of Catalan_Population of 2 years and over': ['11351',
#   '169'],
#  'Libraries_Public libraries': ['1', '0'],
#  'Libraries_Other libraries': ['0', '0'],
#  'Libraries_Libraries': ['1', '0'],
#  'Sports facilities_Pavilions': ['2', '0'],
#  'Sports facilities_Multisport courts': ['9', '0'],
#  'Sports facilities_Multisport fields': ['2', '0'],
#  'Sports facilities_Sports halls': ['12', '0'],
#  'Sports facilities_Indoor swimming pools': ['2', '0'],
#  'Sports facilities_Athelitcs tracks': ['0', '0'],
#  'Sports facilities_Other sports facilities': ['42', '0'],
#  'Sports facilities_Sports facilities': ['69', '0'],
#  'Population aged 15 and over. By level of education attained_Primary education or lower': ['16.9',
#   '23.3'],
#  'Population aged 15 and over. By level of education attained_First stage of secondary education': ['30.5',
#   '26.4'],
#  'Population aged 15 and over. By level of education attained_Second stage of secondary education': ['25.8',
#   '17.0'],
#  'Population aged 15 and over. By level of education attained_Higher education': ['26.9',
#   '33.3'],
#  'Elections to the Parliament of Catalonia_Electors ( Parliament of Catalonia)': ['8965',
#   '145'],
#  'Elections to the Parliament of Catalonia_Turnout (Parliament Catalonia)': ['85.3',
#   '80.7'],
#  'Elections to the Congress of Deputies_Electors (Congress)': ['8907', '144'],
#  'Elections to the Congress of Deputies_Turnout (Elec. Congress)': ['70.9',
#   '50.7'],
#  'Elections to the European Parliament_Turnout (Elec. European Parliament)': ['47.3',
#   '42.0'],
#  'Elections to the European Parliament_Electors (Elec. European Parliament)': ['8806',
#   '143'],
#  'Contributors to Social Security according to the residence of the contributor_Men': ['3144',
#   '38'],
#  'Contributors to Social Security according to the residence of the contributor_Women': ['2617',
#   '31'],
#  'Contributors to Social Security according to the residence of the contributor_Contributors to Social Security according to the residence of the contributor': ['5761',
#   '69'],
#  'Affiliations to Social Security according to the residence of the contributor_Afiliations Social Security according residence': ['5947',
#   '75'],
#  'Affiliations to S. S. general system according to the location of the affilation. By sectors_Agriculture affiliations to General SS': ['13'],
#  'Affiliations to S. S. general system according to the location of the affilation. By sectors_Industry affiliations to General SS': ['2699',
#   '0'],
#  'Affiliations to S. S. general system according to the location of the affilation. By sectors_Construction affiliations to General SS': ['0'],
#  'Affiliations to S. S. general system according to the location of the affilation. By sectors_Services affiliations to General SS': ['3452',
#   '13'],
#  'Affiliations to S. S. general system according to the location of the affilation. By sectors_Affiliations to General SS': ['6508',
#   '26'],
#  'Affiliations to S. S. self-employed system according to the location of the affilation. By sectors_Affiliations contributors to Self-Employed SS': ['6',
#   '103',
#   '24'],
#  'Affiliations to S. S. self-employed system according to the location of the affilation. By sectors_Services afiliaciones to Self-Employed SS': ['5'],
#  'Affiliations to S. S. self-employed system according to the location of the affilation. By sectors_Affiliations to Self-Employed SS': ['30'],
#  'Affiliations to S. S. general system according to the location of the affilation. By size of centre_Affiliations to SS centres with up to 50 workers': ['26'],
#  'Affiliations to S. S. general system according to the location of the affilation. By size of centre_Affiliations to SS centres with 51 to 250 workers': ['0'],
#  'Affiliations to S. S. general system according to the location of the affilation. By size of centre_Affiliations to SS centres with 251 or more workers': ['0'],
#  'Affiliations to S. S. general system according to the location of the affilation. By size of centre_Affiliations to General SS': ['26'],
#  'Contributory accounts_Contributory accounts': ['8'],
#  'Contributory Social Security pensions. December_Contributory Social Security pensions': ['53'],
#  'Contributory Social Security pensions. December_Average contributory pension': ['676.79'],
#  'Contributory Social Security Pensioners. By sex. December_Men': ['23'],
#  'Contributory Social Security Pensioners. By sex. December_Women': ['22'],
#  'Contributory Social Security Pensioners. By sex. December_Total': ['45'],
#  'Registered unemployment. By sectors_Registered unemployment. Agriculture': ['0.6'],
#  'Registered unemployment. By sectors_Registered unemployment. Industry': ['3.0'],
#  'Registered unemployment. By sectors_Registered unemployment. Construction': ['0.0'],
#  'Registered unemployment. By sectors_Registered unemployment. Services': ['6.1'],
#  'Registered unemployment. By sectors_Registered unemployment (without previous employment)': ['0.0'],
#  'Registered unemployment. By sectors_Registered unemployment': ['9.7'],
#  'Registered unemployment. By sex_Registered unemployment. Men': ['5.7'],
#  'Registered unemployment. By sex_Registered unemployment. Women': ['4.0'],
#  'Registered unemployment. By sex_Registered unemployment': ['9.7'],
#  'Family dwellings. By type_Main family dwellings': ['62'],
#  'Family dwellings. By type_Secondary family dwellings': ['28'],
#  'Family dwellings. By type_Family dwellings': ['90'],
#  'Urban property tax (IBI)_IBI. Receipts': ['181'],
#  'Urban property tax (IBI)_IBI. Taxable base by receipt': ['20265.2'],
#  'Urban property tax (IBI)_IBI. Integral quota by receipt': ['121.6'],
#  'Personal Income Tax (IRPF)_IRPF. Taxable base by declarer': ['10332'],
#  'Personal Income Tax (IRPF)_IRPF. Resulting quotafrom self-payment by declarer': ['3477'],
#  'Used agricultural area (UAA)_Cultivated land surface': ['412'],
#  'Used agricultural area (UAA)_Permanent pasture surface': ['1048'],
#  'Used agricultural area (UAA)_Used agricultural area': ['1460'],
#  'Cultivated land. By type of crop_Herbaceous crops': ['226'],
#  'Cultivated land. By type of crop_Fruit trees crops': ['169'],
#  'Cultivated land. By type of crop_Olives crops': ['6'],
#  'Cultivated land. By type of crop_Vines crops': ['1'],
#  'Cultivated land. By type of crop_Other crops': ['11'],
#  'Cultivated land. By type of crop_Cultivated land': ['412'],
#  'Farms. By land ownership_Farms without land': ['3'],
#  'Farms. By land ownership_Farms with land': ['27'],
#  'Farms. By land ownership_Farms with and without land': ['30'],
#  'Farms. By livestock ownership_Farms without livestock': ['11'],
#  'Farms. By livestock ownership_Farms with livestock': ['19'],
#  'Farms. By livestock ownership_Farms with and without livestock': ['30'],
#  'Head of livestock. By species_Bovine head': ['195'],
#  'Head of livestock. By species_Ovine head': ['2030'],
#  'Head of livestock. By species_Caprine head': ['176'],
#  'Head of livestock. By species_Porcine head': ['7289'],
#  'Head of livestock. By species_Avian head': ['75010'],
#  'Head of livestock. By species_Female rabbits head': ['150'],
#  'Head of livestock. By species_Equine head': ['9'],
#  'Housing construction_State subsidised housing starts': ['0'],
#  'Housing construction_Housing starts': ['0'],
#  'Tourist accommodation_Hotels': ['0'],
#  'Tourist accommodation_Hotel beds': ['0'],
#  'Tourist accommodation_Campsites': ['0'],
#  'Tourist accommodation_Campsite places': ['0'],
#  'Tourist accommodation_Rural tourism': ['2'],
#  'Tourist accommodation_Rural tourism beds': ['9'],
#  'Fleet of vehicles_Cars': ['175'],
#  'Fleet of vehicles_Motorcycles': ['13'],
#  'Fleet of vehicles_Industrial vehicles': ['189'],
#  'Fleet of vehicles_Other  vehicles': ['135'],
#  'Fleet of vehicles_Fleet of vehicles': ['512'],
#  'Municipal waste_Municipal waste per capita': ['1.24'],
#  'Municipal waste_Selective collection of municipal waste': ['40.7'],
#  'Industrial waste_Establishments with yearly ind. waste declarations': ['0'],
#  'Industrial waste_Industrial waste': ['0.00'],
#  'AFTE population (annual full time equivalents)_Resident population': 'nan',
#  'AFTE population (annual full time equivalents)_AFTE seasonal population': 'nan',
#  'AFTE population (annual full time equivalents)_AFTE population': 'nan',
#  'AFTE population (annual full time equivalents)_AFTE pop. / resident pop.': 'nan',
#  'Households. By size_One person households': 'nan',
#  'Households. By size_Two person households': 'nan',
#  'Households. By size_Three person households': 'nan',
#  'Households. By size_Four or more person households': 'nan',
#  'Households. By size_Households': 'nan',
#  'Households. By type of nucleus_One person households': 'nan',
#  'Households. By type of nucleus_Households with childless couple': 'nan',
#  'Households. By type of nucleus_Househols with couples with children': 'nan',
#  'Households. By type of nucleus_Single parent households': 'nan',
#  'Households. By type of nucleus_Households': 'nan',
#  'Municipal elections_Electors (Municipal elec.)': 'nan',
#  'Municipal elections_Turnout (Municipal elec.)': 'nan',
#  'Population. By relation with economic activity_Employed population': 'nan',
#  'Population. By relation with economic activity_Unemployed population': 'nan',
#  'Population. By relation with economic activity_Active population': 'nan',
#  'Population. By relation with economic activity_Inactive population': 'nan',
#  'Population. By relation with economic activity_Population of 16 years and over': 'nan',
#  'Affiliations to S. S. self-employed system according to the location of the affilation. By sectors_Industry affiliations to Self-Employed SS': 'nan',
#  'Family dwellings. By type_Vacant family dwellings': 'nan',
#  'Main family dwellings. By type of tenancy_Rented main family homes': 'nan',
#  'Main family dwellings. By type of tenancy_Main family homes': 'nan',
#  'Main family dwellings. By useful surface area_Main family homes from 61 to 90 m²': 'nan',
#  'Main family dwellings. By useful surface area_Main family homes from 91 to 120 m²': 'nan',
#  'Main family dwellings. By useful surface area_Main family homes from 121 m² and over': 'nan',
#  'Main family dwellings. By useful surface area_Main family homes': 'nan',
#  'Small area socioeconomic index (STI). Index Catalonia=100_Small area socioeconòmic index': 'nan',
#  'Gross domestic product (2019 Benchmark revision)_GDP': 'nan',
#  'Gross domestic product (2019 Benchmark revision)_GDP per capita': 'nan',
#  'Gross domestic product (2019 Benchmark revision)_GDP per capita (Catalonia=100)': 'nan',
#  'Gross value added (2019 Benchmark revision). By sectors_GVA agriculture': 'nan',
#  'Gross value added (2019 Benchmark revision). By sectors_GVA industry': 'nan',
#  'Gross value added (2019 Benchmark revision). By sectors_GVA construction': 'nan',
#  'Gross value added (2019 Benchmark revision). By sectors_GAV services': 'nan',
#  'Gross value added (2019 Benchmark revision). By sectors_GVA': 'nan',
#  'Gross disposable household income. 2019 Benchmark revision_GDHI': 'nan',
#  'Gross disposable household income. 2019 Benchmark revision_GDHI per capita': 'nan',
#  'Gross disposable household income. 2019 Benchmark revision_GDHI per capita (Catalonia=100)': 'nan',
#  'Wealth tax (IPPF)_IPPF. Total wealth per declarer': 'nan',
#  'Wealth tax (IPPF)_IPPF. Declaration of real assets': 'nan',
#  'Wealth tax (IPPF)_IPPF. Declaration of financial assets': 'nan',
#  'Main family dwellings. By type of tenancy_Owned main family homes': 'nan'}

# %%
lst = ['s', 'a']
lst.remove('a')
lst.remove('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-dc4131317194> in <module>
#       1 lst = ['s', 'a']
#       2 lst.remove('a')
# ----> 3 lst.remove('a')
#
# ValueError: list.remove(x): x not in list

# %%
test.get('080018')
# Out:
# dict_keys(['fitxes'])

# %%
lst1 = ['a', 'b', 'c']
lst2 = (True, False, True)
for i, ls in enumerate(lst1):
    print(i)
# Out:
# 0
# 1
# 2

# %%
nl = [l1 for i, l1 in enumerate(lst1) if lst2[i]==True]

# %%
nl
# Out:
# ['a', 'c']

# %%
dict(zip(lst1, lst2))
# Out:
# {'a': True, 'b': False, 'c': True}

# %%
lst1.index('p')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-245164bcced2> in <module>
# ----> 1 lst1.index('p')
#
# ValueError: 'p' is not in list

# %%
t = {'a':[False,1], 'b':[True, 2], 'c':[False, 3]}

# %%
for i, (k, v) in enumerate(t.items()):
    print(i, k, v[0], v[1])
# Out:
# 0 a False 1
# 1 b True 2
# 2 c False 3

# %%
a = [(k, v[1]) for i, (k, v) in enumerate(t.items()) if v[0] == False]

# %%
a, b = (2, None)

# %%
(a, b) == (2, 1)
# Out:
# False

# %%
a is not None and b is not None
# Out:
# False

# %%
from json_parser import *

# %%
parser = JSONParser(json_value='v', json_column='calt')

# %%
parser.add_json(d=test['080018'], name='080018')

# %%
len(parser._containers['080018']._dict['Women'][4][4][4][4][4][4])
# Out:
# 5

# %%
parser.parse_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-95bf300d8fd9> in <module>
# ----> 1 parser.parse_data()
#
# ~\Documents\GitHub\CatalanLanguagePrediction\Notebook exploration\json_parser.py in parse_data(self)
#      72
#      73     def parse_data(self):
# ---> 74         self._parse_all()
#      75
#      76     def containers(self):
#
# ~\Documents\GitHub\CatalanLanguagePrediction\Notebook exploration\json_parser.py in _parse_all(self)
#      85             self._containers[_name] = self._current_container
#      86             for _name, _container in self._containers.items():
# ---> 87                 _container._assemble_pandas()
#      88
#      89     def _parse(self, _j):
#
# ~\Documents\GitHub\CatalanLanguagePrediction\Notebook exploration\json_parser.py in _assemble_pandas(self)
#      11
#      12         def _assemble_pandas(self):
# ---> 13             self._pandas = pd.DataFrame(self._dict)
#      14
#      15         def _add_kv(self, key, value):
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length
