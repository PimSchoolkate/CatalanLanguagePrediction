# %%
import json
import requests
import time
import string
import pandas as pd
from json_parser import *
from data_collector import *

# %%
idescat = idescat_API(batch_size=100)

# %%
type(idescat)
# Out:
# data_collector.idescat_API

# %%
idescat.collect_and_parse_data()
# Out:
# The estimated time to download the amount of data is 0.38333333333333336 minutes
# (0/100). Data from 250019 was downloaded in 0.2902500629425049 seconds
# (1/100). Data from 080018 was downloaded in 0.20442795753479004 seconds
# (2/100). Data from 250024 was downloaded in 0.26927804946899414 seconds
# (3/100). Data from 250030 was downloaded in 0.3261547088623047 seconds
# (4/100). Data from 080023 was downloaded in 0.26628875732421875 seconds
# (5/100). Data from 170010 was downloaded in 0.30294370651245117 seconds
# (6/100). Data from 080142 was downloaded in 0.2094414234161377 seconds
# (7/100). Data from 430017 was downloaded in 0.19957876205444336 seconds
# (8/100). Data from 170025 was downloaded in 0.2953155040740967 seconds
# (9/100). Data from 250387 was downloaded in 0.19547510147094727 seconds
# (10/100). Data from 250045 was downloaded in 0.26928043365478516 seconds
# (11/100). Data from 250058 was downloaded in 0.28324317932128906 seconds
# (12/100). Data from 250061 was downloaded in 0.2710270881652832 seconds
# (13/100). Data from 170031 was downloaded in 0.19547295570373535 seconds
# (14/100). Data from 250077 was downloaded in 0.2722458839416504 seconds
# (15/100). Data from 250083 was downloaded in 0.26529502868652344 seconds
# (16/100). Data from 250096 was downloaded in 0.20644283294677734 seconds
# (17/100). Data from 430022 was downloaded in 0.2667393684387207 seconds
# (18/100). Data from 430038 was downloaded in 0.25148653984069824 seconds
# (19/100). Data from 170046 was downloaded in 0.28025031089782715 seconds
# (20/100). Data from 430043 was downloaded in 0.19049429893493652 seconds
# (21/100). Data from 250100 was downloaded in 0.27925753593444824 seconds
# (22/100). Data from 250117 was downloaded in 0.34108638763427734 seconds
# (23/100). Data from 250122 was downloaded in 0.22630977630615234 seconds
# (24/100). Data from 430056 was downloaded in 0.26030516624450684 seconds
# (25/100). Data from 439044 was downloaded in 0.2852358818054199 seconds
# (26/100). Data from 430069 was downloaded in 0.24434685707092285 seconds
# (27/100). Data from 430075 was downloaded in 0.31316256523132324 seconds
# (28/100). Data from 080039 was downloaded in 0.2232522964477539 seconds
# (29/100). Data from 430081 was downloaded in 0.29224658012390137 seconds
# (30/100). Data from 250138 was downloaded in 0.21838736534118652 seconds
# (31/100). Data from 250143 was downloaded in 0.29421377182006836 seconds
# (32/100). Data from 430094 was downloaded in 0.30817556381225586 seconds
# (33/100). Data from 250156 was downloaded in 0.3052999973297119 seconds
# (34/100). Data from 250169 was downloaded in 0.21944260597229004 seconds
# (35/100). Data from 250175 was downloaded in 0.21639442443847656 seconds
# (36/100). Data from 430108 was downloaded in 0.21742033958435059 seconds
# (37/100). Data from 250194 was downloaded in 0.2922172546386719 seconds
# (38/100). Data from 250208 was downloaded in 0.21043682098388672 seconds
# (39/100). Data from 250215 was downloaded in 0.30455803871154785 seconds
# (40/100). Data from 430115 was downloaded in 0.3171374797821045 seconds
# (41/100). Data from 250220 was downloaded in 0.2952108383178711 seconds
# (42/100). Data from 170062 was downloaded in 0.31017231941223145 seconds
# (43/100). Data from 080044 was downloaded in 0.2314157485961914 seconds
# (44/100). Data from 250236 was downloaded in 0.35374021530151367 seconds
# (45/100). Data from 250241 was downloaded in 0.30817580223083496 seconds
# (46/100). Data from 430120 was downloaded in 0.32413387298583984 seconds
# (47/100). Data from 170078 was downloaded in 0.3121776580810547 seconds
# (48/100). Data from 430136 was downloaded in 0.224440336227417 seconds
# (49/100). Data from 080057 was downloaded in 0.32408618927001953 seconds
# (50/100). Data from 439060 was downloaded in 0.2183089256286621 seconds
# (51/100). Data from 430141 was downloaded in 0.29021549224853516 seconds
# (52/100). Data from 170084 was downloaded in 0.31418466567993164 seconds
# (53/100). Data from 250273 was downloaded in 0.20043444633483887 seconds
# (54/100). Data from 250292 was downloaded in 0.20690703392028809 seconds
# (55/100). Data from 430167 was downloaded in 0.3590116500854492 seconds
# (56/100). Data from 430154 was downloaded in 0.2872319221496582 seconds
# (57/100). Data from 170097 was downloaded in 0.2812480926513672 seconds
# (58/100). Data from 080060 was downloaded in 0.4007112979888916 seconds
# (59/100). Data from 080076 was downloaded in 0.3141331672668457 seconds
# (60/100). Data from 170101 was downloaded in 0.23437285423278809 seconds
# (61/100). Data from 080082 was downloaded in 0.1984694004058838 seconds
# (62/100). Data from 430173 was downloaded in 0.2892270088195801 seconds
# (63/100). Data from 080095 was downloaded in 0.31870031356811523 seconds
# (64/100). Data from 170118 was downloaded in 0.22140741348266602 seconds
# (65/100). Data from 430189 was downloaded in 0.2762610912322998 seconds
# (66/100). Data from 250313 was downloaded in 0.2563209533691406 seconds
# (67/100). Data from 250328 was downloaded in 0.26831555366516113 seconds
# (68/100). Data from 080109 was downloaded in 0.3182060718536377 seconds
# (69/100). Data from 250334 was downloaded in 0.2215108871459961 seconds
# (70/100). Data from 250349 was downloaded in 0.304215669631958 seconds
# (71/100). Data from 430192 was downloaded in 0.3699829578399658 seconds
# (72/100). Data from 250365 was downloaded in 0.33791422843933105 seconds
# (73/100). Data from 250371 was downloaded in 0.30314111709594727 seconds
# (74/100). Data from 080116 was downloaded in 0.31322717666625977 seconds
# (75/100). Data from 080121 was downloaded in 0.3091733455657959 seconds
# (76/100). Data from 170123 was downloaded in 0.3279452323913574 seconds
# (77/100). Data from 080137 was downloaded in 0.2084178924560547 seconds
# (78/100). Data from 080155 was downloaded in 0.22941160202026367 seconds
# (79/100). Data from 089045 was downloaded in 0.2283642292022705 seconds
# (80/100). Data from 080168 was downloaded in 0.30219221115112305 seconds
# (81/100). Data from 250390 was downloaded in 0.2857646942138672 seconds
# (82/100). Data from 250404 was downloaded in 0.21545052528381348 seconds
# (83/100). Data from 080174 was downloaded in 0.2902243137359619 seconds
# (84/100). Data from 080180 was downloaded in 0.21838974952697754 seconds
# (85/100). Data from 430206 was downloaded in 0.2812473773956299 seconds
# (86/100). Data from 170157 was downloaded in 0.27381324768066406 seconds
# (87/100). Data from 250411 was downloaded in 0.31149792671203613 seconds
# (88/100). Data from 430213 was downloaded in 0.3151564598083496 seconds
# (89/100). Data from 082520 was downloaded in 0.22170758247375488 seconds
# (90/100). Data from 080193 was downloaded in 0.24675464630126953 seconds
# (91/100). Data from 250426 was downloaded in 0.3361022472381592 seconds
# (92/100). Data from 170160 was downloaded in 0.2238626480102539 seconds
# (93/100). Data from 250447 was downloaded in 0.2882416248321533 seconds
# (94/100). Data from 430228 was downloaded in 0.2982010841369629 seconds
# (95/100). Data from 250450 was downloaded in 0.2862255573272705 seconds
# (96/100). Data from 080207 was downloaded in 0.22641944885253906 seconds
# (97/100). Data from 170139 was downloaded in 0.20841670036315918 seconds
# (98/100). Data from 250463 was downloaded in 0.2034587860107422 seconds
# (99/100). Data from 250485 was downloaded in 0.2243967056274414 seconds
# Retrieved data of 99 municipalities in 27 seconds
# The estimated time to download the amount of data is 0.38333333333333336 minutes
# (0/100). Data from 251706 was downloaded in 0.263369083404541 seconds
# (1/100). Data from 170182 was downloaded in 0.31815218925476074 seconds
# (2/100). Data from 250479 was downloaded in 0.3393290042877197 seconds
# (3/100). Data from 250498 was downloaded in 0.3001983165740967 seconds
# (4/100). Data from 430234 was downloaded in 0.2922208309173584 seconds
# (5/100). Data from 080214 was downloaded in 0.19560885429382324 seconds
# (6/100). Data from 250501 was downloaded in 0.19946694374084473 seconds
# (7/100). Data from 430249 was downloaded in 0.22754359245300293 seconds
# (8/100). Data from 250518 was downloaded in 0.22041082382202148 seconds
# (9/100). Data from 250523 was downloaded in 0.3431398868560791 seconds
# (10/100). Data from 250539 was downloaded in 0.3216376304626465 seconds
# (11/100). Data from 430252 was downloaded in 0.363936185836792 seconds
# (12/100). Data from 430265 was downloaded in 0.31713342666625977 seconds
# (13/100). Data from 080229 was downloaded in 0.2204129695892334 seconds
# (14/100). Data from 170195 was downloaded in 0.31662797927856445 seconds
# (15/100). Data from 170209 was downloaded in 0.3311498165130615 seconds
# (16/100). Data from 170216 was downloaded in 0.2573118209838867 seconds
# (17/100). Data from 080235 was downloaded in 0.362032413482666 seconds
# (18/100). Data from 250557 was downloaded in 0.31660938262939453 seconds
# (19/100). Data from 170221 was downloaded in 0.23615455627441406 seconds
# (20/100). Data from 430271 was downloaded in 0.23038506507873535 seconds
# (21/100). Data from 430287 was downloaded in 0.3181478977203369 seconds
# (22/100). Data from 172348 was downloaded in 0.23361563682556152 seconds
# (23/100). Data from 430290 was downloaded in 0.33314013481140137 seconds
# (24/100). Data from 170237 was downloaded in 0.3631763458251953 seconds
# (25/100). Data from 170293 was downloaded in 0.22440171241760254 seconds
# (26/100). Data from 170242 was downloaded in 0.2431962490081787 seconds
# (27/100). Data from 430304 was downloaded in 0.31319475173950195 seconds
# (28/100). Data from 250576 was downloaded in 0.383181095123291 seconds
# (29/100). Data from 170255 was downloaded in 0.22341060638427734 seconds
# (30/100). Data from 250582 was downloaded in 0.36211299896240234 seconds
# (31/100). Data from 430311 was downloaded in 0.3435995578765869 seconds
# (32/100). Data from 170268 was downloaded in 0.30562376976013184 seconds
# (33/100). Data from 080240 was downloaded in 0.23038482666015625 seconds
# (34/100). Data from 250595 was downloaded in 0.3380928039550781 seconds
# (35/100). Data from 430326 was downloaded in 0.2922184467315674 seconds
# (36/100). Data from 430332 was downloaded in 0.3323326110839844 seconds
# (37/100). Data from 250560 was downloaded in 0.29218339920043945 seconds
# (38/100). Data from 430347 was downloaded in 0.3031909465789795 seconds
# (39/100). Data from 170274 was downloaded in 0.21243023872375488 seconds
# (40/100). Data from 080253 was downloaded in 0.30826783180236816 seconds
# (41/100). Data from 080266 was downloaded in 0.3171544075012207 seconds
# (42/100). Data from 170280 was downloaded in 0.22207307815551758 seconds
# (43/100). Data from 430350 was downloaded in 0.3121650218963623 seconds
# (44/100). Data from 250609 was downloaded in 0.29238295555114746 seconds
# (45/100). Data from 170314 was downloaded in 0.30817484855651855 seconds
# (46/100). Data from 170307 was downloaded in 0.33610105514526367 seconds
# (47/100). Data from 080272 was downloaded in 0.22099852561950684 seconds
# (48/100). Data from 250616 was downloaded in 0.3430821895599365 seconds
# (49/100). Data from 430363 was downloaded in 0.32413291931152344 seconds
# (50/100). Data from 080288 was downloaded in 0.21547484397888184 seconds
# (51/100). Data from 080291 was downloaded in 0.21040654182434082 seconds
# (52/100). Data from 080305 was downloaded in 0.31017613410949707 seconds
# (53/100). Data from 170329 was downloaded in 0.3702352046966553 seconds
# (54/100). Data from 080312 was downloaded in 0.34706878662109375 seconds
# (55/100). Data from 430379 was downloaded in 0.3480691909790039 seconds
# (56/100). Data from 080348 was downloaded in 0.3071770668029785 seconds
# (57/100). Data from 080327 was downloaded in 0.24434781074523926 seconds
# (58/100). Data from 170335 was downloaded in 0.36006736755371094 seconds
# (59/100). Data from 080333 was downloaded in 0.3161509037017822 seconds
# (60/100). Data from 080351 was downloaded in 0.3241443634033203 seconds
# (61/100). Data from 080370 was downloaded in 0.31316041946411133 seconds
# (62/100). Data from 080386 was downloaded in 0.32114338874816895 seconds
# (63/100). Data from 080364 was downloaded in 0.3510603904724121 seconds
# (64/100). Data from 170340 was downloaded in 0.22838878631591797 seconds
# (65/100). Data from 250621 was downloaded in 0.17453360557556152 seconds
# (66/100). Data from 439039 was downloaded in 0.35205793380737305 seconds
# (67/100). Data from 430385 was downloaded in 0.23836421966552734 seconds
# (68/100). Data from 170353 was downloaded in 0.35704541206359863 seconds
# (69/100). Data from 170366 was downloaded in 0.24235057830810547 seconds
# (70/100). Data from 170372 was downloaded in 0.20547747611999512 seconds
# (71/100). Data from 080399 was downloaded in 0.3470463752746582 seconds
# (72/100). Data from 170388 was downloaded in 0.2732689380645752 seconds
# (73/100). Data from 170391 was downloaded in 0.2622997760772705 seconds
# (74/100). Data from 250637 was downloaded in 0.20844101905822754 seconds
# (75/100). Data from 170405 was downloaded in 0.3201446533203125 seconds
# (76/100). Data from 080403 was downloaded in 0.32215332984924316 seconds
# (77/100). Data from 439076 was downloaded in 0.33010315895080566 seconds
# (78/100). Data from 080410 was downloaded in 0.33909106254577637 seconds
# (79/100). Data from 080425 was downloaded in 0.339601993560791 seconds
# (80/100). Data from 170412 was downloaded in 0.31804943084716797 seconds
# (81/100). Data from 080431 was downloaded in 0.22137904167175293 seconds
# (82/100). Data from 430398 was downloaded in 0.3201422691345215 seconds
# (83/100). Data from 430402 was downloaded in 0.2973599433898926 seconds
# (84/100). Data from 080446 was downloaded in 0.2270808219909668 seconds
# (85/100). Data from 170427 was downloaded in 0.2326962947845459 seconds
# (86/100). Data from 080459 was downloaded in 0.18949508666992188 seconds
# (87/100). Data from 080462 was downloaded in 0.3560445308685303 seconds
# (88/100). Data from 080478 was downloaded in 0.22539925575256348 seconds
# (89/100). Data from 080484 was downloaded in 0.20998048782348633 seconds
# (90/100). Data from 430419 was downloaded in 0.30016422271728516 seconds
# (91/100). Data from 170448 was downloaded in 0.2214827537536621 seconds
# (92/100). Data from 080497 was downloaded in 0.313230037689209 seconds
# (93/100). Data from 080575 was downloaded in 0.2094419002532959 seconds
# (94/100). Data from 259046 was downloaded in 0.33496856689453125 seconds
# (95/100). Data from 170486 was downloaded in 0.235368013381958 seconds
# (96/100). Data from 250642 was downloaded in 0.20599794387817383 seconds
# (97/100). Data from 080522 was downloaded in 0.3078341484069824 seconds
# (98/100). Data from 080500 was downloaded in 0.5107038021087646 seconds
# (99/100). Data from 080517 was downloaded in 0.2254009246826172 seconds
# Retrieved data of 99 municipalities in 28 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 idescat.collect_and_parse_data()
#
# File ~\Documents\GitHub\CatalanLanguagePrediction\src\data_collector.py:84, in idescat_API.collect_and_parse_data(self)
#      82 json_parser.parse_data()
#      83 pd_dict = change_dicts_to_panda_df(json_parser.containers())
# ---> 84 df = concatenate_dict_of_dfs(pd_dict)
#      85 df.to_csv(f'../data/data_{batch}.csv')
#      86 batch = batch + 1
#
# File ~\Documents\GitHub\CatalanLanguagePrediction\src\data_collector.py:108, in concatenate_dict_of_dfs(dfs)
#     106         df = d
#     107     else:
# --> 108         df = pd.concat([df, d])
#     109 return df
#
# File ~\.virtualenvs\CatalanLanguagePrediction\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\.virtualenvs\CatalanLanguagePrediction\lib\site-packages\pandas\core\reshape\concat.py:307, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     103 """
#     104 Concatenate pandas objects along a particular axis with optional set logic
#     105 along the other axes.
#    (...)
#     292 ValueError: Indexes have overlapping values: ['a']
#     293 """
#     294 op = _Concatenator(
#     295     objs,
#     296     axis=axis,
#    (...)
#     304     sort=sort,
#     305 )
# --> 307 return op.get_result()
#
# File ~\.virtualenvs\CatalanLanguagePrediction\lib\site-packages\pandas\core\reshape\concat.py:532, in _Concatenator.get_result(self)
#     528             indexers[ax] = obj_labels.get_indexer(new_labels)
#     530     mgrs_indexers.append((obj._mgr, indexers))
# --> 532 new_data = concatenate_managers(
#     533     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     534 )
#     535 if not self.copy:
#     536     new_data._consolidate_inplace()
#
# File ~\.virtualenvs\CatalanLanguagePrediction\lib\site-packages\pandas\core\internals\concat.py:192, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     189 if isinstance(mgrs_indexers[0][0], ArrayManager):
#     190     return _concatenate_array_managers(mgrs_indexers, axes, concat_axis, copy)
# --> 192 concat_plans = [
#     193     _get_mgr_concatenation_plan(mgr, indexers) for mgr, indexers in mgrs_indexers
#     194 ]
#     195 concat_plan = _combine_concat_plans(concat_plans, concat_axis)
#     196 blocks = []
#
# File ~\.virtualenvs\CatalanLanguagePrediction\lib\site-packages\pandas\core\internals\concat.py:193, in <listcomp>(.0)
#     189 if isinstance(mgrs_indexers[0][0], ArrayManager):
#     190     return _concatenate_array_managers(mgrs_indexers, axes, concat_axis, copy)
#     192 concat_plans = [
# --> 193     _get_mgr_concatenation_plan(mgr, indexers) for mgr, indexers in mgrs_indexers
#     194 ]
#     195 concat_plan = _combine_concat_plans(concat_plans, concat_axis)
#     196 blocks = []
#
# File ~\.virtualenvs\CatalanLanguagePrediction\lib\site-packages\pandas\core\internals\concat.py:273, in _get_mgr_concatenation_plan(mgr, indexers)
#     270     # error: Incompatible types in assignment (expression has type "None", variable
#     271     # has type "ndarray")
#     272     ax0_indexer = None  # type: ignore[assignment]
# --> 273     blknos = mgr.blknos
#     274     blklocs = mgr.blklocs
#     276 plan = []
#
# File ~\.virtualenvs\CatalanLanguagePrediction\lib\site-packages\pandas\core\internals\managers.py:170, in BaseBlockManager.blknos(self)
#     160 """
#     161 Suppose we want to find the array corresponding to our i'th column.
#     162
#    (...)
#     166 self.blocks[self.blknos[i]]
#     167 """
#     168 if self._blknos is None:
#     169     # Note: these can be altered by other BlockManager methods.
# --> 170     self._rebuild_blknos_and_blklocs()
#     172 return self._blknos
#
# File ~\.virtualenvs\CatalanLanguagePrediction\lib\site-packages\pandas\core\internals\managers.py:236, in BaseBlockManager._rebuild_blknos_and_blklocs(self)
#     234     rl = blk.mgr_locs
#     235     new_blknos[rl.indexer] = blkno
# --> 236     new_blklocs[rl.indexer] = np.arange(len(rl))
#     238 if (new_blknos == -1).any():
#     239     # TODO: can we avoid this?  it isn't cheap
#     240     raise AssertionError("Gaps in blk ref_locs")
#
# KeyboardInterrupt:

# %%
class idescat_API:    
    def __init__(self):
        meta = self.create_meta_municipalities()
        requested = []

    def request_mun(mun_id):
        mun_res = requests.get("https://api.idescat.cat/emex/v1/dades.json?tipus=mun?id={}&lang=en".format(mun_id))
        return mun_res.json()


    def create_meta_municipalities():
        """
        Retrieves dictionairy containing all municipalities from the idescat. Structure of the dict:
            key: id of the mun
            value: name of the mun
        """
        meta = {}
        mun_res = requests.get("https://api.idescat.cat/emex/v1/dades.json?lang=en")
        mun_meta = mun_res.json()
        muns = mun_meta['fitxes']['cols']['col']
        for mun in muns:
            meta[mun['id']] = mun['content']

        return meta


    def collect_all_muns(meta, n):
        """
        Collects all the data of each municipality, making a request every n seconds
        """

        start_time = time.time()
        municipality_dict = {}
        total = len(meta.keys())
        estimated_time = total * (n + 0.23)
        failed_list = []
        print(f'The estimated time to download the amount of data is {estimated_time/60} minutes')
        for i, identifier in enumerate(meta.keys()):
            try:
                municipality_dict[identifier] = request_mun(identifier)
            except:
                failed_list.append(identifier)
            time.sleep(n)
            if i == 0:
                last_time = time.time()
                print(f'({i}/{total}). Data from {identifier} was downloaded in {last_time - start_time} seconds')
            else:
                now = time.time()
                print(f'({i}/{total}). Data from {identifier} was downloaded in {now - last_time} seconds')
                last_time = now
        print("Retrieved data of {} municipalities in {} seconds".format(i ,int(time.time()-start_time)))
        return municipality_dict


def add_muns_to_parser(parser, muns):
    for name, mun in muns.items():
        parser.add_json(d=mun, name=name)
        

def change_dicts_to_panda_df(dicts):
    pd_dict = {}
    for name, dct in dicts.items():
        df = pd.DataFrame(dct, index=[name])
        pd_dict[name] = df
    return pd_dict        


def concatenate_dict_of_dfs(dfs):
    for i, (name, d) in enumerate(dfs.items()):
        if i == 0:
            df = d
        else:
            df = pd.concat([df, d])
    return df


def pipeline():
    meta = create_meta_municipalities()
    json_data = collect_all_muns(meta, n=0)
    json_parser = JSONParser(json_value='v', json_column_name=['c', 'calt'])
    json_parser.add_value_map(value_splitter)
    json_parser.add_key_map(homogenize_key)
    add_muns_to_parser(json_parser, json_data)
    json_parser.parse_data()
    pd_dict = change_dicts_to_panda_df(json_parser.containers())
    df = concatenate_dict_of_dfs(pd_dict)
    df.to_csv('data.csv')

# %%
pipeline()
# Out:
# The estimated time to download the amount of data is 3.791166666666667 minutes
# (0/989). Data from 250019 was downloaded in 0.21543598175048828 seconds
# (1/989). Data from 080018 was downloaded in 0.31439685821533203 seconds
# (2/989). Data from 250024 was downloaded in 0.23918628692626953 seconds
# (3/989). Data from 250030 was downloaded in 0.36741018295288086 seconds
# (4/989). Data from 080023 was downloaded in 0.33695220947265625 seconds
# (5/989). Data from 170010 was downloaded in 0.3125014305114746 seconds
# (6/989). Data from 080142 was downloaded in 0.280073881149292 seconds
# (7/989). Data from 430017 was downloaded in 0.26648926734924316 seconds
# (8/989). Data from 170025 was downloaded in 0.16276311874389648 seconds
# (9/989). Data from 250387 was downloaded in 0.1767277717590332 seconds
# (10/989). Data from 250045 was downloaded in 0.17409181594848633 seconds
# (11/989). Data from 250058 was downloaded in 0.20891261100769043 seconds
# (12/989). Data from 250061 was downloaded in 0.17540931701660156 seconds
# (13/989). Data from 170031 was downloaded in 0.16652870178222656 seconds
# (14/989). Data from 250077 was downloaded in 0.21074843406677246 seconds
# (15/989). Data from 250083 was downloaded in 0.17221713066101074 seconds
# (16/989). Data from 250096 was downloaded in 0.17704057693481445 seconds
# (17/989). Data from 430022 was downloaded in 0.15536093711853027 seconds
# (18/989). Data from 430038 was downloaded in 0.2600562572479248 seconds
# (19/989). Data from 170046 was downloaded in 0.21075439453125 seconds
# (20/989). Data from 430043 was downloaded in 0.2776768207550049 seconds
# (21/989). Data from 250100 was downloaded in 0.26467394828796387 seconds
# (22/989). Data from 250117 was downloaded in 0.2185988426208496 seconds
# (23/989). Data from 250122 was downloaded in 0.23032164573669434 seconds
# (24/989). Data from 430056 was downloaded in 0.2040853500366211 seconds
# (25/989). Data from 439044 was downloaded in 0.21827125549316406 seconds
# (26/989). Data from 430069 was downloaded in 0.23686838150024414 seconds
# (27/989). Data from 430075 was downloaded in 0.258558988571167 seconds
# (28/989). Data from 080039 was downloaded in 0.2321949005126953 seconds
# (29/989). Data from 430081 was downloaded in 0.25774312019348145 seconds
# (30/989). Data from 250138 was downloaded in 0.17898201942443848 seconds
# (31/989). Data from 250143 was downloaded in 0.17487430572509766 seconds
# (32/989). Data from 430094 was downloaded in 0.18072056770324707 seconds
# (33/989). Data from 250156 was downloaded in 0.1663224697113037 seconds
# (34/989). Data from 250169 was downloaded in 0.1938784122467041 seconds
# (35/989). Data from 250175 was downloaded in 0.17711901664733887 seconds
# (36/989). Data from 430108 was downloaded in 0.14348483085632324 seconds
# (37/989). Data from 250194 was downloaded in 0.1991431713104248 seconds
# (38/989). Data from 250208 was downloaded in 0.14827585220336914 seconds
# (39/989). Data from 250215 was downloaded in 0.16406679153442383 seconds
# (40/989). Data from 430115 was downloaded in 0.14104557037353516 seconds
# (41/989). Data from 250220 was downloaded in 0.12984466552734375 seconds
# (42/989). Data from 170062 was downloaded in 0.1597902774810791 seconds
# (43/989). Data from 080044 was downloaded in 0.13604450225830078 seconds
# (44/989). Data from 250236 was downloaded in 0.16309523582458496 seconds
# (45/989). Data from 250241 was downloaded in 0.2893373966217041 seconds
# (46/989). Data from 430120 was downloaded in 0.14794254302978516 seconds
# (47/989). Data from 170078 was downloaded in 0.18952202796936035 seconds
# (48/989). Data from 430136 was downloaded in 0.2570993900299072 seconds
# (49/989). Data from 080057 was downloaded in 0.1581871509552002 seconds
# (50/989). Data from 439060 was downloaded in 0.20618653297424316 seconds
# (51/989). Data from 430141 was downloaded in 0.13403534889221191 seconds
# (52/989). Data from 170084 was downloaded in 0.19704651832580566 seconds
# (53/989). Data from 250273 was downloaded in 0.218583345413208 seconds
# (54/989). Data from 250292 was downloaded in 0.22036170959472656 seconds
# (55/989). Data from 430167 was downloaded in 0.3270585536956787 seconds
# (56/989). Data from 430154 was downloaded in 0.23624587059020996 seconds
# (57/989). Data from 170097 was downloaded in 0.22232699394226074 seconds
# (58/989). Data from 080060 was downloaded in 0.16551852226257324 seconds
# (59/989). Data from 080076 was downloaded in 0.19914650917053223 seconds
# (60/989). Data from 170101 was downloaded in 0.15769600868225098 seconds
# (61/989). Data from 080082 was downloaded in 0.15089988708496094 seconds
# (62/989). Data from 430173 was downloaded in 0.20881938934326172 seconds
# (63/989). Data from 080095 was downloaded in 0.22792720794677734 seconds
# (64/989). Data from 170118 was downloaded in 0.18142437934875488 seconds
# (65/989). Data from 430189 was downloaded in 0.2529160976409912 seconds
# (66/989). Data from 250313 was downloaded in 0.13805365562438965 seconds
# (67/989). Data from 250328 was downloaded in 0.18414735794067383 seconds
# (68/989). Data from 080109 was downloaded in 0.20851373672485352 seconds
# (69/989). Data from 250334 was downloaded in 0.2673349380493164 seconds
# (70/989). Data from 250349 was downloaded in 0.2581660747528076 seconds
# (71/989). Data from 430192 was downloaded in 0.24190998077392578 seconds
# (72/989). Data from 250365 was downloaded in 0.2206897735595703 seconds
# (73/989). Data from 250371 was downloaded in 0.2216353416442871 seconds
# (74/989). Data from 080116 was downloaded in 0.17200708389282227 seconds
# (75/989). Data from 080121 was downloaded in 0.1644585132598877 seconds
# (76/989). Data from 170123 was downloaded in 0.17753887176513672 seconds
# (77/989). Data from 080137 was downloaded in 1.2065606117248535 seconds
# (78/989). Data from 080155 was downloaded in 0.14551615715026855 seconds
# (79/989). Data from 089045 was downloaded in 0.16448378562927246 seconds
# (80/989). Data from 080168 was downloaded in 0.148085355758667 seconds
# (81/989). Data from 250390 was downloaded in 0.15619730949401855 seconds
# (82/989). Data from 250404 was downloaded in 0.20684313774108887 seconds
# (83/989). Data from 080174 was downloaded in 0.1838078498840332 seconds
# (84/989). Data from 080180 was downloaded in 0.16995644569396973 seconds
# (85/989). Data from 430206 was downloaded in 0.1724393367767334 seconds
# (86/989). Data from 170157 was downloaded in 0.1762685775756836 seconds
# (87/989). Data from 250411 was downloaded in 0.16671991348266602 seconds
# (88/989). Data from 430213 was downloaded in 0.22428464889526367 seconds
# (89/989). Data from 082520 was downloaded in 0.16388678550720215 seconds
# (90/989). Data from 080193 was downloaded in 0.19477534294128418 seconds
# (91/989). Data from 250426 was downloaded in 0.12149333953857422 seconds
# (92/989). Data from 170160 was downloaded in 0.21801161766052246 seconds
# (93/989). Data from 250447 was downloaded in 0.1951746940612793 seconds
# (94/989). Data from 430228 was downloaded in 0.24869275093078613 seconds
# (95/989). Data from 250450 was downloaded in 0.2806239128112793 seconds
# (96/989). Data from 080207 was downloaded in 0.1916365623474121 seconds
# (97/989). Data from 170139 was downloaded in 0.264385461807251 seconds
# (98/989). Data from 250463 was downloaded in 0.30970239639282227 seconds
# (99/989). Data from 250485 was downloaded in 0.37430262565612793 seconds
# (100/989). Data from 251706 was downloaded in 0.2446596622467041 seconds
# (101/989). Data from 170182 was downloaded in 0.21366119384765625 seconds
# (102/989). Data from 250479 was downloaded in 0.23421335220336914 seconds
# (103/989). Data from 250498 was downloaded in 0.14303231239318848 seconds
# (104/989). Data from 430234 was downloaded in 0.17813849449157715 seconds
# (105/989). Data from 080214 was downloaded in 0.15877604484558105 seconds
# (106/989). Data from 250501 was downloaded in 0.13996005058288574 seconds
# (107/989). Data from 430249 was downloaded in 0.16989421844482422 seconds
# (108/989). Data from 250518 was downloaded in 0.16910958290100098 seconds
# (109/989). Data from 250523 was downloaded in 0.1676926612854004 seconds
# (110/989). Data from 250539 was downloaded in 0.1894993782043457 seconds
# (111/989). Data from 430252 was downloaded in 0.14181208610534668 seconds
# (112/989). Data from 430265 was downloaded in 0.20306849479675293 seconds
# (113/989). Data from 080229 was downloaded in 0.2973313331604004 seconds
# (114/989). Data from 170195 was downloaded in 0.19401049613952637 seconds
# (115/989). Data from 170209 was downloaded in 0.3214378356933594 seconds
# (116/989). Data from 170216 was downloaded in 0.18487858772277832 seconds
# (117/989). Data from 080235 was downloaded in 0.20999932289123535 seconds
# (118/989). Data from 250557 was downloaded in 0.15411019325256348 seconds
# (119/989). Data from 170221 was downloaded in 0.26456308364868164 seconds
# (120/989). Data from 430271 was downloaded in 0.1543872356414795 seconds
# (121/989). Data from 430287 was downloaded in 0.2021493911743164 seconds
# (122/989). Data from 172348 was downloaded in 0.20662784576416016 seconds
# (123/989). Data from 430290 was downloaded in 0.26853251457214355 seconds
# (124/989). Data from 170237 was downloaded in 0.3069946765899658 seconds
# (125/989). Data from 170293 was downloaded in 0.26975107192993164 seconds
# (126/989). Data from 170242 was downloaded in 0.20100951194763184 seconds
# (127/989). Data from 430304 was downloaded in 0.14722514152526855 seconds
# (128/989). Data from 250576 was downloaded in 0.1546635627746582 seconds
# (129/989). Data from 170255 was downloaded in 0.16948485374450684 seconds
# (130/989). Data from 250582 was downloaded in 0.18406939506530762 seconds
# (131/989). Data from 430311 was downloaded in 0.8658561706542969 seconds
# (132/989). Data from 170268 was downloaded in 0.15484213829040527 seconds
# (133/989). Data from 080240 was downloaded in 0.1368391513824463 seconds
# (134/989). Data from 250595 was downloaded in 0.1368579864501953 seconds
# (135/989). Data from 430326 was downloaded in 0.15513134002685547 seconds
# (136/989). Data from 430332 was downloaded in 0.2346329689025879 seconds
# (137/989). Data from 250560 was downloaded in 0.22525858879089355 seconds
# (138/989). Data from 430347 was downloaded in 0.21956348419189453 seconds
# (139/989). Data from 170274 was downloaded in 0.20611882209777832 seconds
# (140/989). Data from 080253 was downloaded in 0.17087650299072266 seconds
# (141/989). Data from 080266 was downloaded in 0.34189534187316895 seconds
# (142/989). Data from 170280 was downloaded in 0.16527748107910156 seconds
# (143/989). Data from 430350 was downloaded in 0.27141618728637695 seconds
# (144/989). Data from 250609 was downloaded in 0.21223926544189453 seconds
# (145/989). Data from 170314 was downloaded in 0.21928739547729492 seconds
# (146/989). Data from 170307 was downloaded in 0.2842574119567871 seconds
# (147/989). Data from 080272 was downloaded in 0.2359790802001953 seconds
# (148/989). Data from 250616 was downloaded in 0.1595439910888672 seconds
# (149/989). Data from 430363 was downloaded in 0.17584466934204102 seconds
# (150/989). Data from 080288 was downloaded in 0.21981573104858398 seconds
# (151/989). Data from 080291 was downloaded in 0.16442227363586426 seconds
# (152/989). Data from 080305 was downloaded in 0.20656943321228027 seconds
# (153/989). Data from 170329 was downloaded in 0.16539907455444336 seconds
# (154/989). Data from 080312 was downloaded in 0.22033953666687012 seconds
# (155/989). Data from 430379 was downloaded in 0.20789384841918945 seconds
# (156/989). Data from 080348 was downloaded in 0.17791438102722168 seconds
# (157/989). Data from 080327 was downloaded in 0.14336824417114258 seconds
# (158/989). Data from 170335 was downloaded in 0.20354270935058594 seconds
# (159/989). Data from 080333 was downloaded in 0.2309434413909912 seconds
# (160/989). Data from 080351 was downloaded in 0.2810485363006592 seconds
# (161/989). Data from 080370 was downloaded in 0.17000246047973633 seconds
# (162/989). Data from 080386 was downloaded in 0.3115265369415283 seconds
# (163/989). Data from 080364 was downloaded in 0.1918177604675293 seconds
# (164/989). Data from 170340 was downloaded in 0.24689674377441406 seconds
# (165/989). Data from 250621 was downloaded in 0.1665174961090088 seconds
# (166/989). Data from 439039 was downloaded in 0.22937750816345215 seconds
# (167/989). Data from 430385 was downloaded in 0.22974276542663574 seconds
# (168/989). Data from 170353 was downloaded in 0.25306224822998047 seconds
# (169/989). Data from 170366 was downloaded in 0.23808026313781738 seconds
# (170/989). Data from 170372 was downloaded in 0.21862149238586426 seconds
# (171/989). Data from 080399 was downloaded in 0.2189188003540039 seconds
# (172/989). Data from 170388 was downloaded in 0.18337178230285645 seconds
# (173/989). Data from 170391 was downloaded in 0.19954943656921387 seconds
# (174/989). Data from 250637 was downloaded in 0.16547298431396484 seconds
# (175/989). Data from 170405 was downloaded in 0.15800786018371582 seconds
# (176/989). Data from 080403 was downloaded in 0.18852996826171875 seconds
# (177/989). Data from 439076 was downloaded in 0.1693575382232666 seconds
# (178/989). Data from 080410 was downloaded in 0.23962759971618652 seconds
# (179/989). Data from 080425 was downloaded in 0.2327566146850586 seconds
# (180/989). Data from 170412 was downloaded in 0.22464466094970703 seconds
# (181/989). Data from 080431 was downloaded in 0.16688323020935059 seconds
# (182/989). Data from 430398 was downloaded in 0.12395930290222168 seconds
# (183/989). Data from 430402 was downloaded in 0.20642471313476562 seconds
# (184/989). Data from 080446 was downloaded in 0.2221682071685791 seconds
# (185/989). Data from 170427 was downloaded in 0.2246549129486084 seconds
# (186/989). Data from 080459 was downloaded in 0.19379663467407227 seconds
# (187/989). Data from 080462 was downloaded in 0.2184145450592041 seconds
# (188/989). Data from 080478 was downloaded in 0.224107027053833 seconds
# (189/989). Data from 080484 was downloaded in 0.20704126358032227 seconds
# (190/989). Data from 430419 was downloaded in 0.13271713256835938 seconds
# (191/989). Data from 170448 was downloaded in 0.23895716667175293 seconds
# (192/989). Data from 080497 was downloaded in 0.2565908432006836 seconds
# (193/989). Data from 080575 was downloaded in 0.235748291015625 seconds
# (194/989). Data from 259046 was downloaded in 0.310305118560791 seconds
# (195/989). Data from 170486 was downloaded in 0.8386530876159668 seconds
# (196/989). Data from 250642 was downloaded in 0.15100431442260742 seconds
# (197/989). Data from 080522 was downloaded in 0.13190841674804688 seconds
# (198/989). Data from 080500 was downloaded in 0.16487884521484375 seconds
# (199/989). Data from 080517 was downloaded in 0.16742634773254395 seconds
# (200/989). Data from 080538 was downloaded in 0.23519659042358398 seconds
# (201/989). Data from 080543 was downloaded in 0.16483449935913086 seconds
# (202/989). Data from 080556 was downloaded in 0.1329491138458252 seconds
# (203/989). Data from 250674 was downloaded in 0.19313287734985352 seconds
# (204/989). Data from 080569 was downloaded in 0.14983892440795898 seconds
# (205/989). Data from 080581 was downloaded in 0.2919340133666992 seconds
# (206/989). Data from 170464 was downloaded in 0.2597823143005371 seconds
# (207/989). Data from 080608 was downloaded in 0.17934036254882812 seconds
# (208/989). Data from 080594 was downloaded in 0.17751049995422363 seconds
# (209/989). Data from 080615 was downloaded in 0.21198177337646484 seconds
# (210/989). Data from 080620 was downloaded in 0.1967449188232422 seconds
# (211/989). Data from 250680 was downloaded in 0.21241450309753418 seconds
# (212/989). Data from 170470 was downloaded in 0.18783855438232422 seconds
# (213/989). Data from 250693 was downloaded in 0.17866778373718262 seconds
# (214/989). Data from 080636 was downloaded in 0.3261427879333496 seconds
# (215/989). Data from 250707 was downloaded in 0.34668540954589844 seconds
# (216/989). Data from 080641 was downloaded in 0.38971757888793945 seconds
# (217/989). Data from 430424 was downloaded in 0.2408907413482666 seconds
# (218/989). Data from 080654 was downloaded in 0.17412447929382324 seconds
# (219/989). Data from 080667 was downloaded in 0.18682456016540527 seconds
# (220/989). Data from 430430 was downloaded in 0.17644929885864258 seconds
# (221/989). Data from 250714 was downloaded in 0.21535253524780273 seconds
# (222/989). Data from 171899 was downloaded in 0.1735384464263916 seconds
# (223/989). Data from 170499 was downloaded in 0.16551899909973145 seconds
# (224/989). Data from 080673 was downloaded in 0.2036266326904297 seconds
# (225/989). Data from 082687 was downloaded in 0.21755456924438477 seconds
# (226/989). Data from 082665 was downloaded in 0.15276718139648438 seconds
# (227/989). Data from 080689 was downloaded in 0.1818535327911377 seconds
# (228/989). Data from 250729 was downloaded in 0.1783127784729004 seconds
# (229/989). Data from 250735 was downloaded in 0.2187809944152832 seconds
# (230/989). Data from 170502 was downloaded in 0.20760560035705566 seconds
# (231/989). Data from 170519 was downloaded in 0.23291873931884766 seconds
# (232/989). Data from 250740 was downloaded in 0.23792529106140137 seconds
# (233/989). Data from 250753 was downloaded in 0.19530606269836426 seconds
# (234/989). Data from 250766 was downloaded in 0.14169597625732422 seconds
# (235/989). Data from 170545 was downloaded in 0.16028118133544922 seconds
# (236/989). Data from 250772 was downloaded in 0.18695592880249023 seconds
# (237/989). Data from 080692 was downloaded in 0.29842352867126465 seconds
# (238/989). Data from 430458 was downloaded in 0.22962546348571777 seconds
# (239/989). Data from 080706 was downloaded in 0.24085092544555664 seconds
# (240/989). Data from 170558 was downloaded in 0.20724058151245117 seconds
# (241/989). Data from 251636 was downloaded in 0.2762942314147949 seconds
# (242/989). Data from 251615 was downloaded in 0.1883378028869629 seconds
# (243/989). Data from 430461 was downloaded in 0.14049053192138672 seconds
# (244/989). Data from 430477 was downloaded in 0.14780139923095703 seconds
# (245/989). Data from 080713 was downloaded in 0.18093156814575195 seconds
# (246/989). Data from 430483 was downloaded in 0.16849040985107422 seconds
# (247/989). Data from 080728 was downloaded in 0.1863250732421875 seconds
# (248/989). Data from 250788 was downloaded in 0.17824578285217285 seconds
# (249/989). Data from 170577 was downloaded in 0.17189788818359375 seconds
# (250/989). Data from 080734 was downloaded in 0.18073153495788574 seconds
# (251/989). Data from 170561 was downloaded in 0.1502702236175537 seconds
# (252/989). Data from 430496 was downloaded in 0.16612935066223145 seconds
# (253/989). Data from 430509 was downloaded in 0.16582989692687988 seconds
# (254/989). Data from 170583 was downloaded in 0.17421722412109375 seconds
# (255/989). Data from 179011 was downloaded in 0.2249622344970703 seconds
# (256/989). Data from 080749 was downloaded in 0.23410463333129883 seconds
# (257/989). Data from 250791 was downloaded in 0.19295644760131836 seconds
# (258/989). Data from 430516 was downloaded in 0.2222435474395752 seconds
# (259/989). Data from 170600 was downloaded in 0.21137332916259766 seconds
# (260/989). Data from 170617 was downloaded in 0.19642066955566406 seconds
# (261/989). Data from 439018 was downloaded in 0.16231751441955566 seconds
# (262/989). Data from 080752 was downloaded in 0.6988005638122559 seconds
# (263/989). Data from 430537 was downloaded in 0.18103623390197754 seconds
# (264/989). Data from 170622 was downloaded in 0.36810898780822754 seconds
# (265/989). Data from 080765 was downloaded in 0.1944580078125 seconds
# (266/989). Data from 170638 was downloaded in 0.13972997665405273 seconds
# (267/989). Data from 250812 was downloaded in 0.19426822662353516 seconds
# (268/989). Data from 430542 was downloaded in 0.24749445915222168 seconds
# (269/989). Data from 080771 was downloaded in 0.13724207878112793 seconds
# (270/989). Data from 170643 was downloaded in 0.14261388778686523 seconds
# (271/989). Data from 170656 was downloaded in 0.16403484344482422 seconds
# (272/989). Data from 250827 was downloaded in 0.15666699409484863 seconds
# (273/989). Data from 080787 was downloaded in 0.20504546165466309 seconds
# (274/989). Data from 082541 was downloaded in 0.16102361679077148 seconds
# (275/989). Data from 250886 was downloaded in 0.12348365783691406 seconds
# (276/989). Data from 080790 was downloaded in 0.16594862937927246 seconds
# (277/989). Data from 250851 was downloaded in 0.15445661544799805 seconds
# (278/989). Data from 250864 was downloaded in 0.3085172176361084 seconds
# (279/989). Data from 250870 was downloaded in 0.23302245140075684 seconds
# (280/989). Data from 430555 was downloaded in 0.21927118301391602 seconds
# (281/989). Data from 170059 was downloaded in 0.22849273681640625 seconds
# (282/989). Data from 250899 was downloaded in 0.20566534996032715 seconds
# (283/989). Data from 430568 was downloaded in 0.19033598899841309 seconds
# (284/989). Data from 430574 was downloaded in 0.20448637008666992 seconds
# (285/989). Data from 081347 was downloaded in 0.33310532569885254 seconds
# (286/989). Data from 080804 was downloaded in 0.15839910507202148 seconds
# (287/989). Data from 259084 was downloaded in 0.26282429695129395 seconds
# (288/989). Data from 430580 was downloaded in 0.2973654270172119 seconds
# (289/989). Data from 170669 was downloaded in 0.2391514778137207 seconds
# (290/989). Data from 430593 was downloaded in 0.15783429145812988 seconds
# (291/989). Data from 170675 was downloaded in 0.20885014533996582 seconds
# (292/989). Data from 430607 was downloaded in 0.20500755310058594 seconds
# (293/989). Data from 250925 was downloaded in 0.14482402801513672 seconds
# (294/989). Data from 080826 was downloaded in 0.15093207359313965 seconds
# (295/989). Data from 080811 was downloaded in 0.15540218353271484 seconds
# (296/989). Data from 170681 was downloaded in 0.18120741844177246 seconds
# (297/989). Data from 080832 was downloaded in 0.17991137504577637 seconds
# (298/989). Data from 250931 was downloaded in 0.16960883140563965 seconds
# (299/989). Data from 080847 was downloaded in 0.1778860092163086 seconds
# (300/989). Data from 080850 was downloaded in 0.1497650146484375 seconds
# (301/989). Data from 170694 was downloaded in 0.13286375999450684 seconds
# (302/989). Data from 170708 was downloaded in 0.20250439643859863 seconds
# (303/989). Data from 170715 was downloaded in 0.20593023300170898 seconds
# (304/989). Data from 250946 was downloaded in 0.15178632736206055 seconds
# (305/989). Data from 179026 was downloaded in 0.15894794464111328 seconds
# (306/989). Data from 430614 was downloaded in 0.1944119930267334 seconds
# (307/989). Data from 170736 was downloaded in 0.24071741104125977 seconds
# (308/989). Data from 170741 was downloaded in 0.23675823211669922 seconds
# (309/989). Data from 080863 was downloaded in 0.24694323539733887 seconds
# (310/989). Data from 430629 was downloaded in 0.20461082458496094 seconds
# (311/989). Data from 250962 was downloaded in 0.27924323081970215 seconds
# (312/989). Data from 250978 was downloaded in 0.2375330924987793 seconds
# (313/989). Data from 080902 was downloaded in 0.28806161880493164 seconds
# (314/989). Data from 430635 was downloaded in 0.23974871635437012 seconds
# (315/989). Data from 080879 was downloaded in 0.1700577735900879 seconds
# (316/989). Data from 430640 was downloaded in 0.18218612670898438 seconds
# (317/989). Data from 430653 was downloaded in 0.13994979858398438 seconds
# (318/989). Data from 430666 was downloaded in 0.18406319618225098 seconds
# (319/989). Data from 080885 was downloaded in 0.17482471466064453 seconds
# (320/989). Data from 170754 was downloaded in 0.19140267372131348 seconds
# (321/989). Data from 170767 was downloaded in 0.1333906650543213 seconds
# (322/989). Data from 170773 was downloaded in 0.16669154167175293 seconds
# (323/989). Data from 080898 was downloaded in 0.21474528312683105 seconds
# (324/989). Data from 250984 was downloaded in 0.18051671981811523 seconds
# (325/989). Data from 080919 was downloaded in 0.1377732753753662 seconds
# (326/989). Data from 170789 was downloaded in 0.137953519821167 seconds
# (327/989). Data from 259123 was downloaded in 0.13802599906921387 seconds
# (328/989). Data from 430672 was downloaded in 0.2636544704437256 seconds
# (329/989). Data from 170792 was downloaded in 0.2745962142944336 seconds
# (330/989). Data from 080924 was downloaded in 0.17310166358947754 seconds
# (331/989). Data from 080930 was downloaded in 0.217573881149292 seconds
# (332/989). Data from 430688 was downloaded in 0.22086405754089355 seconds
# (333/989). Data from 250997 was downloaded in 0.23259639739990234 seconds
# (334/989). Data from 170806 was downloaded in 0.19016337394714355 seconds
# (335/989). Data from 251001 was downloaded in 0.1729583740234375 seconds
# (336/989). Data from 080945 was downloaded in 0.9623076915740967 seconds
# (337/989). Data from 251018 was downloaded in 0.22275137901306152 seconds
# (338/989). Data from 080958 was downloaded in 0.19190168380737305 seconds
# (339/989). Data from 251023 was downloaded in 0.13843965530395508 seconds
# (340/989). Data from 080961 was downloaded in 0.15390896797180176 seconds
# (341/989). Data from 251039 was downloaded in 0.1844785213470459 seconds
# (342/989). Data from 251057 was downloaded in 0.16067099571228027 seconds
# (343/989). Data from 251044 was downloaded in 0.17682170867919922 seconds
# (344/989). Data from 430691 was downloaded in 0.1631777286529541 seconds
# (345/989). Data from 080977 was downloaded in 0.1437540054321289 seconds
# (346/989). Data from 170813 was downloaded in 0.20382094383239746 seconds
# (347/989). Data from 080996 was downloaded in 0.1562962532043457 seconds
# (348/989). Data from 430705 was downloaded in 0.1289224624633789 seconds
# (349/989). Data from 170828 was downloaded in 0.221785306930542 seconds
# (350/989). Data from 251095 was downloaded in 0.25200939178466797 seconds
# (351/989). Data from 259031 was downloaded in 0.2409203052520752 seconds
# (352/989). Data from 251109 was downloaded in 0.18810176849365234 seconds
# (353/989). Data from 251116 was downloaded in 0.18689537048339844 seconds
# (354/989). Data from 081000 was downloaded in 0.285947322845459 seconds
# (355/989). Data from 430712 was downloaded in 0.21601653099060059 seconds
# (356/989). Data from 081017 was downloaded in 0.1654343605041504 seconds
# (357/989). Data from 081629 was downloaded in 0.15408921241760254 seconds
# (358/989). Data from 170834 was downloaded in 0.21071147918701172 seconds
# (359/989). Data from 081022 was downloaded in 0.270831823348999 seconds
# (360/989). Data from 251155 was downloaded in 0.24744820594787598 seconds
# (361/989). Data from 170849 was downloaded in 0.2139902114868164 seconds
# (362/989). Data from 251137 was downloaded in 0.2294926643371582 seconds
# (363/989). Data from 251121 was downloaded in 0.6910779476165771 seconds
# (364/989). Data from 251142 was downloaded in 0.16199898719787598 seconds
# (365/989). Data from 170852 was downloaded in 0.21230602264404297 seconds
# (366/989). Data from 170865 was downloaded in 0.19514012336730957 seconds
# (367/989). Data from 081038 was downloaded in 0.18882060050964355 seconds
# (368/989). Data from 259101 was downloaded in 0.15937495231628418 seconds
# (369/989). Data from 170871 was downloaded in 0.2207045555114746 seconds
# (370/989). Data from 251180 was downloaded in 0.13599920272827148 seconds
# (371/989). Data from 251193 was downloaded in 0.12982702255249023 seconds
# (372/989). Data from 251214 was downloaded in 0.14543962478637695 seconds
# (373/989). Data from 251229 was downloaded in 0.15622425079345703 seconds
# (374/989). Data from 081043 was downloaded in 0.1870899200439453 seconds
# (375/989). Data from 170887 was downloaded in 0.14350557327270508 seconds
# (376/989). Data from 251235 was downloaded in 0.21019601821899414 seconds
# (377/989). Data from 251240 was downloaded in 0.18177127838134766 seconds
# (378/989). Data from 081056 was downloaded in 0.22669696807861328 seconds
# (379/989). Data from 170890 was downloaded in 0.23213791847229004 seconds
# (380/989). Data from 170904 was downloaded in 0.13685393333435059 seconds
# (381/989). Data from 170911 was downloaded in 0.18575119972229004 seconds
# (382/989). Data from 170926 was downloaded in 0.22453594207763672 seconds
# (383/989). Data from 251253 was downloaded in 1.6347472667694092 seconds
# (384/989). Data from 251266 was downloaded in 0.1410233974456787 seconds
# (385/989). Data from 251207 was downloaded in 0.16530537605285645 seconds
# (386/989). Data from 170932 was downloaded in 0.24622797966003418 seconds
# (387/989). Data from 251272 was downloaded in 0.19370031356811523 seconds
# (388/989). Data from 081075 was downloaded in 0.149766206741333 seconds
# (389/989). Data from 081081 was downloaded in 0.17515778541564941 seconds
# (390/989). Data from 251288 was downloaded in 0.17221283912658691 seconds
# (391/989). Data from 081069 was downloaded in 0.2344980239868164 seconds
# (392/989). Data from 170947 was downloaded in 0.2054300308227539 seconds
# (393/989). Data from 430727 was downloaded in 0.20792198181152344 seconds
# (394/989). Data from 251291 was downloaded in 0.17493939399719238 seconds
# (395/989). Data from 430733 was downloaded in 0.13823223114013672 seconds
# (396/989). Data from 430748 was downloaded in 0.2052171230316162 seconds
# (397/989). Data from 170950 was downloaded in 0.18300151824951172 seconds
# (398/989). Data from 170963 was downloaded in 0.19046473503112793 seconds
# (399/989). Data from 081094 was downloaded in 0.1523275375366211 seconds
# (400/989). Data from 171024 was downloaded in 0.34996604919433594 seconds
# (401/989). Data from 171030 was downloaded in 0.24277043342590332 seconds
# (402/989). Data from 170979 was downloaded in 0.34623122215270996 seconds
# (403/989). Data from 170985 was downloaded in 0.31708216667175293 seconds
# (404/989). Data from 251333 was downloaded in 0.22874665260314941 seconds
# (405/989). Data from 251305 was downloaded in 0.2617359161376953 seconds
# (406/989). Data from 081108 was downloaded in 0.13703298568725586 seconds
# (407/989). Data from 081115 was downloaded in 0.21009254455566406 seconds
# (408/989). Data from 081120 was downloaded in 0.18097877502441406 seconds
# (409/989). Data from 081136 was downloaded in 0.15738272666931152 seconds
# (410/989). Data from 430764 was downloaded in 0.19795966148376465 seconds
# (411/989). Data from 430751 was downloaded in 0.21319794654846191 seconds
# (412/989). Data from 082423 was downloaded in 0.21123027801513672 seconds
# (413/989). Data from 081141 was downloaded in 0.1736135482788086 seconds
# (414/989). Data from 081154 was downloaded in 0.22860455513000488 seconds
# (415/989). Data from 430770 was downloaded in 0.24863243103027344 seconds
# (416/989). Data from 171002 was downloaded in 0.1907210350036621 seconds
# (417/989). Data from 430786 was downloaded in 0.20121479034423828 seconds
# (418/989). Data from 081167 was downloaded in 0.17267227172851562 seconds
# (419/989). Data from 081173 was downloaded in 0.21268582344055176 seconds
# (420/989). Data from 430799 was downloaded in 0.1982259750366211 seconds
# (421/989). Data from 081189 was downloaded in 0.22031211853027344 seconds
# (422/989). Data from 430803 was downloaded in 0.2536890506744385 seconds
# (423/989). Data from 430810 was downloaded in 0.1983349323272705 seconds
# (424/989). Data from 081192 was downloaded in 0.18093490600585938 seconds
# (425/989). Data from 430825 was downloaded in 0.27196478843688965 seconds
# (426/989). Data from 251312 was downloaded in 0.2402784824371338 seconds
# (427/989). Data from 171019 was downloaded in 0.3043859004974365 seconds
# (428/989). Data from 251327 was downloaded in 0.2192990779876709 seconds
# (429/989). Data from 081206 was downloaded in 0.16859197616577148 seconds
# (430/989). Data from 081213 was downloaded in 0.18070697784423828 seconds
# (431/989). Data from 081228 was downloaded in 0.21318840980529785 seconds
# (432/989). Data from 251348 was downloaded in 0.16685128211975098 seconds
# (433/989). Data from 170998 was downloaded in 0.17839264869689941 seconds
# (434/989). Data from 171058 was downloaded in 0.16920185089111328 seconds
# (435/989). Data from 430831 was downloaded in 0.15014076232910156 seconds
# (436/989). Data from 251351 was downloaded in 0.20262956619262695 seconds
# (437/989). Data from 430846 was downloaded in 0.1761784553527832 seconds
# (438/989). Data from 081385 was downloaded in 0.14539170265197754 seconds
# (439/989). Data from 430859 was downloaded in 0.1354522705078125 seconds
# (440/989). Data from 081234 was downloaded in 0.15483379364013672 seconds
# (441/989). Data from 251370 was downloaded in 0.22240400314331055 seconds
# (442/989). Data from 171061 was downloaded in 0.22494792938232422 seconds
# (443/989). Data from 081249 was downloaded in 0.17446589469909668 seconds
# (444/989). Data from 171077 was downloaded in 0.2475147247314453 seconds
# (445/989). Data from 251364 was downloaded in 0.20626258850097656 seconds
# (446/989). Data from 081287 was downloaded in 0.163893461227417 seconds
# (447/989). Data from 081271 was downloaded in 0.20090126991271973 seconds
# (448/989). Data from 430918 was downloaded in 0.1494617462158203 seconds
# (449/989). Data from 171100 was downloaded in 0.28186869621276855 seconds
# (450/989). Data from 430923 was downloaded in 0.22235822677612305 seconds
# (451/989). Data from 171096 was downloaded in 0.27245211601257324 seconds
# (452/989). Data from 430862 was downloaded in 0.3592534065246582 seconds
# (453/989). Data from 430884 was downloaded in 0.23855924606323242 seconds
# (454/989). Data from 081252 was downloaded in 0.17731213569641113 seconds
# (455/989). Data from 081304 was downloaded in 0.17947816848754883 seconds
# (456/989). Data from 251399 was downloaded in 0.13595914840698242 seconds
# (457/989). Data from 081311 was downloaded in 0.1427161693572998 seconds
# (458/989). Data from 251403 was downloaded in 0.17068910598754883 seconds
# (459/989). Data from 430897 was downloaded in 0.19976449012756348 seconds
# (460/989). Data from 251386 was downloaded in 0.17129063606262207 seconds
# (461/989). Data from 081265 was downloaded in 0.15084052085876465 seconds
# (462/989). Data from 081326 was downloaded in 0.13673186302185059 seconds
# (463/989). Data from 081332 was downloaded in 0.1376955509185791 seconds
# (464/989). Data from 430901 was downloaded in 0.13738155364990234 seconds
# (465/989). Data from 081350 was downloaded in 0.16808724403381348 seconds
# (466/989). Data from 251425 was downloaded in 0.20934581756591797 seconds
# (467/989). Data from 251410 was downloaded in 0.14751839637756348 seconds
# (468/989). Data from 251431 was downloaded in 0.22603869438171387 seconds
# (469/989). Data from 081363 was downloaded in 0.19459843635559082 seconds
# (470/989). Data from 081379 was downloaded in 0.27962636947631836 seconds
# (471/989). Data from 430939 was downloaded in 0.21032381057739258 seconds
# (472/989). Data from 430944 was downloaded in 0.30594420433044434 seconds
# (473/989). Data from 430957 was downloaded in 0.21444344520568848 seconds
# (474/989). Data from 430960 was downloaded in 0.24626970291137695 seconds
# (475/989). Data from 081290 was downloaded in 0.4150526523590088 seconds
# (476/989). Data from 081398 was downloaded in 0.3343074321746826 seconds
# (477/989). Data from 251459 was downloaded in 0.2572455406188965 seconds
# (478/989). Data from 250254 was downloaded in 0.24814343452453613 seconds
# (479/989). Data from 081402 was downloaded in 0.2489619255065918 seconds
# (480/989). Data from 081419 was downloaded in 0.29907655715942383 seconds
# (481/989). Data from 171117 was downloaded in 0.19601821899414062 seconds
# (482/989). Data from 251462 was downloaded in 0.2586054801940918 seconds
# (483/989). Data from 081424 was downloaded in 0.2364945411682129 seconds
# (484/989). Data from 430976 was downloaded in 0.21719813346862793 seconds
# (485/989). Data from 430982 was downloaded in 0.2341291904449463 seconds
# (486/989). Data from 251484 was downloaded in 0.16340875625610352 seconds
# (487/989). Data from 081430 was downloaded in 0.24904108047485352 seconds
# (488/989). Data from 171122 was downloaded in 0.20573139190673828 seconds
# (489/989). Data from 081458 was downloaded in 0.22145843505859375 seconds
# (490/989). Data from 081461 was downloaded in 0.3062267303466797 seconds
# (491/989). Data from 081477 was downloaded in 0.20804238319396973 seconds
# (492/989). Data from 251497 was downloaded in 0.23635387420654297 seconds
# (493/989). Data from 251500 was downloaded in 0.25352931022644043 seconds
# (494/989). Data from 251517 was downloaded in 0.2406008243560791 seconds
# (495/989). Data from 081483 was downloaded in 0.47188901901245117 seconds
# (496/989). Data from 081496 was downloaded in 0.25669145584106445 seconds
# (497/989). Data from 171143 was downloaded in 0.18859338760375977 seconds
# (498/989). Data from 251522 was downloaded in 0.30823493003845215 seconds
# (499/989). Data from 081445 was downloaded in 0.16114306449890137 seconds
# (500/989). Data from 251538 was downloaded in 0.2274625301361084 seconds
# (501/989). Data from 251543 was downloaded in 0.12972426414489746 seconds
# (502/989). Data from 171156 was downloaded in 0.1350727081298828 seconds
# (503/989). Data from 251556 was downloaded in 0.198211669921875 seconds
# (504/989). Data from 081509 was downloaded in 0.25966382026672363 seconds
# (505/989). Data from 081516 was downloaded in 0.23324036598205566 seconds
# (506/989). Data from 081521 was downloaded in 0.23846864700317383 seconds
# (507/989). Data from 081537 was downloaded in 0.2302103042602539 seconds
# (508/989). Data from 251569 was downloaded in 0.247283935546875 seconds
# (509/989). Data from 171169 was downloaded in 0.2512216567993164 seconds
# (510/989). Data from 251575 was downloaded in 0.17861700057983398 seconds
# (511/989). Data from 081542 was downloaded in 0.2529764175415039 seconds
# (512/989). Data from 081555 was downloaded in 0.21987676620483398 seconds
# (513/989). Data from 171175 was downloaded in 0.14643573760986328 seconds
# (514/989). Data from 171181 was downloaded in 0.22849512100219727 seconds
# (515/989). Data from 251581 was downloaded in 0.35868215560913086 seconds
# (516/989). Data from 171194 was downloaded in 0.4222433567047119 seconds
# (517/989). Data from 171215 was downloaded in 0.3237459659576416 seconds
# (518/989). Data from 171208 was downloaded in 0.37006258964538574 seconds
# (519/989). Data from 081568 was downloaded in 0.249833345413208 seconds
# (520/989). Data from 431009 was downloaded in 0.23425960540771484 seconds
# (521/989). Data from 081574 was downloaded in 0.1569044589996338 seconds
# (522/989). Data from 430995 was downloaded in 0.19100069999694824 seconds
# (523/989). Data from 089058 was downloaded in 0.26874256134033203 seconds
# (524/989). Data from 171236 was downloaded in 0.2698988914489746 seconds
# (525/989). Data from 171241 was downloaded in 0.27974605560302734 seconds
# (526/989). Data from 081580 was downloaded in 0.1336839199066162 seconds
# (527/989). Data from 171254 was downloaded in 0.11708712577819824 seconds
# (528/989). Data from 081593 was downloaded in 0.2783012390136719 seconds
# (529/989). Data from 171267 was downloaded in 0.35265040397644043 seconds
# (530/989). Data from 431016 was downloaded in 0.2501394748687744 seconds
# (531/989). Data from 171289 was downloaded in 0.24265289306640625 seconds
# (532/989). Data from 431021 was downloaded in 0.4003016948699951 seconds
# (533/989). Data from 171292 was downloaded in 0.2022082805633545 seconds
# (534/989). Data from 251641 was downloaded in 0.24046683311462402 seconds
# (535/989). Data from 171306 was downloaded in 0.2633795738220215 seconds
# (536/989). Data from 081607 was downloaded in 0.29962801933288574 seconds
# (537/989). Data from 431037 was downloaded in 0.43126726150512695 seconds
# (538/989). Data from 171328 was downloaded in 0.2550840377807617 seconds
# (539/989). Data from 251654 was downloaded in 0.17022347450256348 seconds
# (540/989). Data from 431042 was downloaded in 0.21465373039245605 seconds
# (541/989). Data from 081614 was downloaded in 0.21343111991882324 seconds
# (542/989). Data from 431055 was downloaded in 0.22633934020996094 seconds
# (543/989). Data from 081635 was downloaded in 0.17996692657470703 seconds
# (544/989). Data from 431068 was downloaded in 0.20755577087402344 seconds
# (545/989). Data from 251667 was downloaded in 0.2642209529876709 seconds
# (546/989). Data from 251673 was downloaded in 0.26098132133483887 seconds
# (547/989). Data from 431074 was downloaded in 0.1620481014251709 seconds
# (548/989). Data from 431080 was downloaded in 0.23451447486877441 seconds
# (549/989). Data from 081640 was downloaded in 0.2779850959777832 seconds
# (550/989). Data from 171334 was downloaded in 0.33218836784362793 seconds
# (551/989). Data from 171349 was downloaded in 0.32173752784729004 seconds
# (552/989). Data from 259118 was downloaded in 0.14901447296142578 seconds
# (553/989). Data from 251689 was downloaded in 0.330580472946167 seconds
# (554/989). Data from 251692 was downloaded in 0.24031805992126465 seconds
# (555/989). Data from 081653 was downloaded in 0.3427889347076416 seconds
# (556/989). Data from 081666 was downloaded in 0.36812639236450195 seconds
# (557/989). Data from 431093 was downloaded in 0.29207539558410645 seconds
# (558/989). Data from 431107 was downloaded in 0.4027121067047119 seconds
# (559/989). Data from 431114 was downloaded in 0.3239119052886963 seconds
# (560/989). Data from 251713 was downloaded in 0.3140370845794678 seconds
# (561/989). Data from 431129 was downloaded in 0.23886895179748535 seconds
# (562/989). Data from 081672 was downloaded in 0.16201138496398926 seconds
# (563/989). Data from 431135 was downloaded in 0.21398544311523438 seconds
# (564/989). Data from 250306 was downloaded in 0.24269723892211914 seconds
# (565/989). Data from 171352 was downloaded in 0.22825050354003906 seconds
# (566/989). Data from 251734 was downloaded in 0.2281491756439209 seconds
# (567/989). Data from 081825 was downloaded in 0.2858116626739502 seconds
# (568/989). Data from 431418 was downloaded in 0.20798230171203613 seconds
# (569/989). Data from 081688 was downloaded in 0.2648966312408447 seconds
# (570/989). Data from 171365 was downloaded in 0.24457931518554688 seconds
# (571/989). Data from 251728 was downloaded in 0.32660603523254395 seconds
# (572/989). Data from 171371 was downloaded in 0.22430920600891113 seconds
# (573/989). Data from 431140 was downloaded in 0.3509821891784668 seconds
# (574/989). Data from 171404 was downloaded in 0.26396894454956055 seconds
# (575/989). Data from 171387 was downloaded in 0.269514799118042 seconds
# (576/989). Data from 251749 was downloaded in 0.2159426212310791 seconds
# (577/989). Data from 431153 was downloaded in 0.3661963939666748 seconds
# (578/989). Data from 431166 was downloaded in 0.20034408569335938 seconds
# (579/989). Data from 431172 was downloaded in 0.17559432983398438 seconds
# (580/989). Data from 081691 was downloaded in 0.1921675205230713 seconds
# (581/989). Data from 431188 was downloaded in 0.2636692523956299 seconds
# (582/989). Data from 081712 was downloaded in 0.17829513549804688 seconds
# (583/989). Data from 081705 was downloaded in 0.2438337802886963 seconds
# (584/989). Data from 251752 was downloaded in 0.27083253860473633 seconds
# (585/989). Data from 251765 was downloaded in 0.2894902229309082 seconds
# (586/989). Data from 251771 was downloaded in 0.25410032272338867 seconds
# (587/989). Data from 082303 was downloaded in 0.38392162322998047 seconds
# (588/989). Data from 081727 was downloaded in 0.16767477989196777 seconds
# (589/989). Data from 171390 was downloaded in 0.16649150848388672 seconds
# (590/989). Data from 251790 was downloaded in 0.18306803703308105 seconds
# (591/989). Data from 081751 was downloaded in 0.28105831146240234 seconds
# (592/989). Data from 171411 was downloaded in 0.4229471683502197 seconds
# (593/989). Data from 081748 was downloaded in 0.2343459129333496 seconds
# (594/989). Data from 251804 was downloaded in 0.3071155548095703 seconds
# (595/989). Data from 431191 was downloaded in 0.2616446018218994 seconds
# (596/989). Data from 251811 was downloaded in 0.29939866065979004 seconds
# (597/989). Data from 251826 was downloaded in 0.2064967155456543 seconds
# (598/989). Data from 081764 was downloaded in 0.20896077156066895 seconds
# (599/989). Data from 081770 was downloaded in 0.21273016929626465 seconds
# (600/989). Data from 171426 was downloaded in 0.26360416412353516 seconds
# (601/989). Data from 170433 was downloaded in 0.26235342025756836 seconds
# (602/989). Data from 431205 was downloaded in 0.24794650077819824 seconds
# (603/989). Data from 171432 was downloaded in 0.212721586227417 seconds
# (604/989). Data from 081786 was downloaded in 0.2185652256011963 seconds
# (605/989). Data from 431362 was downloaded in 0.18085026741027832 seconds
# (606/989). Data from 431212 was downloaded in 0.23840069770812988 seconds
# (607/989). Data from 171447 was downloaded in 0.26182055473327637 seconds
# (608/989). Data from 081799 was downloaded in 0.2040421962738037 seconds
# (609/989). Data from 431227 was downloaded in 0.2560403347015381 seconds
# (610/989). Data from 431233 was downloaded in 0.2867271900177002 seconds
# (611/989). Data from 251832 was downloaded in 0.31118249893188477 seconds
# (612/989). Data from 431248 was downloaded in 0.21292495727539062 seconds
# (613/989). Data from 431251 was downloaded in 0.4058356285095215 seconds
# (614/989). Data from 259059 was downloaded in 0.4265105724334717 seconds
# (615/989). Data from 251850 was downloaded in 0.22293424606323242 seconds
# (616/989). Data from 171450 was downloaded in 0.2075040340423584 seconds
# (617/989). Data from 171463 was downloaded in 0.2612485885620117 seconds
# (618/989). Data from 431264 was downloaded in 0.1952657699584961 seconds
# (619/989). Data from 251863 was downloaded in 0.2894883155822754 seconds
# (620/989). Data from 171479 was downloaded in 0.13361454010009766 seconds
# (621/989). Data from 081803 was downloaded in 0.25408363342285156 seconds
# (622/989). Data from 259139 was downloaded in 0.22603750228881836 seconds
# (623/989). Data from 171485 was downloaded in 0.23736023902893066 seconds
# (624/989). Data from 171498 was downloaded in 0.2419111728668213 seconds
# (625/989). Data from 431270 was downloaded in 0.3211174011230469 seconds
# (626/989). Data from 431286 was downloaded in 0.34201574325561523 seconds
# (627/989). Data from 171501 was downloaded in 0.205399751663208 seconds
# (628/989). Data from 431299 was downloaded in 0.31065917015075684 seconds
# (629/989). Data from 171518 was downloaded in 0.2958071231842041 seconds
# (630/989). Data from 081810 was downloaded in 0.30713915824890137 seconds
# (631/989). Data from 431303 was downloaded in 0.2569844722747803 seconds
# (632/989). Data from 431310 was downloaded in 0.4052574634552002 seconds
# (633/989). Data from 081831 was downloaded in 0.36197543144226074 seconds
# (634/989). Data from 431325 was downloaded in 0.4431173801422119 seconds
# (635/989). Data from 431331 was downloaded in 0.17065191268920898 seconds
# (636/989). Data from 171523 was downloaded in 0.1515200138092041 seconds
# (637/989). Data from 251898 was downloaded in 0.25234127044677734 seconds
# (638/989). Data from 431346 was downloaded in 0.3254995346069336 seconds
# (639/989). Data from 081846 was downloaded in 0.2730672359466553 seconds
# (640/989). Data from 081859 was downloaded in 0.18904328346252441 seconds
# (641/989). Data from 171539 was downloaded in 0.1285548210144043 seconds
# (642/989). Data from 089019 was downloaded in 0.22195959091186523 seconds
# (643/989). Data from 081878 was downloaded in 0.17051029205322266 seconds
# (644/989). Data from 081884 was downloaded in 0.12705206871032715 seconds
# (645/989). Data from 251902 was downloaded in 0.22047924995422363 seconds
# (646/989). Data from 081901 was downloaded in 0.24984979629516602 seconds
# (647/989). Data from 171544 was downloaded in 0.3021414279937744 seconds
# (648/989). Data from 081918 was downloaded in 0.23598933219909668 seconds
# (649/989). Data from 431359 was downloaded in 0.3506453037261963 seconds
# (650/989). Data from 439057 was downloaded in 0.21027350425720215 seconds
# (651/989). Data from 171557 was downloaded in 0.3248417377471924 seconds
# ...
# (811/989). Data from 082802 was downloaded in 0.19260430335998535 seconds
# (812/989). Data from 082819 was downloaded in 0.2322549819946289 seconds
# (813/989). Data from 252206 was downloaded in 0.3652193546295166 seconds
# (814/989). Data from 171962 was downloaded in 0.41078925132751465 seconds
# (815/989). Data from 082798 was downloaded in 0.1742253303527832 seconds
# (816/989). Data from 082824 was downloaded in 0.28525638580322266 seconds
# (817/989). Data from 252213 was downloaded in 0.3179330825805664 seconds
# (818/989). Data from 252228 was downloaded in 0.21414971351623535 seconds
# (819/989). Data from 431495 was downloaded in 0.24598145484924316 seconds
# (820/989). Data from 431508 was downloaded in 0.16379642486572266 seconds
# (821/989). Data from 082830 was downloaded in 0.13827013969421387 seconds
# (822/989). Data from 252234 was downloaded in 0.24151897430419922 seconds
# (823/989). Data from 082845 was downloaded in 0.15639615058898926 seconds
# (824/989). Data from 082858 was downloaded in 0.21192097663879395 seconds
# (825/989). Data from 252249 was downloaded in 0.305023193359375 seconds
# (826/989). Data from 252252 was downloaded in 0.23299527168273926 seconds
# (827/989). Data from 252271 was downloaded in 0.36151552200317383 seconds
# (828/989). Data from 082861 was downloaded in 0.21409916877746582 seconds
# (829/989). Data from 431515 was downloaded in 0.20505976676940918 seconds
# (830/989). Data from 431520 was downloaded in 0.3086857795715332 seconds
# (831/989). Data from 252332 was downloaded in 0.2623918056488037 seconds
# (832/989). Data from 252265 was downloaded in 0.2082207202911377 seconds
# (833/989). Data from 431536 was downloaded in 0.24704790115356445 seconds
# (834/989). Data from 252287 was downloaded in 0.33466339111328125 seconds
# (835/989). Data from 259078 was downloaded in 0.425736665725708 seconds
# (836/989). Data from 252304 was downloaded in 0.4085996150970459 seconds
# (837/989). Data from 252311 was downloaded in 0.2014477252960205 seconds
# (838/989). Data from 082877 was downloaded in 0.2340550422668457 seconds
# (839/989). Data from 082883 was downloaded in 0.18224620819091797 seconds
# (840/989). Data from 082896 was downloaded in 0.2570078372955322 seconds
# (841/989). Data from 171978 was downloaded in 0.16325783729553223 seconds
# (842/989). Data from 252326 was downloaded in 0.21244001388549805 seconds
# (843/989). Data from 171984 was downloaded in 0.3015410900115967 seconds
# (844/989). Data from 171997 was downloaded in 0.22498488426208496 seconds
# (845/989). Data from 431541 was downloaded in 0.18576693534851074 seconds
# (846/989). Data from 172001 was downloaded in 0.27812623977661133 seconds
# (847/989). Data from 431554 was downloaded in 0.15802812576293945 seconds
# (848/989). Data from 172018 was downloaded in 0.26355433464050293 seconds
# (849/989). Data from 172023 was downloaded in 0.25205206871032715 seconds
# (850/989). Data from 252347 was downloaded in 0.2624030113220215 seconds
# (851/989). Data from 172044 was downloaded in 0.29673147201538086 seconds
# (852/989). Data from 082900 was downloaded in 0.2055060863494873 seconds
# (853/989). Data from 172057 was downloaded in 0.269073486328125 seconds
# (854/989). Data from 431567 was downloaded in 0.2462015151977539 seconds
# (855/989). Data from 431573 was downloaded in 0.3830912113189697 seconds
# (856/989). Data from 172039 was downloaded in 0.2691843509674072 seconds
# (857/989). Data from 172060 was downloaded in 0.25240111351013184 seconds
# (858/989). Data from 082917 was downloaded in 0.23831725120544434 seconds
# (859/989). Data from 170144 was downloaded in 0.13812589645385742 seconds
# (860/989). Data from 172076 was downloaded in 0.3173391819000244 seconds
# (861/989). Data from 172082 was downloaded in 0.19392061233520508 seconds
# (862/989). Data from 250432 was downloaded in 0.26725244522094727 seconds
# (863/989). Data from 259010 was downloaded in 0.29004740715026855 seconds
# (864/989). Data from 172095 was downloaded in 0.31017184257507324 seconds
# (865/989). Data from 082922 was downloaded in 0.17504525184631348 seconds
# (866/989). Data from 252385 was downloaded in 0.15698909759521484 seconds
# (867/989). Data from 082938 was downloaded in 0.23760223388671875 seconds
# (868/989). Data from 431589 was downloaded in 0.2183995246887207 seconds
# (869/989). Data from 252402 was downloaded in 0.29325032234191895 seconds
# (870/989). Data from 171707 was downloaded in 0.22450470924377441 seconds
# (871/989). Data from 431592 was downloaded in 0.23590683937072754 seconds
# (872/989). Data from 082943 was downloaded in 0.24900221824645996 seconds
# (873/989). Data from 082956 was downloaded in 0.238081693649292 seconds
# (874/989). Data from 431606 was downloaded in 0.3075230121612549 seconds
# (875/989). Data from 082969 was downloaded in 0.35075950622558594 seconds
# (876/989). Data from 431613 was downloaded in 0.277925968170166 seconds
# (877/989). Data from 259062 was downloaded in 0.27048182487487793 seconds
# (878/989). Data from 252398 was downloaded in 0.23792195320129395 seconds
# (879/989). Data from 431628 was downloaded in 0.16219758987426758 seconds
# (880/989). Data from 259097 was downloaded in 0.2603461742401123 seconds
# (881/989). Data from 082975 was downloaded in 0.25055384635925293 seconds
# (882/989). Data from 431634 was downloaded in 0.15892767906188965 seconds
# (883/989). Data from 172109 was downloaded in 0.2556319236755371 seconds
# (884/989). Data from 252424 was downloaded in 0.2296617031097412 seconds
# (885/989). Data from 172116 was downloaded in 0.25018811225891113 seconds
# (886/989). Data from 431649 was downloaded in 0.36496829986572266 seconds
# (887/989). Data from 082981 was downloaded in 0.27951693534851074 seconds
# (888/989). Data from 172121 was downloaded in 0.21739459037780762 seconds
# (889/989). Data from 172137 was downloaded in 0.28331542015075684 seconds
# (890/989). Data from 252430 was downloaded in 0.3398318290710449 seconds
# (891/989). Data from 431704 was downloaded in 0.2332444190979004 seconds
# (892/989). Data from 172305 was downloaded in 0.275862455368042 seconds
# (893/989). Data from 252521 was downloaded in 0.2517368793487549 seconds
# (894/989). Data from 431711 was downloaded in 0.3425412178039551 seconds
# (895/989). Data from 431652 was downloaded in 0.3354363441467285 seconds
# (896/989). Data from 172142 was downloaded in 0.29514145851135254 seconds
# (897/989). Data from 172155 was downloaded in 0.24078726768493652 seconds
# (898/989). Data from 082994 was downloaded in 0.25847387313842773 seconds
# (899/989). Data from 172174 was downloaded in 0.2670443058013916 seconds
# (900/989). Data from 172168 was downloaded in 0.2977936267852783 seconds
# (901/989). Data from 083015 was downloaded in 0.19511985778808594 seconds
# (902/989). Data from 083008 was downloaded in 0.1852266788482666 seconds
# (903/989). Data from 172180 was downloaded in 0.26370739936828613 seconds
# (904/989). Data from 172207 was downloaded in 0.16376757621765137 seconds
# (905/989). Data from 172214 was downloaded in 0.31276988983154297 seconds
# (906/989). Data from 083054 was downloaded in 0.440096378326416 seconds
# (907/989). Data from 252445 was downloaded in 0.2681765556335449 seconds
# (908/989). Data from 172235 was downloaded in 0.40719127655029297 seconds
# (909/989). Data from 431750 was downloaded in 0.2848324775695801 seconds
# (910/989). Data from 083067 was downloaded in 0.2467975616455078 seconds
# (911/989). Data from 252458 was downloaded in 0.28485679626464844 seconds
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\http\client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\http\client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# c:\users\pim\appdata\local\programs\python\python38\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-19-29bc503c7850> in <module>
# ----> 1 pipeline()
#
# <ipython-input-18-d126073b21af> in pipeline()
#      68 def pipeline():
#      69     meta = create_meta_municipalities()
# ---> 70     json_data = collect_all_muns(meta, n=0)
#      71     json_parser = JSONParser(json_value='v', json_column_name=['c', 'calt'])
#      72     json_parser.add_value_map(value_splitter)
#
# <ipython-input-18-d126073b21af> in collect_all_muns(meta, n)
#      31     print(f'The estimated time to download the amount of data is {estimated_time/60} minutes')
#      32     for i, identifier in enumerate(meta.keys()):
# ---> 33         municipality_dict[identifier] = request_mun(identifier)
#      34         time.sleep(n)
#      35         if i == 0:
#
# <ipython-input-18-d126073b21af> in request_mun(mun_id)
#       1 def request_mun(mun_id):
# ----> 2     mun_res = requests.get("https://api.idescat.cat/emex/v1/dades.json?id={}&lang=en".format(mun_id))
#       3     return mun_res.json()
#       4
#       5
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\users\pim\appdata\local\programs\python\python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
lst = {i:'a' for i in range(0,4)}

# %%
lst1 = {'a':1, 'b': 3}

# %%
lst + lst1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-dfe038e3576f> in <module>
# ----> 1 lst + lst1
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'
