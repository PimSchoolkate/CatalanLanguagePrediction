# %%
import json
import requests
import time
import string
import pandas as pd

# %%
def request_mun(mun_id):
    mun_res = requests.get("https://api.idescat.cat/emex/v1/dades.json?id={}&lang=en".format(mun_id))
    return mun_res.json()
   

def create_meta_municipalities():
    """
    Retrieves dictionairy containing all municipalities from the idescat. Structure of the dict:
        key: id of the mun
        value: name of the mun
    """
    meta = {}
    mun_res = requests.get("https://api.idescat.cat/emex/v1/dades.json?lang=en")
    mun_meta = mun_res.json()
    muns = mun_meta['fitxes']['cols']['col']
    for mun in muns:
        meta[mun['id']] = mun['content']
        
    return meta


def collect_all_muns(meta, n):
    """
    Collects all the data of each municipality, making a request every n seconds
    """
    
    start_time = time.time()
    municipality_dict = {}
    i = 0
    for identifier in meta.keys():
        
        municipality_dict[identifier] = request_mun(identifier)
        time.sleep(n)
        i += 1
        if i == 10:
            break
    
    print("Retrieved data of {} municipalities in {} seconds".format(i ,int(time.time()-start_time)))
    return municipality_dict

# %%
testmeta = create_meta_municipalities()

# %%
test = collect_all_muns(testmeta, 0.2)
# Out:
# Retrieved data of 10 municipalities in 4 seconds

# %%
test
# Out:
# {'250019': {'fitxes': {'p': 'id=250019',
#    'gg': {'g': [{'tt': {'t': {'ff': {'f': [{'r': '2021',
#            'c': 'Surface area',
#            'u': 'km²',
#            'v': '78.27,1343.09,32108.00',
#            'calt': 'Surface area',
#            'id': 'f271',
#            'updated': '2021-12-23T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'Altitude',
#            'u': 'm',
#            'v': '956,_,_',
#            'calt': 'Altitude',
#            'id': 'f258',
#            'updated': '2014-02-17T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'Longitude',
#            'u': 'º',
#            'v': '1.092892,_,_',
#            'calt': 'Longitude',
#            'id': 'f328',
#            'updated': '2014-02-17T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'Latitude',
#            'u': 'º',
#            'v': '42.162392,_,_',
#            'calt': 'Latitude',
#            'id': 'f329',
#            'updated': '2014-02-17T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'UTM coordinates x',
#            'u': 'm',
#            'v': '342450,_,_',
#            'calt': 'UTM coordinates x',
#            'id': 'f259',
#            'updated': '2014-02-17T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'UTM coordinates y',
#            'u': 'm',
#            'v': '4669650,_,_',
#            'calt': 'UTM coordinates y',
#            'id': 'f260',
#            'updated': '2014-02-17T11:00:00+00:00'}]},
#         'c': 'Geographic indicators',
#         'id': 't176',
#         'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:250019&lang=en'}},
#       'c': 'Territory',
#       'id': 'g173'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Surface area',
#             'u': 'km²',
#             'v': '78.27,1343.09,32108.00',
#             'calt': 'Surface area',
#             'id': 'f261'},
#            {'c': 'Density',
#             'u': 'inh./km²',
#             'v': '2.2,9.8,241.8',
#             'calt': 'Density',
#             'id': 'f262'}]},
#          'r': '2021',
#          'c': 'Density of population',
#          'calt': 'Density',
#          'id': 't192',
#          'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:250019&lang=en',
#          'updated': '2021-12-23T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Men',
#             'v': '89,6710,3819831',
#             'calt': 'Men',
#             'id': 'f318'},
#            {'c': 'Women',
#             'v': '82,6460,3943531',
#             'calt': 'Women',
#             'id': 'f320'},
#            {'c': 'Total',
#             'v': '171,13170,7763362',
#             'calt': 'Population',
#             'id': 'f321'}]},
#          'r': '2021',
#          'c': 'Population. By sex',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Sex',
#          'id': 't195',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=446&geo=mun:250019&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'From 0 to 14 years',
#             'v': '16,1573,1139260',
#             'calt': 'Population from 0 to 14 years',
#             'id': 'f167'},
#            {'c': 'From 15 to 64 years',
#             'v': '110,8200,5145431',
#             'calt': 'Population from 15 to 64 years',
#             'id': 'f27'},
#            {'c': 'From 65 to 84 years',
#             'v': '33,2523,1228528',
#             'calt': 'Population from 65 to 84 years',
#             'id': 'f28'},
#            {'c': 'From 85 years and over',
#             'v': '12,874,250143',
#             'calt': 'Population from 85 years and over',
#             'id': 'f29'},
#            {'c': 'Total',
#             'v': '171,13170,7763362',
#             'calt': 'Population',
#             'id': 'f171'}]},
#          'r': '2021',
#          'c': 'Population. By age groups',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Age groups',
#          'id': 't25',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:250019&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'From 0 to 14 years',
#             'v': '8,811,586182',
#             'calt': 'Men from 0 to 14 years',
#             'id': 'f176'},
#            {'c': 'From 15 to 64 years',
#             'v': '59,4334,2598440',
#             'calt': 'Men from 15 to 64 years',
#             'id': 'f33'},
#            {'c': 'From 65 to 84 years',
#             'v': '14,1242,552061',
#             'calt': 'Men from 65 to 84 years',
#             'id': 'f34'},
#            {'c': 'From 85 years and over',
#             'v': '8,323,83148',
#             'calt': 'Men from 85 years and over',
#             'id': 'f35'},
#            {'c': 'Total',
#             'v': '89,6710,3819831',
#             'calt': 'Men',
#             'id': 'f36'}]},
#          'r': '2021',
#          'c': 'Population. By age groups. Men',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Age groups. Men',
#          'id': 't31',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:250019&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'From 0 to 14 years',
#             'v': '8,762,553078',
#             'calt': 'Women from 0 to 14 years',
#             'id': 'f38'},
#            {'c': 'From 15 to 64 years',
#             'v': '51,3866,2546991',
#             'calt': 'Women from 15 to 64 years',
#             'id': 'f39'},
#            {'c': 'From 65 to 84 years',
#             'v': '19,1281,676467',
#             'calt': 'Women from 65 to 84 years',
#             'id': 'f40'},
#            {'c': 'From 85 years and over',
#             'v': '4,551,166995',
#             'calt': 'Women from 85 years and over',
#             'id': 'f41'},
#            {'c': 'Total',
#             'v': '82,6460,3943531',
#             'calt': 'Women',
#             'id': 'f42'}]},
#          'r': '2021',
#          'c': 'Population. By age groups. Women',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Age groups. Women',
#          'id': 't37',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:250019&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Catalonia',
#             'v': '143,9619,4952278',
#             'calt': 'Population born in Catalonia',
#             'id': 'f69'},
#            {'c': 'Rest of Spain',
#             'v': '8,1271,1212621',
#             'calt': 'Population born in rest of Spain',
#             'id': 'f72'},
#            {'c': 'Abroad',
#             'v': '20,2280,1598463',
#             'calt': 'Population born abroad',
#             'id': 'f73'},
#            {'c': 'Total',
#             'v': '171,13170,7763362',
#             'calt': 'Population',
#             'id': 'f74'}]},
#          'r': '2021',
#          'c': 'Population. By place of birth',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Place of birth',
#          'id': 't68',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=674&geo=mun:250019&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Spanish',
#             'v': '151,11350,6512697',
#             'calt': 'Population with Spanish nationality',
#             'id': 'f183'},
#            {'c': 'Foreign',
#             'v': '20,1820,1250665',
#             'calt': 'Population with foreign nationality',
#             'id': 'f184'},
#            {'c': 'Total',
#             'v': '171,13170,7763362',
#             'calt': 'Population',
#             'id': 'f263'}]},
#          'r': '2021',
#          'c': 'Population. By nationality',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Nationality',
#          'id': 't75',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:250019&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Spanish',
#             'v': '79,5736,3172812',
#             'calt': 'Men with Spanish nationality',
#             'id': 'f178'},
#            {'c': 'Foreign',
#             'v': '10,974,647019',
#             'calt': 'Men with foreign nationality',
#             'id': 'f77'},
#            {'c': 'Total',
#             'v': '89,6710,3819831',
#             'calt': 'Men',
#             'id': 'f264'}]},
#          'r': '2021',
#          'c': 'Population. By nationality. Men',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Nationality. Men',
#          'id': 't78',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:250019&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Spanish',
#             'v': '72,5614,3339885',
#             'calt': 'Women with Spanish nationality',
#             'id': 'f82'},
#            {'c': 'Foreign',
#             'v': '10,846,603646',
#             'calt': 'Women with foreign nationality',
#             'id': 'f83'},
#            {'c': 'Total',
#             'v': '82,6460,3943531',
#             'calt': 'Women',
#             'id': 'f265'}]},
#          'r': '2021',
#          'c': 'Population. By nationality. Women',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Nationality. Women',
#          'id': 't81',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=680&geo=mun:250019&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Men',
#             'v': '25,608,172716',
#             'calt': 'Men resident abroad',
#             'id': 'f334'},
#            {'c': 'Women',
#             'v': '32,625,167798',
#             'calt': 'Women resident abroad',
#             'id': 'f335'},
#            {'c': 'Total',
#             'v': '57,1233,340514',
#             'calt': 'Population resident abroad',
#             'id': 'f336'}]},
#          'r': '2021',
#          'c': 'Population resident abroad on 1 January. By sex',
#          's': '',
#          'calt': 'Population resident abroad',
#          'id': 't197',
#          'l': 'https://www.idescat.cat/pub/?id=phre&n=3697&geo=mun:250019&lang=en',
#          'updated': '2021-04-22T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Resident Students',
#             'v': '30,1865,1237395',
#             'calt': 'Resident Students (School Age)',
#             'id': 'f380'},
#            {'c': 'Resident Students who study in the same municipality',
#             'u': '%',
#             'v': '0.0,75.6,82.8',
#             'calt': 'Resident Students who study in the same municipality',
#             'id': 'f381'}]},
#          'r': 'SY 2020/21',
#          'c': 'Statistics on Commuting for Non-University Studies',
#          's': "Idescat, a partir de les dades de la matrícula del Departament d'Educació.",
#          'calt': 'Commuting for Study Reasons',
#          'id': 't211',
#          'l': 'https://www.idescat.cat/pub/?id=emoesc&n=8809&geo=mun:250019&lang=en',
#          'updated': '2021-11-18T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Boys',
#             'v': '0,39,29832',
#             'calt': 'Births. Boys',
#             'id': 'f185'},
#            {'c': 'Girls',
#             'v': '1,33,28632',
#             'calt': 'Births. Girls',
#             'id': 'f186'},
#            {'c': 'Total', 'v': '1,72,58464', 'calt': 'Births', 'id': 'f187'}]},
#          'r': '2020',
#          'c': 'Births. By sex',
#          's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#          'calt': 'Births',
#          'id': 't164',
#          'l': 'https://www.idescat.cat/pub/?id=naix&n=364&geo=mun:250019&lang=en',
#          'updated': '2022-01-17T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Men',
#             'v': '0,108,39828',
#             'calt': 'Deaths. Men',
#             'id': 'f181'},
#            {'c': 'Women',
#             'v': '0,113,39956',
#             'calt': 'Deaths. Women',
#             'id': 'f182'},
#            {'c': 'Total',
#             'v': '0,221,79784',
#             'calt': 'Deaths',
#             'id': 'f188'}]},
#          'r': '2020',
#          'c': 'Deaths. By sex',
#          's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#          'calt': 'Deaths',
#          'id': 't165',
#          'l': 'https://www.idescat.cat/pub/?id=def&n=365&geo=mun:250019&lang=en',
#          'updated': '2021-12-10T11:00:00+00:00'},
#         {'ff': {'f': {'c': 'Total',
#            'v': '0,20,15662',
#            'calt': 'Marriages',
#            'id': 'f179'}},
#          'r': '2020',
#          'c': 'Marriages',
#          's': "Idescat, a partir del Moviment natural de la població de l'INE.",
#          'calt': 'Marriages',
#          'id': 't166',
#          'l': 'https://www.idescat.cat/pub/?id=mat&n=317&geo=mun:250019&lang=en',
#          'updated': '2022-01-17T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Balance with Catalonia',
#             'v': '-8,163,_',
#             'calt': 'Migrations (balance) with Catalonia',
#             'id': 'f322'},
#            {'c': 'Balance with Spain',
#             'v': '-1,-121,-8971',
#             'calt': 'Migrations (balance) with Spain',
#             'id': 'f323'},
#            {'c': 'Internal migratory net balance',
#             'v': '-9,42,-8971',
#             'calt': 'Internal migratory net balance',
#             'id': 'f324'}]},
#          'r': '2020',
#          'c': 'Internal migrations. Destination-origin balances',
#          's': "Idescat, based on the INE's Residential Variation Statistics.",
#          'calt': 'Internal migrations',
#          'id': 't196',
#          'l': 'https://www.idescat.cat/pub/?id=mm&n=223&geo=mun:250019&lang=en',
#          'updated': '2021-09-29T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Immigrations',
#             'v': '0,164,118760',
#             'calt': 'External immigrations',
#             'id': 'f372'},
#            {'c': 'Emigrations',
#             'v': '0,91,62236',
#             'calt': 'External emigrations',
#             'id': 'f373'}]},
#          'r': '2020',
#          'c': 'External migrations',
#          's': "Idescat, based on the INE's Residential Variation Statistics.",
#          'calt': 'External migrations',
#          'id': 't208',
#          'l': 'https://www.idescat.cat/pub/?id=mm&n=5489&geo=mun:250019&lang=en',
#          'updated': '2021-09-29T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Rest of EU',
#             'v': '0,44,17499',
#             'calt': 'Immigrations from the rest of EU',
#             'id': 'f314'},
#            {'c': 'Rest of the world',
#             'v': '0,120,101261',
#             'calt': 'Immigrations from the rest of the world',
#             'id': 'f316'},
#            {'c': 'Total',
#             'v': '0,164,118760',
#             'calt': 'External immigrations',
#             'id': 'f317'}]},
#          'r': '2020',
#          'c': 'External immigrations. By place of origin',
#          's': "Idescat, based on the INE's Residential Variation Statistics.",
#          'calt': 'External immigrations',
#          'id': 't194',
#          'l': 'https://www.idescat.cat/pub/?id=mm&n=487&geo=mun:250019&lang=en',
#          'updated': '2021-09-29T10:00:00+00:00'},
#         {'ff': {'f': [{'r': '2011',
#             'c': 'Population Growth',
#             'v': '-7,1689,1176733',
#             'calt': 'Intercensal Population Growth',
#             'id': 'f359'},
#            {'r': '2001-2011',
#             'c': 'Population Growth (annual average)',
#             'u': 'rate per 1,000 inhabitants',
#             'v': '-3.87,13.09,16.98',
#             'calt': 'Intercensal Population Growth (annual average)',
#             'id': 'f360'},
#            {'r': '2001-2011',
#             'c': 'Natural Increase (annual average)',
#             'u': 'rate per 1,000 inhabitants',
#             'v': '-7.97,-4.92,3.04',
#             'calt': 'Intercensal Natural Increase Ratio (annual average)',
#             'id': 'f361'},
#            {'r': '2001-2011',
#             'c': 'Net Migration (annual average)',
#             'u': 'rate per 1,000 inhabitants',
#             'v': '4.11,18.02,13.94',
#             'calt': 'Intercensal Net Migration Ratio (annual average)',
#             'id': 'f362'}]},
#          'c': '2001-2011 Intercensal Population Growth',
#          's': 'Idescat.',
#          'calt': 'Intercensal Population Growth',
#          'id': 't202',
#          'l': 'https://www.idescat.cat/pub/?id=censph&n=97&geo=mun:250019&lang=en',
#          'updated': '2012-12-14T11:00:00+00:00'}]},
#       'c': 'Population',
#       'id': 'g168'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Understand',
#             'v': '169,12680,6949344',
#             'calt': 'Population that understands Catalan',
#             'id': 'f91'},
#            {'c': 'Speak',
#             'v': '164,11028,5345484',
#             'calt': 'Population that can speak Catalan',
#             'id': 'f92'},
#            {'c': 'Read',
#             'v': '161,11052,5750348',
#             'calt': 'Population that can read Catalan',
#             'id': 'f93'},
#            {'c': 'Write',
#             'v': '107,8246,4069219',
#             'calt': 'Population that can write Catalan',
#             'id': 'f94'},
#            {'c': 'Do not understand',
#             'v': '0,403,356728',
#             'calt': "Population that doesn't understand Catalan",
#             'id': 'f95'},
#            {'c': 'Total',
#             'v': '169,13083,7306072',
#             'calt': 'Population of 2 years and over',
#             'id': 'f96'}]},
#          'r': '2011',
#          'c': 'Population of 2 years and over. By knowledge of Catalan',
#          's': "Idescat, based on the INE's Population and Housing Census.",
#          'calt': 'Knowledge of Catalan',
#          'id': 't90',
#          'l': 'https://www.idescat.cat/pub/?id=censph&n=17&geo=mun:250019&lang=en',
#          'updated': '2013-11-21T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Public',
#             'v': '0,2,459',
#             'calt': 'Public libraries',
#             'id': 'f270'},
#            {'c': 'Others',
#             'v': '0,2,391',
#             'calt': 'Other libraries',
#             'id': 'f327'},
#            {'c': 'Total', 'v': '0,4,850', 'calt': 'Libraries', 'id': 'f177'}]},
#          'r': '2018',
#          'c': 'Libraries',
#          's': 'Idescat. Library Statistics.',
#          'calt': 'Libraries',
#          'id': 't156',
#          'l': 'https://www.idescat.cat/pub/?id=bib&n=327&geo=mun:250019&lang=en',
#          'updated': '2019-12-10T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Pavilions',
#             'v': '0,8,1005',
#             'calt': 'Pavilions',
#             'id': 'f293'},
#            {'c': 'Multisport courts',
#             'v': '0,35,8373',
#             'calt': 'Multisport courts',
#             'id': 'f294'},
#            {'c': 'Multisport fields',
#             'v': '0,9,2281',
#             'calt': 'Multisport fields',
#             'id': 'f295'},
#            {'c': 'Sports halls',
#             'v': '0,27,9152',
#             'calt': 'Sports halls',
#             'id': 'f296'},
#            {'c': 'Indoor swimming pools',
#             'v': '0,1,1097',
#             'calt': 'Indoor swimming pools',
#             'id': 'f301'},
#            {'c': 'Athelitcs tracks',
#             'v': '0,1,438',
#             'calt': 'Athelitcs tracks',
#             'id': 'f302'},
#            {'c': 'Other facilities',
#             'v': '0,122,29001',
#             'calt': 'Other sports facilities',
#             'id': 'f299'},
#            {'c': 'Total',
#             'v': '0,203,51347',
#             'calt': 'Sports facilities',
#             'id': 'f300'}]},
#          'r': '2021',
#          'c': 'Sports facilities',
#          's': "Idescat, based on data from the Consell Català de l'Esport.",
#          'calt': 'Sports facilities',
#          'id': 't175',
#          'l': 'https://www.idescat.cat/pub/?id=eesp&n=4332&geo=mun:250019&lang=en',
#          'updated': '2022-01-20T11:00:00+00:00'}]},
#       'c': 'Culture · Language',
#       'id': 'g172'},
#      {'tt': {'t': {'ff': {'f': [{'c': 'Primary education or lower',
#            'v': '23.3,22.5,17.7',
#            'calt': 'Primary education or lower',
#            'id': 'f386'},
#           {'c': 'First stage of secondary education',
#            'v': '26.4,24.3,27.4',
#            'calt': 'First stage of secondary education',
#            'id': 'f387'},
#           {'c': 'Second stage of secondary education',
#            'v': '17.0,23.1,23.2',
#            'calt': 'Second stage of secondary education',
#            'id': 'f388'},
#           {'c': 'Higher education',
#            'v': '33.3,30.1,31.8',
#            'calt': 'Higher education',
#            'id': 'f389'}]},
#         'r': '2019 (p)',
#         'c': 'Population aged 15 and over. By level of education attained',
#         's': 'Idescat. Educational Attainment Statistics.',
#         'u': '%',
#         'calt': 'Level of education attained',
#         'id': 't215',
#         'l': 'https://www.idescat.cat/pub/?id=eep&n=14540&geo=mun:250019&lang=en',
#         'updated': '2021-10-25T10:00:00+00:00'}},
#       'c': 'Education',
#       'id': 'g214'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Electors',
#             'v': '145,9833,5554455',
#             'calt': 'Electors ( Parliament of Catalonia)',
#             'id': 'f267'},
#            {'c': 'Turnout',
#             'u': '%',
#             'v': '80.7,79.6,79.1',
#             'calt': 'Turnout (Parliament Catalonia)',
#             'id': 'f254'}]},
#          'r': '2017',
#          'c': 'Elections to the Parliament of Catalonia',
#          's': 'Idescat i Departament de Polítiques Digitals i Administració Pública.',
#          'calt': 'Elections to the Parliament of Catalonia',
#          'id': 't189',
#          'l': 'https://www.idescat.cat/pub/?id=elepc&n=389&geo=mun:250019&lang=en',
#          'updated': '2018-11-23T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Electors',
#             'v': '144,9917,5519912',
#             'calt': 'Electors (Congress)',
#             'id': 'f268'},
#            {'c': 'Turnout',
#             'u': '%',
#             'v': '50.7,61.6,63.4',
#             'calt': 'Turnout (Elec. Congress)',
#             'id': 'f255'}]},
#          'r': '2016',
#          'c': 'Elections to the Congress of Deputies',
#          's': 'Idescat, based on data from the Departament de Governació i Relacions Institucionals.',
#          'calt': 'Elections to the Congress of Deputies',
#          'id': 't190',
#          'l': 'https://www.idescat.cat/pub/?id=elecd&n=385&geo=mun:250019&lang=en',
#          'updated': '2017-10-27T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Turnout',
#             'u': '%',
#             'v': '42.0,48.6,47.6',
#             'calt': 'Turnout (Elec. European Parliament)',
#             'id': 'f256'},
#            {'c': 'Electors',
#             'v': '143,10087,5318296',
#             'calt': 'Electors (Elec. European Parliament)',
#             'id': 'f269'}]},
#          'r': '2014 (p)',
#          'c': 'Elections to the European Parliament',
#          'calt': 'Elections to the European Parliament',
#          'id': 't191',
#          'l': 'https://www.idescat.cat/pub/?id=elepe&n=390&geo=mun:250019&lang=en',
#          'updated': '2015-10-07T10:00:00+00:00'}]},
#       'c': 'Elections',
#       'id': 'g174'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Men',
#             'v': '38,2767,1773542',
#             'calt': 'Men',
#             'id': 'f378'},
#            {'c': 'Women',
#             'v': '31,2361,1563911',
#             'calt': 'Women',
#             'id': 'f379'},
#            {'c': 'Total',
#             'v': '69,5128,3337453',
#             'calt': 'Contributors to Social Security according to the residence of the contributor',
#             'id': 'f377'}]},
#          'r': '02/2022',
#          'c': 'Contributors to Social Security according to the residence of the contributor',
#          's': 'Idescat.',
#          'calt': "Contributors to Social Security according to contributors's residence",
#          'id': 't210',
#          'l': 'https://www.idescat.cat/pub/?id=afi&n=8604&geo=mun:250019&lang=en',
#          'updated': '2022-03-11T11:00:00+00:00'},
#         {'ff': {'f': {'c': 'Total',
#            'v': '75,5517,3508935',
#            'calt': 'Afiliations Social Security according residence',
#            'id': 'f363'}},
#          'r': '02/2022',
#          'c': 'Affiliations to Social Security according to the residence of the contributor',
#          's': 'Idescat.',
#          'calt': "Affiliations to Social Security according to contributor's residence",
#          'id': 't203',
#          'l': 'https://www.idescat.cat/pub/?id=afi&n=8598&geo=mun:250019&lang=en',
#          'updated': '2022-03-11T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Agriculture',
#             'v': '13,132,9822',
#             'calt': 'Agriculture affiliations to General SS',
#             'id': 'f273'},
#            {'c': 'Industry',
#             'v': '0,170,444816',
#             'calt': 'Industry affiliations to General SS',
#             'id': 'f278'},
#            {'c': 'Construction',
#             'v': '0,334,142281',
#             'calt': 'Construction affiliations to General SS',
#             'id': 'f279'},
#            {'c': 'Services',
#             'v': '13,2094,2248270',
#             'calt': 'Services affiliations to General SS',
#             'id': 'f280'},
#            {'c': 'Total',
#             'v': '26,2730,2845189',
#             'calt': 'Affiliations to General SS',
#             'id': 'f282'}]},
#          'r': '12/2021 (p)',
#          'c': 'Affiliations to S. S. general system according to the location of the affilation. By sectors',
#          's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#          'calt': 'Affiliations to general system according to location of affilation. By sectors',
#          'id': 't183',
#          'l': 'https://www.idescat.cat/pub/?id=afic&n=8270&geo=mun:250019&lang=en',
#          'updated': '2022-01-17T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Agriculture',
#             'v': '24,385,22038',
#             'calt': 'Affiliations contributors to Self-Employed SS',
#             'id': 'f229'},
#            {'c': 'Services',
#             'v': '5,662,428694',
#             'calt': 'Services afiliaciones to Self-Employed SS',
#             'id': 'f290'},
#            {'c': 'Total',
#             'v': '30,1290,558654',
#             'calt': 'Affiliations to Self-Employed SS',
#             'id': 'f291'}]},
#          'r': '12/2021 (p)',
#          'c': 'Affiliations to S. S. self-employed system according to the location of the affilation. By sectors',
#          's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#          'calt': 'Affiliations to self-employed system according to location of affilation. By sectors',
#          'id': 't184',
#          'l': 'https://www.idescat.cat/pub/?id=afic&n=8272&geo=mun:250019&lang=en',
#          'updated': '2022-01-17T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Up to 50 workers',
#             'v': '26,1860,1236248',
#             'calt': 'Affiliations to SS centres with up to 50 workers',
#             'id': 'f225'},
#            {'c': 'From 51 to 250 workers',
#             'v': '0,870,661338',
#             'calt': 'Affiliations to SS centres with 51 to 250 workers',
#             'id': 'f284'},
#            {'c': 'From 251 workers and over',
#             'v': '0,0,947603',
#             'calt': 'Affiliations to SS centres with 251 or more workers',
#             'id': 'f227'},
#            {'c': 'Total',
#             'v': '26,2730,2845189',
#             'calt': 'Affiliations to General SS',
#             'id': 'f286'}]},
#          'r': '12/2021 (p)',
#          'c': 'Affiliations to S. S. general system according to the location of the affilation. By size of centre',
#          's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#          'calt': 'Affiliations to gen. system according to location of affilation. By size of the centre',
#          'id': 't185',
#          'l': 'https://www.idescat.cat/pub/?id=afic&n=8271&geo=mun:250019&lang=en',
#          'updated': '2022-01-17T11:00:00+00:00'},
#         {'ff': {'f': {'c': 'Total',
#            'v': '8,509,243338',
#            'calt': 'Contributory accounts',
#            'id': 'f239'}},
#          'r': '12/2021 (p)',
#          'c': 'Contributory accounts',
#          's': 'Idescat, a partir dels fitxers d’afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.',
#          'calt': 'Contributory accounts of Social Security',
#          'id': 't186',
#          'l': 'https://www.idescat.cat/pub/?id=afic&n=8273&geo=mun:250019&lang=en',
#          'updated': '2022-01-17T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Total',
#             'v': '53,3810,1720098',
#             'calt': 'Contributory Social Security pensions',
#             'id': 'f375',
#             'updated': '2020-05-29T10:00:00+00:00'},
#            {'c': 'Average pension',
#             'u': 'euros',
#             'v': '676.79,874.02,1041.97',
#             'calt': 'Average contributory pension',
#             'id': 'f376',
#             'updated': '2020-05-29T10:00:00+00:00'}]},
#          'r': '2019',
#          'c': 'Contributory Social Security pensions. December',
#          's': '',
#          'calt': 'Contributory Social Security pensions',
#          'id': 't209',
#          'l': 'https://www.idescat.cat/pub/?id=pens&geo=mun:250019&lang=en'},
#         {'ff': {'f': [{'c': 'Men',
#             'v': '23,1570,737855',
#             'calt': 'Men',
#             'id': 'f382'},
#            {'c': 'Women',
#             'v': '22,1613,775829',
#             'calt': 'Women',
#             'id': 'f383'},
#            {'c': 'Total',
#             'v': '45,3183,1513684',
#             'calt': 'Total',
#             'id': 'f384'}]},
#          'r': '2019',
#          'c': 'Contributory Social Security Pensioners. By sex. December',
#          's': '',
#          'calt': 'Contributory Social Security Pensioners',
#          'id': 't212',
#          'l': 'https://www.idescat.cat/pub/?id=pens&n=10756&geo=mun:250019&lang=en',
#          'updated': '2020-05-29T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Agriculture',
#             'v': '0.6,42.4,9562.4',
#             'calt': 'Registered unemployment. Agriculture',
#             'id': 'f243'},
#            {'c': 'Industry',
#             'v': '3.0,47.6,45324.2',
#             'calt': 'Registered unemployment. Industry',
#             'id': 'f303'},
#            {'c': 'Construction',
#             'v': '0.0,69.2,33714.0',
#             'calt': 'Registered unemployment. Construction',
#             'id': 'f304'},
#            {'c': 'Services',
#             'v': '6.1,467.1,320048.0',
#             'calt': 'Registered unemployment. Services',
#             'id': 'f305'},
#            {'c': 'Without previous employment',
#             'v': '0.0,30.3,28517.0',
#             'calt': 'Registered unemployment (without previous employment)',
#             'id': 'f307'},
#            {'c': 'Total',
#             'v': '9.7,656.7,437165.6',
#             'calt': 'Registered unemployment',
#             'id': 'f308'}]},
#          'r': '2021',
#          'c': 'Registered unemployment. By sectors',
#          's': 'Ministry of Business and Employment.',
#          'u': 'annual averages',
#          'calt': 'Registered unemployment by sectors',
#          'id': 't188',
#          'l': 'https://www.idescat.cat/pub/?id=atureg&n=4302&geo=mun:250019&lang=en',
#          'updated': '2022-01-13T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Men',
#             'v': '5.7,310.6,191728.2',
#             'calt': 'Registered unemployment. Men',
#             'id': 'f240'},
#            {'c': 'Women',
#             'v': '4.0,346.1,245437.3',
#             'calt': 'Registered unemployment. Women',
#             'id': 'f241'},
#            {'c': 'Total',
#             'v': '9.7,656.7,437165.6',
#             'calt': 'Registered unemployment',
#             'id': 'f242'}]},
#          'r': '2021',
#          'c': 'Registered unemployment. By sex',
#          's': 'Ministry of Business and Employment.',
#          'u': 'annual averages',
#          'calt': 'Registered unemployment by sex',
#          'id': 't187',
#          'l': 'https://www.idescat.cat/pub/?id=atureg&n=4299&geo=mun:250019&lang=en',
#          'updated': '2022-01-13T11:00:00+00:00'}]},
#       'c': 'Labour',
#       'id': 'g169'},
#      {'tt': {'t': {'ff': {'f': [{'c': 'Main',
#            'v': '62,5639,2944944',
#            'calt': 'Main family dwellings',
#            'id': 'f250'},
#           {'c': 'Secondary',
#            'v': '28,3786,470081',
#            'calt': 'Secondary family dwellings',
#            'id': 'f119'},
#           {'c': 'Total',
#            'v': '90,10966,3863381',
#            'calt': 'Family dwellings',
#            'id': 'f122'}]},
#         'r': '2011',
#         'c': 'Family dwellings. By type',
#         's': "Idescat, based on the INE's Population and Housing Census.",
#         'calt': 'Type of dwellings',
#         'id': 't116',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=30&geo=mun:250019&lang=en',
#         'updated': '2013-12-19T11:00:00+00:00'}},
#       'c': 'Quality of life',
#       'id': 'g171'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Number of receipts',
#             'v': '181,17974,5855886',
#             'calt': 'IBI. Receipts',
#             'id': 'f198'},
#            {'c': 'Taxable base by receipt',
#             'u': 'euros',
#             'v': '20265.2,29494.8,70537.2',
#             'calt': 'IBI. Taxable base by receipt',
#             'id': 'f199'},
#            {'c': 'Integral quota by receipt',
#             'u': 'euros',
#             'v': '121.6,204.0,485.9',
#             'calt': 'IBI. Integral quota by receipt',
#             'id': 'f200'}]},
#          'r': '2020',
#          'c': 'Urban property tax (IBI)',
#          's': 'Idescat, based on data from the Dirección General del Catastro.',
#          'calt': 'Urban property tax',
#          'id': 't179',
#          'l': 'https://www.idescat.cat/pub/?id=ibi&n=173&geo=mun:250019&lang=en',
#          'updated': '2021-06-29T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Taxable base by declarer',
#             'v': '10332,19087,24984',
#             'calt': 'IRPF. Taxable base by declarer',
#             'id': 'f10'},
#            {'c': 'Resulting quota from self-payment by declarer',
#             'v': '3477,5136,7193',
#             'calt': 'IRPF. Resulting quotafrom self-payment by declarer',
#             'id': 'f11'}]},
#          'r': '2019',
#          'c': 'Personal Income Tax (IRPF)',
#          's': "Idescat, based on data from the Agència Estatal d'Administració Tributària.",
#          'u': 'euros',
#          'calt': 'Personal Income Tax',
#          'id': 't9',
#          'l': 'https://www.idescat.cat/pub/?id=irpf&n=4070&geo=mun:250019&lang=en',
#          'updated': '2021-11-26T11:00:00+00:00'}]},
#       'c': 'Main aggregates · Public sector finance',
#       'id': 'g163'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Cultivated land',
#             'v': '412,16919,792425',
#             'calt': 'Cultivated land surface',
#             'id': 'f133'},
#            {'c': 'Permanent pasture',
#             'v': '1048,35219,355107',
#             'calt': 'Permanent pasture surface',
#             'id': 'f134'},
#            {'c': 'Total',
#             'v': '1460,52138,1147532',
#             'calt': 'Used agricultural area',
#             'id': 'f345'}]},
#          'r': '2009',
#          'c': 'Used agricultural area (UAA)',
#          's': '',
#          'u': 'hectares',
#          'calt': 'Used agricultural area',
#          'id': 't132',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5173&geo=mun:250019&lang=en',
#          'updated': '2012-04-04T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Herbaceous crops',
#             'v': '226,14140,511150',
#             'calt': 'Herbaceous crops',
#             'id': 'f346'},
#            {'c': 'Fruit trees',
#             'v': '169,1749,110819',
#             'calt': 'Fruit trees crops',
#             'id': 'f347'},
#            {'c': 'Olives',
#             'v': '6,609,101236',
#             'calt': 'Olives crops',
#             'id': 'f348'},
#            {'c': 'Vines',
#             'v': '1,400,61391',
#             'calt': 'Vines crops',
#             'id': 'f349'},
#            {'c': 'Others',
#             'v': '11,22,7829',
#             'calt': 'Other crops',
#             'id': 'f350'},
#            {'c': 'Total',
#             'v': '412,16919,792425',
#             'calt': 'Cultivated land',
#             'id': 'f351'}]},
#          'r': '2009',
#          'c': 'Cultivated land. By type of crop',
#          's': '',
#          'u': 'hectares',
#          'calt': 'Cultivated land',
#          'id': 't199',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5084&geo=mun:250019&lang=en',
#          'updated': '2012-03-20T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Without land',
#             'v': '3,19,1519',
#             'calt': 'Farms without land',
#             'id': 'f352'},
#            {'c': 'With land',
#             'v': '27,870,59320',
#             'calt': 'Farms with land',
#             'id': 'f353'},
#            {'c': 'Total',
#             'v': '30,889,60839',
#             'calt': 'Farms with and without land',
#             'id': 'f356'}]},
#          'r': '2009',
#          'c': 'Farms. By land ownership',
#          's': '',
#          'calt': 'Land ownership',
#          'id': 't200',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5172&geo=mun:250019&lang=en',
#          'updated': '2012-04-04T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Without livestock',
#             'v': '11,542,47172',
#             'calt': 'Farms without livestock',
#             'id': 'f139'},
#            {'c': 'With livestock',
#             'v': '19,347,13667',
#             'calt': 'Farms with livestock',
#             'id': 'f204'},
#            {'c': 'Total',
#             'v': '30,889,60839',
#             'calt': 'Farms with and without livestock',
#             'id': 'f138'}]},
#          'r': '2009',
#          'c': 'Farms. By livestock ownership',
#          's': '',
#          'calt': 'Livestock ownership',
#          'id': 't137',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5172&geo=mun:250019&lang=en',
#          'updated': '2012-04-04T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Bovine',
#             'v': '195,13121,544135',
#             'calt': 'Bovine head',
#             'id': 'f141'},
#            {'c': 'Ovine',
#             'v': '2030,45750,600082',
#             'calt': 'Ovine head',
#             'id': 'f142'},
#            {'c': 'Caprine',
#             'v': '176,3026,71748',
#             'calt': 'Caprine head',
#             'id': 'f252'},
#            {'c': 'Porcine',
#             'v': '7289,149104,6742638',
#             'calt': 'Porcine head',
#             'id': 'f144'},
#            {'c': 'Avian',
#             'v': '75010,350918,43890563',
#             'calt': 'Avian head',
#             'id': 'f145'},
#            {'c': 'Female rabbits',
#             'v': '150,1625,335054',
#             'calt': 'Female rabbits head',
#             'id': 'f146'},
#            {'c': 'Equine',
#             'v': '9,981,19352',
#             'calt': 'Equine head',
#             'id': 'f147'}]},
#          'r': '2009',
#          'c': 'Head of livestock. By species',
#          's': '',
#          'calt': 'Head of livestock',
#          'id': 't140',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5107&geo=mun:250019&lang=en',
#          'updated': '2012-04-04T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'State subsidised housing starts',
#             'v': '0,0,1903',
#             'calt': 'State subsidised housing starts',
#             'id': 'f13'},
#            {'c': 'Housing starts',
#             'v': '0,8,11395',
#             'calt': 'Housing starts',
#             'id': 'f14'}]},
#          'r': '2020',
#          'c': 'Housing construction',
#          's': "Idescat, based on data from the Departament de Territori i Sostenibilitat. Secretaria d'Habitatge i Millora Urbana.",
#          'calt': 'Housing construction',
#          'id': 't12',
#          'l': 'https://www.idescat.cat/pub/?id=habit&n=86&geo=mun:250019&lang=en',
#          'updated': '2021-04-28T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Hotels',
#             'v': '0,18,3083',
#             'calt': 'Hotels',
#             'id': 'f215',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Hotel beds',
#             'v': '0,707,318954',
#             'calt': 'Hotel beds',
#             'id': 'f216',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Campsites',
#             'v': '0,5,351',
#             'calt': 'Campsites',
#             'id': 'f217',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Campsite places',
#             'v': '0,1794,262346',
#             'calt': 'Campsite places',
#             'id': 'f218',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Rural tourism',
#             'v': '2,60,2514',
#             'calt': 'Rural tourism',
#             'id': 'f219',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Rural tourism beds',
#             'v': '9,503,20190',
#             'calt': 'Rural tourism beds',
#             'id': 'f220',
#             'updated': '2021-07-01T10:00:00+00:00'}]},
#          'r': '2020',
#          'c': 'Tourist accommodation',
#          's': 'Idescat, based on data from the Ministry of Business and Labour.',
#          'calt': 'Tourist accommodation',
#          'id': 't182',
#          'l': 'https://www.idescat.cat/pub/?id=turall&geo=mun:250019&lang=en'},
#         {'ff': {'f': [{'c': 'Estate cars',
#             'v': '175,6961,3554258',
#             'calt': 'Cars',
#             'id': 'f19'},
#            {'c': 'Motorcycles',
#             'v': '13,895,882094',
#             'calt': 'Motorcycles',
#             'id': 'f325'},
#            {'c': 'Industrial vehicles',
#             'v': '189,2853,779051',
#             'calt': 'Industrial vehicles',
#             'id': 'f272'},
#            {'c': 'Others',
#             'v': '135,726,172003',
#             'calt': 'Other  vehicles',
#             'id': 'f326'},
#            {'c': 'Total',
#             'v': '512,11435,5387406',
#             'calt': 'Fleet of vehicles',
#             'id': 'f163'}]},
#          'r': '2020',
#          'c': 'Fleet of vehicles',
#          's': 'Idescat, based on data from the DGT.',
#          'calt': 'Fleet of vehicles',
#          'id': 't18',
#          'l': 'https://www.idescat.cat/pub/?id=parcc&n=291&geo=mun:250019&lang=en',
#          'updated': '2021-09-22T10:00:00+00:00'}]},
#       'c': 'Economic sectors',
#       'id': 'g170'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Generation per capita',
#             'u': 'kg/inhab./day',
#             'v': '1.24,1.50,1.40',
#             'calt': 'Municipal waste per capita',
#             'id': 'f366'},
#            {'c': 'Selective collection',
#             'u': '%',
#             'v': '40.7,43.2,45.9',
#             'calt': 'Selective collection of municipal waste',
#             'id': 'f368'}]},
#          'r': '2020',
#          'c': 'Municipal waste',
#          's': 'The Waste Agency of Catalonia.',
#          'calt': 'Municipal waste',
#          'id': 't204',
#          'l': 'https://www.idescat.cat/pub/?id=resmc&n=6997&geo=mun:250019&lang=en',
#          'updated': '2022-02-14T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Establishments with yearly waste declarations',
#             'v': '0,46,15166',
#             'calt': 'Establishments with yearly ind. waste declarations',
#             'id': 'f371'},
#            {'c': 'Industrial waste',
#             'u': 'tonnes',
#             'v': '0.00,937.38,3793347.50',
#             'calt': 'Industrial waste',
#             'id': 'f369'}]},
#          'r': '2017',
#          'c': 'Industrial waste',
#          's': 'The Waste Agency of Catalonia.',
#          'calt': 'Industrial waste',
#          'id': 't207',
#          'l': 'https://www.idescat.cat/pub/?id=resic&n=7083&geo=mun:250019&lang=en',
#          'updated': '2019-05-15T10:00:00+00:00'}]},
#       'c': 'Environment',
#       'id': 'g205'}]},
#    'lang': 'en',
#    'version': '1.00',
#    'cols': {'col': [{'scheme': 'mun',
#       'id': '250019',
#       'content': 'Abella de la Conca'},
#      {'scheme': 'com', 'id': '25', 'content': 'Pallars Jussà'},
#      {'scheme': 'ca', 'id': '09', 'content': 'Catalunya'}]},
#    'o': 'dades'}},
#  '080018': {'fitxes': {'p': 'id=080018',
#    'gg': {'g': [{'tt': {'t': {'ff': {'f': [{'r': '2021',
#            'c': 'Surface area',
#            'u': 'km²',
#            'v': '19.94,485.99,32108.00',
#            'calt': 'Surface area',
#            'id': 'f271',
#            'updated': '2021-12-23T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'Altitude',
#            'u': 'm',
#            'v': '105,_,_',
#            'calt': 'Altitude',
#            'id': 'f258',
#            'updated': '2014-02-17T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'Longitude',
#            'u': 'º',
#            'v': '1.903100,_,_',
#            'calt': 'Longitude',
#            'id': 'f328',
#            'updated': '2014-02-17T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'Latitude',
#            'u': 'º',
#            'v': '41.518531,_,_',
#            'calt': 'Latitude',
#            'id': 'f329',
#            'updated': '2014-02-17T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'UTM coordinates x',
#            'u': 'm',
#            'v': '408471,_,_',
#            'calt': 'UTM coordinates x',
#            'id': 'f259',
#            'updated': '2014-02-17T11:00:00+00:00'},
#           {'r': '2013',
#            'c': 'UTM coordinates y',
#            'u': 'm',
#            'v': '4596983,_,_',
#            'calt': 'UTM coordinates y',
#            'id': 'f260',
#            'updated': '2014-02-17T11:00:00+00:00'}]},
#         'c': 'Geographic indicators',
#         'id': 't176',
#         'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:080018&lang=en'}},
#       'c': 'Territory',
#       'id': 'g173'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Surface area',
#             'u': 'km²',
#             'v': '19.94,485.99,32108.00',
#             'calt': 'Surface area',
#             'id': 'f261'},
#            {'c': 'Density',
#             'u': 'inh./km²',
#             'v': '632.9,1714.7,241.8',
#             'calt': 'Density',
#             'id': 'f262'}]},
#          'r': '2021',
#          'c': 'Density of population',
#          'calt': 'Density',
#          'id': 't192',
#          'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:080018&lang=en',
#          'updated': '2021-12-23T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Men',
#             'v': '6373,409210,3819831',
#             'calt': 'Men',
#             'id': 'f318'},
#            {'c': 'Women',
#             'v': '6247,424102,3943531',
#             'calt': 'Women',
#             'id': 'f320'},
#            {'c': 'Total',
#             'v': '12620,833312,7763362',
#             'calt': 'Population',
#             'id': 'f321'}]},
#          'r': '2021',
#          'c': 'Population. By sex',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Sex',
#          'id': 't195',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=446&geo=mun:080018&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'From 0 to 14 years',
#             'v': '2138,128735,1139260',
#             'calt': 'Population from 0 to 14 years',
#             'id': 'f167'},
#            {'c': 'From 15 to 64 years',
#             'v': '8503,554817,5145431',
#             'calt': 'Population from 15 to 64 years',
#             'id': 'f27'},
#            {'c': 'From 65 to 84 years',
#             'v': '1749,128135,1228528',
#             'calt': 'Population from 65 to 84 years',
#             'id': 'f28'},
#            {'c': 'From 85 years and over',
#             'v': '230,21625,250143',
#             'calt': 'Population from 85 years and over',
#             'id': 'f29'},
#            {'c': 'Total',
#             'v': '12620,833312,7763362',
#             'calt': 'Population',
#             'id': 'f171'}]},
#          'r': '2021',
#          'c': 'Population. By age groups',
#          's': 'Idescat, from the Continuous Register Statistic of INE.',
#          'calt': 'Age groups',
#          'id': 't25',
#          'l': 'https://www.idescat.cat/pub/?id=pmh&n=9548&geo=mun:080018&lang=en',
#          'updated': '2022-02-28T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'From 0 to 14 years',
#             'v': '1100,66082,586182',
#             'calt': 'Men from 0 to 14 years',
#             'id': 'f176'},
#            {'c': 'From 15 to 64 years',
#             'v': '4366,278413,2598440',
#             'calt': 'Men from 15 to 64 years',
#             'id': 'f33'},
#            {'c': 'From 65 to 84 years',
#             'v': '809,57388,552061',
#             'calt': 'Men from 65 to 84 years',
# ...
#             'calt': 'Registered unemployment. Women',
#             'id': 'f241'},
#            {'c': 'Total',
#             'v': '161.1,12748.7,437165.6',
#             'calt': 'Registered unemployment',
#             'id': 'f242'}]},
#          'r': '2021',
#          'c': 'Registered unemployment. By sex',
#          's': 'Ministry of Business and Employment.',
#          'u': 'annual averages',
#          'calt': 'Registered unemployment by sex',
#          'id': 't187',
#          'l': 'https://www.idescat.cat/pub/?id=atureg&n=4299&geo=mun:250387&lang=en',
#          'updated': '2022-01-13T11:00:00+00:00'}]},
#       'c': 'Labour',
#       'id': 'g169'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Main',
#             'v': '832,81550,2944944',
#             'calt': 'Main family dwellings',
#             'id': 'f250'},
#            {'c': 'Secondary',
#             'v': '129,5799,470081',
#             'calt': 'Secondary family dwellings',
#             'id': 'f119'},
#            {'c': 'Vacant',
#             'v': '108,12502,448356',
#             'calt': 'Vacant family dwellings',
#             'id': 'f120'},
#            {'c': 'Total',
#             'v': '1069,99851,3863381',
#             'calt': 'Family dwellings',
#             'id': 'f122'}]},
#          'r': '2011',
#          'c': 'Family dwellings. By type',
#          's': "Idescat, based on the INE's Population and Housing Census.",
#          'calt': 'Type of dwellings',
#          'id': 't116',
#          'l': 'https://www.idescat.cat/pub/?id=censph&n=30&geo=mun:250387&lang=en',
#          'updated': '2013-12-19T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Owned',
#             'v': '610,61662,2188657',
#             'calt': 'Owned main family homes',
#             'id': 'f126'},
#            {'c': 'Rented',
#             'v': '145,14978,582701',
#             'calt': 'Rented main family homes',
#             'id': 'f128'},
#            {'c': 'Total',
#             'v': '832,81550,2944944',
#             'calt': 'Main family homes',
#             'id': 'f131'}]},
#          'r': '2011',
#          'c': 'Main family dwellings. By type of tenancy',
#          's': "Idescat, based on the INE's Population and Housing Census.",
#          'calt': 'Type of tenancy of dwellings',
#          'id': 't124',
#          'l': 'https://www.idescat.cat/pub/?id=censph&n=310&geo=mun:250387&lang=en',
#          'updated': '2013-12-19T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'From 61 to 90 m²',
#             'v': '308,39894,1476187',
#             'calt': 'Main family homes from 61 to 90 m²',
#             'id': 'f190'},
#            {'c': 'From 91 to 120 m²',
#             'v': '275,20900,560379',
#             'calt': 'Main family homes from 91 to 120 m²',
#             'id': 'f191'},
#            {'c': 'Total',
#             'v': '832,81550,2944944',
#             'calt': 'Main family homes',
#             'id': 'f193'}]},
#          'r': '2011',
#          'c': 'Main family dwellings. By useful surface area',
#          's': "Idescat, based on the INE's Population and Housing Census.",
#          'calt': 'Useful surface area of dwellings',
#          'id': 't177',
#          'l': 'https://www.idescat.cat/pub/?id=censph&n=7008&geo=mun:250387&lang=en',
#          'updated': '2013-12-19T11:00:00+00:00'}]},
#       'c': 'Quality of life',
#       'id': 'g171'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'GDHI',
#             'u': 'thousands of euros',
#             'v': '29028,3232756,133679103',
#             'calt': 'GDHI',
#             'id': 'f6'},
#            {'c': 'GDHI per capita',
#             'u': 'thousands of euros',
#             'v': '11.5,15.7,17.6',
#             'calt': 'GDHI per capita',
#             'id': 'f7'},
#            {'c': 'GDHI per capita',
#             'u': 'Catalonia index=100',
#             'v': '65.3,89.3,100.0',
#             'calt': 'GDHI per capita (Catalonia=100)',
#             'id': 'f8'}]},
#          'r': '2018',
#          'c': 'Gross disposable household income. 2019 Benchmark revision',
#          's': 'Idescat.',
#          'calt': 'Disposable household income',
#          'id': 't5',
#          'l': 'https://www.idescat.cat/pub/?id=rfdbc&n=13301&geo=mun:250387&lang=en',
#          'updated': '2021-04-30T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Number of receipts',
#             'v': '1436,163929,5855886',
#             'calt': 'IBI. Receipts',
#             'id': 'f198'},
#            {'c': 'Taxable base by receipt',
#             'u': 'euros',
#             'v': '35150.4,45424.6,70537.2',
#             'calt': 'IBI. Taxable base by receipt',
#             'id': 'f199'},
#            {'c': 'Integral quota by receipt',
#             'u': 'euros',
#             'v': '232.0,406.6,485.9',
#             'calt': 'IBI. Integral quota by receipt',
#             'id': 'f200'}]},
#          'r': '2020',
#          'c': 'Urban property tax (IBI)',
#          's': 'Idescat, based on data from the Dirección General del Catastro.',
#          'calt': 'Urban property tax',
#          'id': 't179',
#          'l': 'https://www.idescat.cat/pub/?id=ibi&n=173&geo=mun:250387&lang=en',
#          'updated': '2021-06-29T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Taxable base by declarer',
#             'v': '13922,21721,24984',
#             'calt': 'IRPF. Taxable base by declarer',
#             'id': 'f10'},
#            {'c': 'Resulting quota from self-payment by declarer',
#             'v': '3898,5993,7193',
#             'calt': 'IRPF. Resulting quotafrom self-payment by declarer',
#             'id': 'f11'}]},
#          'r': '2019',
#          'c': 'Personal Income Tax (IRPF)',
#          's': "Idescat, based on data from the Agència Estatal d'Administració Tributària.",
#          'u': 'euros',
#          'calt': 'Personal Income Tax',
#          'id': 't9',
#          'l': 'https://www.idescat.cat/pub/?id=irpf&n=4070&geo=mun:250387&lang=en',
#          'updated': '2021-11-26T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Total weath by declarer',
#             'u': 'euros',
#             'v': '377050,453633,516035',
#             'calt': 'IPPF. Total wealth per declarer',
#             'id': 'f180'},
#            {'c': 'Real assets',
#             'u': '%',
#             'v': '29.4,41.8,37.4',
#             'calt': 'IPPF. Declaration of real assets',
#             'id': 'f202'},
#            {'c': 'Financial assets',
#             'u': '%',
#             'v': '70.6,58.2,62.6',
#             'calt': 'IPPF. Declaration of financial assets',
#             'id': 'f203'}]},
#          'r': '2007',
#          'c': 'Wealth tax (IPPF)',
#          's': "Idescat, based on data from the Agència Estatal d'Administració Tributària.",
#          'calt': 'Wealth tax',
#          'id': 't167',
#          'l': 'https://www.idescat.cat/pub/?id=ippf&n=382&geo=mun:250387&lang=en',
#          'updated': '2010-06-11T10:00:00+00:00'}]},
#       'c': 'Main aggregates · Public sector finance',
#       'id': 'g163'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Cultivated land',
#             'v': '3406,85018,792425',
#             'calt': 'Cultivated land surface',
#             'id': 'f133'},
#            {'c': 'Permanent pasture',
#             'v': '153,8638,355107',
#             'calt': 'Permanent pasture surface',
#             'id': 'f134'},
#            {'c': 'Total',
#             'v': '3559,93656,1147532',
#             'calt': 'Used agricultural area',
#             'id': 'f345'}]},
#          'r': '2009',
#          'c': 'Used agricultural area (UAA)',
#          's': '',
#          'u': 'hectares',
#          'calt': 'Used agricultural area',
#          'id': 't132',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5173&geo=mun:250387&lang=en',
#          'updated': '2012-04-04T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Herbaceous crops',
#             'v': '575,42846,511150',
#             'calt': 'Herbaceous crops',
#             'id': 'f346'},
#            {'c': 'Fruit trees',
#             'v': '2390,28459,110819',
#             'calt': 'Fruit trees crops',
#             'id': 'f347'},
#            {'c': 'Olives',
#             'v': '422,11229,101236',
#             'calt': 'Olives crops',
#             'id': 'f348'},
#            {'c': 'Vines',
#             'v': '0,2228,61391',
#             'calt': 'Vines crops',
#             'id': 'f349'},
#            {'c': 'Others',
#             'v': '19,256,7829',
#             'calt': 'Other crops',
#             'id': 'f350'},
#            {'c': 'Total',
#             'v': '3406,85018,792425',
#             'calt': 'Cultivated land',
#             'id': 'f351'}]},
#          'r': '2009',
#          'c': 'Cultivated land. By type of crop',
#          's': '',
#          'u': 'hectares',
#          'calt': 'Cultivated land',
#          'id': 't199',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5084&geo=mun:250387&lang=en',
#          'updated': '2012-03-20T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Without land',
#             'v': '2,171,1519',
#             'calt': 'Farms without land',
#             'id': 'f352'},
#            {'c': 'With land',
#             'v': '262,5803,59320',
#             'calt': 'Farms with land',
#             'id': 'f353'},
#            {'c': 'Total',
#             'v': '264,5974,60839',
#             'calt': 'Farms with and without land',
#             'id': 'f356'}]},
#          'r': '2009',
#          'c': 'Farms. By land ownership',
#          's': '',
#          'calt': 'Land ownership',
#          'id': 't200',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5172&geo=mun:250387&lang=en',
#          'updated': '2012-04-04T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Without livestock',
#             'v': '248,4852,47172',
#             'calt': 'Farms without livestock',
#             'id': 'f139'},
#            {'c': 'With livestock',
#             'v': '16,1122,13667',
#             'calt': 'Farms with livestock',
#             'id': 'f204'},
#            {'c': 'Total',
#             'v': '264,5974,60839',
#             'calt': 'Farms with and without livestock',
#             'id': 'f138'}]},
#          'r': '2009',
#          'c': 'Farms. By livestock ownership',
#          's': '',
#          'calt': 'Livestock ownership',
#          'id': 't137',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5172&geo=mun:250387&lang=en',
#          'updated': '2012-04-04T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Bovine',
#             'v': '120,59113,544135',
#             'calt': 'Bovine head',
#             'id': 'f141'},
#            {'c': 'Ovine',
#             'v': '2889,40046,600082',
#             'calt': 'Ovine head',
#             'id': 'f142'},
#            {'c': 'Caprine',
#             'v': '5,2441,71748',
#             'calt': 'Caprine head',
#             'id': 'f252'},
#            {'c': 'Porcine',
#             'v': '23060,943807,6742638',
#             'calt': 'Porcine head',
#             'id': 'f144'},
#            {'c': 'Avian',
#             'v': '100000,3570783,43890563',
#             'calt': 'Avian head',
#             'id': 'f145'},
#            {'c': 'Female rabbits',
#             'v': '0,16964,335054',
#             'calt': 'Female rabbits head',
#             'id': 'f146'},
#            {'c': 'Equine',
#             'v': '0,216,19352',
#             'calt': 'Equine head',
#             'id': 'f147'}]},
#          'r': '2009',
#          'c': 'Head of livestock. By species',
#          's': '',
#          'calt': 'Head of livestock',
#          'id': 't140',
#          'l': 'https://www.idescat.cat/pub/?id=censag&n=5107&geo=mun:250387&lang=en',
#          'updated': '2012-04-04T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'State subsidised housing starts',
#             'v': '0,0,1903',
#             'calt': 'State subsidised housing starts',
#             'id': 'f13'},
#            {'c': 'Housing starts',
#             'v': '0,301,11395',
#             'calt': 'Housing starts',
#             'id': 'f14'}]},
#          'r': '2020',
#          'c': 'Housing construction',
#          's': "Idescat, based on data from the Departament de Territori i Sostenibilitat. Secretaria d'Habitatge i Millora Urbana.",
#          'calt': 'Housing construction',
#          'id': 't12',
#          'l': 'https://www.idescat.cat/pub/?id=habit&n=86&geo=mun:250387&lang=en',
#          'updated': '2021-04-28T10:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Hotels',
#             'v': '0,32,3083',
#             'calt': 'Hotels',
#             'id': 'f215',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Hotel beds',
#             'v': '0,2848,318954',
#             'calt': 'Hotel beds',
#             'id': 'f216',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Campsites',
#             'v': '0,1,351',
#             'calt': 'Campsites',
#             'id': 'f217',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Campsite places',
#             'v': '0,111,262346',
#             'calt': 'Campsite places',
#             'id': 'f218',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Rural tourism',
#             'v': '1,8,2514',
#             'calt': 'Rural tourism',
#             'id': 'f219',
#             'updated': '2021-07-01T10:00:00+00:00'},
#            {'c': 'Rural tourism beds',
#             'v': '7,68,20190',
#             'calt': 'Rural tourism beds',
#             'id': 'f220',
#             'updated': '2021-07-01T10:00:00+00:00'}]},
#          'r': '2020',
#          'c': 'Tourist accommodation',
#          's': 'Idescat, based on data from the Ministry of Business and Labour.',
#          'calt': 'Tourist accommodation',
#          'id': 't182',
#          'l': 'https://www.idescat.cat/pub/?id=turall&geo=mun:250387&lang=en'},
#         {'ff': {'f': [{'c': 'Estate cars',
#             'v': '1413,105075,3554258',
#             'calt': 'Cars',
#             'id': 'f19'},
#            {'c': 'Motorcycles',
#             'v': '137,15444,882094',
#             'calt': 'Motorcycles',
#             'id': 'f325'},
#            {'c': 'Industrial vehicles',
#             'v': '417,27644,779051',
#             'calt': 'Industrial vehicles',
#             'id': 'f272'},
#            {'c': 'Others',
#             'v': '122,8364,172003',
#             'calt': 'Other  vehicles',
#             'id': 'f326'},
#            {'c': 'Total',
#             'v': '2089,156527,5387406',
#             'calt': 'Fleet of vehicles',
#             'id': 'f163'}]},
#          'r': '2020',
#          'c': 'Fleet of vehicles',
#          's': 'Idescat, based on data from the DGT.',
#          'calt': 'Fleet of vehicles',
#          'id': 't18',
#          'l': 'https://www.idescat.cat/pub/?id=parcc&n=291&geo=mun:250387&lang=en',
#          'updated': '2021-09-22T10:00:00+00:00'}]},
#       'c': 'Economic sectors',
#       'id': 'g170'},
#      {'tt': {'t': [{'ff': {'f': [{'c': 'Generation per capita',
#             'u': 'kg/inhab./day',
#             'v': '0.95,1.15,1.40',
#             'calt': 'Municipal waste per capita',
#             'id': 'f366'},
#            {'c': 'Selective collection',
#             'u': '%',
#             'v': '44.5,41.8,45.9',
#             'calt': 'Selective collection of municipal waste',
#             'id': 'f368'}]},
#          'r': '2020',
#          'c': 'Municipal waste',
#          's': 'The Waste Agency of Catalonia.',
#          'calt': 'Municipal waste',
#          'id': 't204',
#          'l': 'https://www.idescat.cat/pub/?id=resmc&n=6997&geo=mun:250387&lang=en',
#          'updated': '2022-02-14T11:00:00+00:00'},
#         {'ff': {'f': [{'c': 'Establishments with yearly waste declarations',
#             'v': '9,385,15740',
#             'calt': 'Establishments with yearly ind. waste declarations',
#             'id': 'f371'},
#            {'c': 'Industrial waste',
#             'u': 'tonnes',
#             'v': '252.08,61280.23,3812262.98',
#             'calt': 'Industrial waste',
#             'id': 'f369'}]},
#          'r': '2019',
#          'c': 'Industrial waste',
#          's': 'The Waste Agency of Catalonia.',
#          'calt': 'Industrial waste',
#          'id': 't207',
#          'l': 'https://www.idescat.cat/pub/?id=resic&n=7083&geo=mun:250387&lang=en',
#          'updated': '2021-05-04T10:00:00+00:00'}]},
#       'c': 'Environment',
#       'id': 'g205'}]},
#    'lang': 'en',
#    'version': '1.00',
#    'cols': {'col': [{'scheme': 'mun', 'id': '250387', 'content': 'Aitona'},
#      {'scheme': 'com', 'id': '33', 'content': 'Segrià'},
#      {'scheme': 'ca', 'id': '09', 'content': 'Catalunya'}]},
#    'o': 'dades'}}}

# %%
with open("test.json", 'w') as file:
    json.dump(test['250019'], file)

# %%
# def parse_mun_to_dict_of_list(data):
#     """FUnction build before the knowledge of data not being complete."""
#     columns = {}
#     for key in data.keys():
#         print(data[key]['fitxes']['cols']['col'][0]['id'])
#         print(key)
#         assert data[key]['fitxes']['cols']['col'][0]['id'] == key
        
        
#         for g in data[key]['fitxes']['gg']['g']:
            
#             if type(g['tt']['t']) == type(dict):
                
#                 if type(g['tt']['t']['ff']['f']) == type(dict):
#                     value = value_splitter(g['tt']['t']['ff']['f']['v'])
#                     if g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt'] in columns.keys():
#                         columns[g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt']].append(value)
#                     else:
#                         columns[g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt']] = [value]
#                 else:
#                     for f in g['tt']['t']['ff']['f']:
#                         value = value_splitter(f['v'])
#                         if g['tt']['t']['c'] + "_" + f['calt'] in columns.keys():
#                             columns[g['tt']['t']['c'] + "_" + f['calt']].append(value)
#                         else:
#                             columns[g['tt']['t']['c'] + "_" + f['calt']] = [value]
#             else:
#                 for t in g['tt']['t']:
#                     if type(t['ff']['f']) == type(dict):
#                         value = value_splitter(t['ff']['f']['v'])
#                         if t['c'] + "_" + t['ff']['f']['calt'] in columns.keys():
#                             columns[t['c'] + "_" + t['ff']['f']['calt']].append(value)
#                         else:
#                             columns[t['c'] + "_" + t['ff']['f']['calt']] = [value]
#                     else:
#                         for f in t['ff']['f']:
#                             value = value_splitter(f['v'])
#                             if t['c'] + "_" + f['calt'] in columns.keys():
#                                 columns[t['c'] + "_" + f['calt']].append(value)
#                             else:
#                                 columns[t['c'] + "_" + f['calt']] = [value]
                    
#     return columns

# %%
# def value_splitter(value):
#     assert type(value) == str
#     mun, com, ca = value.split(',')
#     return mun, com, ca


# def is_not_in_column_names(column_names, name):
#     if name in column_names:
#         return False
#     else:
#         return True

        
# def get_column_names_from_muns(data):
#     """Returns all the names of the columns which are in the data set
#     It looks super cumbersome because the people from idescat do not know how to keep consistency in their data
#     """
#     column_names = []
#     # For each municipality in the data, go over the json.
#     for key in data.keys():
#         # Check if the municipality is really that municipality.
#         assert data[key]['fitxes']['cols']['col'][0]['id'] == key
        
#         # go over all 'groups' in the dictoinary structure
#         for g in data[key]['fitxes']['gg']['g']:
            
#             # Check if the group contains one or more tables. The group is a dictoinary of tables when there is
#             # is multiple tables in the group, and a list when there is only one. When this if statement returns true,
#             # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
#             if type(g['tt']['t']) == dict:

#                 # Check if the table contains one or more rows. The table is a list of rows when there is
#                 # is multiple rows in the table, and a dictionary when there is only one. When this if statement returns true,
#                 # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
#                 if type(g['tt']['t']['ff']['f']) == dict:
                    
#                     # Check if the name is already in the column names list, and otherwise append it to the list.
#                     if is_not_in_column_names(column_names, g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt']):
#                         column_names.append(g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt'])
#                 else:
#                     for f in g['tt']['t']['ff']['f']:
#                         # Check if the name is already in the column names list, and otherwise append it to the list.
#                         if is_not_in_column_names(column_names, g['tt']['t']['c'] + "_" + f['calt']):
#                             column_names.append(g['tt']['t']['c'] + "_" + f['calt'])
#                         #print(f['calt'])
#             else:
#                 for t in g['tt']['t']:
                    
#                     # Check if the table contains one or more rows. The table is a dictoinary of rows when there is
#                     # is multiple rows in the table, and a list when there is only one. When this if statement returns true,
#                     # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
#                     if type(t['ff']['f']) == dict:
#                         # Check if the name is already in the column names list, and otherwise append it to the list.
#                         if is_not_in_column_names(column_names, t['c'] + "_" + t['ff']['f']['calt']):
#                             column_names.append(t['c'] + "_" + t['ff']['f']['calt'])

#                     else:
#                         for f in t['ff']['f']:
#                             # Check if the name is already in the column names list, and otherwise append it to the list.
#                             if is_not_in_column_names(column_names, t['c'] + "_" + f['calt']):
#                                 column_names.append(t['c'] + "_" + f['calt'])
#     return column_names
        
    
# def make_col_dict(column_names):
#     col_dict = {}
#     for col in column_names:
#         col_dict[col] = []
#     return col_dict


# def retrieve_mun_from_json(data, columns):
#     column_names = list(columns.keys())
#     for g in data['fitxes']['gg']['g']:
            
#         # Check if the group contains one or more tables. The group is a dictoinary of tables when there is
#         # is multiple tables in the group, and a list when there is only one. When this if statement returns true,
#         # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
#         if type(g['tt']['t']) == dict:

#             # Check if the table contains one or more rows. The table is a dictoinary of rows when there is
#             # is multiple rows in the table, and a list when there is only one. When this if statement returns true,
#             # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
#             if type(g['tt']['t']['ff']['f']) == dict:
#                 v, _, _ = value_splitter(g['tt']['t']['ff']['f']['v'])
#                 columns[g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt']].append(v)
#                 print(g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt'])
#                 print(g['tt']['t']['ff']['f']['r'])
#                 column_names.remove(g['tt']['t']['c'] + "_" + g['tt']['t']['ff']['f']['calt'])
#             else:
#                 for f in g['tt']['t']['ff']['f']:
#                     v, _, _ = value_splitter(f['v'])
#                     columns[g['tt']['t']['c'] + "_" + f['calt']].append(v)
#                     print(g['tt']['t']['c'] + "_" + f['calt'])
#                     print('f')
#                     column_names.remove(g['tt']['t']['c'] + "_" + f['calt'])
#         else:
#             for t in g['tt']['t']:
                    
#                 # Check if the table contains one or more rows. The table is a dictoinary of rows when there is
#                 # is multiple rows in the table, and a list when there is only one. When this if statement returns true,
#                 # the next element is treated as a dictoinary, and when it returns false, it is treated as a list.
#                 if type(t['ff']['f']) == dict:
#                     v, _, _ = value_splitter(t['ff']['f']['v'])
#                     columns[t['c'] + "_" + t['ff']['f']['calt']].append(v)
#                     print(t['c'] + "_" + t['ff']['f']['calt'])
#                     print(t['ff']['f']['r'])
#                     column_names.remove(t['c'] + "_" + t['ff']['f']['calt'])
#                 else:
#                     for f in t['ff']['f']:                     
#                         v, _, _ = value_splitter(f['v'])
#                         columns[t['c'] + "_" + f['calt']].append(v)
#                         print(t['c'] + "_" + f['calt'])
#                         print(f['r'])
#                         column_names.remove(t['c'] + "_" + f['calt'])
    
#     for c in column_names:
#         columns[c].append('nan')
#     return columns

# %%
test.keys()
# Out:
# dict_keys(['250019', '080018', '250024', '250030', '080023', '170010', '080142', '430017', '170025', '250387'])

# %%
def add_muns_to_parser(parser, muns):
    for name, mun in muns.items():
        parser.add_json(d=mun, name=name)

# %%
def change_dicts_to_panda_df(dicts):
    pd_dict = {}
    for name, dct in dicts.items():
        df = pd.DataFrame(dct, index=[name])
        pd_dict[name] = df
    return pd_dict

# %%
def concatenate_dict_of_dfs(dfs):
    for i, (name, d) in enumerate(dfs.items()):
        if i == 0:
            df = d
        else:
            df = pd.concat([df, d])
    return df

# %%
concatenate_dict_of_dfs(ptest)
# Out:
#        Territory_Geographic_indicators_Surface_area_Surface_area  \
# 080018                                              19.94
# 250019                                              78.27
# 250024                                             160.57
# 250030                                              79.65
# 080023                                              43.32
# 170010                                              27.73
#
#        Territory_Geographic_indicators_Altitude_Altitude  \
# 080018                                               105
# 250019                                               956
# 250024                                               642
# 250030                                               337
# 080023                                               480
# 170010                                               166
#
#        Territory_Geographic_indicators_Longitude_Longitude  \
# 080018                                           1.903100
# 250019                                           1.092892
# 250024                                           0.762617
# 250030                                           1.099819
# 080023                                           1.632131
# 170010                                           2.847522
#
#        Territory_Geographic_indicators_Latitude_Latitude  \
# 080018                                         41.518531
# 250019                                         42.162392
# 250024                                         42.002881
# 250030                                         41.788086
# 080023                                         41.740044
# 170010                                         42.395189
#
#        Territory_Geographic_indicators_UTM_coordinates_x_UTM_coordinates_x  \
# 080018                                             408471
# 250019                                             342450
# 250024                                             314700
# 250030                                             342100
# 080023                                             386250
# 170010                                             487450
#
#        Territory_Geographic_indicators_UTM_coordinates_y_UTM_coordinates_y  \
# 080018                                            4596983
# 250019                                            4669650
# 250024                                            4652600
# 250030                                            4628075
# 080023                                            4621900
# 170010                                            4693750
#
#        Population_Geographic_indicators_UTM_coordinates_y_UTM_coordinates_y_Density_Density_of_population_Surface_area_Surface_area  \
# 080018                                              19.94
# 250019                                              78.27
# 250024                                             160.57
# 250030                                              79.65
# 080023                                              43.32
# 170010                                              27.73
#
#        Population_Geographic_indicators_UTM_coordinates_y_UTM_coordinates_y_Density_Density_of_population_Density_Density  \
# 080018                                              632.9
# 250019                                                2.2
# 250024                                                3.7
# 250030                                               68.6
# 080023                                                6.6
# 170010                                               31.9
#
#        Population_Geographic_indicators_UTM_coordinates_y_UTM_coordinates_y_Sex_Population._By_sex_Men_Men  \
# 080018                                               6373
# 250019                                                 89
# 250024                                                322
# 250030                                               2763
# 080023                                                154
# 170010                                                445
#
#        Population_Geographic_indicators_UTM_coordinates_y_UTM_coordinates_y_Sex_Population._By_sex_Women_Women  \
# 080018                                               6247
# 250019                                                 82
# 250024                                                266
# 250030                                               2701
# 080023                                                132
# 170010                                                440
#
#         ...  \
# 080018  ...
# 250019  ...
# 250024  ...
# 250030  ...
# 080023  ...
# 170010  ...
#
#        Economic_sectors_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Fleet_of_vehicles_Fleet_of_vehicles_Cars_Estate_cars  \
# 080018                                                NaN
# 250019                                                175
# 250024                                                367
# 250030                                                NaN
# 080023                                               8645
# 170010                                                559
#
#        Economic_sectors_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Fleet_of_vehicles_Fleet_of_vehicles_Motorcycles_Motorcycles  \
# 080018                                                NaN
# 250019                                                 13
# 250024                                                 69
# 250030                                                NaN
# 080023                                                168
# 170010                                                 82
#
#        Economic_sectors_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Fleet_of_vehicles_Fleet_of_vehicles_Industrial_vehicles_Industrial_vehicles  \
# 080018                                                NaN
# 250019                                                189
# 250024                                                191
# 250030                                                NaN
# 080023                                               6314
# 170010                                                187
#
#        Economic_sectors_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Fleet_of_vehicles_Fleet_of_vehicles_Other__vehicles_Others  \
# 080018                                                NaN
# 250019                                                135
# 250024                                                 75
# 250030                                                NaN
# 080023                                               2749
# 170010                                                 28
#
#        Economic_sectors_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Fleet_of_vehicles_Fleet_of_vehicles_Fleet_of_vehicles_Total  \
# 080018                                                NaN
# 250019                                                512
# 250024                                                702
# 250030                                                NaN
# 080023                                              17876
# 170010                                                856
#
#        Environment_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Municipal_waste_Municipal_waste_Municipal_waste_per_capita_Generation_per_capita  \
# 080018                                                NaN
# 250019                                               1.24
# 250024                                               1.60
# 250030                                                NaN
# 080023                                               1.37
# 170010                                               1.54
#
#        Environment_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Municipal_waste_Municipal_waste_Selective_collection_of_municipal_waste_Selective_collection  \
# 080018                                                NaN
# 250019                                               40.7
# 250024                                               43.6
# 250030                                                NaN
# 080023                                               44.0
# 170010                                               48.9
#
#        Environment_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Industrial_waste_Industrial_waste_Establishments_with_yearly_ind._waste_declarations_Establishments_with_yearly_waste_declarations  \
# 080018                                                NaN
# 250019                                                  0
# 250024                                                  0
# 250030                                                NaN
# 080023                                                  1
# 170010                                                  2
#
#        Environment_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total_Industrial_waste_Industrial_waste_Industrial_waste_Industrial_waste  \
# 080018                                                NaN
# 250019                                               0.00
# 250024                                               0.00
# 250030                                                NaN
# 080023                                               2.24
# 170010                                              45.66
#
#        Quality_of_life_Level_of_education_attained_Population_aged_15_and_over._By_level_of_education_attained_Contributory_accounts_Total_Type_of_tenancy_of_dwellings_Main_family_dwellings._By_type_of_tenancy_Owned_main_family_homes_Owned
# 080018                                                NaN
# 250019                                                NaN
# 250024                                                NaN
# 250030                                               1534
# 080023                                                NaN
# 170010                                                NaN
#
# [6 rows x 261 columns]

# %%
add_muns_to_parser(parser, test)

# %%
ptest = change_dicts_to_panda_df(containers)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(ptest['080018']))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
parser._json_data.keys()
# Out:
# dict_keys(['080018', '250019', '250024', '250030', '080023', '170010', '080142', '430017', '170025', '250387'])

# %%
from json_parser import *

# %%
parser = JSONParser(json_value='v', json_column_name=['c', 'calt'])

# %%
parser.add_json(d=test['080018'], name='080018')
parser.add_json(d=test['250019'], name='250019')
parser.add_json(d=test['250024'], name='250024')
parser.add_json(d=test['250030'], name='250030')
parser.add_json(d=test['080023'], name='080023')
parser.add_json(d=test['170010'], name='170010')
parser.add_key_map(homogenize_key)
parser.add_value_map(value_splitter)

# %%
parser.parse_data()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
parser._holder._keys
# Out:
# {}

# %%
containers = parser.containers()
for name, con in containers.items():
    print(len(con))
# Out:
# 211
# 168
# 168
# 212
# 161
# 169

# %%
dct={1:'a'}
1 in dct.keys()
# Out:
# True

# %%
for key, value in containers['250019'].items():
    print(f'{value} \t {key}')
# Out:
# 78.27 	 Territory_Geographic_indicators_Surface_area_Surface_area
# 956 	 Territory_Geographic_indicators_Altitude_Altitude
# 1.092892 	 Territory_Geographic_indicators_Longitude_Longitude
# 42.162392 	 Territory_Geographic_indicators_Latitude_Latitude
# 342450 	 Territory_Geographic_indicators_UTM_coordinates_x_UTM_coordinates_x
# 4669650 	 Territory_Geographic_indicators_UTM_coordinates_y_UTM_coordinates_y
# 78.27 	 Population_Density_Density_of_population_Surface_area_Surface_area
# 2.2 	 Population_Density_Density_of_population_Density_Density
# 89 	 Population_Sex_Population._By_sex_Men_Men
# 82 	 Population_Sex_Population._By_sex_Women_Women
# 171 	 Population_Sex_Population._By_sex_Population_Total
# 16 	 Population_Age_groups_Population._By_age_groups_Population_from_0_to_14_years_From_0_to_14_years
# 110 	 Population_Age_groups_Population._By_age_groups_Population_from_15_to_64_years_From_15_to_64_years
# 33 	 Population_Age_groups_Population._By_age_groups_Population_from_65_to_84_years_From_65_to_84_years
# 12 	 Population_Age_groups_Population._By_age_groups_Population_from_85_years_and_over_From_85_years_and_over
# 171 	 Population_Age_groups_Population._By_age_groups_Population_Total
# 8 	 Population_Age_groups._Men_Population._By_age_groups._Men_Men_from_0_to_14_years_From_0_to_14_years
# 59 	 Population_Age_groups._Men_Population._By_age_groups._Men_Men_from_15_to_64_years_From_15_to_64_years
# 14 	 Population_Age_groups._Men_Population._By_age_groups._Men_Men_from_65_to_84_years_From_65_to_84_years
# 8 	 Population_Age_groups._Men_Population._By_age_groups._Men_Men_from_85_years_and_over_From_85_years_and_over
# 89 	 Population_Age_groups._Men_Population._By_age_groups._Men_Men_Total
# 8 	 Population_Age_groups._Women_Population._By_age_groups._Women_Women_from_0_to_14_years_From_0_to_14_years
# 51 	 Population_Age_groups._Women_Population._By_age_groups._Women_Women_from_15_to_64_years_From_15_to_64_years
# 19 	 Population_Age_groups._Women_Population._By_age_groups._Women_Women_from_65_to_84_years_From_65_to_84_years
# 4 	 Population_Age_groups._Women_Population._By_age_groups._Women_Women_from_85_years_and_over_From_85_years_and_over
# 82 	 Population_Age_groups._Women_Population._By_age_groups._Women_Women_Total
# 143 	 Population_Place_of_birth_Population._By_place_of_birth_Population_born_in_Catalonia_Catalonia
# 8 	 Population_Place_of_birth_Population._By_place_of_birth_Population_born_in_rest_of_Spain_Rest_of_Spain
# 20 	 Population_Place_of_birth_Population._By_place_of_birth_Population_born_abroad_Abroad
# 171 	 Population_Place_of_birth_Population._By_place_of_birth_Population_Total
# 151 	 Population_Nationality_Population._By_nationality_Population_with_Spanish_nationality_Spanish
# 20 	 Population_Nationality_Population._By_nationality_Population_with_foreign_nationality_Foreign
# 171 	 Population_Nationality_Population._By_nationality_Population_Total
# 79 	 Population_Nationality._Men_Population._By_nationality._Men_Men_with_Spanish_nationality_Spanish
# 10 	 Population_Nationality._Men_Population._By_nationality._Men_Men_with_foreign_nationality_Foreign
# 89 	 Population_Nationality._Men_Population._By_nationality._Men_Men_Total
# 72 	 Population_Nationality._Women_Population._By_nationality._Women_Women_with_Spanish_nationality_Spanish
# 10 	 Population_Nationality._Women_Population._By_nationality._Women_Women_with_foreign_nationality_Foreign
# 82 	 Population_Nationality._Women_Population._By_nationality._Women_Women_Total
# 25 	 Population_Population_resident_abroad_Population_resident_abroad_on_1_January._By_sex_Men_resident_abroad_Men
# 32 	 Population_Population_resident_abroad_Population_resident_abroad_on_1_January._By_sex_Women_resident_abroad_Women
# 57 	 Population_Population_resident_abroad_Population_resident_abroad_on_1_January._By_sex_Population_resident_abroad_Total
# 30 	 Population_Commuting_for_Study_Reasons_Statistics_on_Commuting_for_Non-University_Studies_Resident_Students_(School_Age)_Resident_Students
# 0.0 	 Population_Commuting_for_Study_Reasons_Statistics_on_Commuting_for_Non-University_Studies_Resident_Students_who_study_in_the_same_municipality_Resident_Students_who_study_in_the_same_municipality
# 0 	 Population_Births_Births._By_sex_Births._Boys_Boys
# 1 	 Population_Births_Births._By_sex_Births._Girls_Girls
# 1 	 Population_Births_Births._By_sex_Births_Total
# 0 	 Population_Deaths_Deaths._By_sex_Deaths._Men_Men
# 0 	 Population_Deaths_Deaths._By_sex_Deaths._Women_Women
# 0 	 Population_Deaths_Deaths._By_sex_Deaths_Total
# 0 	 Population_Marriages_Marriages_Marriages_Total
# -8 	 Population_Internal_migrations_Internal_migrations._Destination-origin_balances_Migrations_(balance)_with_Catalonia_Balance_with_Catalonia
# -1 	 Population_Internal_migrations_Internal_migrations._Destination-origin_balances_Migrations_(balance)_with_Spain_Balance_with_Spain
# -9 	 Population_Internal_migrations_Internal_migrations._Destination-origin_balances_Internal_migratory_net_balance_Internal_migratory_net_balance
# 0 	 Population_External_migrations_External_migrations_External_immigrations_Immigrations
# 0 	 Population_External_migrations_External_migrations_External_emigrations_Emigrations
# 0 	 Population_External_immigrations_External_immigrations._By_place_of_origin_Immigrations_from_the_rest_of_EU_Rest_of_EU
# 0 	 Population_External_immigrations_External_immigrations._By_place_of_origin_Immigrations_from_the_rest_of_the_world_Rest_of_the_world
# 0 	 Population_External_immigrations_External_immigrations._By_place_of_origin_External_immigrations_Total
# -7 	 Population_Intercensal_Population_Growth_2001-2011_Intercensal_Population_Growth_Intercensal_Population_Growth_Population_Growth
# -3.87 	 Population_Intercensal_Population_Growth_2001-2011_Intercensal_Population_Growth_Intercensal_Population_Growth_(annual_average)_Population_Growth_(annual_average)
# -7.97 	 Population_Intercensal_Population_Growth_2001-2011_Intercensal_Population_Growth_Intercensal_Natural_Increase_Ratio_(annual_average)_Natural_Increase_(annual_average)
# 4.11 	 Population_Intercensal_Population_Growth_2001-2011_Intercensal_Population_Growth_Intercensal_Net_Migration_Ratio_(annual_average)_Net_Migration_(annual_average)
# 169 	 Culture_·_Language_Knowledge_of_Catalan_Population_of_2_years_and_over._By_knowledge_of_Catalan_Population_that_understands_Catalan_Understand
# 164 	 Culture_·_Language_Knowledge_of_Catalan_Population_of_2_years_and_over._By_knowledge_of_Catalan_Population_that_can_speak_Catalan_Speak
# 161 	 Culture_·_Language_Knowledge_of_Catalan_Population_of_2_years_and_over._By_knowledge_of_Catalan_Population_that_can_read_Catalan_Read
# 107 	 Culture_·_Language_Knowledge_of_Catalan_Population_of_2_years_and_over._By_knowledge_of_Catalan_Population_that_can_write_Catalan_Write
# 0 	 Culture_·_Language_Knowledge_of_Catalan_Population_of_2_years_and_over._By_knowledge_of_Catalan_Population_that_doesn't_understand_Catalan_Do_not_understand
# 169 	 Culture_·_Language_Knowledge_of_Catalan_Population_of_2_years_and_over._By_knowledge_of_Catalan_Population_of_2_years_and_over_Total
# 0 	 Culture_·_Language_Libraries_Libraries_Public_libraries_Public
# 0 	 Culture_·_Language_Libraries_Libraries_Other_libraries_Others
# 0 	 Culture_·_Language_Libraries_Libraries_Libraries_Total
# 0 	 Culture_·_Language_Sports_facilities_Sports_facilities_Pavilions_Pavilions
# 0 	 Culture_·_Language_Sports_facilities_Sports_facilities_Multisport_courts_Multisport_courts
# 0 	 Culture_·_Language_Sports_facilities_Sports_facilities_Multisport_fields_Multisport_fields
# 0 	 Culture_·_Language_Sports_facilities_Sports_facilities_Sports_halls_Sports_halls
# 0 	 Culture_·_Language_Sports_facilities_Sports_facilities_Indoor_swimming_pools_Indoor_swimming_pools
# 0 	 Culture_·_Language_Sports_facilities_Sports_facilities_Athelitcs_tracks_Athelitcs_tracks
# 0 	 Culture_·_Language_Sports_facilities_Sports_facilities_Other_sports_facilities_Other_facilities
# 0 	 Culture_·_Language_Sports_facilities_Sports_facilities_Sports_facilities_Total
# 23.3 	 Education_Level_of_education_attained_Population_aged_15_and_over._By_level_of_education_attained_Primary_education_or_lower_Primary_education_or_lower
# 26.4 	 Education_Level_of_education_attained_Population_aged_15_and_over._By_level_of_education_attained_First_stage_of_secondary_education_First_stage_of_secondary_education
# 17.0 	 Education_Level_of_education_attained_Population_aged_15_and_over._By_level_of_education_attained_Second_stage_of_secondary_education_Second_stage_of_secondary_education
# 33.3 	 Education_Level_of_education_attained_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Higher_education
# 145 	 Elections_Elections_to_the_Parliament_of_Catalonia_Elections_to_the_Parliament_of_Catalonia_Electors_(_Parliament_of_Catalonia)_Electors
# 80.7 	 Elections_Elections_to_the_Parliament_of_Catalonia_Elections_to_the_Parliament_of_Catalonia_Turnout_(Parliament_Catalonia)_Turnout
# 144 	 Elections_Elections_to_the_Congress_of_Deputies_Elections_to_the_Congress_of_Deputies_Electors_(Congress)_Electors
# 50.7 	 Elections_Elections_to_the_Congress_of_Deputies_Elections_to_the_Congress_of_Deputies_Turnout_(Elec._Congress)_Turnout
# 42.0 	 Elections_Elections_to_the_European_Parliament_Elections_to_the_European_Parliament_Turnout_(Elec._European_Parliament)_Turnout
# 143 	 Elections_Elections_to_the_European_Parliament_Elections_to_the_European_Parliament_Electors_(Elec._European_Parliament)_Electors
# 38 	 Labour_Contributors_to_Social_Security_according_to_contributors's_residence_Contributors_to_Social_Security_according_to_the_residence_of_the_contributor_Men_Men
# 31 	 Labour_Contributors_to_Social_Security_according_to_contributors's_residence_Contributors_to_Social_Security_according_to_the_residence_of_the_contributor_Women_Women
# 69 	 Labour_Contributors_to_Social_Security_according_to_contributors's_residence_Contributors_to_Social_Security_according_to_the_residence_of_the_contributor_Contributors_to_Social_Security_according_to_the_residence_of_the_contributor_Total
# 75 	 Labour_Affiliations_to_Social_Security_according_to_contributor's_residence_Affiliations_to_Social_Security_according_to_the_residence_of_the_contributor_Afiliations_Social_Security_according_residence_Total
# 13 	 Labour_Affiliations_to_general_system_according_to_location_of_affilation._By_sectors_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Agriculture_affiliations_to_General_SS_Agriculture
# 0 	 Labour_Affiliations_to_general_system_according_to_location_of_affilation._By_sectors_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Industry_affiliations_to_General_SS_Industry
# 0 	 Labour_Affiliations_to_general_system_according_to_location_of_affilation._By_sectors_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Construction_affiliations_to_General_SS_Construction
# 13 	 Labour_Affiliations_to_general_system_according_to_location_of_affilation._By_sectors_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Services_affiliations_to_General_SS_Services
# 26 	 Labour_Affiliations_to_general_system_according_to_location_of_affilation._By_sectors_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Affiliations_to_General_SS_Total
# 24 	 Labour_Affiliations_to_self-employed_system_according_to_location_of_affilation._By_sectors_Affiliations_to_S._S._self-employed_system_according_to_the_location_of_the_affilation._By_sectors_Affiliations_contributors_to_Self-Employed_SS_Agriculture
# 5 	 Labour_Affiliations_to_self-employed_system_according_to_location_of_affilation._By_sectors_Affiliations_to_S._S._self-employed_system_according_to_the_location_of_the_affilation._By_sectors_Services_afiliaciones_to_Self-Employed_SS_Services
# 30 	 Labour_Affiliations_to_self-employed_system_according_to_location_of_affilation._By_sectors_Affiliations_to_S._S._self-employed_system_according_to_the_location_of_the_affilation._By_sectors_Affiliations_to_Self-Employed_SS_Total
# 26 	 Labour_Affiliations_to_gen._system_according_to_location_of_affilation._By_size_of_the_centre_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_size_of_centre_Affiliations_to_SS_centres_with_up_to_50_workers_Up_to_50_workers
# 0 	 Labour_Affiliations_to_gen._system_according_to_location_of_affilation._By_size_of_the_centre_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_size_of_centre_Affiliations_to_SS_centres_with_51_to_250_workers_From_51_to_250_workers
# 0 	 Labour_Affiliations_to_gen._system_according_to_location_of_affilation._By_size_of_the_centre_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_size_of_centre_Affiliations_to_SS_centres_with_251_or_more_workers_From_251_workers_and_over
# 26 	 Labour_Affiliations_to_gen._system_according_to_location_of_affilation._By_size_of_the_centre_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_size_of_centre_Affiliations_to_General_SS_Total
# 8 	 Labour_Contributory_accounts_of_Social_Security_Contributory_accounts_Contributory_accounts_Total
# 53 	 Labour_Contributory_Social_Security_pensions_Contributory_Social_Security_pensions._December_Contributory_Social_Security_pensions_Total
# 676.79 	 Labour_Contributory_Social_Security_pensions_Contributory_Social_Security_pensions._December_Average_contributory_pension_Average_pension
# 23 	 Labour_Contributory_Social_Security_Pensioners_Contributory_Social_Security_Pensioners._By_sex._December_Men_Men
# 22 	 Labour_Contributory_Social_Security_Pensioners_Contributory_Social_Security_Pensioners._By_sex._December_Women_Women
# 45 	 Labour_Contributory_Social_Security_Pensioners_Contributory_Social_Security_Pensioners._By_sex._December_Total_Total
# 0.6 	 Labour_Registered_unemployment_by_sectors_Registered_unemployment._By_sectors_Registered_unemployment._Agriculture_Agriculture
# 3.0 	 Labour_Registered_unemployment_by_sectors_Registered_unemployment._By_sectors_Registered_unemployment._Industry_Industry
# 0.0 	 Labour_Registered_unemployment_by_sectors_Registered_unemployment._By_sectors_Registered_unemployment._Construction_Construction
# 6.1 	 Labour_Registered_unemployment_by_sectors_Registered_unemployment._By_sectors_Registered_unemployment._Services_Services
# 0.0 	 Labour_Registered_unemployment_by_sectors_Registered_unemployment._By_sectors_Registered_unemployment_(without_previous_employment)_Without_previous_employment
# 9.7 	 Labour_Registered_unemployment_by_sectors_Registered_unemployment._By_sectors_Registered_unemployment_Total
# 5.7 	 Labour_Registered_unemployment_by_sex_Registered_unemployment._By_sex_Registered_unemployment._Men_Men
# 4.0 	 Labour_Registered_unemployment_by_sex_Registered_unemployment._By_sex_Registered_unemployment._Women_Women
# 9.7 	 Labour_Registered_unemployment_by_sex_Registered_unemployment._By_sex_Registered_unemployment_Total
# 62 	 Quality_of_life_Type_of_dwellings_Family_dwellings._By_type_Main_family_dwellings_Main
# 28 	 Quality_of_life_Type_of_dwellings_Family_dwellings._By_type_Secondary_family_dwellings_Secondary
# 90 	 Quality_of_life_Type_of_dwellings_Family_dwellings._By_type_Family_dwellings_Total
# 181 	 Main_aggregates_·_Public_sector_finance_Urban_property_tax_Urban_property_tax_(IBI)_IBI._Receipts_Number_of_receipts
# 20265.2 	 Main_aggregates_·_Public_sector_finance_Urban_property_tax_Urban_property_tax_(IBI)_IBI._Taxable_base_by_receipt_Taxable_base_by_receipt
# 121.6 	 Main_aggregates_·_Public_sector_finance_Urban_property_tax_Urban_property_tax_(IBI)_IBI._Integral_quota_by_receipt_Integral_quota_by_receipt
# 10332 	 Main_aggregates_·_Public_sector_finance_Personal_Income_Tax_Personal_Income_Tax_(IRPF)_IRPF._Taxable_base_by_declarer_Taxable_base_by_declarer
# 3477 	 Main_aggregates_·_Public_sector_finance_Personal_Income_Tax_Personal_Income_Tax_(IRPF)_IRPF._Resulting_quotafrom_self-payment_by_declarer_Resulting_quota_from_self-payment_by_declarer
# 412 	 Economic_sectors_Used_agricultural_area_Used_agricultural_area_(UAA)_Cultivated_land_surface_Cultivated_land
# 1048 	 Economic_sectors_Used_agricultural_area_Used_agricultural_area_(UAA)_Permanent_pasture_surface_Permanent_pasture
# 1460 	 Economic_sectors_Used_agricultural_area_Used_agricultural_area_(UAA)_Used_agricultural_area_Total
# 226 	 Economic_sectors_Cultivated_land_Cultivated_land._By_type_of_crop_Herbaceous_crops_Herbaceous_crops
# 169 	 Economic_sectors_Cultivated_land_Cultivated_land._By_type_of_crop_Fruit_trees_crops_Fruit_trees
# 6 	 Economic_sectors_Cultivated_land_Cultivated_land._By_type_of_crop_Olives_crops_Olives
# 1 	 Economic_sectors_Cultivated_land_Cultivated_land._By_type_of_crop_Vines_crops_Vines
# 11 	 Economic_sectors_Cultivated_land_Cultivated_land._By_type_of_crop_Other_crops_Others
# 412 	 Economic_sectors_Cultivated_land_Cultivated_land._By_type_of_crop_Cultivated_land_Total
# 3 	 Economic_sectors_Land_ownership_Farms._By_land_ownership_Farms_without_land_Without_land
# 27 	 Economic_sectors_Land_ownership_Farms._By_land_ownership_Farms_with_land_With_land
# 30 	 Economic_sectors_Land_ownership_Farms._By_land_ownership_Farms_with_and_without_land_Total
# 11 	 Economic_sectors_Livestock_ownership_Farms._By_livestock_ownership_Farms_without_livestock_Without_livestock
# 19 	 Economic_sectors_Livestock_ownership_Farms._By_livestock_ownership_Farms_with_livestock_With_livestock
# 30 	 Economic_sectors_Livestock_ownership_Farms._By_livestock_ownership_Farms_with_and_without_livestock_Total
# 195 	 Economic_sectors_Head_of_livestock_Head_of_livestock._By_species_Bovine_head_Bovine
# 2030 	 Economic_sectors_Head_of_livestock_Head_of_livestock._By_species_Ovine_head_Ovine
# 176 	 Economic_sectors_Head_of_livestock_Head_of_livestock._By_species_Caprine_head_Caprine
# 7289 	 Economic_sectors_Head_of_livestock_Head_of_livestock._By_species_Porcine_head_Porcine
# 75010 	 Economic_sectors_Head_of_livestock_Head_of_livestock._By_species_Avian_head_Avian
# 150 	 Economic_sectors_Head_of_livestock_Head_of_livestock._By_species_Female_rabbits_head_Female_rabbits
# 9 	 Economic_sectors_Head_of_livestock_Head_of_livestock._By_species_Equine_head_Equine
# 0 	 Economic_sectors_Housing_construction_Housing_construction_State_subsidised_housing_starts_State_subsidised_housing_starts
# 0 	 Economic_sectors_Housing_construction_Housing_construction_Housing_starts_Housing_starts
# 0 	 Economic_sectors_Tourist_accommodation_Tourist_accommodation_Hotels_Hotels
# 0 	 Economic_sectors_Tourist_accommodation_Tourist_accommodation_Hotel_beds_Hotel_beds
# 0 	 Economic_sectors_Tourist_accommodation_Tourist_accommodation_Campsites_Campsites
# 0 	 Economic_sectors_Tourist_accommodation_Tourist_accommodation_Campsite_places_Campsite_places
# 2 	 Economic_sectors_Tourist_accommodation_Tourist_accommodation_Rural_tourism_Rural_tourism
# 9 	 Economic_sectors_Tourist_accommodation_Tourist_accommodation_Rural_tourism_beds_Rural_tourism_beds
# 175 	 Economic_sectors_Fleet_of_vehicles_Fleet_of_vehicles_Cars_Estate_cars
# 13 	 Economic_sectors_Fleet_of_vehicles_Fleet_of_vehicles_Motorcycles_Motorcycles
# 189 	 Economic_sectors_Fleet_of_vehicles_Fleet_of_vehicles_Industrial_vehicles_Industrial_vehicles
# 135 	 Economic_sectors_Fleet_of_vehicles_Fleet_of_vehicles_Other__vehicles_Others
# 512 	 Economic_sectors_Fleet_of_vehicles_Fleet_of_vehicles_Fleet_of_vehicles_Total
# 1.24 	 Environment_Municipal_waste_Municipal_waste_Municipal_waste_per_capita_Generation_per_capita
# 40.7 	 Environment_Municipal_waste_Municipal_waste_Selective_collection_of_municipal_waste_Selective_collection
# 0 	 Environment_Industrial_waste_Industrial_waste_Establishments_with_yearly_ind._waste_declarations_Establishments_with_yearly_waste_declarations
# 0.00 	 Environment_Industrial_waste_Industrial_waste_Industrial_waste_Industrial_waste

# %%
pd1 = pd.DataFrame(containers['080018'])
pd2 = pd.DataFrame(containers['250019'], index=[0])

# %%
pd3 = pd.concat([pd1,pd2])

# %%
for col in pd3.columns:
    print(pd3[col])
# Out:
# 0    19.94
# 1    19.94
# 0    78.27
# Name: Territory_Geographic_indicators_Surface_area, dtype: object
# 0    105
# 1    105
# 0    956
# Name: Territory_Geographic_indicators_Altitude, dtype: object
# 0    1.903100
# 1    1.903100
# 0    1.092892
# Name: Territory_Geographic_indicators_Longitude, dtype: object
# 0    41.518531
# 1    41.518531
# 0    42.162392
# Name: Territory_Geographic_indicators_Latitude, dtype: object
# 0    408471
# 1    408471
# 0    342450
# Name: Territory_Geographic_indicators_UTM_coordinates_x, dtype: object
# 0    4596983
# 1    4596983
# 0    4669650
# Name: Territory_Geographic_indicators_UTM_coordinates_y, dtype: object
# 0    19.94
# 1    19.94
# 0    78.27
# Name: Population_Geographic_indicators_UTM_coordinates_y_Density_of_population_Surface_area, dtype: object
# 0    632.9
# 1    632.9
# 0      2.2
# Name: Population_Geographic_indicators_UTM_coordinates_y_Density_of_population_Density, dtype: object
# 0    6373
# 1    6373
# 0      89
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_sex_Men, dtype: object
# 0    6247
# 1    6247
# 0      82
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_sex_Women, dtype: object
# 0    12620
# 1    12620
# 0      171
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_sex_Total, dtype: object
# 0    2138
# 1    2138
# 0      16
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups_From_0_to_14_years, dtype: object
# 0    8503
# 1    8503
# 0     110
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups_From_15_to_64_years, dtype: object
# 0    1749
# 1    1749
# 0      33
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups_From_65_to_84_years, dtype: object
# 0    230
# 1    230
# 0     12
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups_From_85_years_and_over, dtype: object
# 0    12620
# 1    12620
# 0      171
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups_Total, dtype: object
# 0    1100
# 1    1100
# 0       8
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Men_From_0_to_14_years, dtype: object
# 0    4366
# 1    4366
# 0      59
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Men_From_15_to_64_years, dtype: object
# 0    809
# 1    809
# 0     14
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Men_From_65_to_84_years, dtype: object
# 0    98
# 1    98
# 0     8
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Men_From_85_years_and_over, dtype: object
# 0    6373
# 1    6373
# 0      89
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Men_Total, dtype: object
# 0    1038
# 1    1038
# 0       8
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Women_From_0_to_14_years, dtype: object
# 0    4137
# 1    4137
# 0      51
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Women_From_15_to_64_years, dtype: object
# 0    940
# 1    940
# 0     19
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Women_From_65_to_84_years, dtype: object
# 0    132
# 1    132
# 0      4
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Women_From_85_years_and_over, dtype: object
# 0    6247
# 1    6247
# 0      82
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_age_groups._Women_Total, dtype: object
# 0    8717
# 1    8717
# 0     143
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_place_of_birth_Catalonia, dtype: object
# 0    2575
# 1    2575
# 0       8
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_place_of_birth_Rest_of_Spain, dtype: object
# 0    1328
# 1    1328
# 0      20
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_place_of_birth_Abroad, dtype: object
# 0    12620
# 1    12620
# 0      171
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_place_of_birth_Total, dtype: object
# 0    11778
# 1    11778
# 0      151
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality_Spanish, dtype: object
# 0    842
# 1    842
# 0     20
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality_Foreign, dtype: object
# 0    12620
# 1    12620
# 0      171
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality_Total, dtype: object
# 0    5968
# 1    5968
# 0      79
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality._Men_Spanish, dtype: object
# 0    405
# 1    405
# 0     10
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality._Men_Foreign, dtype: object
# 0    6373
# 1    6373
# 0      89
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality._Men_Total, dtype: object
# 0    5810
# 1    5810
# 0      72
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality._Women_Spanish, dtype: object
# 0    437
# 1    437
# 0     10
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality._Women_Foreign, dtype: object
# 0    6247
# 1    6247
# 0      82
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population._By_nationality._Women_Total, dtype: object
# 0    124
# 1    124
# 0     25
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population_resident_abroad_on_1_January._By_sex_Men, dtype: object
# 0    129
# 1    129
# 0     32
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population_resident_abroad_on_1_January._By_sex_Women, dtype: object
# 0    253
# 1    253
# 0     57
# Name: Population_Geographic_indicators_UTM_coordinates_y_Population_resident_abroad_on_1_January._By_sex_Total, dtype: object
# 0    12538
# 1    12538
# 0      NaN
# Name: Population_Geographic_indicators_UTM_coordinates_y_AFTE_population_(annual_full_time_equivalents)_Resident_population, dtype: object
# 0    388
# 1    388
# 0    NaN
# Name: Population_Geographic_indicators_UTM_coordinates_y_AFTE_population_(annual_full_time_equivalents)_AFTE_seasonal_population, dtype: object
# 0    12926
# 1    12926
# 0      NaN
# Name: Population_Geographic_indicators_UTM_coordinates_y_AFTE_population_(annual_full_time_equivalents)_Total, dtype: object
# 0    103.1
# 1    103.1
# 0      NaN
# Name: Population_Geographic_indicators_UTM_coordinates_y_AFTE_population_(annual_full_time_equivalents)_AFTE_population_/_resident_population, dtype: object
# 0    2475
# 1    2475
# 0      30
# Name: Population_Geographic_indicators_UTM_coordinates_y_Statistics_on_Commuting_for_Non-University_Studies_Resident_Students, dtype: object
# 0    71.5
# 1    71.5
# 0     0.0
# Name: Population_Geographic_indicators_UTM_coordinates_y_Statistics_on_Commuting_for_Non-University_Studies_Resident_Students_who_study_in_the_same_municipality, dtype: object
# 0    41
# 1    41
# 0     0
# Name: Population_Geographic_indicators_UTM_coordinates_y_Births._By_sex_Boys, dtype: object
# 0    49
# 1    49
# 0     1
# Name: Population_Geographic_indicators_UTM_coordinates_y_Births._By_sex_Girls, dtype: object
# 0    90
# 1    90
# 0     1
# Name: Population_Geographic_indicators_UTM_coordinates_y_Births._By_sex_Total, dtype: object
# 0    49
# 1    49
# 0     0
# Name: Population_Geographic_indicators_UTM_coordinates_y_Deaths._By_sex_Men, dtype: object
# 0    48
# 1    48
# 0     0
# Name: Population_Geographic_indicators_UTM_coordinates_y_Deaths._By_sex_Women, dtype: object
# 0    97
# 1    97
# 0     0
# Name: Population_Geographic_indicators_UTM_coordinates_y_Deaths._By_sex_Total, dtype: object
# 0    35
# 1    35
# 0     0
# Name: Population_Geographic_indicators_Total_Marriages_Total, dtype: object
# 0    861
# 1    861
# 0    NaN
# Name: Population_Geographic_indicators_Total_Households._By_size_One_person, dtype: object
# 0    1258
# 1    1258
# 0     NaN
# Name: Population_Geographic_indicators_Total_Households._By_size_Two_people, dtype: object
# 0    1233
# 1    1233
# 0     NaN
# Name: Population_Geographic_indicators_Total_Households._By_size_Three_people, dtype: object
# 0    1098
# 1    1098
# 0     NaN
# Name: Population_Geographic_indicators_Total_Households._By_size_Four_people_and_over, dtype: object
# 0    4450
# 1    4450
# 0     NaN
# Name: Population_Geographic_indicators_Total_Households._By_size_Total, dtype: object
# 0    861
# 1    861
# 0    NaN
# Name: Population_Geographic_indicators_Total_Households._By_type_of_nucleus_One_person, dtype: object
# 0    1069
# 1    1069
# 0     NaN
# Name: Population_Geographic_indicators_Total_Households._By_type_of_nucleus_Couple_without_children, dtype: object
# 0    2030
# 1    2030
# 0     NaN
# Name: Population_Geographic_indicators_Total_Households._By_type_of_nucleus_Couple_with_children, dtype: object
# 0    349
# 1    349
# 0    NaN
# Name: Population_Geographic_indicators_Total_Households._By_type_of_nucleus_Father_or_mother_with_children, dtype: object
# 0    4450
# 1    4450
# 0     NaN
# Name: Population_Geographic_indicators_Total_Households._By_type_of_nucleus_Total, dtype: object
# 0    102
# 1    102
# 0     -8
# Name: Population_Geographic_indicators_Total_Internal_migrations._Destination-origin_balances_Balance_with_Catalonia, dtype: object
# 0    -41
# 1    -41
# 0     -1
# Name: Population_Geographic_indicators_Total_Internal_migrations._Destination-origin_balances_Balance_with_Spain, dtype: object
# 0    61
# 1    61
# 0    -9
# Name: Population_Geographic_indicators_Total_Internal_migrations._Destination-origin_balances_Internal_migratory_net_balance, dtype: object
# 0    62
# 1    62
# 0     0
# Name: Population_Geographic_indicators_Total_External_migrations_Immigrations, dtype: object
# 0    52
# 1    52
# 0     0
# Name: Population_Geographic_indicators_Total_External_migrations_Emigrations, dtype: object
# 0    7
# 1    7
# 0    0
# Name: Population_Geographic_indicators_Total_External_immigrations._By_place_of_origin_Rest_of_EU, dtype: object
# 0    55
# 1    55
# 0     0
# Name: Population_Geographic_indicators_Total_External_immigrations._By_place_of_origin_Rest_of_the_world, dtype: object
# 0    62
# 1    62
# 0     0
# Name: Population_Geographic_indicators_Total_External_immigrations._By_place_of_origin_Total, dtype: object
# 0    3191
# 1    3191
# 0      -7
# Name: Population_Geographic_indicators_Total_2001-2011_Intercensal_Population_Growth_Population_Growth, dtype: object
# 0    31.23
# 1    31.23
# 0    -3.87
# Name: Population_Geographic_indicators_Total_2001-2011_Intercensal_Population_Growth_Population_Growth_(annual_average), dtype: object
# 0     9.33
# 1     9.33
# 0    -7.97
# Name: Population_Geographic_indicators_Total_2001-2011_Intercensal_Population_Growth_Natural_Increase_(annual_average), dtype: object
# 0    21.9
# 1    21.9
# 0    4.11
# Name: Population_Geographic_indicators_Total_2001-2011_Intercensal_Population_Growth_Net_Migration_(annual_average), dtype: object
# 0    10796
# 1    10796
# 0      169
# Name: Culture_·_Language_Geographic_indicators_Total_Population_of_2_years_and_over._By_knowledge_of_Catalan_Understand, dtype: object
# 0    7703
# 1    7703
# 0     164
# Name: Culture_·_Language_Geographic_indicators_Total_Population_of_2_years_and_over._By_knowledge_of_Catalan_Speak, dtype: object
# 0    8748
# 1    8748
# 0     161
# Name: Culture_·_Language_Geographic_indicators_Total_Population_of_2_years_and_over._By_knowledge_of_Catalan_Read, dtype: object
# 0    6099
# 1    6099
# 0     107
# Name: Culture_·_Language_Geographic_indicators_Total_Population_of_2_years_and_over._By_knowledge_of_Catalan_Write, dtype: object
# 0    556
# 1    556
# 0      0
# Name: Culture_·_Language_Geographic_indicators_Total_Population_of_2_years_and_over._By_knowledge_of_Catalan_Do_not_understand, dtype: object
# 0    11351
# 1    11351
# 0      169
# Name: Culture_·_Language_Geographic_indicators_Total_Population_of_2_years_and_over._By_knowledge_of_Catalan_Total, dtype: object
# 0    1
# 1    1
# 0    0
# Name: Culture_·_Language_Geographic_indicators_Total_Libraries_Public, dtype: object
# 0    0
# 1    0
# 0    0
# Name: Culture_·_Language_Geographic_indicators_Total_Libraries_Others, dtype: object
# 0    1
# 1    1
# 0    0
# Name: Culture_·_Language_Geographic_indicators_Total_Libraries_Total, dtype: object
# 0    2
# 1    2
# 0    0
# Name: Culture_·_Language_Geographic_indicators_Total_Sports_facilities_Pavilions, dtype: object
# 0    9
# 1    9
# 0    0
# Name: Culture_·_Language_Geographic_indicators_Total_Sports_facilities_Multisport_courts, dtype: object
# 0    2
# 1    2
# 0    0
# Name: Culture_·_Language_Geographic_indicators_Total_Sports_facilities_Multisport_fields, dtype: object
# 0    12
# 1    12
# 0     0
# Name: Culture_·_Language_Geographic_indicators_Total_Sports_facilities_Sports_halls, dtype: object
# 0    2
# 1    2
# 0    0
# Name: Culture_·_Language_Geographic_indicators_Total_Sports_facilities_Indoor_swimming_pools, dtype: object
# 0    0
# 1    0
# 0    0
# Name: Culture_·_Language_Geographic_indicators_Total_Sports_facilities_Athelitcs_tracks, dtype: object
# 0    42
# 1    42
# 0     0
# Name: Culture_·_Language_Geographic_indicators_Total_Sports_facilities_Other_facilities, dtype: object
# 0    69
# 1    69
# 0     0
# Name: Culture_·_Language_Geographic_indicators_Total_Sports_facilities_Total, dtype: object
# 0    16.9
# 1    16.9
# 0    23.3
# Name: Education_Population_aged_15_and_over._By_level_of_education_attained_Primary_education_or_lower_Sports_facilities_Total, dtype: object
# 0    30.5
# 1    30.5
# 0    26.4
# Name: Education_Population_aged_15_and_over._By_level_of_education_attained_First_stage_of_secondary_education_Sports_facilities_Total, dtype: object
# 0    25.8
# 1    25.8
# 0    17.0
# Name: Education_Population_aged_15_and_over._By_level_of_education_attained_Second_stage_of_secondary_education_Sports_facilities_Total, dtype: object
# 0    26.9
# 1    26.9
# 0    33.3
# Name: Education_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Sports_facilities_Total, dtype: object
# 0    8851
# 1    8851
# 0     NaN
# Name: Elections_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Municipal_elections_Electors, dtype: object
# 0    59.0
# 1    59.0
# 0     NaN
# Name: Elections_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Municipal_elections_Turnout, dtype: object
# 0    8965
# 1    8965
# 0     145
# Name: Elections_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Elections_to_the_Parliament_of_Catalonia_Electors, dtype: object
# 0    85.3
# 1    85.3
# 0    80.7
# Name: Elections_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Elections_to_the_Parliament_of_Catalonia_Turnout, dtype: object
# 0    8907
# 1    8907
# 0     144
# Name: Elections_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Elections_to_the_Congress_of_Deputies_Electors, dtype: object
# 0    70.9
# 1    70.9
# 0    50.7
# Name: Elections_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Elections_to_the_Congress_of_Deputies_Turnout, dtype: object
# 0    47.3
# 1    47.3
# 0    42.0
# Name: Elections_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Elections_to_the_European_Parliament_Turnout, dtype: object
# 0    8806
# 1    8806
# 0     143
# Name: Elections_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Elections_to_the_European_Parliament_Electors, dtype: object
# 0    5192
# 1    5192
# 0     NaN
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Population._By_relation_with_economic_activity_Employed_population, dtype: object
# 0    1531
# 1    1531
# 0     NaN
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Population._By_relation_with_economic_activity_Unemployed_population, dtype: object
# 0    6723
# 1    6723
# 0     NaN
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Population._By_relation_with_economic_activity_Active_population, dtype: object
# 0    5078
# 1    5078
# 0     NaN
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Population._By_relation_with_economic_activity_Inactive_population, dtype: object
# 0    9465
# 1    9465
# 0     NaN
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Population._By_relation_with_economic_activity_Population_of_16_years_and_over, dtype: object
# 0    3144
# 1    3144
# 0      38
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Contributors_to_Social_Security_according_to_the_residence_of_the_contributor_Men, dtype: object
# 0    2617
# 1    2617
# 0      31
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Contributors_to_Social_Security_according_to_the_residence_of_the_contributor_Women, dtype: object
# 0    5761
# 1    5761
# 0      69
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Higher_education_Contributors_to_Social_Security_according_to_the_residence_of_the_contributor_Total, dtype: object
# 0    5947
# 1    5947
# 0      75
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_Social_Security_according_to_the_residence_of_the_contributor_Total, dtype: object
# 0    2699
# 1    2699
# 0       0
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Industry, dtype: object
# 0    3452
# 1    3452
# 0      13
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Services, dtype: object
# 0    6508
# 1    6508
# 0      26
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Total, dtype: object
# 0     6
# 1     6
# 0    24
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._self-employed_system_according_to_the_location_of_the_affilation._By_sectors_Agriculture, dtype: object
# 0     33
# 1     33
# 0    NaN
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._self-employed_system_according_to_the_location_of_the_affilation._By_sectors_Industry, dtype: object
# 0    103
# 1    103
# 0    NaN
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._self-employed_system_according_to_the_location_of_the_affilation._By_sectors_Construction, dtype: object
# 0    486
# 1    486
# 0      5
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._self-employed_system_according_to_the_location_of_the_affilation._By_sectors_Services, dtype: object
# 0    628
# 1    628
# 0     30
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._self-employed_system_according_to_the_location_of_the_affilation._By_sectors_Total, dtype: object
# 0    3006
# 1    3006
# 0      26
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_size_of_centre_Up_to_50_workers, dtype: object
# 0    2610
# 1    2610
# 0       0
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_size_of_centre_From_51_to_250_workers, dtype: object
# 0    892
# 1    892
# 0      0
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_size_of_centre_From_251_workers_and_over, dtype: object
# 0    6508
# 1    6508
# 0      26
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_size_of_centre_Total, dtype: object
# 0    397
# 1    397
# 0      8
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Contributory_accounts_Total, dtype: object
# 0    2406
# 1    2406
# 0      53
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Contributory_Social_Security_pensions._December_Total, dtype: object
# 0    1153.73
# 1    1153.73
# 0     676.79
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Contributory_Social_Security_pensions._December_Average_pension, dtype: object
# 0    1178
# 1    1178
# 0      23
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Contributory_Social_Security_Pensioners._By_sex._December_Men, dtype: object
# 0    997
# 1    997
# 0     22
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Contributory_Social_Security_Pensioners._By_sex._December_Women, dtype: object
# 0    2175
# 1    2175
# 0      45
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Contributory_Social_Security_Pensioners._By_sex._December_Total, dtype: object
# 0    7.2
# 1    7.2
# 0    0.6
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sectors_Agriculture, dtype: object
# 0    80.2
# 1    80.2
# 0     3.0
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sectors_Industry, dtype: object
# 0    36.4
# 1    36.4
# 0     0.0
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sectors_Construction, dtype: object
# 0    488.4
# 1    488.4
# 0      6.1
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sectors_Services, dtype: object
# 0    23.6
# 1    23.6
# 0     0.0
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sectors_Without_previous_employment, dtype: object
# 0    635.9
# 1    635.9
# 0      9.7
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sectors_Total, dtype: object
# 0    262.7
# 1    262.7
# 0      5.7
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sex_Men, dtype: object
# 0    373.2
# 1    373.2
# 0      4.0
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sex_Women, dtype: object
# 0    635.9
# 1    635.9
# 0      9.7
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Registered_unemployment._By_sex_Total, dtype: object
# 0    4450
# 1    4450
# 0     NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Family_dwellings._By_type_Main, dtype: object
# 0    503
# 1    503
# 0    NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Family_dwellings._By_type_Secondary, dtype: object
# 0    269
# 1    269
# 0    NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Family_dwellings._By_type_Vacant, dtype: object
# 0    5222
# 1    5222
# 0     NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Family_dwellings._By_type_Total, dtype: object
# 0    335
# 1    335
# 0    NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Main_family_dwellings._By_type_of_tenancy_Rented, dtype: object
# 0    4450
# 1    4450
# 0     NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Main_family_dwellings._By_type_of_tenancy_Total, dtype: object
# 0    1975
# 1    1975
# 0     NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Main_family_dwellings._By_useful_surface_area_From_61_to_90_m², dtype: object
# 0    1324
# 1    1324
# 0     NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Main_family_dwellings._By_useful_surface_area_From_91_to_120_m², dtype: object
# 0    939
# 1    939
# 0    NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Main_family_dwellings._By_useful_surface_area_From_121_m²_and_over, dtype: object
# 0    4450
# 1    4450
# 0     NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Total_Main_family_dwellings._By_useful_surface_area_Total, dtype: object
# 0    104.1
# 1    104.1
# 0      NaN
# Name: Quality_of_life_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Small_area_socioeconomic_index_(STI)._Index_Catalonia=100_Total, dtype: object
# 0    649.2
# 1    649.2
# 0      NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_domestic_product_(2019_Benchmark_revision)_GDP, dtype: object
# 0     52.3
# 1    160.5
# 0      NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_domestic_product_(2019_Benchmark_revision)_GDP_per_capita, dtype: object
# 0    0.5
# 1    0.5
# 0    NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_value_added_(2019_Benchmark_revision)._By_sectors_Agriculture, dtype: object
# 0    223.7
# 1    223.7
# 0      NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_value_added_(2019_Benchmark_revision)._By_sectors_Industry, dtype: object
# 0    17.8
# 1    17.8
# 0     NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_value_added_(2019_Benchmark_revision)._By_sectors_Construction, dtype: object
# 0    353.8
# 1    353.8
# 0      NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_value_added_(2019_Benchmark_revision)._By_sectors_Services, dtype: object
# 0    595.8
# 1    595.8
# 0      NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_value_added_(2019_Benchmark_revision)._By_sectors_Total, dtype: object
# 0    217630
# 1    217630
# 0       NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_disposable_household_income._2019_Benchmark_revision_GDHI, dtype: object
# 0     17.7
# 1    100.3
# 0      NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Gross_disposable_household_income._2019_Benchmark_revision_GDHI_per_capita, dtype: object
# 0    7311
# 1    7311
# 0     NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Urban_property_tax_(IBI)_Number_of_receipts, dtype: object
# 0    77450.8
# 1    77450.8
# 0        NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Urban_property_tax_(IBI)_Taxable_base_by_receipt, dtype: object
# 0    625.5
# 1    625.5
# 0      NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Urban_property_tax_(IBI)_Integral_quota_by_receipt, dtype: object
# 0    24636
# 1    24636
# 0      NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Personal_Income_Tax_(IRPF)_Taxable_base_by_declarer, dtype: object
# 0    5680
# 1    5680
# 0     NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Personal_Income_Tax_(IRPF)_Resulting_quota_from_self-payment_by_declarer, dtype: object
# 0    368165
# 1    368165
# 0       NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Wealth_tax_(IPPF)_Total_weath_by_declarer, dtype: object
# 0    37.5
# 1    37.5
# 0     NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Wealth_tax_(IPPF)_Real_assets, dtype: object
# 0    62.5
# 1    62.5
# 0     NaN
# Name: Main_aggregates_·_Public_sector_finance_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Wealth_tax_(IPPF)_Financial_assets, dtype: object
# 0    211
# 1    211
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Used_agricultural_area_(UAA)_Cultivated_land, dtype: object
# 0    310
# 1    310
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Used_agricultural_area_(UAA)_Permanent_pasture, dtype: object
# 0    521
# 1    521
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Used_agricultural_area_(UAA)_Total, dtype: object
# 0    145
# 1    145
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Cultivated_land._By_type_of_crop_Herbaceous_crops, dtype: object
# 0     19
# 1     19
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Cultivated_land._By_type_of_crop_Fruit_trees, dtype: object
# 0     16
# 1     16
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Cultivated_land._By_type_of_crop_Olives, dtype: object
# 0     31
# 1     31
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Cultivated_land._By_type_of_crop_Vines, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Cultivated_land._By_type_of_crop_Others, dtype: object
# 0    211
# 1    211
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Cultivated_land._By_type_of_crop_Total, dtype: object
# 0      1
# 1      1
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Farms._By_land_ownership_Without_land, dtype: object
# 0     13
# 1     13
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Farms._By_land_ownership_With_land, dtype: object
# 0     14
# 1     14
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Farms._By_land_ownership_Total, dtype: object
# 0     10
# 1     10
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Farms._By_livestock_ownership_Without_livestock, dtype: object
# 0      4
# 1      4
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Farms._By_livestock_ownership_With_livestock, dtype: object
# 0     14
# 1     14
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Farms._By_livestock_ownership_Total, dtype: object
# 0    593
# 1    593
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Head_of_livestock._By_species_Bovine, dtype: object
# 0    656
# 1    656
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Head_of_livestock._By_species_Ovine, dtype: object
# 0     84
# 1     84
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Head_of_livestock._By_species_Caprine, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Head_of_livestock._By_species_Porcine, dtype: object
# 0     33
# 1     33
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Head_of_livestock._By_species_Avian, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Head_of_livestock._By_species_Female_rabbits, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Head_of_livestock._By_species_Equine, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Housing_construction_State_subsidised_housing_starts, dtype: object
# 0     94
# 1     94
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Housing_construction_Housing_starts, dtype: object
# 0      1
# 1      1
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Tourist_accommodation_Hotels, dtype: object
# 0     39
# 1     39
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Tourist_accommodation_Hotel_beds, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Tourist_accommodation_Campsites, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Tourist_accommodation_Campsite_places, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Tourist_accommodation_Rural_tourism, dtype: object
# 0      0
# 1      0
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Tourist_accommodation_Rural_tourism_beds, dtype: object
# 0    7153
# 1    7153
# 0     NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Fleet_of_vehicles_Estate_cars, dtype: object
# 0    1302
# 1    1302
# 0     NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Fleet_of_vehicles_Motorcycles, dtype: object
# 0    1280
# 1    1280
# 0     NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Fleet_of_vehicles_Industrial_vehicles, dtype: object
# 0    872
# 1    872
# 0    NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Fleet_of_vehicles_Others, dtype: object
# 0    10607
# 1    10607
# 0      NaN
# Name: Economic_sectors_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Fleet_of_vehicles_Total, dtype: object
# 0    1.41
# 1    1.41
# 0     NaN
# Name: Environment_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Municipal_waste_Generation_per_capita, dtype: object
# 0    26.6
# 1    26.6
# 0     NaN
# Name: Environment_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Municipal_waste_Selective_collection, dtype: object
# 0     59
# 1     59
# 0    NaN
# Name: Environment_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Industrial_waste_Establishments_with_yearly_waste_declarations, dtype: object
# 0    63678.95
# 1    63678.95
# 0         NaN
# Name: Environment_Population_aged_15_and_over._By_level_of_education_attained_Small_area_socioeconòmic_index_Industrial_waste_Industrial_waste, dtype: object
# 0    NaN
# 1    NaN
# 0     13
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Agriculture, dtype: object
# 0    NaN
# 1    NaN
# 0      0
# Name: Labour_Population_aged_15_and_over._By_level_of_education_attained_Total_Affiliations_to_S._S._general_system_according_to_the_location_of_the_affilation._By_sectors_Construction, dtype: object
# 0    NaN
# 1    NaN
# 0     62
# Name: Quality_of_life_Family_dwellings._By_type_Main_Registered_unemployment._By_sex_Total, dtype: object
# 0    NaN
# 1    NaN
# 0     28
# Name: Quality_of_life_Family_dwellings._By_type_Secondary_Registered_unemployment._By_sex_Total, dtype: object
# 0    NaN
# 1    NaN
# 0     90
# Name: Quality_of_life_Family_dwellings._By_type_Total_Registered_unemployment._By_sex_Total, dtype: object
# 0    NaN
# 1    NaN
# 0    181
# Name: Main_aggregates_·_Public_sector_finance_Family_dwellings._By_type_Total_Urban_property_tax_(IBI)_Number_of_receipts, dtype: object
# 0        NaN
# 1        NaN
# 0    20265.2
# Name: Main_aggregates_·_Public_sector_finance_Family_dwellings._By_type_Total_Urban_property_tax_(IBI)_Taxable_base_by_receipt, dtype: object
# 0      NaN
# 1      NaN
# 0    121.6
# Name: Main_aggregates_·_Public_sector_finance_Family_dwellings._By_type_Total_Urban_property_tax_(IBI)_Integral_quota_by_receipt, dtype: object
# 0      NaN
# 1      NaN
# 0    10332
# Name: Main_aggregates_·_Public_sector_finance_Family_dwellings._By_type_Total_Personal_Income_Tax_(IRPF)_Taxable_base_by_declarer, dtype: object
# 0     NaN
# 1     NaN
# 0    3477
# Name: Main_aggregates_·_Public_sector_finance_Family_dwellings._By_type_Total_Personal_Income_Tax_(IRPF)_Resulting_quota_from_self-payment_by_declarer, dtype: object
# 0    NaN
# 1    NaN
# 0    412
# Name: Economic_sectors_Family_dwellings._By_type_Total_Used_agricultural_area_(UAA)_Cultivated_land, dtype: object
# 0     NaN
# 1     NaN
# 0    1048
# Name: Economic_sectors_Family_dwellings._By_type_Total_Used_agricultural_area_(UAA)_Permanent_pasture, dtype: object
# 0     NaN
# 1     NaN
# 0    1460
# Name: Economic_sectors_Family_dwellings._By_type_Total_Used_agricultural_area_(UAA)_Total, dtype: object
# 0    NaN
# 1    NaN
# 0    226
# Name: Economic_sectors_Family_dwellings._By_type_Total_Cultivated_land._By_type_of_crop_Herbaceous_crops, dtype: object
# 0    NaN
# 1    NaN
# 0    169
# Name: Economic_sectors_Family_dwellings._By_type_Total_Cultivated_land._By_type_of_crop_Fruit_trees, dtype: object
# 0    NaN
# 1    NaN
# 0      6
# Name: Economic_sectors_Family_dwellings._By_type_Total_Cultivated_land._By_type_of_crop_Olives, dtype: object
# 0    NaN
# 1    NaN
# 0      1
# Name: Economic_sectors_Family_dwellings._By_type_Total_Cultivated_land._By_type_of_crop_Vines, dtype: object
# 0    NaN
# 1    NaN
# 0     11
# Name: Economic_sectors_Family_dwellings._By_type_Total_Cultivated_land._By_type_of_crop_Others, dtype: object
# 0    NaN
# 1    NaN
# 0    412
# Name: Economic_sectors_Family_dwellings._By_type_Total_Cultivated_land._By_type_of_crop_Total, dtype: object
# 0    NaN
# 1    NaN
# 0      3
# Name: Economic_sectors_Family_dwellings._By_type_Total_Farms._By_land_ownership_Without_land, dtype: object
# 0    NaN
# 1    NaN
# 0     27
# Name: Economic_sectors_Family_dwellings._By_type_Total_Farms._By_land_ownership_With_land, dtype: object
# 0    NaN
# 1    NaN
# 0     30
# Name: Economic_sectors_Family_dwellings._By_type_Total_Farms._By_land_ownership_Total, dtype: object
# 0    NaN
# 1    NaN
# 0     11
# Name: Economic_sectors_Family_dwellings._By_type_Total_Farms._By_livestock_ownership_Without_livestock, dtype: object
# 0    NaN
# 1    NaN
# 0     19
# Name: Economic_sectors_Family_dwellings._By_type_Total_Farms._By_livestock_ownership_With_livestock, dtype: object
# 0    NaN
# 1    NaN
# 0     30
# Name: Economic_sectors_Family_dwellings._By_type_Total_Farms._By_livestock_ownership_Total, dtype: object
# 0    NaN
# 1    NaN
# 0    195
# Name: Economic_sectors_Family_dwellings._By_type_Total_Head_of_livestock._By_species_Bovine, dtype: object
# 0     NaN
# 1     NaN
# 0    2030
# Name: Economic_sectors_Family_dwellings._By_type_Total_Head_of_livestock._By_species_Ovine, dtype: object
# 0    NaN
# 1    NaN
# 0    176
# Name: Economic_sectors_Family_dwellings._By_type_Total_Head_of_livestock._By_species_Caprine, dtype: object
# 0     NaN
# 1     NaN
# 0    7289
# Name: Economic_sectors_Family_dwellings._By_type_Total_Head_of_livestock._By_species_Porcine, dtype: object
# 0      NaN
# 1      NaN
# 0    75010
# Name: Economic_sectors_Family_dwellings._By_type_Total_Head_of_livestock._By_species_Avian, dtype: object
# 0    NaN
# 1    NaN
# 0    150
# Name: Economic_sectors_Family_dwellings._By_type_Total_Head_of_livestock._By_species_Female_rabbits, dtype: object
# 0    NaN
# 1    NaN
# 0      9
# Name: Economic_sectors_Family_dwellings._By_type_Total_Head_of_livestock._By_species_Equine, dtype: object
# 0    NaN
# 1    NaN
# 0      0
# Name: Economic_sectors_Family_dwellings._By_type_Total_Housing_construction_State_subsidised_housing_starts, dtype: object
# 0    NaN
# 1    NaN
# 0      0
# Name: Economic_sectors_Family_dwellings._By_type_Total_Housing_construction_Housing_starts, dtype: object
# 0    NaN
# 1    NaN
# 0      0
# Name: Economic_sectors_Family_dwellings._By_type_Total_Tourist_accommodation_Hotels, dtype: object
# 0    NaN
# 1    NaN
# 0      0
# Name: Economic_sectors_Family_dwellings._By_type_Total_Tourist_accommodation_Hotel_beds, dtype: object
# 0    NaN
# 1    NaN
# 0      0
# Name: Economic_sectors_Family_dwellings._By_type_Total_Tourist_accommodation_Campsites, dtype: object
# 0    NaN
# 1    NaN
# 0      0
# Name: Economic_sectors_Family_dwellings._By_type_Total_Tourist_accommodation_Campsite_places, dtype: object
# 0    NaN
# 1    NaN
# 0      2
# Name: Economic_sectors_Family_dwellings._By_type_Total_Tourist_accommodation_Rural_tourism, dtype: object
# 0    NaN
# 1    NaN
# 0      9
# Name: Economic_sectors_Family_dwellings._By_type_Total_Tourist_accommodation_Rural_tourism_beds, dtype: object
# 0    NaN
# 1    NaN
# 0    175
# Name: Economic_sectors_Family_dwellings._By_type_Total_Fleet_of_vehicles_Estate_cars, dtype: object
# 0    NaN
# 1    NaN
# 0     13
# Name: Economic_sectors_Family_dwellings._By_type_Total_Fleet_of_vehicles_Motorcycles, dtype: object
# 0    NaN
# 1    NaN
# 0    189
# Name: Economic_sectors_Family_dwellings._By_type_Total_Fleet_of_vehicles_Industrial_vehicles, dtype: object
# 0    NaN
# 1    NaN
# 0    135
# Name: Economic_sectors_Family_dwellings._By_type_Total_Fleet_of_vehicles_Others, dtype: object
# 0    NaN
# 1    NaN
# 0    512
# Name: Economic_sectors_Family_dwellings._By_type_Total_Fleet_of_vehicles_Total, dtype: object
# 0     NaN
# 1     NaN
# 0    1.24
# Name: Environment_Family_dwellings._By_type_Total_Municipal_waste_Generation_per_capita, dtype: object
# 0     NaN
# 1     NaN
# 0    40.7
# Name: Environment_Family_dwellings._By_type_Total_Municipal_waste_Selective_collection, dtype: object
# 0    NaN
# 1    NaN
# 0      0
# Name: Environment_Family_dwellings._By_type_Total_Industrial_waste_Establishments_with_yearly_waste_declarations, dtype: object
# 0     NaN
# 1     NaN
# 0    0.00
# Name: Environment_Family_dwellings._By_type_Total_Industrial_waste_Industrial_waste, dtype: object
